# %%
#import pymysql as db
try:
  import MySQLdb
except:
  import pymysql as MySQLdb
import sqlite3
from pandas import DataFrame
from pandas.io.sql import read_sql
import json
#from pandas.io.pytables import HDFStore, read_hdf
#import multiprocessing
#pool = multiprocessing.Pool(100)
#print pool.map(f, range(10))

#tablename = 'course_grades'
#tablename = 'videos'
#databasename = 'coursera_eventing_12-002-ml'
#databasename = 'coursera_eventing_pgm-003'
#databasename = 'coursera_pgm-003_anonymized_general'

datastage_login = json.load(open('datastage_login.json'))

# %%
import collections
import functools

class memoized(object):
   '''Decorator. Caches a function's return value each time it is called.
   If called later with the same arguments, the cached value is returned
   (not reevaluated).
   '''
   def __init__(self, func):
      self.func = func
      self.cache = {}
   def __call__(self, *args):
      if not isinstance(args, collections.Hashable):
         # uncacheable. a list, for instance.
         # better to not cache than blow up.
         return self.func(*args)
      if args in self.cache:
         return self.cache[args]
      else:
         value = self.func(*args)
         self.cache[args] = value
         return value
   def __repr__(self):
      '''Return the function's docstring.'''
      return self.func.__doc__
   def __get__(self, obj, objtype):
      '''Support instance methods.'''
      return functools.partial(self.__call__, obj)

# %%
databases = {}

#databasename = 'ml-004_clickstream_video.sqlite'
databasename = 'ml-004_clickstream_video.sqlite'
tablename = 'videos'

def listVideosReal(dbname):
  output_set = set()
  output = []
  for lecture_id in listDistinct('lecture_id'):
    if lecture_id not in output_set:
      output_set.add(lecture_id)
      output.append(lecture_id)
  return sorted(output)

@memoized
def listVideosJsonMemoized(dbname):
  jsonfile = dbname + '_videolist.pickle'
  if not os.path.exists(jsonfile):
    pickle.dump(listVideosReal(dbname), open(jsonfile, 'w'))
  return pickle.load(open(jsonfile))

def listVideos():
  return listVideosJsonMemoized(getDatabaseName())

def getTableName():
  return tablename

def getDatabaseName():
  return databasename

def getDatabasePath():
  return '/lfs/local/0/geza/' + databasename

def getDatabaseNameForLectureNum(lectureid):
  return getDatabaseName().replace('.sqlite', '_lecture-' + str(lectureid) + '.sqlite')

def getDatabasePathForLectureNum(lectureid):
  return getDatabasePath().replace('.sqlite', '_lecture-' + str(lectureid) + '.sqlite')

def getDatabaseNameForLectureNumAndUser(lectureid, userid):
  return getDatabaseName().replace('.sqlite', '_lecture-' + str(lectureid) + '_user-' + str(userid) + '.sqlite')

def getDatabasePathForLectureNumAndUser(lectureid, userid):
  return getDatabasePath().replace('.sqlite', '_lecture-' + str(lectureid) + '_user-' + str(userid) + '.sqlite')

def getColumns():
  return list(read_sql("select * from " + getTableName() + " limit 1", getDatabase()).columns.values)

def getDatabase(dbname=databasename):
  if dbname not in databases and 'sqlite' in dbname:
    databases[dbname] = sqlite3.connect('/lfs/local/0/geza/' + dbname)
  elif databasename not in databases:
    MySQLdb.connect(host='datastage.stanford.edu', user=datastage_login['user'], passwd=datastage_login['passwd'], db=dbname)
  return databases[dbname]

def getDatabaseForLectureNum(lectureid):
  if 'sqlite' not in databasename:
    raise Exception('can only use getDatabaseForLectureNum feature on sqlite databases')
  real_database_name = getDatabasePathForLectureNum(lectureid)
  if real_database_name not in databases:
    databases[real_database_name] = sqlite3.connect(real_database_name)
  return databases[real_database_name]

def getDatabaseForLectureNumAndUser(lectureid, userid):
  if 'sqlite' not in databasename:
    raise Exception('can only use getDatabaseForLectureNumAndUser feature on sqlite databases')
  real_database_name = getDatabasePathForLectureNumAndUser(lectureid, userid)
  if real_database_name not in databases:
    databases[real_database_name] = sqlite3.connect(real_database_name)
  return databases[real_database_name]

def listDistinctForDatabase(fieldname, database_instance, extraquery=''):
  data = read_sql("select distinct " + fieldname + " from " + getTableName() + " " + extraquery, database_instance)
  return [x[0] for x in data[[fieldname]].itertuples(index=False)]

def listDistinct(fieldname, extraquery=''):
  return listDistinctForDatabase(fieldname, getDatabase(), extraquery)

def listDistinctForLecture(fieldname, lectureid, extraquery=''):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return listDistinctForDatabase(fieldname, getDatabaseForLectureNum(lectureid), extraquery)

def listFieldsForDatabase(fieldnames, database_instance, extraquery=''):
  fieldnameString = ','.join(fieldnames)
  data = read_sql("select " + fieldnameString + " from " + getTableName() + " " + extraquery, database_instance)
  return data.itertuples(index=False)

def listFields(fieldnames, extraquery=''):
  return listFieldsForDatabase(fieldnames, getDatabase(), extraquery)

@memoized
def getDataFrame(dbname, tbname):
  return read_sql("select * from " + getTableName(), getDatabase(dbname))

def getDataFrame():
  return getDataFrameReal(getDatabase(), getTableName())

def cacheLecture(lectureid):
  if os.path.exists(getDatabasePathForLectureNum(lectureid)):
    return
  print 'caching lecture:', lectureid
  data = read_sql('select * from ' + getTableName() + ' where lecture_id=' + str(lectureid), getDatabase())
  write_frame(data, getTableName(), getDatabaseForLectureNum(lectureid))

def listFieldsForLecture(fieldnames, lectureid, extraquery=''):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return listFieldsForDatabase(fieldnames, getDatabaseForLectureNum(lectureid), extraquery)

@memoized
def getFrameForLectureReal(dbname, lectureid):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return read_sql('select * from ' + getTableName(), getDatabaseForLectureNum(lectureid))

def getFrameForLecture(lectureid):
  return getFrameForLectureReal(getDatabaseName(), lectureid)

@memoized
def getUserToEventsForLectureReal(dbname, lectureid):
  lecture_frame = getFrameForLectureReal(dbname, lectureid)
  return frameToDictByKey(lecture_frame, 'anon_username')

def getFrameForLectureUser(lectureid, userid):
  user_to_events = getUserToEventsForLectureReal(getDatabaseName(), lectureid)
  if userid in user_to_events:
    return user_to_events[userid]
  else:
    return None

def frameToDictByKey(frame, key):
  output = {}
  for k,grouped_frame in frame.groupby(key):
    output[k] = grouped_frame
  return output

#def cacheLectureUser(lectureid, userid):
#  #if os.path.exists(getDatabasePathForLectureNumAndUser(lectureid, userid)):
#  #  return
#  print 'caching lecture and user id:', lectureid, userid
#  #data = read_sql('select * from ' + getTableName() + ' where lecture_id=' + str(lectureid) + ' and anon_username="' + str(userid) + '"', getDatabaseForLectureNum(lectureid))
#  #frame = getFrameForLecture(lectureid)
#  #data = frame[frame.anon_username == userid]
#  data = getFrameForLectureAndUser(lectureid, userid)
#  #write_frame(data, getTableName(), getDatabaseForLectureNumAndUser(lectureid, userid))

# %%
# %matplotlib inline
import matplotlib.pyplot
import matplotlib.pylab as pylab
import numpy

def binsum(inp):
  output = []
  for i in range(len(inp)):
    curbin = inp[i-2:i+3]
    val = sum(curbin)
    output.append(val)
  return output

def barPlotWithStderr(means, stderrs=None, x_tick_labels=None, xlabel='', ylabel='', title='', addLabels=True):
    if stderrs:
        assert len(means) == len(stderrs)
    if x_tick_labels:
        assert len(means) == len(x_tick_labels)
        x_tick_labels = [str(x) for x in x_tick_labels]
    else:
        x_tick_labels = [str(x) for x in range(len(means))]
    N = len(means)
    ind = numpy.arange(N) # the x locations for the groups
    width = 0.35 # the width of the bars
    fig, ax = matplotlib.pyplot.subplots()
    if stderrs:
        rects1 = ax.bar(ind, means, width, color='r', yerr=stderrs)
    else:
        rects1 = ax.bar(ind, means, width, color='r')
    
    if ylabel and not title:
        title = ylabel
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticks(ind+width)
    ax.set_xticklabels( x_tick_labels )
    
    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            #ax.text('foobar', 1.05*height, '%d'%int(height), ha='center', va='bottom')
            ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height), ha='center', va='bottom')
    if addLabels:
      autolabel(rects1)

def plotBarDictionary(datadict, xlabel='', ylabel='', title='', x_tick_label_map=None):
    keys = datadict.keys()
    keys.sort()
    means = [datadict[k] for k in keys]
    if not x_tick_label_map:
      x_tick_labels = keys
    else:
      x_tick_labels = [x_tick_label_map[key] for key in keys]
    barPlotWithStderr(means, x_tick_labels=x_tick_labels, xlabel=xlabel, ylabel=ylabel, title=title)

# %%
#frame = getDataFrame()

# %%
#print frame

# %%
lecture_end_times = {}
lecture_pause_to_counts = {}

for event_type,curr_time,lecture_id in listFields(['event_type', 'curr_time', 'lecture_id'], 'where event_type="pause"'):
  if curr_time > 3600: # there are no lectures more than an hour long, if have such a result is bugggy data
    continue
  if lecture_id not in lecture_end_times:
    lecture_end_times[lecture_id] = curr_time
    lecture_pause_to_counts[lecture_id] = {curr_time: 1}
  else:
    if curr_time not in lecture_pause_to_counts[lecture_id]:
      lecture_pause_to_counts[lecture_id][curr_time] = 0
    lecture_pause_to_counts[lecture_id][curr_time] += 1
    if (lecture_pause_to_counts[lecture_id][curr_time] >= 10):
      lecture_end_times[lecture_id] = max(curr_time, lecture_end_times[lecture_id])

# %%
def fix_lecture_end_times(ref_times):
  for k,v in ref_times.iteritems():
    if k in lecture_end_times:
      lecture_end_times[k] = v

import video_annotations

fix_lecture_end_times(video_annotations.video_lengths_ml_004)

# %%
import plotly.plotly as py
from plotly.graph_objs import *

def iplot(data, layout=None):
  if not layout:
    py.iplot(Figure(data=data))
  else:
    py.iplot(Figure(data=data, layout=layout))

def scatter(x, y):
  return Data([Scatter(x=x, y=y)])

def scatterdict(d):
  return scatter(d.keys(), d.values())

def scatterlist(l):
  return scatter(range(len(l)), l)

def mklayout(title, x, y):
  if title and x and y:
    return Layout(title=title, xaxis=XAxis(title=x), yaxis=YAxis(title=y))
  if title and x:
    return Layout(title=title, xaxis=XAxis(title=x))
  if title and y:
    return Layout(title=title, yaxis=YAxis(title=y))
  if x and y:
    return Layout(xaxis=XAxis(title=x), yaxis=YAxis(title=y))
  if title:
    return Layout(title=title)
  if x:
    return Layout(xaxis=XAxis(title=x))
  if y:
    return Layout(yaxis=YAxis(title=y))
  return Layout()

fig_data = []
fig_labels = []
fig_xlabel = None
fig_ylabel = None
fig_title = None

#def newfig():
#  global fig_data
#  global fig_labels
#  fig_data = []
#  fig_labels = []

def addxlabel(label):
  global fig_xlabel
  fig_xlabel = label

def addylabel(label):
  global fig_ylabel
  fig_ylabel = label

def addtitle(label):
  global fig_title
  fig_title = label

def addtrace(datl, label=None):
  fig_data.append(datl)
  if label:
    fig_labels.append(label)
  else:
    fig_labels.append('trace ' + str(len(fig_labels)))

def plotfig():
  global fig_data
  global fig_labels
  global fig_xlabel
  global fig_ylabel
  global fig_title
  figd = Data([Scatter(x=range(len(datl)), y=datl, name=labl) for datl,labl in zip(fig_data, fig_labels)])
  figl = mklayout(fig_title, fig_xlabel, fig_ylabel)
  fig_data = []
  fig_labels = []
  fig_xlabel = None
  fig_ylabel = None
  fig_title = None
  py.iplot(Figure(data=figd, layout=figl))
  
curfigure = None

def newfig_mpl():
  global curfigure
  curfigure = pylab.figure()

def plotfig_mpl():
  py.iplot_mpl(curfigure)

# %%
data = scatterdict(lecture_end_times)
layout = mklayout('lecture end times', 'lecture index', 'lecture duration in seconds')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/143" height="525" width="100%"></iframe>

# %%
print lecture_end_times
# Out:
# {1: 414, 2: 434, 3: 749, 4: 853, 5: 490, 6: 492, 7: 669, 8: 528, 9: 620, 10: 710, 11: 690, 12: 349, 13: 525, 14: 413, 15: 819, 16: 669, 17: 542, 18: 672, 19: 502, 20: 304, 21: 531, 22: 538, 23: 459, 24: 977, 25: 358, 26: 839, 27: 967, 28: 794, 29: 578, 30: 828, 31: 775, 32: 213, 33: 488, 34: 444, 35: 889, 36: 614, 37: 846, 38: 375, 39: 582, 40: 610, 41: 640, 42: 513, 43: 575, 44: 467, 45: 721, 46: 706, 47: 435, 48: 620, 49: 231.29400634765625, 50: 403.21499999999997, 51: 719.30799999999999, 52: 764.19249400000001, 53: 467.58100000000002, 54: 697.48101806640625, 55: 411.4580078125, 56: 803.666015625, 57: 390.26666499999999, 58: 685, 59: 350.529, 60: 455.11200000000002, 61: 723.25599999999997, 62: 462.3330078125, 63: 680.15899999999999, 64: 713.45979499999999, 65: 410.01800537109375, 66: 569.7490234375, 67: 791.98699999999997, 68: 695.76300048828125, 69: 845.64801025390625, 70: 669.50099999999998, 71: 887.1190185546875, 72: 636.25, 73: 1181.780029296875, 74: 944.75099999999998, 75: 943.19500732421875, 76: 1262.818, 77: 752.53221995400008, 78: 752.5360107421875, 79: 424.62400000000002, 80: 469.22900390625, 81: 502.24799999999999, 82: 609.73299999999995, 83: 327.5880126953125, 84: 545.60000000000002, 85: 913.9840087890625, 86: 630.28302001953125, 87: 234.1510009765625, 88: 768.66666499999997, 89: 458.24600219726562, 90: 627.54302978515625, 91: 722.76800537109375, 92: 787.71400000000006, 93: 456.08700561523438, 95: 737.18799999999999, 96: 825.84100341796875, 97: 843.46666500000003, 98: 474.57000732421875, 99: 871.58502197265625, 100: 614.6090087890625, 101: 506.892, 102: 507.91400146484375, 103: 510.81600952148438, 104: 344.97943299999997, 105: 799.11500000000001, 106: 377.952, 107: 691.468017578125, 108: 770.78700000000003, 109: 848.62, 110: 422.23200000000003, 111: 879.99000000000001, 112: 980.02200000000005, 113: 830.69444399999998, 114: 282.066665}

# %%
numLectures = 0
for lecture_id, in listFields(['max(lecture_id)']):
  numLectures = lecture_id + 1
print numLectures
# Out:
# 115

# %%
for anon_username,event_type,curr_time,lecture_id in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id'], 'where event_type="play" limit 10'):
  print curr_time, curr_time == 0
# Out:
# 655.888978 False
# 180.805698 False
# 686.290747 False
# 0.0 True
# 715.555577 False
# 85.873197 False
# 725.557958 False
# 395.207094 False
# 741.088434 False
# 797.553876 False

# %%
lecture_to_user_to_start_timestamps = [{} for i in range(numLectures)]
lecture_to_user_to_finish_timestamps = [{} for i in range(numLectures)]
lecture_to_user_to_seek_timestamps = [{} for i in range(numLectures)]

lecture_to_user_to_seek_times = [{} for i in range(numLectures)]

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="play"'):
  if abs(curr_time - 0) > 3:
    continue
  if anon_username not in lecture_to_user_to_start_timestamps[lecture_id]:
    lecture_to_user_to_start_timestamps[lecture_id][anon_username] = []
  lecture_to_user_to_start_timestamps[lecture_id][anon_username].append(event_timestamp)

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="pause"'):
  #if curr_time != lecture_end_times[lecture_id]:
  if abs(curr_time - lecture_end_times[lecture_id]) > 3:
    continue
  if anon_username not in lecture_to_user_to_finish_timestamps[lecture_id]:
    lecture_to_user_to_finish_timestamps[lecture_id][anon_username] = []
  lecture_to_user_to_finish_timestamps[lecture_id][anon_username].append(event_timestamp)

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="seeked" and curr_time<>0'):
  if curr_time == lecture_end_times[lecture_id]:
    continue
  if anon_username not in lecture_to_user_to_seek_timestamps[lecture_id]:
    lecture_to_user_to_seek_timestamps[lecture_id][anon_username] = []
    lecture_to_user_to_seek_times[lecture_id][anon_username] = []
  lecture_to_user_to_seek_timestamps[lecture_id][anon_username].append(event_timestamp)
  lecture_to_user_to_seek_times[lecture_id][anon_username].append(curr_time)

# %%
lecture_to_num_users_finished_without_starting = [0 for i in range(numLectures)]

#for user_to_finish_timestamps,user_to_start_timestamps in zip(lecture_to_user_to_finish_timestamps, lecture_to_user_to_start_timestamps):
for lecture_num in range(numLectures):
  user_to_finish_timestamps = lecture_to_user_to_finish_timestamps[lecture_num]
  user_to_start_timestamps = lecture_to_user_to_start_timestamps[lecture_num]
  for userid,finish_timestamps in user_to_finish_timestamps.iteritems():
    if userid not in user_to_start_timestamps:
      if lecture_num == 114:
        print userid
      lecture_to_num_users_finished_without_starting[lecture_num] += 1


data = scatterlist(lecture_to_num_users_finished_without_starting)
iplot(data)
#layout = mklayout('view start events over time', 'lecture num', 'number of view start events')
#iplot(data, layout)
# Out:
# 2466e09c4681bc4a744502d81838596a2d81c12b
# 75ec7afbc2cf25ffb30d3dd6c74f00a9559542d6
# f1026580e6cdce834ca50d525e6833ed5171f0b6
# 2514f3524caf03e6555b44b283ef29ff37e1a1a8
# aa7d060f3b866327bf4229c0dcbfb228fc96f885
# 1c08a5cfc6e5bc300c8cf78bfb9206b5ddc10a50
# 56cf4a12009b1da6b5413e856ccfe06dc7ec24be
# 27960b9ab0a21dddf26092585caa963018b06993
# 4b51541aab376565797bfe6d9df059d75539df8d
# 804efb7c4b4ff40c8f81dc6e68fcba762cb81619
# 3b043b2789124e909bc0f1f9ec6bd731129a9b03
# 66fe9e50b18e2066cfaac3528296dce86aa8a702
# dfab69a484850a6efb8821b5ef825a0bb0f86009
# 2a1cdc1a1b6718ddc8d3366b7650fabd242208ea
# 37afc80b0369b36e1421dc69662e7838b08e85a6
# 2201e7949b2b185969f9c1be8973d30aa1cbc120
# f3f37ebe4fec98acd4c25cef37476cbc8e536f7a
# 3484574b36437e20b19066c7d444bd863c70e800
# 79ed5d0c76f79226f71c8d822e9dab4ac0d3de55
# daee00a886ec11d2b378be9445677289fccf210b
# 0939f6b739275afda1e070558c3bec2396e49f1e
# 4dcea5085ad326e286c01b3ac71400b613e2f22a
# 1729b3d3d86d8aa7a6f0457a2691bd7c5aa7a8b1
# bab9a3152668a206fa9d5bee49164f120c91b14f
# 366d162e4923a7e85692b3b3d351698b7daff484
# 0e3c6fcd7a9201dddf6278f785337a6679969c08
# 0f0a36db381ac91a03f0f4f97fb569cfbc351231
# 094e7c7b05f8e3ee5141ae5fb8b71d0a602b144f
# 69bd1a92738dbcff99ff2dd0f126c7a53cbe9c1e
# fe1e8f7086e4e578b36cc3e1f7fff96abf9ca576
# 2e663c539f1ce02976fdd5932d7a339189c7d528
# 2bb86a9f914f7d76f3541772dd30180aa40cfa84
# c6b9511ad035a012d9d2b7cf601a7429d985316e
# 6a294cff8f6bca33c95d3af1cbf921f769fd5530
# 961a78e551fdfffd6c92d8d8f8309f13bef3f328
# d91598622636560363dc8d9e41c27692da8c1889
# dc811a69b53d3f60d393b2855af8194e68b12269
# bfb1d61eac97aa22c3e833b8489e5a7ea2da8e36
# 0a9c78d706e3140dbc42d6138f67d8dd74ef44bd
# 0a08db0d183fe8a8a75c4471b9976bd9537b291a
# ffc226096eb8222e7034aa44590485c049f18fdc
# e51f1f3447b5bc21de680fd9b75b30898d867c5d
# a7132cc2e28162d25d3868de83b4d21470828395
# ca975fadd624ed20ea8b22f6e4e32d38130f247c
# 4d0e664b9eaf821aa8f79254396f57beb7686036
# 2ef26084a30d9d34f6702294b7b3eb0782832945
# 0b7900f09f5cbef1bd029104a2b47dedcb7e01e8
# cb18f5e8d4953296c8cbd17d10517654b1c6341e
# 4416ac43a548bfd779ca9aeadad670ab4724ff4d
# 4d6d74261cbbca84ba80276c85cbdfe3fa371979
# ef61231520afda0565e20373a82644bc874cef7c
# 835dd7f2f2aaad8f30b971441453a09b04c0fd10
# 2ee402d1476bb3fd085e79f2c68f521302eba4f5
# 9fe628367babcf94539d5e5188930d523d88e735
# f3a9f616d9d9ab135de95571d3ba8c4b3b8aefe2
# 3afcd13df663fed87e00110415b3a44f05b7fbeb
# 87aaf692a1635290b586d11d7d0fddbfe711894e
# 845c680fbb31cb878987cd93820f87857f11f7ab
# 6cb2c7c4c935786dceb94b9d036f821a6b94bd10
# ec33cc93ced77bada979b827b2e90773694e7449
# 9eb6fecf3f1566571e5fb30994921ca066dfdaf2
# f310046c04c2b968217cd68cd0eb8803a7429c52
# 2a6d63fc004e53970cd8c49f7854342b9794467a
# 7f95b8093aad025c9512d5aa92428f20dc1258ff
# 74192ba6f6c332b2f704910284052552e20c65ca
# 04d4ef406f204b8a7647c9ce0de3c8d3c275b2c5
# fe87b87a863a470d95c8b9047e59d5af06d03549
# 66a9d816a2cb3ea6593f22ad94ae5347d3d9d6e9
# 4311ae4b622d910f4cf80efe60bcfc65dced3962
# 37020f6604db5c63b3ce5806b02f7f29bc2d0f9b
# 97bda74aec8ff32f8a484e30cc87d1a926c46ff2
# 3e90258b03c26c499cfe721b9ac64277c3bdd13e
# fba5a080b874c83e83e541255d1a3711823d030c
# dd11b8eac73cb21b451ad89ed8e3e7c2888aa21f
# 7dd6edc1b8facfd3547d3d5476b37daddbd5ad84
# 7bb448eb39a023218a1b6f68483e13b33e37f7bf
# a8c529615e5bcbd38d2b2b08a01e8f115785cc56
# 6d9233a72986032bffedbbe278c8bf1841efa8dc
# 0f0a8a2469d0fdb13e6e6dbfe6e7f02fedb58601
# 5bdf2ed29de067cd9377350cde3fdf2b1a6a28ff
# f694e823e00be538f4bf2b3eacf010e1d1e2e0b9
# 4596f7b51dabea217c32f58bb91168a30a5db5e6
# 8ff73ee2e4d9c8ba87a64a4e2d7b9602cea62f4d
# c4e9fde06a0ace29cb45b9318589b455108e69c8
# e3c39407ff01d0bb942e87b8200c7210f9da08d2
# 2096e8eead6d9cc181c75787e9729a724c2f4f98
# b5919af4837cf688993f9ee626bbfe037fd7fa72
# eec235ec51adc31f5a435f295ebd708619b6996f
# 7b8e8dafbde38e8dec696f4e020558c4f52a1af7
# 94684580e72044c53f762767d4cdca0f6922186e
# 1eb65d51278f876cc9a6ef9e0debd39b12f0c12c
# e5f7de739c6b40b3559ae4ed334025e2e5207e0c
# dc2472725233639d10eccaaa68cdddb0ced706bd
# 0b960107ee2f56ea3e1fde681e4059da06508041
# bd55bd3ab3897128bc4dc1d4e92321a5903e8889
# c5510915115ff475097e76eae4d12ef7700a1f6a
# 0c638bf72fe32604fd2480e3840dff21e1ac99da
# f90ddd3c852e41d5ba245e28e87a5644bdff2053
# d5862b587d54a9de3e0b18a98ac5af73546e101c
# 0d34cbc1d5e7d657d6704efa294b1fbb327b1fe7
# 58dd05cac2c3cffca64eebc57443532779879e32
# 7d557670e70cc8bd2acfd29e99086dc86f09acc2
# a5cfb756f30101a94b97cf0439839c00951177da
# a89188543fed8162b3c020c348752f1210a6e35c
# b985eae6e167d369c0183367c59d836bf75a2abb
# 21b1c2b0a5e49bb48dd8429dc1ac5ac5bc4f698e
# adda1d5bf66976d116f47499090a093d158fef5b
# 0a495aa2dc2a1949ceb6abf1c9ed12655230d651
# 98748dd694199bbf9857d2221d75f967069c2dce
# c3146dba0bc3aab3893dad599c02d49db31a56d8
# 2c2725f48d06fdd83d846aa2e8d5e6a95c6abea8
# 9c60b00f1fd94ce19a64fc72ee59a03b24fc5618
# c227e5d14fbf8019b06399fe0368d25b26586a80
# c7f8171dd2211bb8db6b0d120efae5624df4daf9
# 8bb6adad4ec7d94b5c42f7d55016cb6e254ce373
# 0c4b7c4bf30a335f32696e81304ecf533227ef39
# 169ce0759d7eca6ccd9bd373b7da1daccc77fcfb
# 2bcfb8fe56572c2ff8703f047408ab8fc38a2f59
# e49c944d534b58a9eb7dccb18236e546c5d388dc
# 4b56762527ab4283722e9c62991e87761fed4905
# 2861fab1c42d2ca3142ae98b855a08c25b0ff769
# f3e0f5efeac885f0def7d0466e2d5ccd7535afc7
# e9096138b412f1909ee1702f2f79c0ff558548a0
# a15708bdff1441ba8ffdebc26f085f178833a3ff
# fcdcee379c02f09b4075579c663be8317c2de5b6
# b1e86fb981a260c22dc45ab4c47f5066de80c49f
# 2d523e59beea0d3b52a8537f8c70f80fa42a506e
# 422d53c2d964bfa15f42d44609e1d3a11a42b08e
# 91e57d00c0109cb626e8cd95d48ec0dd06fbb2c0
# c97a12b7b523f455d0ed09f0747d11dd68a81d47
# 95427d83d3a9d5a42a7b5c52a055610a5dd35518
# 87890660316f5961a3d18eeb8ab79c88286aec9e
# 336a49ee66622230315a6e8583c9349a1db41c3a
# a4b5723f016b998ebb643ed7d43c6353a480271a
# 823a7a96deb69bb37e6a8e0b49f1f476df4df6e4
# b9caa19a4d177708addf84d33c6a6ab9f7a4c058
# c653c604606f3a05467004b6913ca696405b32fd
# a3bd39bfce6bd68414200988953de90819900d42
# 809c5113dcf6c469c703ac50f5c3e9b6685d615c
# a3117fe889c5b1d1347171d0834d2020de89db85
# 825291fa0ca2443d6fd3b4ce53e16eed087fe5a3
# 0a8da4ef1739665b92cfb48da4c82aced54e9e45
# 30477aa08e01f6f86ace74337450a1f6cf2b443f
# 39b91295fbba54e6c065dde5d1e939fc486c23ea
# 3a3d4b3b82886417f6dd2ab9e9b68fd65a531785
# 9ba1e805aecf56862c4a7eda827daac2dd3a5f9c
# 870dd57ad8bbacf19ef7985733358b1c6a3125b9
# aed8a4704af26573599dca86355182fba2acbe13
# 7d1063abdf1b22902724f185820670c1e9111773
# 5e8fd9a3db045741a44c830a27f95ccd7048d1a7
# dfe5eaf04685357ae16879bc226e472b0d950ed4
# e7019bbd23dde363d7f183f88c798f39674c8b10
# 67a09ab39252bab1e2d7a21cb7ea20b61ad4983b
# 804f07db2708016b1fa505df585f0151c4c4f0e2
# b2fc18133c06954e2a73d86efbbb2a46a7d902f7
# ce068b8972de85502cf3dc5c9cb012d6628c68b6
# 1100e2162c603a30a01189b9de77ffb9690783ee
# 86aafcc4e263ab9cd80fc9e3a46a96c93b369988
# 7ffb3d47a508bdf617fdea58b94c415e3c91060c
# 94f02e13aaedd77f11cdeb65b019a45f98eb4388
# 9a1fe258b01c861a5c0970c0a9de5bfab52e7178
# 2f6c2d3d8070b5f83d5a2c21265d3aa774569d19
# ad49fb8ddbe431514cf416874dbcbd3c4824922f
# 865c69aeb7cc1fa61c6d81283af54fedc1e7c520
# 7421a81a6cd221cd32aea34d04c765e7ed603f27
# 2309b9f41302f549cfa2cc6f91d145223f089ad9
# 4daeaf0ee70efcddddc0ebe8741e2715f0c52cd8
# f5a7b97cf00c942b7d879f4355a7590dfacdd3b2
# ee58d9c4430a4576b11adcba0475796ebeb5c067
# dfce323bdfca25f1eeb5430f7838b5548681a8c6
# 6776c9b2bae670ea73ede21abf3e742d21d35f8b
# fac4bb150127b68ef80bb4d4f08eac1c41b80aa6
# c7af71d18b1ff955ec1453e5814969066589a96b
# a691eeecb93c6aa218fb6280b11e4ae0f589165a
# 16c525eee775ad84132a796b6e7f8205cef118be
# 46322205d32850d060535188ee0cfe567ed6b7d4
# e2ae598a29cce00f55b479e0f4401a8e99c911ec
# 2aa0605ad687db2ee62b8cfbc78af09364ace9b0
# f77b793625cb066874f952bee1a84c676040d768
# 3e1d5905d32892703fcf203eec90381689b76ba1
# c42e60efcc909581d0f17762db1e55067b0091b8
# 90ae837e4d718d9e76a2e1c08873537f54dd4ce3
# 127bd7fe8ab136dbcc49410061db38c892f350dc
# 210214b218a1541db56019735f0ea0423cfd1353
# 558f46aca7d1d2f0e20424c3e642e450f9e1274a
# 479619c9463df11ea36197a50ffac333154d0f61
# fdac295ae0c8e5a5f62851224c518cae3774e858
# 157fe60e962466f4b5c804389c50ba9007e355b8
# 74137c4ae232df527c85600469b555cefa173ef6
# f68143d429cc429a7c1378528ac3b3b90decf527
# b56bdb16d770362757f5362f59868211ff8630e2
# 643e95a388680dcf271363f37b674235acdfa745
# d2b7c09ad66418c5f8d317a599fe4948483ae954
# 7f11e867986be0850e3af58dbff0a899a001cea0
# 064f8c236007b8810eedb31c13072310deb4c32b
# 0360a9012c7fcbd3f818097a883274da6b5e523f
# 63b062688ece791f9bc8b09845be1a5df3edc648
# e69189f176f7736318d05742578c60e03a904f30
# 94cc24475830610955d5439a155822fe7ce99655
# add6900b2935dece06b353b7cd5d6dc08e814b4f
# a8daa435cf5829eb924fc08618a0d77161c497f1
# bd59f8b5fcd20ae5788a67c3a5749f5eecda825b
# dc2e2d681dd31de767cca73a6ece4a4562ff7bb7
# 6eded2ea2eea15f9446c0e1395ad9776102dce21
# 0400c922e2da3b955c03ecf513ccc7c154209c74
# 57fbe7aaa335f69a392ce63da115c57c87e980a2
# a7f198bcc9c5d0555b4ebde2cba4bb516eff753b
# 777e50cc12c2b64330dec479030eb9feea871e7a
# c33ab8a1f9103490025f838ebacaa2bf5306f9e2
# 29a670a25ac0a27fe4e8f8ece85e283b26424735
# 9090c0943f08ae91540063aeaa5f4d0ff4d79de0
# e6503e84efa64491dd947541475da98744a33643
# 9784f38ce2013580a83802f5c26f3ac05e922e26
# cdc3117b1bba7b9c50992c06b44a941f53dd9c6a
# b05f562503b829324a05908661bde9a573bd02a0
# c708ab58e23334ae66da90d28f3a30a7675b4401
# cc96674746d7aefde1b9695b4e1b307b36f50961
# 23b4bd80c76fa257c30e0cf569c286b4100e3985
# ebd776962f52105afcac0be7f5e26988c79d4951
# 56c31a55d5c82261f2e22e7557e6fd9ba81f1946
# 7419451b74de1fba84d6116ecb5dcd29156d23a5
# 9c4d9cf0a9bbf4d6e536136ef0cb2d13284fdb6a
# a8f45a2cf47c634726d45fcf296c66498b4ca162
# ce6d8a519c2d6a0166d8bb3e5c120221981d8e23
# 3777c500b85ad1b81039a4f07ca968d072445615
# 1cfa9346eed3a8fcdce0017c163585b40d058e40
# cb86fa2a9d2b1c943c55808e58839d4133c2907e
# a5e5daf00685a98adc7bbbad95c766b7dc0a2db5
# 372b3c3ef71503b6a7cdcbadc46a820c88c70b52
# 25b504cfa23386d4c523d0b63f5af2155abaeec2
# f3ac5bf96d2087614362cf841c1d89653de4ca7b
# 5f0d2b083835bea9f46cf619b919d429599e5e20
# fe16c48e499479e8458827c7fa3d956b2f120ec3
# f14b13ccc70ef0e24b0ea2737e49b458d02deb35
# 64a2baadb7d162d4ae6c419fe62aef4230f8e621
# 6c05390abbdcdb888a657ba66538b4ce8fb5dc9a
# 2cda049b1a18792f5120f13b1f292e6e82da2bad
# 7d19090c5237cd0ea382babc05c255c0f54c54e5
# 90857f84dff09e8210ae1c1aa0faf3d186add4c1
# 3093b9da3675c86a5cd27b17e89b28e7eed95cce
# 46b35b5689f7f2dbffb546f41a9672c073749e36
# 20575cd14a5460334a040937478c6f3ad18de806
# 95582728dddd523c8b9410f2c33484511119499e
# 4adbbf2e1ee80ce3181c34f46bfda11caea62ea2
# ef28ed33531696ebaaee26182e4a67313cf212f2
# b879a2d2ee805170202b550848434be141977702
# 4f57e77a21f2cc434f48a941448fbb2b7bece4a1
# 1af342b67d856d4a40ef08cd04e90c247f14492c
# 30acfe90eb585ed4acdfc4f8ccb13a37b29c3080
# d9c9f6f549ef70b3d6d7ada7e71272d7857bcbf5
# 0222f7d615528f8acaed48ccdf058853a8d2154b
# 0ac81e11a5f78ea06fda324662c171f6bec8a6b0
# 10719ae404dd8096bff71cdb015087a58667d38d
# 207174df5ea75001102a03b135e4cabc83ad4c01
# 0691f81fe6f65d96653763d41ebc00a0fd0b7db3
# f907715596d7dc45d30e03cc201d47e81134cb7f
# ccf2a239a74d51ce1719f3c1581c6c860be0abae
# 411a73abf1e3e8f32a7806726a4448a835978c75
# 692a0f19a30a4b21a8371b92f48838625643933c
# fe5f66db10470d92fbc18fbfd7d7ac96a5b0e049
# 7103fb519fa06da2cd865f3746f501a49e5be35b
# 252523f20546051c8fd2bd0dab1984caccd9014b
# c09d914ff8a00b526c1b8617405de1b74216629f
# cf0a1436c15b65e3c84ac59263aad37933c8d7d6
# eb7d72214b599b1b7618f35c2b54fbec019d0088
# 85acd64aa40f67897cab3e2aa57281996270e404
# 9da5e42b996fcac27cb5f56eaaa85ac96667d648
# 2b2aa627c7be8856308df6588792303bef5954f0
# 237a1e3d3c8ffdddcc885375e8cd87883ec3bc1e
# d4eda55908ab7ecca61b626b72964817eb906068
# e54a7022aee9a136e6ebaf17604218afcffc03ad
# eed57d6cdfc0949485f1ffe6d65444d45a8a5f11
# 23bdd760d08c8917539ae06546501ca7cb57e3d8
# d5461af13fb15c230ceae67cd043257bbcee9c55
# ac7a02d15bb7a41b5b1573efce1a2bb20b51603d
# dee7b482e493b8491103e8aa98185c659987e9cb
# 79a91f96d410a3f736b3db9c84d4dcb38b186af1
# b641859b56a2eb49bd7896501ea238d6fd381372
# 23deeb4423a21f7931a8dc754d0ee4c7f8818ba1
# 422bb2fe0f309582c70beab5245b7112108d4f62
# a9d73d51a982667da5e4d57851d8974e12ab0457
# e1c547502a0927e5cc7dff63422de75bf63213a0
# d4e9e25543f602a83be24c544ee97f9a6110eefa
# 4d451295c396019970e27de19ed56aad69b49ffc
# 2902e6d06d095685e759a68d871c039ae5884a79
# b5de4b36db3a877a4cb5ebc1fdf12d7cc50d44e9
# 7c97655805bf6f17620e7d0af50f37317fcd1c61
# 93ab9983d021acd76200bfd5ebb4db2796e576a8
# c3cec5cb1c57ab84319f797bd7cd3ec529f1cb5d
# 9df936d4eed6615f4e59fadf90d8da5fd3bbc5c5
# 40209af76077a60d6ebede1f66be85e7a2d32b78
# 37129f09b02613744ebf0650c3638be469e6f5f9
# 0cda9f34d253c4a8ade2e94fb9e38b4fb1a0176b
# 917e58863d153edd44c37dda706f54cc1667411c
# 6f6a52968ff208bbfb3ac212a8e02891cd2813df
# 1bc4708548698c6ac65036be7c7565c7084a0dc6
# 74217b1e90798f68e3e3e8279880359755255798
# 39509d9217940137a5e644185fdb0c5dcd5d9c0c
# f5c59612ecf99c717ac563d76c62cc9e8ff13ddf
# 15c6ec9388e596548cd6af862e208498f6891f1b
# ba5a5cf8dc863c1a6cf76da35db848ca591efc05
# f682bfce71938114c2cafbef92991d2f1d89c0c6
# d13820f0fadc00c385cb604676ee2c033f233f77
# 08d83eea923a0e9f931dabb31224f7eb4393296c
# 54b888c827246e0be1bb1fecee8ba38acd8da37b
# 1e2e3887c0e4b38e4f2bfce29e2b3c33dbaee2dd
# fd2afae2d5b1776eccc1b6757f8c4b4e001afca9
# 969874798df8d7fbbcd296b0f311e2a19ce6d5ed
# 29a7410d5c89bb2fd77bc62f8a55e30fca6f7fcd
# 10ca97a1a5c0cba0e135ad8bc07d076d36f395d8
# a811cd576392f3c4396477d07a139c817a849ac6
# 00e26568013fe5a0afb975c9c93fee3a9bdbfeaa
# c3ceb8d8a4a8f456c4b3cdb24184331ebf6eee12
# cf8e5485cf69b3f96fbc3ad20abf78e8873fd038
# 26ca830cc1ef312c139ceeba455b476d4edde037
# a52c1ef4c27f5afd0f468ae00ba974d4a9acf54c
# e6bf4fabd8993d4a1350f93e9d27288669f08335
# c0a96866cbca04788ef07f73ef11e637f13c7e85
# 0593ca57d9ec674f26b759267c11c42511fc97e4
# 511caa30e4e95bb71bd2d7e6c469fb9db2ca5b0e
# 657de4cbca345441bf37352d3586cba9af0426f7
# 112f92f30c6f0e98314b08a92ee892e01cebe075
# 543eb6dea7f120cf6165417b37caabb7ad275978
# 4ffab8c3c5327a82b7bee418b99af6fc85568536
# a24b20bb92afbbe6f1cc7796291f802c52dec97f
# 26ff4ebf544a9affc897751abb95619b84de0130
# becba453c942cedb8efea3257636018b46272950
# eea43384f2a5ce1fc813a595eca25f018fc7f72f
# 2d2b2c3b18d98eb5e395bf6a1b4d098ccb182389
# c124ad8cced7ab0206c1b044f93a2d6e63a812b5
# f4d8e70b9bad9b26e8d3a6e21d7269004bc15ca5
# c24c0ba8c12f690d8223b6798b48f7832b3b5d28
# 5edeb8dec141f8ae919a933aaecb70b114047b7a
# 0ebd1b6a1e90f49bb0ab2e94187d3f644a82eb65
# a850d6745a025bb519eaaa44113e7effa7006f1a
# a75e8783fd07355ded4fb5bd751d738479162548
# 201951f99c096865b94a302fb186c0adeebb938a
# 43962063f6449db0b3a6968bcde2d934b3cbbdb5
# ef55bd0660f6508bba7641057de405ed8ec0ae08
# 16b64ec54c99ce96dd2a1e08991b3236d23d9c37
# 19cc4a91fd0fd18e0231df6507cbe9ea88fe8791
# 63712b4f7170e83f66cfd3edafcb12b8adbd59ab
# 41341b1ae386bf1676a4ffddbd816d9b58d67f1c
# c5c9b07d200c4f49ed884d356aedebcbb36480f0
# 07f14ca3e846ba85c83e65b10e8aef16fc41c408
# d872ad255ef90603d2362c590d65b64bc4f35111
# e79726a57cdcdb1fc73382e160c53dbd6c6a250b
# 451aba38229fde374d257bfb85e846aae6471c57
# caedbc45178a80a50fe41a76e0286f15e90a3b06
# 7dd158ff5cd2c4d2a8e3d87bb2695244e5783715
# 643cfdc70d9c4266ccea2f2e1c8403de0e730073
# d203e9d897439ae2b77ccf4ab265779e1abd0b79
# 358c786e8f85a9247aef603fe64c48efeeb66750
# 499f2804e1a1c641dd7bb0a17c742b7d27e186ed
# c7e0654395eb794288ad6fc2b159df57adc26e83
# ed518ef98f9e8f033a0cc7f15cb72ca709493fad
# 429b88f3b67505da5aea705853f03f1c82cdf556
# 680f7d5654d2cafcf03bff6d49b2f6d88c2051e8
# c8e63542a482b0acdcba9e4ab4dc39619a0aa768
# b4d0b4fa0adfcf41ecd1296679ee2d4c64158bfa
# 7cdd65fc98b02e0a93b6d69617ac4029ddf35c82
# 0b5fe4ddb5e380ba6476fb8e578e66fcedc6b53d
# fc67c855cbc02147923b374006290b9acf9b351f
# 603339d5e632bb3196b62f50eddbe1d4f6329be2
# d7e13a0aaa1eee5f6cd166fc827310f4a9a29a1e
# bbdc4bfc14d75965ea66f4add793b1b8f0fd7f2a
# 58e478ee44504d8f8a43cb3cd275ed05530ced0b
# f180e6ed323bbeb6086ccf9dd3cf1096d7605b30
# 51a0e60f9c336b8b645fb30e500926e1075229cc
# 75ac6b9a61ef09d6cd561661819c66182d5b1a8f
# 4ca727d34c9523ffe10836a6dd20628043c83e31
# aa1ae844da00f11b59303627710e8ffe08130200
# cb42b44d32521ab903d69b0e3407d7ee97bb4339
# ea91595e45e729b4c008a3aee4f55e0bb12ea0eb
# 5dd745dceae2b223ee81ca58e2503880d72f7142
# a0f8bf1f12d18a2c21f63eccbd07a7d8fea51210
# 363d9b19255be7df374d0ff95b17f2496e417984
# 4d1d8fe2c415c0d487f721b67689b7873795e117
# 0b0668d7c0c756e90042db3d74ba1d804f373c01
# 5dcc01b1b1d07dd3abb88cdbb7fb28698517052f
# be5f4e68f71a04862ac05be3f49fcedb51124dba
# e78cdef20eac7caf927dd1a7bbf781bad46dbebd
# 9c8bcf78d4acb564da2de5f4e716882fdea57b82
# e99da4cfac90abb31bc0ab4c604e2ce03f7f7b94
# aec42d2c2efaa76565b7616375038b5df4ace608
# 0dfe0844ece8609d42a8d021e1735d41be348bc3
# e66f6cc478f5f254f1607d518cdf6bc5bde5bf56
# 38dc92c10c589cc64ef6e08d06a7ef764f61f558
# f967bdb87126baa05c7275166c882b63d24bd0d9
# 3c965cfc8f0d260b94934889a122ecf3177c6601
# c45add112b212393dc53908b3c4a3ba8e9ec14cf
# d238abb43d041cb307d43a037f16b2178d53136a
# 7df7d0c2852e119e104cafe64be38a597c17029e
# ac05339e5fbbe5c9db011ef9b27c5380f65ccc1c
# 283c18df31c76cf959a68794d4ebb2ef94821ccb
# 6ae1a0f0192f6ba7109d5b42e075567e20d59b49
# 8f6309face1fe53b782d179cd1b7137fde9bf8e0
# c834ecb2eb07dddf4921cf497debc16bf9442364
# c625a3c0b7a2dfc695cf3ae1758a11717f60e901
# 6d4327753fe883f7f76edc587563ae8e3735c55e
# e78cdeb45eec6dd24986c797b79fd2c587d4dffe
# 8a719e0bd0c01bde194c07140076395b9a753d9d
# b467aca6f4e24c33f39ea09dc4eb2698f6ede182
# dfa757ca7df0bff2eed8731754a7b89894f9cb7e
# 0bb6256f0ba85695570fffdf72489227bfd4b734
# 04f64c6c665d920389b9d79fc5eb06eaf2857595
# 90939e85ecee91bcb647aed556b515cb25d12376
# 762d13d56cffb95c0c8302170b7dd877c50602df
# 28b08d8cba5123870042898052fb7da9ed645d65
# a8c9c91b6fc478109d1cab0508e1a4b282c5a3a8
# d0fdcb659cdebd795b8654735b211f1211e915a4
# d158049cee998d063b8f0f5392185456f7bb4584
# 799a44b97f164944f519dc345275381231aad3f3
# 35dfce24680d19ef4bc7a3f4b84d3a43087e296d
# 795d5b93dbd20912e36fe5422a662ceaea63ebfa
# d87b348687680d986bf87f40d42c0372319f3e06
# feee501ac3d2c0275116941b367a9b47a068fa6d
# db99a75ac3cba3ab6ff4e376fa60d1cdd8b5eef7
# 349f408520c406a38e71c1f71f54d1b56a23bbc0
# fc498969147e41755ff39044285a0ef7c1090bb8
# b027a96c0eccd5eb680d49d8ace2618556c37d54
# 14e4b23dd6187ac92b40b090daaad54389acb84c
# 2f0d5baa340495d380135d4a6b168de4abc93534
# dc5e8ede129de031562bd9c0823022cb115410d3
# c060a89f76feea8047e557aeef2900c4b7e44528
# 3d9ce9017cf96d06ada9b3f7834effef74336230
# 883c5c054ead7e65d5e9205b74e3d4c305a781ad
# 0a2102c381ab6eecf393cfd32536390272e2bc0c
# abbd51a8f2ab6c065a577707923f203b2b4b3f3b
# b983096b352eda049cfdd9e223a9f9003640f610
# 0f88c3407be34daa9f5f790c8e05e147b8833f85
# 290c6988d637f4b26bd2f824319b0683dac6ab1a
# a8c31e477cbe2c6b9102d92cabcf5e7af64c7777
# 1eca642526c75b6ade88c100b0329b98d62a9aa9
# 5edf76db87b8435647e571f99af205d901861432
# 6a2f7ea4bf39d632f23617281a33084ecdf66a44
# 9e4130616a4a4355a4246a31cd5845fae881ea19
# 16a2eee89af24bb81e833d96d00870e63f407f27
# b3e835484e313223477a0997a91051e702638d25
# 9238ac2f155cb77f98d5aa787381414fab876df7
# 5bd15c4b73cae95df20e45a9710f60623cff74cd
# d1413663780adc3d829512caeaf6da466927e38a
# 2cc9c9dcda139f6dab7078cac28fa47cc6130feb
# 7277bfaa4c0e3600c41d508a076d9bff14779d01
# 8d37bb0963d5242e2b1b89cf4a43dc11b7f75b1a
# 1b1fbffc0d04a6b33d8ffea0f4a9b2aa97161b8b
# b26e86a1cbae47964f96e08d6d0c70283b3f8333
# 826aad347a11240182c81c77e82729d7fbd48e40
# 0043f3f88ac1708ef28ee45f5eb0f08323fdbb6c
# 4d056289a1fe530083da0b8fb96fee689df74886
# 180899413379ac980d434a81633b930e2c14b997
# cb963982de8fe71a2ecd900ebd7e2bd020680dac
# a5287c275aa3b9dbf6d093ba9985101147a70c27
# 2fda643612097338b0f90e08fd8026dc82321451
# 81d470ebd8cb5a333ee51c4d4c8aa2521b64483b
# 6b7ac65444259a42a43d980b8e0ca9095bcd25ad
# b7d5a3aad38cf7736fd851754ff92835dd364470
# c8db3cd8765fbc47a0ec9b55151f77175cf95340
# f792fee86b630f52b1d7b478ceb9f114cf72898f
# 5817e22fade602857eca2f118f99c1f9065b64b5
# bd945314c7e0cfcb06e4f85006eae3fdeacd4c21
# ce00fd2541ca5a841871aacf67c5a79dd9e978bd
# bf7a9c55296c3353710562188ea327368a1c74ff
# 1203e594c474f56500e4210fbfbe697e57a58d0a
# 839042b05629847e9c372438a838487b43fcc789
# 95c3c27f7a1bc4eaf88884bbf1a367096da019de
# 2c5bec30deb557f1b4cad3b02acaf0f1b8510269
# c6901b61830e751af179e1a653572e96172a1b9d
# 6aac5fedb0dc03c240b52f222d131a29995f61ed
# c2279b9c54dde2530d29a5b01beaaee9c86dc34c
# b7ebe87c16ab4ddca67bdd146ae8dff5d3f84461
# 55cdcba672322ddbc038a2033a120ff3a57cb662
# f724fc6b92dbd9b94ffb96d2f5c380e300a3af2b
# e2362f28022c151dbf31de654e80e7c5ef254a8e
# 92be178ecce4e1e7f0998bb7e128e421866e94ea
# a74baf38cf0738d769f097b18940c40ddcbdcc3a
# a766554e411c051a5844113c6c2de2c7a735feb0
# deeb11479d987174a584ab8592050467d48b7df8
# 9036f3ef93476e93192ad850c66f87814e5022a3
# 76b9950c4727136d5737d21a61599073805dc43f
# fe4a5fce5e407f6e98e0bdb056025960b1f781ee
# 0386a85935083498c491c74e4b5bb49553c906f7
# 8d0361ffb56dd15b7733cef3b322e856cd0c9ae9
# 4f6f824f0645f74a81b5782be1686a332d83b07f
# fbe19fd0563fe9f02b17ca4642f5f5a4c2d26233
# 96bac05d15ebc8b5c7ee52ffa0f2edb3a885129e
# 1a53d31fe85d6a63ca8e9c5466b8bec70b86a503
# d69071bd329c19234ef8d394697b387fc82ddb0c
# e2bf0a600df649cef73c85ce1dc190f6cd394f6e
# 63b92a767f25cdb156b0ee6505e97cc190f52990
# 86c4ec6c35de37d626cbe44bff59322c659f11d9
# 4cb413f7affef702d2d7cc016ea91ea7bdd2c892
# 8f2fc5176d37c0ef31b97d83cdb679ce0a022097
# fa36502be927ff615f5f225191e96180f5558533
# 440ecc0e252f3ccf96b1070df7328067ed49e556
# ef1b58ec5db957d0de69ac0f9818482f091fefd2
# 422799ffbf678d7c6436e307ddf365c60e17a715
# 4edc0912376bfd449e7900076002712e0350cf4d
# 6170a07a0c3f04c69189162387642415a3c68a7b
# 0bc2f21a8eb2eac04d5a42dc1d47a3074ec25eb9
# d016ac928e8f7788e74d258821f55403a51e9874
# 5e90bf05050a1efb031013e36daf80d2a4ceec21
# c11e407c26df740f55ba8be7839a6ea43c77aa74
# 2993b7aa20616aee1ba61efa7a0b4cca3bafd4cf
# 905d90fb7b8b9721e026ea02790ee0efbd357db6
# aab262df2defced4727839877383564f1c0d7737
# a93a579e853e472333dd61d7500e074135ae3ab3
# c9fcb38abc9dda7897ca56e60f8b43274b715c74
# 78d01d7361bb6574e66c5e5fc7528e575e9cad12
# 77f2a55e5d34a4e1badec193aba0e0474df7f66b
# 0b3f701b20e52b06ca34765ee6960a7cfa8903d7
# 114fd2944344b59a501d6558104ea59d52a13220
# 29908e6fbbf577b6d85ba41f171b54f550564445
# 509bb9d50f7c3cb7ddc9ef00ad1a7d5d85505e49
# bdbd793162a6c0d483fb52f5a5c5c81af704e197
# f3f1364948c9a54703c598d15b9cb2447a5d9dbe
# 8732f62ed824f5a0133ffc44f8d8379bb7012dcb
# a9e4bf6a8d5ee66083c05e6ed47077a94ac738a6
# 61b46271e71155056c7eef28872c95b5404d9925
# bc7bfd0343e1fe15aa88fe7490581a8ece91b3cd
# 09105be4a5299833af0369e8a569876f0992dc8e
# cc2e9365923d0ac8bc637ada79dbd035ed699447
# eb0c6c0bf656a404dd33e8e40251b1e90fa0ed34
# 291e5d31e188eb0104a9fed70a429344d1316d2e
# 9fc1fd871f21824f09ab27cd292927c6657cae0c
# d0e049bcc806a778d8c8a2674d0c7fd93b536328
# 23ad1af7b7333af6692f461eed580498264c4784
# 71a6f237a30d3a140b40feb5e231680ed442d4fb
# f562249b07299e9084419ee5e257ad3bc657ca41
# 3c99114ddd13a25b04576e0af8d95871b427a523
# 4d5f9732116ec96fcdfde984ef3bd6f00f27ff9d
# 8dc3bba6924566edfd303348caa08d4c1d6f5b01
# 8490f512f3fe4ea0af8d181540599d01cd1b025f
# 8abbb5272d4e9e86e18199abfb7dc6c35881e06c
# 771c677218a526b387a87df8c44e516994f90832
# 05a63d3b7116db1c8e9951b5776a375244327e68
# 15c3156e7f61f261928124a1fd65d6a72ad5e18d
# 869d46fda1d93a853931a22f7311950cc980ac99
# 319a6d5402198574da79bdb2b4234f1600723b49
# 0c84b726c5aef46de88b7e2dd5c0de2b1cc96036
# a00ebb80712d574119d53cc115c4047ba65848d5
# adde542f55b83091ae106a8a4b1f630cc95ce577
# 87f1fc680832fbd9913e0d21e5b49af6629ffa92
# 45ad85c438cd74c5c6e3e2baab5f635228f344be
# 76fc5db0ebb73c8777ca58c6c0b98ff8f5cd8484
# 2cc1a9d4bb1d1834f61964c8e63dc6e34a59b6d4
# f2bfdb246aff3768306a95c71136be18fd023405
# 441f4aec23c831ca1dd7db7f22d51120708a9870
# 73eefd99433243c17e2404025dc34d9202c150ee
# 52ac66b87b1462a821d9d6104942ce6c6d7dfc15
# 83154d8ec9a1cf4cc56d629156fd3b367ff20f51
# 58f155cddcbdade529d71598f2e43ceb13fba142
# c7760230a4b48877bfc2eaf61aedc4258e4b7c98
# 0e560811639e0c0d81be1d692691770a7132a3a2
# 7ee9828f859296cf6992be2ba95f8441d7c951b4
# fd466b2d1af79f4ecd474ef471a270f7564f481f
# a066a18e3672655fbd082c9b7f2cac3d64d78829
# 13cfa870d04b782dcae0075e64d5e9231b3c985a
# 364f90395012721b7a1366c1b7c91b79cce0091b
# 710bd96a8935a793e02cc6a6d87f9190fc895fa4
# f3aaa922e72aea565ccdeaa19aaf0a3b77b9d658
# 3a2964cf65afa30f3995ff7de30ac46f0ff3bae6
# 105110e3cc08b8998834530be2f075357aa02da0
# 688fc46df8ed76efa4e782a77c68bb1bff81ff97
# 0c32362c727c18003d72e69701d0c986522d85a3
# 411c0b70513249e435d4bc22b21a59aabe135810
# 1e950697b34235ee815831cba3bd85ecbe3f2756
# 136aabe8ba69f5ed4daad19d086b13775281176a
# 077b0bae0fcdde6713e16c2cfe95bb942b9a5718
# 54e4511cf5980c992b1c4a329dc315be13f96927
# 898506f15877618f0836cfc133e0179de80af338
# ac935c2445cafdc3f6e09f7bbca0aa9ca721176c
# de21201870e03f3d913b7639da0c837f70f204b9
# cb325c33097063479d638bc2000e3e3f321890b4
# 9e9d20ada2fe3a6afea3854258ae27014de4f5ec
# 3f40486865098160f379641c80228f2d7b6800f1
# 2dbd66a727fd8def816ac7d499c999ec5bd87c92
# 4f042bc5a02ab81e07e8c37f3ea33538c0b06be7
# d212f1610c23ebe8d768865f25a5ce4571400347
# 833ff852f1350dacf6f88c170632836dbc40b356
# 9ea7c23ea0e29783ec1e4df67ddb8afc6352ef01
# 93a3aa9c4f09242bb95586491628e2efbef4e435
# 808c51a3fa4d5b251ac705bc14658f1875f2b024
# 5ad58a4286b0adf345e7123d4434a48818611995
# 0283bcfd3688a30940d03b2091a4d90946d4874d
# 250e54cb672372bb508f846dc9a520cc566296a4
# a6d3bda3d4e6c215048c438bc1dea7c9b4de6f54
# 4451451ee2b5fc15bad6bd5fb559e4212d23b6b1
# fe0ade240eadbc0d7b9827e49cd1b59ac5afcaf3
# 2cf89fb29775a5cb403308d367919c18c25dd56b
# 32a21c4228dde9127caa668b322b130ae1b392c7
# 6f109ea9cd22818bf702af9f919ca469c3f12385
# ca96dc567125cc5b03fdbb9052cba7ef35730bd6
# 2cdb4ee857f29c0fac1760e6cad943b54dbf1c8d
# 74d4b222a4a66732edababd4c4b534a73aeb48d3
# 6a5bfef597f1d9d28f96c08222510fa04e784034
# 04ac8366fb677af1c992bb5cb930d292be9d530d
# 5ba3e3424bab9851636b83199cf00d9cb3b73937
# d0723d7d138cf961eec97946a53b59094297c667
# ee600b01da0bbae5c257764ffa4589c23e16d2e7
# 9dbafbef1a2a40d095e06dc9bd1ad50747b589e9
# db89a4873f41c72494132600e1b90c76b5dabd28
# f840e4442e680216675448c33083fc1084d8084c
# 2ac618795309ba7e6d69b0100c8ef6e6c83fc249
# 8f5a45c421decc36bf86e05e885baf5523afc8fe
# 186b8ca4d841aa888d4a0d28f0fb487d5eaa5ab9
# 25b5cf9b03f7b867b5dcac2bb2d5f7b97dc42f58
# 67da60c34b64b257316df8a03d9a6e329b587b4c
# 3699e794328dd16447118b375d83d998b54e472e
# 95bcf2e204af8805dfb009013119a946fbd8511d
# f9b10652e5ee8ad7aece4e53114db2d21ea9374e
# 2f4e9b702e6eb6dbf6fa70990017b8af8da3f1d2
# b10149ec33975d75ef1120f3abf2db51dd69d5ae
# 9b2b59e0482f14d219c9afc9d26350629fa0b6c0
# 26a52b93938fcbddb4e2a215c31bbf7e999b34aa
# 3deda47860ce95dcfdddac407f107dd9b1fab383
# d609ee3d39c9a66ab0cb8c58a78547391a111ae8
# 41b7513136920dc797ac72f888ffa4a02ff687f6
# 604be9c83f4a957fef2c555672ed75c6874251ef
# 39edc3881743f3dcc55b031ae4a9f3e1146ae514
# 4ab6b0be0bd88b9de7d083b9ef126020d43099d9
# 7f5e65e743602fcb438d3d38134e47833e0bfa71
# 00864ccccbb7f1cb852be8e481ac97edc98f8a8f
# 61af1e788aa10ff8dfbd6e8a836208064b0d7ad4
# abd16916e30cfcdeb26e231b41b3d80e3b4cf5ac
# feb9084cce2c56403e8d10f4f8d76c46d5848608
# 0ee704370a9b9307c26b86c9fa8900aa27083c18
# 91d759f30b8933202fc7b7bd7813c32842fe7852
# 44c12bd47a1e52374865b9233dbed9830ab2dda4
# 29d6af7e0d096384060d08282d21522aa08b6db7
# 1fcb0a349518b3cc941d6c3c5a27a72488c31220
# 122a03fbda91c280a0a35c4fabcbb6efbb25454c
# baea5035b77013f5ff22cf01365a57a0a3e1ec5a
# 133ab6e0e159dc90af297a6a9c9e93b8c0220b3f
# 20f08a6f0d007c973e62f6e242784c1f72ec4fe4
# eeb84109cdbe894f2496fe05a121f758e456b4e8
# f8c7cf754d2fddb72a53dea7479e08d230637a24
# a9abc4634adaacc0ebc3a21cb0060da65df015e4
# d4a10ab14e31bb82e490baee8520fb69a541368b
# e0dc4d7186b130ed57182426e7117514ade8bea7
# 72b9e045cf8260550bf6ddda67302922a7d51f67
# 59fcdfb6f3ba9ddd2370f68310650bd49fb8a525
# f44f010adbba9e1ec4f820cd39bd3f88731e34e4
# fa34180a720b917436f1de27527f0ad47b5bc457
# 011f5e6d2bd18f7ad770857f22ebb50b0c0eae2e
# 7634215440ad9c198376852405b5f9ab42d5bbbd
# 61f004680591ca5682be11b20cff0e437a8e0d8b
# 69eb254c24aabe10d86c8565a174bdf55a35d7e3
# db36054b71c613a2a2425039b2e77391e2833509
# a84b170a81d570cbadc2f1e08d5410681915a5b5
# 86ea28a2e1d67f62a306caa6150d8def57c2cb1b
# 7a717a2d02094fbce74d113e91286912f1a5dfb5
# 98d5741b911ff2b0ccf1ee0490a57be8968c6860
# 4737d0ecfe55a0233fc0a46c6788c7aec5b62a13
# 3bd9ebfeec63f487f1bb86f3953a70ec55176666
# 688c82a80a3220a781185184e837415010c62859
# 7bcdc8d15eb8ce4d65329d88a52a27305a0d0320
# 70316467d1c546e97da3bacb67551f0fc9d90a02
# 524d0c527fa100bf6fd9b6a52acdd940eaa40dca
# 35f8dd12dd1611cb84d61cb7c0bb8e8e1efda138
# 44196914836bd3b9da8731ca96b2edcbb23a7d63
# 8a2ec479c82a4311d8a181b447dce39848db0de0
# 42ac06d3c888eb5ce0f591302c830588a2d5a1fb
# b44e564c1641f5b1499034bcdcb0695825efa4c3
# b90414d31dd143cae21d6151a64236a3c234aba7
# 1a55bfaf8affceb45f05167756c0df5e0e47ad23
# 8b374a216ee7fae28a9addc44ad26818120b9bae
# 531791a27e6c6ad4bf59b4a756a76a6cd7c8f1eb
# 952a4bcca29832c958ed3e7af9a4c4f9af1d150b
# b95c047441fba35d3565511f13730ea263538a58
# eab03d10cd0394b16bf226b45248b6976bb61558
# 5311cc0d49f8de03402d1edd69d1c8f0022291d1
# 754f1e4033fd382ce3dfd3c0e18ff3d3fa095c11
# fe1e6a4a72ba2b0f161260e4eeaf721712cd39ef
# f0f139946532dacf2ee7ae75fee553cfa2279ccf
# 5c8eaeaa7043945b971e7cd43732c4d3c605ba31
# d1151e1e17f5ca0574e3ee352860261e1dd3aaa2
# 6f8e87242cdfc9d3e2381d4ee9ed9f2c1efeaa89
# 47fcf4559a0f0613360fd6a770e2bbf548ace95f
# cc3f511b86861825c141831345bcd704695fe51e
# 28fca91f6542f6d749166c769df40efef1e15b72
# a7b76b49f947dbb7318ee79049e7940e9bb7e386
# 4e2082b9e8ab4ecf364533baeb3b7022d028e454
# 83499a0c538b4d51ad43aa1f161f57df4d090a0c
# 3cf0f93f06fefdd0c1aa41a96184bb0287147edd
# 3cfab7c70bc0f9226e47141a4a1efb2dc3719448
# a0b8b45b9f152b8cd658951ef80bf92c58e19feb
# 200501477e53d290609e562dc93caacf8a51b396
# 8a67ad4ffe0c81fe2bff1e44af971c335380ac4b
# fba2e5d39e971e0ccfe45e44d7dc6654051d0218
# f9ab05129696ba39d64c3f07e139d6ea5a7134f8
# 17cbc2b54c2ada5a78bd6735595de0c7c2444e05
# 801774ddb9f46e50541031d01365c254b89411ae
# da015d9bc72db28d830dd7430329a4c771136a3b
# 7a81e8d375a4fadfb894b352ce1b08ea47dde1a7
# 09264d1d2e0b3677ba86f5573a9667281ba98ee4
# 63668c405e820a64a08d7ae21a31833fc8e69671
# eac821f73ee6d872ad915b02c09312f0eeee0867
# 91059edff74814824a9220a02158f18478bfbd7a
# 7781c772eb8bb65ffafb8d303f8e6a33a7384667
# 3631249f1296a192b5ed8e978b924ac8defa360b
# 93ed5a24f33e8f842d317eaf308a8ac5a8c04692
# 320cf14f610304272d67c2e68cc904e1d69fda8f
# d3ce0092deb639d95f1b410cddf4ac1ba468fd49
# 78cd8a86dca2992450559347c4902db4058026d9
# ca78cd0d04e28d30afd4c7c957d19c6913aa3702
# 1a4d5339f864d2c71e228c20f8d7bb8071cf795c
# a5e59dbf24e657d101a53141b1536740e116568b
# 391473dd57414a65c7e41529626e8d32ab48df33
# e412b42a0b12646da53e492ad2efb9fc43f8d7b2
# 56a943646bb21295cd14910ea2cbf90c3907532e
# 895d220929aba9a9b43767388911ab0625fc6e1d
# d882aea35b57a128c6199aef789e5a8f632c3c91
# 90539858c48f2e727314f9d157e2dacf5fe2ac17
# c2a975b918f0ba3217601ea99d1aaba5c4b32409
# 0df7f06e5d8b930e4ce4047b91b59614ad91fa45
# 7d4fef33daf4e32cc483b257845ca7cefe8eb4f7
# ccbb89c9f459c821cb033cf60f7b845e32202747
# cb456013682bfdbda5d7c15f0d9b557836f757d8
# d77518555a5bcfa9786762dc77334164e193fa9e
# ea247da56d74f989f9e0665712e4bf52ce8eb4ba
# 06e54353328ef7220b20b8de0547d224b5f479fd
# db1cf4a1500806ab91957ee38495a7da262befcb
# 88ab32d52503ff319610b040bc27d43ee852e81e
# 0b0c562382a183c710eede0e4f7ce3d69a883338
# 104ab236e224b952d3e1e768f7d69167a8c3a0df
# f66e3357a6c7746eef9e9174b43422dd33825c63
# 5ac16578332eb2537907176742fe9bd254aa0f0f
# 4aca5beda6088be874985d500a5f08bf069981c5
# 8de043e87fec0d620073287e8b857d89faa44948
# 69c852302a3aaac3c906f2d09fb44c8cc06ac86f
# 898d8ecf9f23d4cf1d9d957f60b7fb109037632a
# c9227e478288a7fad758a2008312e340cfa267f4
# bf7652cbb1e970b5faaac55c5ac26a6d00a80fa3
# c30fc7460d3cfe9dff34407aa46a397d0647076a
# 2c841e773e1d3e5d825ca85c37deb82b22f85733
# 142cf33f918d7beb23104e60ac3138de21ba624a
# 8605dac660a9213aadfb0bee22a3bdcda1b1805a
# 1ebcdd106ba67499cd9e52b6b936d613afa7fd65
# 080e02505dfc9ce0551087030acb93316c08e91c
# a7b6bb17cc5565431cabd7bd86284c49efaf3641
# a6693b26d7474943f6aa323b81f824f9bbc6207f
# 587d1c21fc741c65a0f3cca74625c1dc347968f0
# 6b628a8819237b0b28119ec9dfc7865fcae4cfe6
# f763cb779c247fce7f5f833e6e75f243e73c7bec
# 2534e9b23a20e94b45f4138368b02909c615051b
# 7a72cad14f396d5452c960d9168bbdadaad19436
# 49fb5b405c1eaefea5f54b10c4a3b56a18cc6562
# bfd868ec57030ad5962080f50eb6a3ce4f181f9e
# d82d7268697890fbe7ccc9cd8198004c18112358
# d4c204df3962e8282eee0924d2d856261e37a6b1
# b21f8cd9040e82413e063531339e4a68f172555e
# 7929a72284fd264733e3ef00d6f3260bae890514
# fed00b8ef1f504f4f1ef8638e84d2e0ced5e77b2
# d2548338c373bd2c61057e37de49e4796508ded8
# 8900799ad15864beafafa27eb5707ee8afef4713
# fd1f12b89838bde74b12d1aedc62bfd2f4f4867b
# 89f2fe5ea6f10379aaee0a100f622f9671616267
# c322e0f1713aa66312ded18f96af4a8219608131
# 8322b106e7a9069f82d997dac759c8150eff8aaa
# 2f837f23eaac84549fa8d7a7d0fed87b74000033
# b63457298f42747f8286e8b455cd62a355d77820
# b6ef9df8c0edde4964d3a5177ffab4d177737d60
# 06838f53a2cd2cdb902abb09a569fb0d937bfbcb
# 90e6bf8a7394664b5a3babc63aa2df3e74e72e09
# 52a4c9d3699473cd43444042156f04f288fd8f90
# 18fd9ae053fbabdd7cc0c1bc1b2e6a545789f6e2
# e95c55207db132dbd8fd63bb2e53f2a1d58795e7
# a8d5e62fe575871f7f0fbd321eb3635b4cad3c5f
# 6b4b9d5d8fff984bfb1911d9c39c129b84759fc1
# 38ce75c426bbd916ec2d5f6c8cc8b022009f7682
# 57d3a2ec1c15af60d9c3a4312c3c17551018255b
# 5329e64ab04101835459ae3a7afc2abc8966f72c
# 8246ee33d53d43fea70a1888480cd8200d547579
# 601dbb2c225b277e182f9e620544908a6dc1356d
# 412bbdeefdc241fa65a2c60629f67448cc1cbbd9
# 3b696da0005437b171b51c83c2ae88ca79fffdb5
# 857193383f42247b13c57c864f56c61fe4381a72
# 652846fafdf3d0d9c812ed2797c2e7d2896baa06
# d9316bada94d5a417ae7dcf6b4ca74aa4c4f3582
# a1d9282c38856e9b9d4957bfbe664fa807f82cc6
# d002e5c244ed947202a574778491198cc671a171
# a2be08aea2324796b2709222f39bd3ade39a0eb9
# 124dad774102f4002946c0aa7261427a24d27002
# def632a4dde52d7ffbd4990e1cc851f211d04830
# 0fb303177d8cf95d74852fa4d3e30244daada561
# 1f0fe8ccbe9ed100b24f59750d07481d7a585b91
# ff2e5b30af03e427822501bfb6bbe9f635b2a4e9
# f30de8d93016301cde19efc18684ed977f91d60a
# 77beb1a55ff7bb069ab8996135187835f0e27248
# cd66ed218f3eed117daba41bc1761e191f242c1f
# 3aeba0951e420972d2b155afbd6c5363880b68b8
# 97bebb815e73e71951face48816a30e48025d00e
# 659eed42ee25d68cc8854b275949da1c59d46e80
# c9f22632093806e3325ce655ffeabdb056193f0b
# dce91b9d1b37c88a1e28b5bdb5cf05f44dcb36c5
# a8d9825ddd6f37dc4db9e13558c0bc6256c8d29b
# b12a3ec56da9fd72c5fa11a32dda1849dfa08c71
# c4ccd2cbde65a2884611502ec75c360aa6ff311a
# 946efddae282ed6a7de1b4293f7e379fd5f7f312
# 301fa201cf1c78b38ae4b316a1f385891258cd12
# 718c077521b429d7bbaf19070bb7fc81f890d202
# 1d3146fd4ac1b4294b7d03811851677acca743bb
# 3ccc9912b758f3bb0d40518e80223ea826642264
# 1615b347cdd32f510796fd0512a6d7a4cc005024
# 7b8e23e149b027c60bb0a75f95da88c3864d2141
# 30ba00f4f40a9730ac98a47ebe491d826bd37f22
# b88e090acfa89e6ed9d15c62194249434350f551
# 276036d06d17db7cd412210cd3f73359f4fab5f8
# c76d50ef710b33443bb05baab879f20557954e9f
# 870bd86fbf8b44daf6a371dc8538973f1f4ac841
# 2eb18b94f9d74ad4ecc498e4c6fe333e5bfcf7ef
# 43616929713a6c54f9b85810c73ff0545ef8fd88
# 211a5699fa1d8a08667fa62fa10b78a896019b92
# 2a6e3f70d71bbb727525bfe2808e85721fcc0add
# fc262c04949e57765fdc18e84813095dae3e4496
# 5e45011f330c1945c03cc7f9c06b855894a7b89f
# 6b9b8dab5f2bb1dc12c316beda73cdfe651db386
# 629e48711eff877962b3ba7393fbde65576dbbb0
# b0b4f50560a3df6029506dae8d2496cf0e6f30d4
# 376340f7cf1038fbe1b090b94ff202ea4ae37dc1
# 174f89eb05fecaef828da7d1aaa2f7c42ba5382b
# f03e53d9d94fa58046cd74922c80df2b148fc7de
# 3d70bcb7e6d4d22e445e9883ae6f145baf2b4e59
# 70bcdd01ef8afa6bd05e5eaf6f059af3b7be7d2f
# 6ff3330924894d08d6bc69bfd6bcc4346d7fd931
# 9edb5ef3ae3750c3f4395fc03123ce141bf1f337
# 4fbc46387f45c12b95525316ee9d6b8521f631c2
# d5455855f4fd59de3b4dd9834d6f11aae90a02b0
# fb603da81fb69b098e499204534c4ea95b0ed720
# bf8880cd88bc09fa22b504733cc282d28f3a1cf2
# 79a4730d00ff7db4fb96581df70aee6b90e03e47
# 1fbf4b5c797c02f70d4e4adb52be6b76f44ffad1
# 8a10faa976e83a8ed96cb726222d361cfc5ac235
# 2386c59f9cd992c5a173e87e3c93e80f675c60b4
# 2694450996c036196d203c34bb8bb09b99caf266
# aff6aed92d57d6aa7a7786a47a1c1f70c0852e85
# 30ee3eaa72743916792f049c1e94dc62d799d1c0
# f02944d24d79d08781990a763bcd3e5566484bc2
# 719eab55b513d0b9f686d1eb00350b97b802fbe0
# bd6410edd2c46fd678f6a02b669209f619eb045e
# 4799e3ac282c866029533a5c2834b5b5bb46d71a
# 6a3e2cc757ac395d7615b722c10190854d5f9389
# c0088b637f339c7cc22c020d2ffe865f2cd3ba15
# dda036a1d51704238758c4dcd4a8fd252c0226d5
# 470064119af8adf70da7e3408b4b9b1f3ea2b13b
# fccfcee00d68b86f154f739094776b758077cfc7
# c2a25f0ee9449a41393c7dfccbaf82af9c78e362
# 935751857e1c749118bdd77d07456647c7c891db
# 96da0721ff952d440f4739a04c273a5e71942a75
# 845c9d84ae5b83e5780843fa2e2a933ffd0e32e5
# 7799f5eb5c2a380bbc0e29701a1741924b2592ec
# 070ac15acebe2b8ad80865e7cfdb49ff9936c76a
# fee273f5df003a1d4faabe16f8fb01cf983a04e9
# 06a04eeda53d54202b5fee075141f254cedb039b
# a6d7ad989b9ab4fc4845eb174511390f9d8c8178
# 410ff3e84719c2e877c23b0597b7c9c52c038566
# 3027c57e6a28929b3e726e03e138d5682b3c8bb2
# 9683533097c02b9dfec2e857e7ca5a1049385b3c
# 673912ffb976fa63ae4190f82a663a6d016f1d79
# 0e769f414a4355a3cd979b9c281390cdd29203f4
# c93e83b8761e688067319eb7c01fbd1d0b3cc8d5
# d2e0dab7298b4c87123ddd53d059b00f47542fff
# 64f47fe552e4249b1545e5ca10e7069d5629ea3e
# 23a1934b7e50c6a7b9e42669675efcbb267e4679
# 24775e577b5010843b51fcf8a21bded107c9b320
# 153d895d82a91e2dde575c5f5b7a8ea44889a986
# 17948d566a80b6a0f1baa9e85a8792cb7b6122bc
# 969e8686d6fc0fdd39fa27e0956387d71e90ca0e
# 52a34da1387993762b09de9929f737a5a94a4ff8
# be01fe4a069d61bcecc7d83806b8043aafe3827f
# fb456d492b94a39b4697fe8051a59075f1b4c479
# 88d7b6d2e4de934de1895043a779d5ca65106153
# 4ccf42974cdc5eae7d107963e78fbb012f132eec
# de031e5225e5f0fc95cd888af0aebb1aea6244c2
# 3402f614527ede54d3d9f2c491d084f30731cd65
# 60b13f2f41f384cf883269a7e00663b78f221492
# 8eb3a8ceeb00930faf0017ec9f25bc6f18bd7d5c
# 2129eb70c72101bfb0bbb23e39d8a7a40c8cdee0
# d7ed8d141e879c4bd269f11e630bc09b807a4f3a
# d2fb14b70263af75a9ee14b64cd5b8cd30b816d8
# e6c7543afc6334be1e781e52cb2583dc6e359633
# 01f178d7d19cedd8ca61dca08af130cb3c4d0fb8
# 308f0b1677baa8c5dbc2c8c7397ea397b21db7b0
# d2b1027d05e9e687200807e4d04183cf1cafafc5
# 7ccaee6c23059695e8ec0290d52d10d312e13ca0
# c005966ff4c48230ea81ebadf89e07c61cd830e2
# 784877ae878807595dfd9a69cbb69834cdbc6ac9
# 0a870e6542a1798b1a58afccf4c7c08234ca1c70
# 0a9c87ddd0b0a6d0e4543efe505e41f102b69875
# 6c1604c37b4268cb1fb68829ceb206c05e73878f
# 8b2da0af5a722369b2fb776743b36ccdd9c65f06
# b22a05b65bc5fa5b98f7a1c14b9931fdaf46370d
# 2fa609128bfadd102aafb05647b923f9ba83da26
# c5fb0c512fd188807cc0b61e4a4a7b553f9d34aa
# d3e04190ae9dd0e7865ba559f0f52e08e5a8171d
# 873c6282c6c3e4b90b5476190883e2aad4b9ddc3
# 3466bcd169640791283f2154334ae5c8e77bc2ac
# 2ed8b22b6cbe6bab9a0db0893b9e9bf2e8a74ac9
# 0aca28e065202b480dc3dbce34d83757c231dff2
# 8c69c5feee4232191e9e7bfb21ff9d25a775ab46
# 850446c111ab05e03cd999101f888083ddc72e96
# 3e6a0215f5de266ee00994ecb7bdca70b551bdd0
# 3b1596e744f44cf88285ac908f8900ce54d2ae54
# 64a52ded880268946a08b685cc90ba2899761ccf
# 7b14cf433772c071e6b5a921e50808a26965387b
# 4b1930e93a65d49c264b4bfc60d69d3f7ebf99f1
# 94ea578729d529e92b896ce4d00d78e0c68907d4
# 199d0a2962044bbf278df852b349d510b41bbb36
# efa0c7be9a23f04dabf4a8f56de63e92db4f5f95
# f54500e9f822b9cdeedde0f020c24ceb9b15e331
# 161b2f7a7d7fb6af41b0d7fedd01b07cf715c7b2
# cd110e6d4ae7980604501e9a8e6c40f2d42e1145
# 300d0ae60e68ef003bc74934a7dc12c48642dae0
# f061d48111202be05f67513e91e7a5afe83f4db8
# 6e3894504e0d3f8a8db50f2033960837fa6b3407
# 0749f5b1d4e29651e758f8d8753ba3fd110e9ee7
# e411627cb877f410ea2068a26c15aad241e1d140
# 74c9a86529a8536276c844f7d89659e7a6fbaa45
# ad813f9a2a4194c279caba65e0bfdf22720f177e
# eff69ca4db522fdb8143c3921a7a788d4c19b9dc
# 94bac444bdcf34f06fa1aa6f43a8c26ae7959dda
# b3faae1db05af6a7d006691c92a9b41d7054cc38
# 441a7dc1d49915fc63b103f3af7cf3e6415bd8a2
# 3e59f27e43714699884f18217e23aa190d18f7b1
# 19f5f8b09ab9fff6020c70518824253af696586b
# 56b4f00982cf1fc84371ef72cb1b33450a73d799
# 8bb838275e1e71b07d6d99936cf87f82b4203b2f
# 7e22cd22e58cb8a8315462bc438325f3e71d96ce
# 419bd593da12470014082c7d5e11f1f717ca3708
# 65d7b757bb113a0d9060696219a0c5ec072132be
# f7f9e4a87b4af38db763807aa0714a7e498f0eac
# 191bbb4bf6f9128fdb7201e79e94c4bab34e7ef2
# e5cb17854bee70888e5edd3fe1064a7cfda590a9
# 61f2e4a0cf1d13d119c53b0c6c5e39401096aa69
# 2040f694b611f6c87a6d73f860c878dee37f4904
# 23982bc262673df588d253bfcdd67530d94f0c6e
# 6f692e9810333bfe3f5d08e5ea49ffdbef64ddba
# 80be611def671fec00124fd12e626992d9cfeaf0
# 9117fe4bdfd25cc5a90cfaf36fddb033357d8a74
# 6269e390f2b77da7d066934436b64a94958eceb4
# 83b8bb56e295a6297d9f226ad02e43b02ca42014
# 4ccf5279cebb51f6c7ffb50410677efec15d1b83
# 03abe14335aeb57b788642ef419b430ebb73364c
# 6e848ceb0bcf5ae329292e1706d1dccb2819e55a
# cca7189e636e1086d888263346ea2033f2526ee6
# b4b230e84773c474223b0c60b3d3a204db6371ff
# df11accb7c537e6e6c8c8c90e9b94a82b92bd367
# d7a7d2ce7972e39638df4af5b03824943bb2ef4d
# 75246a3716eb1aa354d087faafefef553ee38677
# 4154a6ba14df599f9eed670846853c6841cdfdc9
# 5cc27146b1fda412276832354359bf4c421dc89b
# bdca4ffa5c66036fe39af770d5f38af15caa9e3e
# f3885e59c629c5c8457ed443bb92f370dda62a53
# 8debe0bbf0a088fb8be97b5732fd080d603976d2
# 36b28bab51c212390d1edf212ec87f8bd93b3025
# 62a4f35c5fdb9c73ec74db4195e0e0b91c7322a2
# 41e9bf4ac16b28372795ae48d83f137fab579272
# ee64d05918daec9a2935471e9e5ea5d3df1f1de3
# 4c9f0be88e2ac2ee64990be3002755d6bfb9e4b4
# 126ef718c3a96ecae9bfc2c7380e03ddf607d3cd
# b5dc586ab49cc1f0e071c94d0de017bc8a3dc006
# fadefd7be0ae1eba261f8548224e047838866033
# 84ba347c64f17087f584a07e91e9f65641d2829e
# 4b0c8afbf11ab53d4872747eb378c27c4e255947
# e467c14edbb5692db4f1e130a2069b6a78f78b59
# 1e6483cb66c4fd54688115ece493d34015ee3b66
# fb9be74b01fbb8f75e4d3904db7e6367021055b3
# dd664293e7ae469e085ed0982324b93bf09e24b0
# 62752f2639850f0c0a2c2cb55697192e635c74a0
# 7e1ebf3ef2777ff6fd3f3975624040d10fecf133
# de01a0b9f5c0f3587f410a3ed53b09565348581a
# f8b545afb449daf007e06e25765c6a5311c3d11d
# 56153ebc53ccabbbc5fd5f50434bc011d484e8ea
# 1bd26d0ec8b14d1e3db019427be5f264b244b793
# 30aaf4d21749c5e6c81d3c54e17c2b6d8009c204
# 83719678b5539edd393bf7b4755f7d17a8ba8a91
# c4e6c1bc04441d7aaecdd4001db79f61873bb2fd
# 11706bb89655334afbe740b508585b90f6acd72e
# 293a69476a6a7207134808f17d162fa0539a6322
# 7f58ca381046474a9c8b2a6a79f9ac83ce8f0290
# ce204a3266290800eece0bb815315e7d0d8f1047
# f65c861e137553782297ea55314595cfbd87b875
# 40b6e005cf2094b8de92907568042db9de227522
# 713c0de77af3bd9e60ba9d76e4455531b86d0883
# 2b527a13758823e83e836d84947092aadce9d681
# 27c2c9495695ae81381ccb4fa7294859f832e028
# a8e6619d79a235671031eb1067cf4d9e333a9203
# fe2df7251de942859082fd088739c32595ffbbcb
# 4e72be42c12fa29d74033e5f3dce7c83eae6225a
# 522953f3939e1181876eaef49d75a50e0f8f9558
# 04377e1132199280ca76eaf19e288ab37ab1c46b
# b1a953436e94b9bd977b392cfa6d5046a39b6788
# 4a47db839f7e6acee4f8e62df2df89487fd9dc10
# 3269c4c489adda7442304a34040a3f144f32b538
# cebd7dcef3a5363b291fc43e84eb3a2ed897a920
# a79bb6e4bbd41fecaa8edcfa22d18a5606778198
# 711a880a8fa184f80827f25ef216dae3a51345ee
# 55fc0c0959df1184e96fa0d9359982d9b5e38cf4
# 18fffefca51d8b8c6e1e85aa3b6a606989e427ae
# 1274fc1f0ef381eba6747a059f3df42432596d7a
# 25ac409c021769a3467a5037019c7399a46d4a7d
# a3a0d5915347b24468b014e2f8fa82571d6ef372
# f6d483ca1791b70bed80896f8e5096a576d1f02c
# fdfda045955566a0fd089a4997b6333510c99845
# 643d3f4b12d021dfbab8e09f4a9528ec4fcf4cce
# 9cde10655abe602d8d1adcdc01f30293fc341941
# a062375f8ec1534e9f52ef0c05eae09be4870919
# e471c91166f90a868ec3bf295ca9137241973062
# d98de87dc813bca0018de9516192e5a300cd8898
# b5ddb8626bfca8ae959bbeaf7e12ce0eed634c42
# 8a8b6b5c25e53e87de751088bbec46940518cd9c
# ec0e165e533d2780237ed0a9c67971cbf0cdf635
# 59f53828dbc4cac6fb398e61c95379de9063e6ed
# 041b7ecd4f53c1026eb876f2c5deaa4f9afa9462
# 4a8211a863688f61c86bc1b7565f414bcb6034ba
# b971fa0c09ad5d7e99fab9d706a91e97ba9b7ea9
# 6db95ae5a40fa18b1f8a65f5d18da417607f78e5
# 8323a659822343ffa741e23186b4e63283c99ff5
# 3d5aec3308a83b054ed45ddc1ad3c6d4730fed58
# 55d4e054e09b0b9e01970d975cc9a4622b69b999
# cf5c4ce66b20023eb5142af3516dc1b73a9c8576
# 0355de14207c642ffd51b102e8dd2c2e0a0cac08
# 81001652de5e7899bdd2862483e51306343f9644
# 285afa03b2b3cf342879dc0eda7cf67da5a35aaa
# fdbb609385480f21ee660307b47978b59f9b40aa
# c762055dde38b095be0ae3a727fc947e05e98069
# 3d730b1c606dfe062403a67017019456a1b1b2af
# d5d6d41148f3a03b9e1ccc006d3dc1776d59ce7e
# 5d01c48c41d6bc843a6c66f2436f0a0f62f6c8b0
# a1f55cc011a958d778836caca8eb3cc5fb8b81ca
# 8193add4d305df8944827e496651d191aadced31
# d266b8ffa8868bbcd5c1b666e18817dcd8865292
# be661e57ac8dad075553fb9f9d74d2a1569b25fe
# 28611e4cd40a351b1bc9533285acb961af435233
# b63ffd524aef65f69f3cc041f8a76033eb208874
# aa0c1a0a50c8b5b568b4b281de93edf2d9719c91
# df1deb1e5a6827b15d18def2211c0270ba4df83f
# 4ea35ca0eb24c5f54dbc90ce1a4cbd6033296cd8
# a80e9351efae642d8161ad59fc014a4dcfa25714
# a92c1c6f20fc29457479e3a79ca0967f0c66d9bc
# d30f53ec089c73e08ce628a8a2df5d63aa8e3e72
# 2c93a5ca00035b0d66035c115380c3535d6bab56
# bfb713ce9699089899dbf98a1b929b6433faa71b
# 50583b7285268bc6fe58e10c6d8e778d1a6a8840
# 5f68d71a64e5c128cc21f389301185b67ed1cfdd
# 912c8feb441e543b5b1ea4df1924cde7c630352a
# 3b8eda9b34023cce46390b26c03d70269975cc1f
# ad7101d32f4d7158ec1147c91e11dbbd253ca941
# f9ddd9ae6edaa127f9a448682e829de27c637221
# bc6b6150f35722c7973b949ecec75dfd1c3f0022
# 6b2f2ebae3d62507e6191846234e7446878fe916
# 7aee039f728897c4445d250c477374daf65169c5
# c3631f5e46d91bb9b6c719c1f31bd0dc5c92e84d
# 51c9a6894b3c76e0ed762ec0281f4b9bf5a71f1a
# ffd9de8888568cee6b54c2f7830ec7faec502185
# 883e13b9c33f6cf9e54e468b2716bc7e28cac230
# 504cc5d71619a8a839806821df3baff8ced00682
# fe250faa8029b7d2cdba2d226730802842ea707d
# 15cff935d0fc13a28b14a268ab5a8471dd45536b
# 165b9cb75b71843ba1ab09fdae0df389b1852210
# b9c5962088802f76b3a457c51e6ae5bf69733499
# 2e08db441d2964f32d4ec96347d7f92f1715cd02
# 2e5e918c0e1ac8e4057a0a9fa0fb20428b7d6d06
# fb95aaaf64efbe1108c4f89712685cb373c860b7
# 1f1e40ca85bc9d6af05b8ccaf619a6fc1a762b96
# 606559250fbd6450e9272c8fd00d53913010f556
# d5bbfd24b07e8ed73ab526b42fa472baf775f651
# 033808da248d4b1477ed2fe4995f899241d8bfdf
# cc21d5e9f72b57cc09cc89461c72a11902da745d
# 0475477109d099c7e3de3e49022e86b571d518bf
# 59c8e120e00ae4f5e332ff24befa83ef515be7a0
# dc732505d32718fcab4cb119e3e0f408bd39fdd7
# ae1ffafa73f1d28ee8a580ef6d3c29317131f211
# a0e262eab1ab35c889d9e9fb3667755a9a7bf911
# 96970edea7a97095f4689f42a12da3b9e9538c43
# e9d7b34406ae073d11063c6e19cb3b801e3bd3dc
# df5217a3a1c73613363a7f4c704b97a6f4e78cce
# ebd0eef3a5c0709a402fc7b43859485c749cc608
# 720de7b29db7ce7e16e459bde9ae00748d25811c
# ef0cf3306de150f7245f5d0f88fb4026d4ee8a33
# a3d7ce50c30097733e1528c7ecbc7791c5d734e9
# 2fcb091601509b7ccc470e643bd2e3f9df7a702e
# 15c7b5abfcf50145975c3595384fff625c165821
# 231a3b216ddc59343c91808a62f5c15b25300da3
# 87459aa2f3710ea8e8bd8fb60100495e36e84f7f
# 562a9e62aa718a8a81258cd2f0ddae198ff01880
# 6ad9a6bfe86574b30c69cd4c7d92f5236ef30318
# fdd0cebc2592390b54b61ab2512365380ab79899
# aec29f517fbec85de92d0a533011c69029e9f38b
# 39633d62136088721f77154916e396779fa7801c
# 304cd4af6236f29231124167821303088741383a
# e858fcc01297f85ac1d841615675d9d364433d64
# c2ead1652ed9a661776ba0150093c95227428b20
# f86a58101d3e7367a088c465467759ceab7213b2
# 6e02a5287d7fa999100a0a9d64eb22672d36639f
# d59becd2025ff68536e6f4b6a6b2f46390070ade
# ee2b2d91f993c2dbaf576182807edae23487dd15
# 57505a465b305400fc7baa4846f10c1ef7c1572f
# 6f510d8a5f9d02cc13ba76e20365e735b45bd2d8
# 5fe71d3ea5dcf9283e0a9708c5b295c7f7836f40
# e11cdcc459244f366a4b1e29bf688fa5bd789d1f
# 4914034d8e5eab89285617e2ca083bacfea29250
# 8bb4470e99aa81fcccb17c9bba1bceef256ded3a
# 8f561c8116041532fb7d16d7f60694b7c3e0fecd
# b110488f0ca25f6cb593d0a21f34695b48e4a797
# a5c8bbec9d3af6d459a4000c09a45ef665dbf71f
# ad6ebd6e9279f71bbd554d11d83436af22dc886a
# 81d1db7b5209f7d3231cc3a9c3836dff8f152cbf
# 395658ff6280ed5b84d01554fca84bdf6caca146
# 9fcaa8dc356306f5c3a14ec64f87e8ff021d3467
# 1d8f60f0ed89f82e04531b5909e0d6c8de0a2c04
# 2935d5b4446c13688069176606b8dd6be2c4e560
# 63f9caf7f47848c35b1629467b9647bbd4dee496
# 4f92eb2e48ac1daa56a7e1a81c46e9215e749730
# dcba230a5dd9d6493936f35fd8c0f77c448f19c8
# de5650d3d2309875746b8d3de75eb833cc7a418d
# 7139d6f5c7e253a1cacfbb478b1a6411707fae47
# 13efb5c5ee9c27dd6c645c0ea089340a1652bdd2
# ce7d88906ab8f5ad3a04692fa3c2faf6b4bdbe97
# 596843c0edb6a6e5d865d8939769ab7ef6c570ab
# 625d62ea798e59e952a3029e99061a48c2533f19
# b010f796b0c69d0ed3e94e5436920db6fc6a45b5
# 34c8dc787fc63ad85752b53f702198106ee07b2b
# 8545d5e2940dce9e0577e3b447f5f7e63cb776cd
# 838b79a528c14e2b3c3db7bdf1f4e5dcfdc83c22
# 3e7ef74da18d93e209a7fd7d0de24abb5da51ed8
# 383756b0090afb399330d17433fdfaae7ca41a52
# ba4446aa53c3b3deecb84556235babf5bd5e7c15
# a7f226677fffdae9e466d20adba5541700e3d905
# c1335fb508a8752161b571da746b907f3c746204
# 3250640a6cf576c1e2c1b4ade14015dfa6a22ecd
# 35e8c54d8e88eef965bea905ddc0afb11eab5069
# 2e21ea1fc638d584172f6978ddd9324863ad050e
# 591e1171e838baf50776b421b58a9e462cc5c24b
# 872beb95c1d4f8322ad04127b8fcfeaf725b86a4
# ade2a65cedb328782409052ceaeafedb92055127
# 705c91bd3c8821cc3888d373524d8b92e31916cf
# 8239632dd5b56fe07bd3a47b3b6f3496be68362c
# e04d90502511c32fbd46325484a8a6b8d321bc1d
# 1af0dd5e1f8553f705f1bf9d355421da0e8891e7
# 1f67ea11808bc4aad5a95da205568431a29df02e
# be26852a9049d5313877bc0db856fab3ee696db0
# 63b9f7cdac1a96a1d3c7954caae00dadccb5c004
# 8f12166eed4e2f21d65022af69c44dd0ebdd6011
# badaed354c05cb1c4803b511bc168d77c63a7df1
# 391d2d2c8c0b4da710c6943118d80536b5d9ac19
# 4b5ecf85df187ce380c0a1c264c360cdff11de00
# 9bd11e641f4084660da61d07f9858a36490a8388
# 8ffc89557b88e1a5c57edfbf813e97d866e15044
# 85e726cfcdd8b6ddb9402ad2c267e7a3653cb458
# 1e085e97707c04151ec3f67daa3f5b50c49da63b
# 0b7a5967813a62603bd73dc95b39c3d6b0693f93
# 3c9bd8ec9eaecde25ca45e15b64636334cb5381b
# 808bddd73fee5e9e25811e57f4673a91a863b186
# 5c5ba2bebce2371eefd83c8910b167bfcb16434b
# ea52852e2aa7e03f5dbd0517458e548f542a4392
# 3ed931c1d50e524033089bfff4875f13a67d0bac
# 6c6a1462c067d9944fbad8a4da44dc26fec7457b
# c8b3986bf2e1be455783e8bbc16de1e48566e767
# 715909329cd3b755bf87f383d5e29c137b3aff97
# f5ec9308e386bf783511838b14a113dc50132464
# 3143b61e0e6d28ca70bf85cd8f0d1908c71786db
# b664170e1c678b0373fc7a9f3b77e4fac476fa56
# 56df2af2d76f0f3c554865f3844fc764be65b1ea
# 3c57ecd81d4925bb0d32142872f05fe2833db603
# ede514a1600520e87fdd99f554b1d2a1a1c11525
# 61b6e0692447c553b0612464d803712ad0cbbfe6
# 6709ba2548fcf5ddabffb3025b665b10862797ad
# 3945c587fa32ac868f46af263d7407ad9f193874
# ...
# bf7bf8230e1ac364dd1dc9ec6d30c9f80b218944
# ad5d162bde1ccdbef3e9752eec04eb15110ab26f
# bbf6ee565e0c76dda983a99711b79e5388f444fc
# 9a8a08875a654f681772dc7614f8af98f0ad9d3d
# 674f483b2eba670081e2a797a285acf483d4bd70
# 1cc979e94453ad110174b0bfd21c4d2066c9c8f6
# 4c9d4486eee830892c80a0297839f621754afe7a
# 40cc020f2fd0389e32d983d2c28394b78061aa76
# b64f6eebb556bd6c26c1a7fb8cd543fc0a0744dc
# 9609004162bc1749c45754a8cea1a1604b31caa0
# 770f435400065013b339d7bc8709fb8de5a83974
# c43f49b3c5b374b0bd6b3b2a807ae8e3c5876b53
# d009ef122383a8540e5e0924aa5e6c557636a576
# 52725f0e1dfe2645e36a96385a5e801cd1f5f69a
# ce2f2b9f918e2b69de5a87d10ce4aeaae8943b3c
# eaf315de4f73e1318adf792ceadcb2539e02aed1
# bb8e26eb7ce122209b80661d8ac4ea9d34ce0053
# 2764907c9cd47e8fa4362ffee18739d7486242db
# e60e15b931367ce8e3e0b4c77b8cbc906bbd344a
# 88a00992d68654e86721e78baf92e8d58347b3f1
# 18850bb5fba644b90a2ac4a1e9c2f11e27fb5d37
# abf086e2fddd66d05376f073f3bf51374cbf10fa
# c643f9268f845215446bc720a9a30b352808ed71
# 12ad054c6cc4cf191a5097a68d46c2e27060ff99
# 76376221c17d8081de8f397c0c266563b407ea04
# 3a519102309e2554e9b9ea1309dc8e7e7ae0c3ec
# d9c7bbc85ecb681773d4e40ddb5c8a0774fb82d3
# f5d73c3b381cce6be3157239cb28f19bec6d248a
# 07b6bb9acfffb4d91a9ef0ea0316a96a6da31e8f
# 4bbe341961d2b4862663a6d80ced1eaa5f3a4c9e
# 5448b7a3d3a03fc0d517fd7375be216aa286ba8d
# edbb4d12a103a90eb1a25f573411edf0098a2840
# 4f260ac4b5c85235aaa1c1e53345c63da6b1475f
# 9d387f6f6eff321f435477bf3cfeb754b701abb3
# 4e9b6ca37ac6ec5369f291d329c6811c93f225e7
# 5c5aaff2d0c18de2633c3dd4853314353ab1f0ab
# b1aff424a388f7d29e5a2dac8f46a0625f6d3863
# c8c203ff3e8a464f0b5e5339c6e4d8f5046f9dce
# c1df124b3f92c9f00f2d93fb9a78bf6789effb52
# d851097eda53d13e55638a962a16bdb5b5ea3a4a
# fda88a3b1304787df3f768adc7e525ad0185fbb1
# be91bf42a23810d565a24a90f67724e8f6c59617
# 6cee9131783771d02e79c2f33ad44759965a54ee
# 0e29ca7f39de8a7deb1a8553e756b3624b21fc5f
# 39fc83cc335a9de2c4b31f96f6cbdc6ccf0ef376
# 70036a1d60200c4df2d0007e96abb39f34225c1c
# 9fdc3e18c095789881c904572be41c37a4e1df67
# 73c5541606a3b8409385fb71c57aa89a27f7492b
# 8bf8f29eb2323cfe7910f3a1bdcd79e83281bd43
# 32961d2eddf389bc537d15b947a292bf827297a0
# 5c69fd8ee59ccde918163d10e02521d581038a8e
# 098369d532c5b5a57452276b97165180c418931c
# 0516f89ec14521f9f6c3213164a5f5fca47b1dd4
# f4797e612edc2aaa678f42210832fa06f75ada75
# 577d75b4725fa4c96e387c297112aa17af61375d
# 1a449eaa31ade89cc1c520f74bec283bdfbbaa55
# 2666d7af1ea2eb398c562385f70f57932556bfa0
# be8b577b2d38fe6edacbdb413b774626f6562459
# 267384c7d7df6d6274c832b087f68fb63c37a5f4
# ee8620d019f5d5139ec236c2a4e1bdfd63abae9e
# 5308274ffbea75a2e412ff922d16dc157aae6cf8
# fe8a6d6a02615535b8560c3930e1a82fe88d3b58
# 7ef9367c9b0eee6249106bea96607a45f7256cd2
# fceb6d1ff9caf9680741042a8da84acdf2ffcf2a
# 3180b938b4ff9f58b399dfff9ee2c11be5135287
# d974a4423af8f02c7713a8f148489c317881012f
# 019bb5785a3dc6c8f993ddd0f874342e6fe061da
# 6997ea9e0455fea47751309391e43dfba52f03e5
# c0dd7f4bf0e3b6bfe5c41770bec1507e9bdd9a8b
# 96b9c74ca1fe7a54b300e53bf8d903daf3373824
# 16ef19fee907f4feeb9640d17d051fe8b5755389
# 70c511f291b00c3642cf92aa6ac52ebbb60ccb30
# 86affa0dfa5e70074eb539124d129bf8a02e5853
# b7ea60e302249d9c434179ea2a091739b7d88374
# 67415be480775fe05f034de347ca83606170bf04
# 34c651cd385a81187cab8f3e2c9931db3d42bc6d
# eb5a2cc2339b8dea138d5ab042dea796e32bedf6
# 6fa28e803ab4f9c2366c52ffbc56960c015c68d2
# 39459eb1731574b94f3a30992c7b094908de0d38
# c9943e82408c668e5b020be53447d38a3c9b9f35
# 26ee582b36632d6b76788b342cdf498a08d5bd72
# dffb2bb63119a9d7491467fffdd6abafe5b475e7
# 486906de35ef966b0fd048f4955f1b7b64385a07
# a9911d126c07a3b1e5827374f93a8727699741a2
# 02bf255e6b24d646cdebc46b689464f573620414
# 3b31bffbf6496499bf8d9bea89034d65cdc31c40
# bf06b9a1cd906a8cf040bc95e1232ef2b2c1dff1
# c18c105151e8604c47bb29d80d4460007558a04f
# cd1b05766e1605adbac195764f365e563364d764
# a68a180ef5b2ef15b6d1c4ea9b16b40df3a0144d
# ac78228b31a23c01ad269a1f886d82e4106e2de5
# c86526e2f324cc6eedda0a339fcdad22211ab2e2
# 5b358af76a39993c7c1e432d4aec5e6b46232f22
# 749c41c311d059b34b6f2bbfd0e2a6b2f83921e3
# 8d20421a9cfb0d07ab6ebe2bec68aacf6a0344af
# ea57ddaaf61e9d3c69f2462c84e9c83cea2f1447
# 2fd07624939400a73b50fdf7cf2e9a07e92fb788
# 9dabeff633bb1a1d99c537313621939856cf0c1e
# 03a7535843ec41390bb64a28c461f77cfe377275
# 75b7959ff384bd6eeda782e162d1fb9f6b37088e
# 2eb079928052b7365d922dd5bee73415163d4ee1
# 4cf4b01e06adde62548594be1936a4bcfb725a7f
# b0e16d184f266809ed65e1e08d28d1741c1556c8
# da4679498e4213e5e2da47596285e09781f368eb
# f365e0623d7c3a4eedac243e6158e9353de9d124
# 99f9286f64d89f66d7933317b5b4d4eaea73459e
# 2574224adfc7baa1195fa821f3a27d1303c0ea33
# fa80004b04a76021f2deeb589fe8d08516113ca6
# 96c7c5ad9e53c3da765f0ad4b6e6d9b0713e688b
# aade28f908624f2bf87ffd577d1c8b69a4f9d422
# b679e8831dad378d0f39aa8c712c69b44530d398
# eb398c1e4a107bcc49c06aa34c16e4db3bd9ba7b
# 42faef902fc11d308d4e645c4ce29a9ef3fa0641
# 11d6a78dee0327009151cdeb0c12734328c64802
# 8d87450768c17793516b0fec339226006325cea2
# ba3103ae3e4e8648ba3e0cb4ad3d6336c1cb0d33
# 60748208b4c2bbb2efd04fdee3be211ae68a0b34
# 58c610e7cf15c0ed044f86b8deb549ec5aad8be2
# 670218bd02a1b5d08a87a2b28e5ca4862e32e8fa
# b8031c0f2f09b9bc43efe4348d4b73c553730815
# 24fd824462bc5eb628781c6dbfe65d3b74d225bb
# 031c300c2410c08c4b5eb415e4f0a16ebb167afe
# 99c69cf7eda9cc6dc6d49c92f6cb2ec5aa8827da
# da02c144d5eae938d08597e21541fa2c86f3bbb2
# fce6b3e46bfe7608a38cca681fa114dfab781dea
# 41807ffddbab7d7124fdbf9e7189d3cce4692af4
# 0f16ba460127cfe0d5ebf0ff630cbe2e8fa39522
# 5f72bc8c9a5982c02131866f805bf934da8e28d2
# 201f6133891e2a26c965c1c1a5b859401538c279
# 3f95c46e0c4dec083f2920de98a684536977debf
# 48ad44735232f53ead4534db57894d54b7863b13
# 4954f0204c02869283c6713599eaf61c10ad51b4
# a32a370323496cb3d270827958ce4ff12bf0e21d
# 04e87f529a20b87997d5cc31ccc8ddca3602e828
# 6122a4c6e9c09bff2400c59127081a163879dc87
# 2baa00ff757a1bd957cef13112117ef1e714cd25
# 17e404db6d940f638c6668a850e5a3e1bf5d148b
# 24894c00ba336433ca220fb1fe3c038ded1f3b6f
# 9405ff5bfee7f1da66d238a327d847a13d371648
# 3303c899a36344db3dc851758de1d14de4320bc2
# a82e460834c6eded7bd3b8817ef988fdb3458a09
# 0bffee56f07918ab3d0d8f31a09be3ee4da2812f
# 41a04cee71ea3358c42bf6c17d1d5ddc2f06bcc9
# 340e0e3d58ac04682b09da2cc7593843762ef3ba
# 7f927d667b978bc5fbd11239b84ded0bc20ed9e8
# f85ceb652eb5d32c72841b5935898faf7d27f438
# 6d09922b32417045027c30c3e515ee2001de9a2f
# 7897df07cdd8a9addfc7e792d0a597c2acfa0b03
# 61ae0a37d1fda756f9559151c2bd18bd37427ea3
# a4bd7719f18747cdea5611d7eaa45ab0fb1e9fd2
# caf0eb5e225794141016d4d74b42decf0ecdbd4d
# e88472626fbcffda4bd994e5128e35d91741a79d
# 4b948d3748fdc8e2b5088685896951e65047504b
# 029a66db09c45b596049c09a444ec2a3c9fd3244
# 2655bbc2175d175a235bfc6ff74a136c36ce701f
# 7d916b88cc82d178066ea6ba72a2e5476e002aa6
# 45e8cf746d3540955ad765b8d810a3837b3c0471
# e5213c3a23b926d1067105a2d39c2604c5aa94b6
# 8e30f55af8a98f82dc3aba47c276301a0bf96c92
# 4863b138e69eda191caa7988b24d7b4d6a451061
# f9b37175c5f2da89516863136e872ce4ec0a9fb6
# 5669863369b79daab148eb46ee990edd96021e1e
# 900741908985931ce4be5cf340a70a2b9d3c4401
# bc0aad148cd8af505496e2511ed9d4ebde26864b
# dbb7188528b9182b603f1de3563e7965de8de215
# 1d91aef4978745063c15b1368a27aab075203113
# 7b3b2c94fb32eb6962ae0027507cb4f755e3d9ed
# 642be1926bd8a5920996fa9ae85d2526958f0a4e
# 2c417124a5df377aa3bdb2d3c30e26a1e2011de7
# ad12713d067602d6e186f58378fe4c8f939e4c48
# c5edde426d5bfd79fddcf416bbacaa0d017321b0
# b635807536b047b438e8b0bd78a2cbd9b45747b9
# 2d7e6ffd7d6741289429d2a223bdf62272e75ad6
# e23cc873737b558cc9173d657d6ea1bc24e12833
# b9add7d69dbcddecd837c3a855a9d60dba4265c1
# 8e4d3e9c4790dfb3e7d25ac74d5e9480b35996cb
# 38a2d7f9bf92f8f974aaacf842400ffab2dbaef5
# cdd04e45e96b30109346a6bdd9411e1f2dfc9d0d
# b8f8f766fb2f58e3a27c2ece940a2aea8621f035
# beab4520436c098a1942bd054c2d8d4cad7b640a
# dbd1c849815738be162c493d5a3894e374339ebe
# 63f8da424b8ee5b0744d24149c2eefdf68c451ef
# ef3cb19b1ce47d3d7dead059a21f0f38040e056d
# 0675cae97b8ae0e3d84d69342c773c8dc9266a13
# 242f8898157e05909db22538294809db0a3f03ef
# 28eada3c338c5279923cd29352c90ed3d94601aa
# f2e514821a85d365044a2400f45d0052e9a21e58
# 71ddbd0a8ae255c7a243ad403e10604c5fd25e18
# a1e28ef0e16b6d305330e5bf88cb733ac76cfe24
# 1a3b38b6ea936c31e76c3943b4f3d623c6f04fc9
# a687d7a724da54603aa09c3a2e3e3cd8f6ecc6eb
# b8f9c525cdda29d7e7574d5caccec5af84816243
# f88974cd7a8374beba23644d8b9f80b643ee1057
# e03c8072701dff471881741f1d4aa752ab389ad5
# efaeb4125f206b9978ee0566fa9675c4685cf6a2
# a812f9bb174e904e4b26343ac1863903b9dc82fe
# 273b53c1b1187b960c5edae4715f6d3bd60e5f22
# f4eb0bfa40253c0b3e5660cdbd465c9265564032
# 94131ed1b3ea42c71ee0e2cfd86fb01bb8bb11e0
# d1ebc77d98aa165abbce1d5f70bc90034126111a
# 5e67bd598d6ce0da54760aa7f349ed19f485312d
# d952e76d815696c6a0b5d551b15346a40523163a
# 1ca2f17b67eb0891590556da31b26a1c4af25f15
# e790860695779b4872436c2710944869455f2916
# 3998b337ac9e24c8073584c5929bc390736b96de
# 0ebf04baef4d5fa63a7b784c937691aada168c67
# a3e1d146fc77f95557d45599bdc99e22396019f7
# 51d9bdfed6f936c54b4399bdfca413b8cc648dbe
# 75e64492440a8e170549a0b11d0f83fe81cd4396
# e01c4648836678dcaf71ec2dd76bee795d14c96c
# 5095acffb6ba8e74e304c56429c833ce3799b332
# 005bd8e461c5f00300d9ec515988168fa6a486e5
# 23e6a164159cc50ed14df8251422b7ec232d555b
# 7d0198364cc9bcf7b3e97c1fe990500ff12e489a
# 6d41dbc554457357404f382d92048519542a798a
# 8e17a9291e703216a794522f85d238130e2a6706
# d55936abb989a6aa77f6e351b574d190f09cccfb
# e363e765467b195395785997dadf7c4bce3224a0
# c8964cf123720aa8d33823e9c0f33b80faac8458
# 5ac8c7cf7c7673ce409425ad7212a8c730cb7843
# 6a07780f2b003497fa5f5c3f35f0b0f598a79239
# 36f1153c87e77a9356a9badb259a7ad46c0b6ca5
# da9984b2ad0aac03a9d878c9eb7fc46a6ae3b037
# e8e933b43d6cadd367c77bb519108d8204a024e0
# 72ab40e0e24a0be8fed9a123c4b5f8859e104e21
# 5fd920e5c6ecba8a06f8af42ad802f75c2d700e3
# 4e341fab284685c55814caf3047456cb0d89ab89
# fd52d75060bd854ba5521244c189ceb493536858
# a311b08a9f91ecbd666b4fd17ba4a49c9f9c9ad4
# 84a4dcb9f60ee683012999e21c0bfe80132614be
# ad7a91db1d8947463eff4c5eded70f1fe28a0e5b
# 2d0b68d8271526b7ef174cd35829c1720ce3d1d3
# 039a2cf51f9d6367278a39586dbb246e946eb7aa
# f0175adc9b4ec09e9e034ee37038178ab5982f31
# 099e2dd4e586b7b3f59ad5169f319fe09804c1e8
# 9ae9f5a107ce42110ef7e56bf6b2e6501eb125fd
# 181a79fbd5c4b34a0f873b4b4858d3eade3f0d35
# b4417b134d0eaa61a4cc64f76aa8bdfc9711a7a8
# badc9d6ca4a4c61983af291a49973fab1fadf392
# c11c98e36f47717601c8c8f7d81144d3d0626cf9
# cb246bad436b9692af13eefd9b1407770d1cf996
# 4bbe0e3bdd5538f3dc104ebf808ed6e68d5f7718
# 82689516732e9a1023264d0634bf2463e585ad6a
# 30df682cdfee9c30734048c1547f56c3646f8c96
# 969894fa6a5a967eb7eaba656f4051dd13b45c0d
# 83f1c061d22018a1cbc9259df394c5589d5a7887
# 208a8100db1e69bd0457c90843aa474834cfce16
# b58ea50a8257f8a547dc228710a00814f51074a9
# 07e75b2f031c8d1f94053364ae4e200e7b61d214
# 6bf8331d937f86643f8b24406e58ce3030841d12
# 56e12dd50e3e8ac126f1a5e62cee72dacf103468
# b545d6460108fea12170aefda241e0e77d129c3c
# 60b7f5b44f9e887930e0769b9a9d630c92c56632
# 676bd38c2e0af297e064d529eb06b3d92c8d2308
# 0c12fa5c7cfd9c5af62805b0c7b7b1422591b680
# fc8d476bba7ccd714c1582c597c4c19d04386267
# d6ef898becc7932287ca3865ccd58597f24e3c9b
# 3a39e05c6a6701ff5547ba39a67f8553bbe68965
# 651c13127ee47b7d69e91443464177f8dd333890
# fd8fd0683e07324f8205ac79b452454e04e7fc2a
# dc863b6b930c4b7f0f7f4629acf15224de5e7fa5
# 7fd95ade1aa7036bcb029ec8378a5d9d4fc09c1f
# a19e0b3c47990a76503ae33f17103c00fadbe09d
# a474a93f401604adc51152f9a5031a9a229e79cf
# 1e666a1e4cc4d7c4a443dd2ddb1651350a66e5d0
# 1860dea06595b352ba9ebe0902c838af4aee8a52
# 71d93a47503f8a346abbb96b50a3d82e879f5c59
# 7678b39c55176b76f2c224dc95b2fceceb8bead7
# bb0ca9688219c0f15644efb169e587cfedf6d53f
# aae857ebeed3d56faf5aced95b822fbeb6d79470
# a70e57660eaa8b1bad2ac2d5f781a4b4761f1c77
# 190866e405701567c474de2dcf5c02402645fce8
# 43642488538693d2f2fc3bb5aefa174b50352aa5
# b925d7f5e87010b16451b66e5be194a5fb22f463
# 460a1d31dee1728168a39719efd1608d9fe262c1
# 688e7e13099397977271b01b715ca4a0fb6c0d82
# 92869ca0e62a309c86b629929a3c286d1b026e18
# 3297e73ff36b2ec50926bf4c740740581e3acbc2
# 158a9faebc165b6d2e9670d17ff7340006a6e96d
# f597e18c052ca9cc0cbae5d16aba1487505995b3
# d5553d47eac8ba1baf278591fb857773d8dd6ddb
# 95af4d98b7bdca3972bf8e1b8ca5bcb21f57b1db
# 98c010e65732ad1b8ce0a4645ee9485e68341a55
# 4c27d015069179075d85f29c6b0a1ff307dd73a5
# 8f5aacf3dad043c2b66cc09d4ab289778c1903f3
# cc17f242050477c3499953e161cd1ae54df4a14b
# e204a97c295016d111d9b0e44dbd2f2e5df08951
# 6c7b8fe6fbd0af5b6e49efcaade201299fca180b
# 84179076fbb7a8d4e558b6c970b6e47a8aff0e3c
# 672352defdcd2f5bbbde6d53c43076d50b6aacae
# e7c712c541fa30058af09beea6dd0464e438fa40
# a9f7bfae0404f3edc451c84558e55dd4eb2fd3be
# 72cd9dcb765c1ac5197e8748c32a87a500c777a5
# ae7c2d0ead091368055ae4b24451d1ba9ce0291b
# 20d5b4d5821f44cedc5fea3653e39bfa3f408ead
# 94b2e1e8ce9c6df7d83cb2c30bf6bfb11f54f9e0
# 733fcda4d231603fa7f3537af41c8e3680a854f0
# 3dd178af01b9ea6d72148fac968bf8fd7fc1dce3
# e3ce12589cc711e1f45dc6efab95c65621f86c8a
# 4d7a33c736c7a5a6342bd97913642c7fe1982fd5
# 3136fcade67e1acad1360d0fff1294b6fad8ccca
# f4300c07f06a71cb4e73e7e69a73370bb58e2738
# 9070c5b4ef098dc72a022c041e162749355247ca
# c59cbc607562b6a7c14d449a31f3e6d90cf2694e
# 0aea3f1606ada91134aff124c26a9763cf8a1a14
# 50e77a4c062445a4574ff8bd5da42c9f5b3c58d8
# 41e3da21139610a127754b214bdbc7f52ef08557
# 854c4c809b36df770653b76e3c15c53ad593ed60
# 7ff4e258fbbdec270a32029c75018107bea8f33c
# d140c0440c1c4e3034656ffac46add6fc61c154c
# 087c64d2af3a294413b6f111569cc49ebcc30bc4
# a1f2c298ed766cccf59506e44b2a30b1566758e2
# cd1664cf743d0d76cf6e64a977e430cd768b3afe
# 80348c19d50861b7f0bc41eee860decc64689b99
# cbc0fe66a8e0eb6db7a8b2d948dc783513e90d43
# bd2a248bb204234016d83919abf0e08657d012e0
# cbf0f8295905ecebb0a2218f8275400dc7dbb248
# e03b1095e4b996965d36bb87aa564feacccedbbd
# ee3d5c5bf013c4a46bef507c71af893ef8a2180b
# e2d6c7898b0a9226519a973ea784fd79a6aee9aa
# 014f2dbfccbf33e74e02f62ad2104d239eb5be45
# 8e0103adf8257d1878292902b30146c5bcd39237
# fd5d0218497b326c0ecb1531bc45129e2be62fbc
# bc574395dc4a0cd8aecc44b7f00134f8b683919e
# e17f9904d1ddd7c9a61669bc76cb81162a34e9a6
# d7b1c73f926fa578e6480eff57e8e36927ce273c
# 7f2f49d72db025a9254aa667eedcb3f3dbdb5587
# 0bee57e651b80500d6c0a23bf9337095f2628846
# 1a70fd5abed2ed45cc228ca8d8ca5527250d7127
# 7c3822654440afb8cbf7b905f4b36e8d69bc63bc
# 73abb79f868fa46e6f5c0745165953622a65799c
# c13bd2c0cf21e2b9a4d71c394619d6e6031c534e
# 945743206cbcb17e40162994df855abe2e393b43
# 716b8ce22a2ce86062e1df714c3ac534ff165bb6
# ad3fa276f42019e24270d5f9f568ea1b3567f71d
# 74001d7515045679aa0a5333f466acc9178e85ae
# 56db6782bfcce3c89fe1fdf7de738364041b6c8c
# eb131ce8d361471c36522503caec949c1fe3c448
# 43d277585b14483b0afc62aaa27e29298c8c7a80
# 246cf25e14fc9940d80c07a63e62b9126715d824
# 5748d7b280a5179e9a5161bd83954384abfb22fa
# 31328da5230d872950fc53bab14473fc5127da33
# 9ecb865a28d033691d4b68a242aa55cb60c80ea7
# 2727c6fcbe057e7a01d7305fa08589bd95658236
# 34fd59e9545367d3293652162b8d1b5d1a75cff0
# d861fb8a9457d59e7f478218555fa807eaf25eb1
# 7fcc18ccbf3fd34d916ad5c688cef0bbeb61b7b8
# 13f81a2e56084da615a667082f85d0fb8c264f80
# 411db3f9e94bcd3693926c7b595c4554bab8ef0a
# 0872bae1428b99f528f27493e287adf01c29f98c
# da662e859f9bf8c33fe1b62f6dc0820598c3d96a
# 4a0ebb7ba942150b13511bbbcf62e76008187b76
# 515596176b5e34feb5b71c5d2be8e4de86861bfc
# d7417d249e69d9ac505a1f93f7544c49f5bc3889
# 125e946b1ca5ef38561490444d87bb766b7aa4da
# ff7253290120aaa51daf7b8c581a1ae3fc1b8f1c
# 12e6345f07bcf9af8e3058160312858ed9bd7867
# 378bd0eed3b6e78861d55da20fd7a642df507eba
# 1803c0f6b7d29b68a9d7385ffb846a93075b9e26
# 1439a23939c350fd6ab30c7f0c991e4a65a70eb8
# 8f7eccb8dff881cfc047bd7739e0980220e94641
# d2b1212efd6afd53ab9a250ea8dff09b2cddfdac
# 74e27d8e52cbf576feb82b91f44d1735ee11b1c8
# 858a5c1e1f5aadf3244229b3e2dd06494d794032
# eee0526156f7e5d39947378e5b860d0e61f9c9fe
# 92c0c054a1038678f9c7d04ea6b1625c871d31c1
# a8e5c6e4e1a3c1f838560a8b00929ece603fb527
# 626cd734a3a270a208dbb6d121b2c771fd9c1b7c
# 3082bc940ca8f3f927144dbaba22c6c0d611bbc3
# 4ee7941b2cecd0fc9e67657b3b44a694e2975cf1
# 806d72fca51e5681c81fb4fc062bb67b8baa01bc
# 7da7a69587aa3c9814154c4fc9c0230cbe45fc0b
# 0fd8f78f185d54eae6bec466850a7238aa0e05de
# 76930a1c2d3bfd8aa129279148e82431bd2476e8
# 4f7ab383947e8837841cdf5999040b2d7059541a
# 08ee1dea6ad4ef477f4a699621555df51bb54be2
# 94b75dd478e2f7e8cd80f0c5dd8ecb19d1649c8c
# 79ae0f33c6b4a8b46fcf1733e51d2ccd2d6600b2
# 38d078c79bc7bd7068363c2c4dd8134bc678c662
# 856eafe15628333d3c15d9e1bb7738febde5a10d
# 90cd50c46e4078a5efe02c86879ec764ee47368a
# 75baa010ea8b2daa6fa2c7a549b9a1727ea897a0
# 0c83e7e3c6ed28ca48bb66c75b053bc5dbfd79fc
# 3929dd8d2a6086b328472f30cc4b0c658f7ced75
# 2351d0f6100a8f062e697d575f962d0ef3961d65
# 7570f25fbecc40958c0a5a244a85d9921bb072d4
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/144" height="525" width="100%"></iframe>

# %%
lecture_to_num_start = []
lecture_to_num_finish = []
lecture_to_num_seek = []

for v in lecture_to_user_to_start_timestamps:
  lecture_to_num_start.append(sum([len(x) for x in v.values()]))

for v in lecture_to_user_to_finish_timestamps:
  lecture_to_num_finish.append(sum([len(x) for x in v.values()]))

for v in lecture_to_user_to_seek_timestamps:
  lecture_to_num_seek.append(sum([len(x) for x in v.values()]))

# %%
data = scatterlist(lecture_to_num_start)
layout = mklayout('view start events over time', 'lecture num', 'number of view start events')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/145" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_finish)
layout = mklayout('view finish events over time', 'lecture num', 'number of view finish events')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/146" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_seek)
layout = mklayout('seek events over time', 'lecture num', 'number of seek events')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/147" height="525" width="100%"></iframe>

# %%
lecture_to_finish_ratio = []

for numstart,numfinish in zip(lecture_to_num_start, lecture_to_num_finish):
  if numstart == 0:
    lecture_to_finish_ratio.append(0)
  else:
    lecture_to_finish_ratio.append(float(numfinish)/numstart)

data = scatterlist(lecture_to_finish_ratio)
layout = mklayout('lecture finish fraction over time', 'lecture num', 'fraction of students who finish viewing lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/148" height="525" width="100%"></iframe>

# %%
lecture_to_seek_ratio = []

for numstart,numseek in zip(lecture_to_num_start, lecture_to_num_seek):
  if numstart == 0:
    lecture_to_seek_ratio.append(0)
  else:
    lecture_to_seek_ratio.append(float(numseek)/numstart)

data = scatterlist(lecture_to_seek_ratio)
layout = mklayout('ratio of seek events to video starts over time', 'lecture num', 'ratio of seek events to number of video starts')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/149" height="525" width="100%"></iframe>

# %%
lecture_to_num_users_with_at_least_one_start = []
lecture_to_num_users_with_at_least_one_finish = []
lecture_to_num_users_with_at_least_one_seek = []

def nonzero(l):
  if len(l) > 0:
    return 1
  return 0

for v in lecture_to_user_to_start_timestamps:
  lecture_to_num_users_with_at_least_one_start.append(sum([nonzero(x) for x in v.values()]))

for v in lecture_to_user_to_finish_timestamps:
  lecture_to_num_users_with_at_least_one_finish.append(sum([nonzero(x) for x in v.values()]))

for v in lecture_to_user_to_seek_timestamps:
  lecture_to_num_users_with_at_least_one_seek.append(sum([nonzero(x) for x in v.values()]))

# %%
data = scatterlist(lecture_to_num_users_with_at_least_one_start)
layout = mklayout('number of users who started watching lecture over time', 'lecture num', 'number of users who started watching lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/150" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_users_with_at_least_one_finish)
layout = mklayout('number of users who finished watching lecture over time', 'lecture num', 'number of users who finished watching lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/151" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_users_with_at_least_one_seek)
layout = mklayout('number of users who seeked at least once in lecture over time', 'lecture num', 'number of users who seeked at least once in lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/152" height="525" width="100%"></iframe>

# %%
lecture_to_users_who_seeked_ratio = []

for numstart,numseek in zip(lecture_to_num_users_with_at_least_one_start, lecture_to_num_users_with_at_least_one_seek):
  if numstart == 0:
    lecture_to_users_who_seeked_ratio.append(0)
  else:
    lecture_to_users_who_seeked_ratio.append(float(numseek)/numstart)

data = scatterlist(lecture_to_users_who_seeked_ratio)
layout = mklayout('fraction of users who seeked at least once during the lecture, over time', 'lecture num', 'fraction of users who seeked at least once during the lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/153" height="525" width="100%"></iframe>

# %%
lecture_to_users_who_finished_ratio = []

for numstart,numseek in zip(lecture_to_num_users_with_at_least_one_start, lecture_to_num_users_with_at_least_one_finish):
  if numstart == 0:
    lecture_to_users_who_finished_ratio.append(0)
  else:
    lecture_to_users_who_finished_ratio.append(float(numseek)/numstart)

data = scatterlist(lecture_to_users_who_seeked_ratio)
layout = mklayout('fraction of users who finished watching the lecture, over time', 'lecture num', 'fraction of users who finished watching the lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/154" height="525" width="100%"></iframe>

# %%
num_seeks_to_users_single_lecture = [0]*51

for user,seek_times in lecture_to_user_to_seek_timestamps[30].iteritems():
  numseeks = len(seek_times)
  if numseeks >= len(num_seeks_to_users_single_lecture):
    num_seeks_to_users_single_lecture[len(num_seeks_to_users_single_lecture)-1] += 1
  else:
    num_seeks_to_users_single_lecture[numseeks] += 1

data = scatterlist(num_seeks_to_users_single_lecture)
layout = mklayout('histogram of users and seek times (in lecture 30)', 'number of times video seeked (in lecture 30)', 'number of users who seeked video this many times (in lecture 30)')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/155" height="525" width="100%"></iframe>

# %%
timepoint_to_num_seeks = []

for user,seek_times in lecture_to_user_to_seek_times[30].iteritems():
  for seek_time in seek_times:
    while seek_time >= len(timepoint_to_num_seeks) - 1:
      timepoint_to_num_seeks.append(0)
    timepoint_to_num_seeks[int(round(seek_time))] += 1

data = scatterlist(timepoint_to_num_seeks)
layout = mklayout('distribution of seeks over time (in lecture 30)', 'time in video (in lecture 30)', 'number of seeks that go to this destination')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/156" height="525" width="100%"></iframe>

# %%
num_seeks_to_users_all_lectures = [0]*101

for lecture in lecture_to_user_to_seek_timestamps:
  for user,seek_times in lecture.iteritems():
    numseeks = len(seek_times)
    if numseeks >= len(num_seeks_to_users_all_lectures):
      num_seeks_to_users_all_lectures[len(num_seeks_to_users_all_lectures)-1] += 1
    else:
      num_seeks_to_users_all_lectures[numseeks] += 1

data = scatterlist(num_seeks_to_users_all_lectures)
layout = mklayout('histogram of users and num seeks (over all lectures)', 'number of times video seeked (over all lectures)', 'number of users who seeked video this many times (over all lectures)')
iplot(data, layout)

# log-log version
#data = scatterlistloglog(num_seeks_to_users_all_lectures)
#layout = mklayout('histogram of users and num seeks (over all lectures)', 'number of times video seeked (over all lectures)', 'number of users who seeked video this many times (over all lectures)')
#iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/157" height="525" width="100%"></iframe>

# %%
def at_least_a_minute_apart(times):
  prevtime=-9999
  output = []
  for time in sorted(times):
    if abs(time - prevtime) > 60 * 1000:
      output.append(time)
      prevtime = time
  return output

def at_least_an_hour_apart(times):
  prevtime=-9999
  output = []
  for time in sorted(times):
    if abs(time - prevtime) > 3600 * 1000:
      output.append(time)
      prevtime = time
  return output

def at_least_a_day_apart(times):
  prevtime=-9999
  output = []
  for time in sorted(times):
    if abs(time - prevtime) > 24 * 3600 * 1000:
      output.append(time)
      prevtime = time
  return output

# %%
#newfig()

xaxis_length = 6

num_starts_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(start_times)
  if numstarts >= len(num_starts_to_users_single_lecture):
    num_starts_to_users_single_lecture[len(num_starts_to_users_single_lecture)-1] += 1
  else:
    num_starts_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_to_users_single_lecture, label='all watches')
addtrace(num_starts_to_users_single_lecture, label='all watches')

num_starts_minute_apart_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(at_least_a_minute_apart(start_times))
  if numstarts >= len(num_starts_minute_apart_to_users_single_lecture):
    num_starts_minute_apart_to_users_single_lecture[len(num_starts_minute_apart_to_users_single_lecture)-1] += 1
  else:
    num_starts_minute_apart_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_minute_apart_to_users_single_lecture, label='at least a minute apart')
addtrace(num_starts_minute_apart_to_users_single_lecture, label='at least a minute apart')

num_starts_hour_apart_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(at_least_an_hour_apart(start_times))
  if numstarts >= len(num_starts_hour_apart_to_users_single_lecture):
    num_starts_hour_apart_to_users_single_lecture[len(num_starts_hour_apart_to_users_single_lecture)-1] += 1
  else:
    num_starts_hour_apart_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_hour_apart_to_users_single_lecture, label='at least an hour apart')
addtrace(num_starts_hour_apart_to_users_single_lecture, label='at least an hour apart')

num_starts_day_apart_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(at_least_a_day_apart(start_times))
  if numstarts >= len(num_starts_day_apart_to_users_single_lecture):
    num_starts_day_apart_to_users_single_lecture[len(num_starts_day_apart_to_users_single_lecture)-1] += 1
  else:
    num_starts_day_apart_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_day_apart_to_users_single_lecture, label='at least a day apart')
addtrace(num_starts_day_apart_to_users_single_lecture, label='at least a day apart')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))

addxlabel('number of times started watching video (in lecture 30)')
addylabel('number of users who started watching video this many times (in lecture 30)')
addtitle('histogram of users and num starts (in lecture 30)')

#from matplotlylib import fig_to_plotly

#fig_to_plotly(gcf(), notebook=True)

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/158" height="525" width="100%"></iframe>

# %%
#newfig()

xaxis_length = 6

num_finishes_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(finish_times)
  if numfinishes >= len(num_finishes_to_users_single_lecture):
    num_finishes_to_users_single_lecture[len(num_finishes_to_users_single_lecture)-1] += 1
  else:
    num_finishes_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_to_users_single_lecture, label='all watches')

num_finishes_minute_apart_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(at_least_a_minute_apart(finish_times))
  if numfinishes >= len(num_finishes_minute_apart_to_users_single_lecture):
    num_finishes_minute_apart_to_users_single_lecture[len(num_finishes_minute_apart_to_users_single_lecture)-1] += 1
  else:
    num_finishes_minute_apart_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_minute_apart_to_users_single_lecture, label='at least a minute apart')

num_finishes_hour_apart_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(at_least_an_hour_apart(finish_times))
  if numfinishes >= len(num_finishes_hour_apart_to_users_single_lecture):
    num_finishes_hour_apart_to_users_single_lecture[len(num_finishes_hour_apart_to_users_single_lecture)-1] += 1
  else:
    num_finishes_hour_apart_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_hour_apart_to_users_single_lecture, label='at least an hour apart')

num_finishes_day_apart_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(at_least_a_day_apart(finish_times))
  if numfinishes >= len(num_finishes_day_apart_to_users_single_lecture):
    num_finishes_day_apart_to_users_single_lecture[len(num_finishes_day_apart_to_users_single_lecture)-1] += 1
  else:
    num_finishes_day_apart_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_day_apart_to_users_single_lecture, label='at least a day apart')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))

addxlabel('number of times finished watching video (in lecture 30)')
addylabel('number of users who finished watching video this many times (in lecture 30)')
addtitle('histogram of users and num finishes (in lecture 30)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/159" height="525" width="100%"></iframe>

# %%
#newfig()

xaxis_length = 6

watch_session_to_completions = [0]*xaxis_length
watch_session_to_seeks = [0]*xaxis_length
watch_session_to_at_least_one_seek = [0]*xaxis_length
watch_session_to_starts = [0]*xaxis_length

for lecturenum in range(len(lecture_to_user_to_start_timestamps)):
  for user,start_times in lecture_to_user_to_start_timestamps[lecturenum].iteritems():
    for watch_session_idx,start_time in enumerate(at_least_an_hour_apart(start_times)):
      finished_watching = False
      at_least_one_seek = False
      if user in lecture_to_user_to_finish_timestamps[lecturenum]:
        for end_time in lecture_to_user_to_finish_timestamps[lecturenum][user]:
          if start_time <= end_time <= start_time + 3600 * 1000:
            finished_watching = True
      num_seeks = 0
      if user in lecture_to_user_to_seek_timestamps[lecturenum]:
        for seek_time in lecture_to_user_to_seek_timestamps[lecturenum][user]:
          if start_time <= seek_time <= start_time + 3600 * 1000:
            num_seeks += 1
            at_least_one_seek = True
      if watch_session_idx >= xaxis_length:
        watch_session_idx = xaxis_length-1
      watch_session_to_starts[watch_session_idx] += 1
      if finished_watching:
        watch_session_to_completions[watch_session_idx] += 1
      if at_least_one_seek:
        watch_session_to_at_least_one_seek[watch_session_idx] += 1
      watch_session_to_seeks[watch_session_idx] += num_seeks

addtrace(watch_session_to_starts, label='watches started')
addtrace(watch_session_to_completions, label='watches finished')
addtrace(watch_session_to_at_least_one_seek, label='seeked at least once during session')
addtrace(watch_session_to_seeks, label='total number of seeks')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/160" height="525" width="100%"></iframe>

# %%
#newfig()

watch_session_to_completions_ratio = []
watch_session_to_seeks_ratio = []
watch_session_to_at_least_one_seek_ratio = []

for completions,starts in zip(watch_session_to_completions,watch_session_to_starts):
  if starts == 0:
    watch_session_to_completions_ratio.append(0)
  else:
    watch_session_to_completions_ratio.append(float(completions)/starts)

for seeks,starts in zip(watch_session_to_seeks,watch_session_to_starts):
  if starts == 0:
    watch_session_to_seeks_ratio.append(0)
  else:
    watch_session_to_seeks_ratio.append(float(seeks)/starts)

for at_least_one_seek,starts in zip(watch_session_to_at_least_one_seek,watch_session_to_starts):
  if starts == 0:
    watch_session_to_at_least_one_seek_ratio.append(0)
  else:
    watch_session_to_at_least_one_seek_ratio.append(float(at_least_one_seek)/starts)


addtrace(watch_session_to_completions_ratio, label='watches finished')
addtrace(watch_session_to_at_least_one_seek_ratio, label='seeked at least once during session')
#pylab.plot(watch_session_to_seeks_ratio, label='total number of seeks')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos, normalized by number of starts')

#pylab.ylim([0.0,1.0])

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/161" height="525" width="100%"></iframe>

# %%
print watch_session_to_completions
print watch_session_to_at_least_one_seek
# Out:
# [822156, 88207, 16566, 4139, 1239, 799]
# [488861, 137117, 33560, 9803, 3247, 2092]

# %%
#newfig()

addtrace(watch_session_to_completions_ratio, label='watches finished')
addtrace(watch_session_to_at_least_one_seek_ratio, label='seeked at least once during session')
addtrace(watch_session_to_seeks_ratio, label='total number of seeks')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos, normalized by number of starts')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/162" height="525" width="100%"></iframe>

# %%
xaxis_length = 6

watch_session_to_completions = [0]*xaxis_length
watch_session_to_completions_and_at_least_one_seek = [0]*xaxis_length
watch_session_to_starts = [0]*xaxis_length

for lecturenum in range(len(lecture_to_user_to_start_timestamps)):
  for user,start_times in lecture_to_user_to_start_timestamps[lecturenum].iteritems():
    for watch_session_idx,start_time in enumerate(at_least_an_hour_apart(start_times)):
      finished_watching = False
      at_least_one_seek = False
      if user in lecture_to_user_to_finish_timestamps[lecturenum]:
        for end_time in lecture_to_user_to_finish_timestamps[lecturenum][user]:
          if start_time <= end_time <= start_time + 3600 * 1000:
            finished_watching = True
      num_seeks = 0
      if user in lecture_to_user_to_seek_timestamps[lecturenum]:
        for seek_time in lecture_to_user_to_seek_timestamps[lecturenum][user]:
          if start_time <= seek_time <= start_time + 3600 * 1000:
            num_seeks += 1
            at_least_one_seek = True
      if watch_session_idx >= xaxis_length:
        watch_session_idx = xaxis_length-1
      watch_session_to_starts[watch_session_idx] += 1
      if finished_watching:
        watch_session_to_completions[watch_session_idx] += 1
        if at_least_one_seek:
          watch_session_to_completions_and_at_least_one_seek[watch_session_idx] += 1

addtrace(watch_session_to_completions, label='watches finished')
addtrace(watch_session_to_completions_and_at_least_one_seek, label='completed, and seeked at least once during session')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/163" height="525" width="100%"></iframe>

# %%
watch_session_to_completion_and_at_least_one_seek_ratio = []

for completed_and_seeked_at_least_once,completions in zip(watch_session_to_completions_and_at_least_one_seek,watch_session_to_completions):
  if completions == 0:
    watch_session_to_completion_and_at_least_one_seek_ratio.append(0)
  else:
    watch_session_to_completion_and_at_least_one_seek_ratio.append(float(completed_and_seeked_at_least_once)/completions)

addtrace(watch_session_to_completion_and_at_least_one_seek_ratio, label='fraction of people among those who completed who seeked at least once during the session')

#pylab.legend(bbox_to_anchor=(2.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos, normalized by number of starts')

#pylab.ylim([0.0,1.0])

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/164" height="525" width="100%"></iframe>

# %%
addtrace(num_starts_day_apart_to_users_single_lecture)
addxlabel('number of times started watching video (in lecture 30, at least a day apart)')
addylabel('number of users who started watching video this many times (in lecture 30, at least a day apart)')
addtitle('histogram of users and num starts (in lecture 30, at least a day apart)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/165" height="525" width="100%"></iframe>

# %%
num_finishes_to_users_single_lecture = [0]*11

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(finish_times)
  if numfinishes >= len(num_finishes_to_users_single_lecture):
    num_finishes_to_users_single_lecture[len(num_finishes_to_users_single_lecture)-1] += 1
  else:
    num_finishes_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_to_users_single_lecture)
addxlabel('number of times finished watching video (in lecture 30)')
addylabel('number of users who finished watching video this many times (in lecture 30)')
addtitle('histogram of users and num finishes (in lecture 30)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/166" height="525" width="100%"></iframe>

# %%
num_starts_to_users_all_lectures = [0]*11

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    numstarts = len(start_times)
    if numstarts >= len(num_starts_to_users_all_lectures):
      num_starts_to_users_all_lectures[len(num_starts_to_users_all_lectures)-1] += 1
    else:
      num_starts_to_users_all_lectures[numstarts] += 1

addtrace(num_starts_to_users_all_lectures)
addxlabel('number of times started watching video (all lectures)')
addylabel('number of users who started watching video this many times (all lectures)')
addtitle('histogram of users and num starts (all lectures)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/167" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

addtrace(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in hours')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/168" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

time_between_rewatches[0] = 0
      
addtrace(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in hours, excluding first hour')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/169" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600*24))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

#time_between_rewatches[0] = 0
      
addtrace(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in days')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/170" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600*24))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

time_between_rewatches[0] = 0
      
addtrace(time_between_rewatches)
addxlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in days, excluding first day')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/171" height="525" width="100%"></iframe>
