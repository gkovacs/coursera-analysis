# %%
import MySQLdb
import sqlite3
import json
import gzip
import os
import cPickle as pickle

from collections import Counter

# For autoreloading of modules (%autoreload, %aimport)    
import video_annotations
reload(video_annotations)
import video_annotations

from json import loads, dumps

from pandas import DataFrame
from pandas.io.sql import read_frame, write_frame

datastage_login = json.load(open('datastage_login.json'))

#database = MySQLdb.connect(host='datastage.stanford.edu', user=datastage_login['user'], passwd=datastage_login['passwd'])

# %%
import collections
import functools

class memoized(object):
   '''Decorator. Caches a function's return value each time it is called.
   If called later with the same arguments, the cached value is returned
   (not reevaluated).
   '''
   def __init__(self, func):
      self.func = func
      self.cache = {}
   def __call__(self, *args):
      if not isinstance(args, collections.Hashable):
         # uncacheable. a list, for instance.
         # better to not cache than blow up.
         return self.func(*args)
      if args in self.cache:
         return self.cache[args]
      else:
         value = self.func(*args)
         self.cache[args] = value
         return value
   def __repr__(self):
      '''Return the function's docstring.'''
      return self.func.__doc__
   def __get__(self, obj, objtype):
      '''Support instance methods.'''
      return functools.partial(self.__call__, obj)

# %%
databases = {}

#databasename = 'ml-004_clickstream_video.sqlite'
databasename = 'ml-004_clickstream_video.sqlite'
#databasename = 'crypto-009_clickstream_video_sqlite'
tablename = 'videos'

def listVideosReal(dbname):
  output_set = set()
  output = []
  for lecture_id in listDistinct('lecture_id'):
    if lecture_id not in output_set:
      output_set.add(lecture_id)
      output.append(lecture_id)
  return sorted(output)

@memoized
def listVideosJsonMemoized(dbname):
  jsonfile = dbname + '_videolist.pickle'
  if not os.path.exists(jsonfile):
    pickle.dump(listVideosReal(dbname), open(jsonfile, 'w'))
  return pickle.load(open(jsonfile))

def listVideos():
  return listVideosJsonMemoized(getDatabaseName())

def getTableName():
  return tablename

def getDatabaseName():
  return databasename

def getDatabasePath():
  return '/lfs/local/0/geza/' + databasename

def getDatabaseNameForLectureNum(lectureid):
  return getDatabaseName().replace('.sqlite', '_lecture-' + str(lectureid) + '.sqlite')

def getDatabasePathForLectureNum(lectureid):
  return getDatabasePath().replace('.sqlite', '_lecture-' + str(lectureid) + '.sqlite')

def getDatabaseNameForLectureNumAndUser(lectureid, userid):
  return getDatabaseName().replace('.sqlite', '_lecture-' + str(lectureid) + '_user-' + str(userid) + '.sqlite')

def getDatabasePathForLectureNumAndUser(lectureid, userid):
  return getDatabasePath().replace('.sqlite', '_lecture-' + str(lectureid) + '_user-' + str(userid) + '.sqlite')

def getColumns():
  return list(read_frame("select * from " + getTableName() + " limit 1", getDatabase()).columns.values)

def getDatabase():
  if databasename not in databases and 'sqlite' in databasename:
    databases[databasename] = sqlite3.connect('/lfs/local/0/geza/' + databasename)
  elif databasename not in databases:
    MySQLdb.connect(host='datastage.stanford.edu', user=datastage_login['user'], passwd=datastage_login['passwd'], db=databasename)
  return databases[databasename]

def getDatabaseForLectureNum(lectureid):
  if 'sqlite' not in databasename:
    raise Exception('can only use getDatabaseForLectureNum feature on sqlite databases')
  real_database_name = getDatabasePathForLectureNum(lectureid)
  if real_database_name not in databases:
    databases[real_database_name] = sqlite3.connect(real_database_name)
  return databases[real_database_name]

def getDatabaseForLectureNumAndUser(lectureid, userid):
  if 'sqlite' not in databasename:
    raise Exception('can only use getDatabaseForLectureNumAndUser feature on sqlite databases')
  real_database_name = getDatabasePathForLectureNumAndUser(lectureid, userid)
  if real_database_name not in databases:
    databases[real_database_name] = sqlite3.connect(real_database_name)
  return databases[real_database_name]

def listDistinctForDatabase(fieldname, database_instance, extraquery=''):
  data = read_frame("select distinct " + fieldname + " from " + getTableName() + " " + extraquery, database_instance)
  return [x[0] for x in data[[fieldname]].itertuples(index=False)]

def listDistinct(fieldname, extraquery=''):
  return listDistinctForDatabase(fieldname, getDatabase(), extraquery)

def listDistinctForLecture(fieldname, lectureid, extraquery=''):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return listDistinctForDatabase(fieldname, getDatabaseForLectureNum(lectureid), extraquery)

def listFieldsForDatabase(fieldnames, database_instance, extraquery=''):
  fieldnameString = ','.join(fieldnames)
  data = read_frame("select " + fieldnameString + " from " + getTableName() + " " + extraquery, database_instance)
  return data.itertuples(index=False)

def listFields(fieldnames, extraquery=''):
  return listFieldsForDatabase(fieldnames, getDatabase(), extraquery)

def cacheLecture(lectureid):
  if os.path.exists(getDatabasePathForLectureNum(lectureid)):
    return
  print 'caching lecture:', lectureid
  data = read_frame('select * from ' + getTableName() + ' where lecture_id=' + str(lectureid), getDatabase())
  write_frame(data, getTableName(), getDatabaseForLectureNum(lectureid))

def listFieldsForLecture(fieldnames, lectureid, extraquery=''):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return listFieldsForDatabase(fieldnames, getDatabaseForLectureNum(lectureid), extraquery)

@memoized
def getFrameForLectureReal(dbmame, lectureid):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return read_frame('select * from ' + getTableName(), getDatabaseForLectureNum(lectureid))

def getFrameForLecture(lectureid):
  return getFrameForLectureReal(getDatabaseName(), lectureid)

@memoized
def getUserToEventsForLectureReal(dbname, lectureid):
  lecture_frame = getFrameForLectureReal(dbname, lectureid)
  return frameToDictByKey(lecture_frame, 'anon_username')

def getFrameForLectureUser(lectureid, userid):
  user_to_events = getUserToEventsForLectureReal(getDatabaseName(), lectureid)
  if userid in user_to_events:
    return user_to_events[userid]
  else:
    return None

def frameToDictByKey(frame, key):
  output = {}
  for k,grouped_frame in frame.groupby(key):
    output[k] = grouped_frame
  return output

#def cacheLectureUser(lectureid, userid):
#  #if os.path.exists(getDatabasePathForLectureNumAndUser(lectureid, userid)):
#  #  return
#  print 'caching lecture and user id:', lectureid, userid
#  #data = read_frame('select * from ' + getTableName() + ' where lecture_id=' + str(lectureid) + ' and anon_username="' + str(userid) + '"', getDatabaseForLectureNum(lectureid))
#  #frame = getFrameForLecture(lectureid)
#  #data = frame[frame.anon_username == userid]
#  data = getFrameForLectureAndUser(lectureid, userid)
#  #write_frame(data, getTableName(), getDatabaseForLectureNumAndUser(lectureid, userid))

# %%
def getLectureEndTime(lectureid):
  pause_to_counts = {}
  lecture_end_time = 0
  for event_type,curr_time in listFieldsForLecture(['event_type', 'curr_time'], lectureid, 'where event_type="pause"'):
    if curr_time > 3600: # there are no lectures more than an hour long, if have such a result is bugggy data
      continue
    if curr_time not in pause_to_counts:
      pause_to_counts[curr_time] = 1
    else:
      pause_to_counts[curr_time] += 1
    if pause_to_counts[curr_time] >= 10:
      lecture_end_time = max(curr_time, lecture_end_time)
  return lecture_end_time

def getLectureEndTimesReal(dbname):
  output = {}
  for lectureid in listVideos():
    output[lectureid] = getLectureEndTime(lectureid)
  return output

@memoized
def getLectureEndTimesJsonMemoized(dbname):
  jsonfile = dbname + '_videoendtimes.pickle'
  if not os.path.exists(jsonfile):
    pickle.dump(getLectureEndTimesReal(dbname), open(jsonfile, 'w'))
  return pickle.load(open(jsonfile))

def getLectureEndTimes():
  return getLectureEndTimesJsonMemoized(getDatabaseName())

# %%
def getUsersWhoWatchedLecture(lectureid):
  return listDistinctForLecture('anon_username', lectureid)

def getLecturesToViewersReal(dbname):
  output = {}
  for lectureid in listVideos():
    output[lectureid] = getUsersWhoWatchedLecture(lectureid)
  return output

@memoized
def getLecturesToViewersJsonMemoized(dbname):
  jsonfile = dbname + '_lecturestoviewers.pickle'
  if not os.path.exists(jsonfile):
    pickle.dump(getLecturesToViewersReal(dbname), open(jsonfile, 'w'))
  return pickle.load(open(jsonfile))

def getLecturesToViewers():
  return getLecturesToViewersJsonMemoized(getDatabaseName())

def getViewersToLecturesReal(dbname):
  output = {}
  for lectureid,users in getLecturesToViewers().iteritems():
    for user in users:
      if user not in output:
        output[user] = []
      else:
        output[user].append(lectureid)
  return output

@memoized
def getViewersToLecturesJsonMemoized(dbname):
  jsonfile = dbname + '_viewerstolectures.pickle'
  if not os.path.exists(jsonfile):
    pickle.dump(getViewersToLecturesReal(dbname), open(jsonfile, 'w'))
  return pickle.load(open(jsonfile))

def getViewersToLectures():
  return getViewersToLecturesJsonMemoized(getDatabaseName())

@memoized
def getViewersWhoWatchedMostLecturesReal(dbname):
  output = []
  numlectures = len(listVideos())
  for user,lectures_watched in getViewersToLectures().iteritems():
    if len(lectures_watched) >= numlectures/2:
      output.append(user)
  return output

def getViewersWhoWatchedMostLectures():
  return getViewersWhoWatchedMostLecturesReal(getDatabaseName())

@memoized
def getViewersWhoWatchedMostLecturesSetReal(dbname):
  return frozenset(getViewersWhoWatchedMostLecturesReal(dbname))

def getViewersWhoWatchedMostLecturesSet():
  return getViewersWhoWatchedMostLecturesSetReal(getDatabaseName())

print len(getViewersToLectures().keys())
print len(getViewersWhoWatchedMostLectures())
# Out:
# 59641
# 8935

# %%
#for lectureid in listVideos():
#  print lectureid
#  cacheLecture(lectureid)

print len(getViewersToLectures().keys())
print len(getViewersWhoWatchedMostLectures())
# Out:
# 59641
# 8935

# %%
class SeekEvent:
  def __init__(self, timestamp, start, end, paused):
    self.timestamp = timestamp
    self.start = start
    self.end = end
    self.event_type = 'seeked'
    self.paused = bool(paused)
    if self.end >= self.start:
      self.direction = 'forward'
    else:
      self.direction = 'back'
  def __str__(self):
    return dumps(self.__dict__)
  def __repr__(self):
    return str(self)

class SeekChain:
  def __init__(self, seek_events):
    assert len(seek_events) > 0
    self.seek_events = seek_events
    self.start = seek_events[0].start
    self.end = seek_events[-1].end
    self.event_type = 'seek_chain'
    if self.end >= self.start:
      self.direction = 'forward'
    else:
      self.direction = 'back'
    self.timestamp = seek_events[0].timestamp
    self.timestamp_end = seek_events[-1].timestamp
  def __str__(self):
    output = self.__dict__
    output['seek_events'] = [x.__dict__ for x in output['seek_events']]
    return dumps(output)
  def __repr__(self):
    return str(self)

class PlayEvent:
  def __init__(self, timestamp, start, playback_rate):
    self.timestamp = timestamp
    self.start = start
    self.playback_rate = playback_rate
    self.event_type = 'play'

class PlaySpan:
  def __init__(self, timestamp, timestamp_end, start, end, playback_rate):
    self.timestamp = timestamp
    self.timestamp_end = timestamp_end
    self.start = start
    self.end = end
    self.playback_rate = playback_rate
    self.event_type = 'play_span'
    if self.timestamp == None:
      raise DataException('PlaySpan timestamp cannot be None')
    if self.timestamp_end == None:
      raise DataException('PlaySpan timestamp_end cannot be None')
    if self.start == None:
      raise DataException('PlaySpan start cannot be None')
    if self.end == None:
      raise DataException('PlaySpan end cannot be None')
    if self.playback_rate == None:
      raise DataException('PlaySpan playback_rate cannot be None')

class PauseEvent:
  def __init__(self, timestamp, start):
    self.timestamp = timestamp
    self.start = start
    self.event_type = 'pause'

class RateChangeEvent:
  def __init__(self, timestamp, start, playback_rate, paused):
    self.timestamp = timestamp
    self.start = start
    self.playback_rate = playback_rate
    self.event_type = 'ratechange'
    self.paused = bool(paused)

from math import isnan

num_data_exceptions = 0
    
def getNumDataExceptions():
  return num_data_exceptions

def resetNumDataExceptions():
  global num_data_exceptions
  num_data_exceptions = 0

class DataException(Exception):
  def __init__(self, message):
    # Call the base class constructor with the parameters it needs
    global num_data_exceptions
    num_data_exceptions += 1
    Exception.__init__(self, message)

def extractAllEvents(frame):
  output = []
  prev_timestamp = None
  prev_curr_time = None
  playback_rate = 1.0
  paused = 0
  for index,row in frame.iterrows():
    if prev_timestamp != None:
      assert row['event_timestamp'] >= prev_timestamp # needs to be sorted
    if row['event_type'] == 'play':
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      if not isnan(row['playback_rate']) and 0.75 <= row['playback_rate'] <= 2.0:
        playback_rate = row['playback_rate']
      #paused = row['paused']
      #assert paused == 0
      paused = 0
      output.append(PlayEvent(row['event_timestamp'], row['curr_time'], playback_rate))
    if row['event_type'] == 'ratechange':
      playback_rate = row['playback_rate']
      if isnan(playback_rate) or not 0.75 <= playback_rate <= 2.0:
        raise DataException('incorrect playback rate - ' + str(playback_rate))
      #assert not isnan(playback_rate) and 0.75 <= playback_rate <= 2.0, 'playback_rate is ' + str(playback_rate)
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      #paused = row['paused']
      #assert not isnan(paused)
      output.append(RateChangeEvent(row['event_timestamp'], row['curr_time'], playback_rate, paused))
    if row['event_type'] == 'pause':
      #paused = row['paused']
      #assert paused == 1, 'expected paused to be 1, is actually ' + str(paused)
      paused = 1
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      if not isnan(row['playback_rate']) and 0.75 <= row['playback_rate'] <= 2.0:
        playback_rate = row['playback_rate']
      output.append(PauseEvent(row['event_timestamp'], row['curr_time']))
    if row['event_type'] == 'seeked':
      #assert prev_timestamp != None
      if prev_timestamp == None:
        raise DataException('prev_timestamp is None - did not have start event prior to seeked')
      #if prev_timestamp == None: # did not have any start event for user, cannot determine where the seek started! discard it.
      #  prev_timestamp = row['event_timestamp']
      #  prev_curr_time = row['curr_time']
      #  continue
      seek_source = prev_curr_time
      if paused == 0:
        time_since_last_event_milliseconds = row['event_timestamp'] - prev_timestamp
        time_since_last_event_seconds = time_since_last_event_milliseconds / 1000.0
        seconds_video_played_since_last_event = time_since_last_event_seconds * playback_rate
        assert seconds_video_played_since_last_event >= 0, 'time since last event is ' + str(time_since_last_event_seconds) + ' playback rate is ' + str(playback_rate)
        seek_source = prev_curr_time + seconds_video_played_since_last_event
      seekEvent = SeekEvent(row['event_timestamp'], seek_source, row['curr_time'], paused)
      output.append(seekEvent)
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      #paused = row['paused']
      #assert not isnan(paused)
  return output

def extractSeekEvents(frame):
  output = []
  prev_timestamp = None
  prev_curr_time = None
  playback_rate = 1.0
  paused = True
  for index,row in frame.iterrows():
    if prev_timestamp != None:
      assert row['event_timestamp'] >= prev_timestamp # needs to be sorted
    if row['event_type'] == 'play':
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      if not isnan(row['playback_rate']) and 0.75 <= row['playback_rate'] <= 2.0:
        playback_rate = row['playback_rate']
      #paused = row['paused']
      #assert paused == 0
      paused = False
    if row['event_type'] == 'ratechange':
      playback_rate = row['playback_rate']
      if isnan(playback_rate) or not 0.75 <= playback_rate <= 2.0:
        raise DataException('incorrect playback rate - ' + str(playback_rate))
      #assert not isnan(playback_rate) and 0.75 <= playback_rate <= 2.0, 'playback_rate is ' + str(playback_rate)
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      #paused = row['paused']
      #assert not isnan(paused)
    if row['event_type'] == 'pause':
      #paused = row['paused']
      #assert paused == 1, 'expected paused to be 1, is actually ' + str(paused)
      paused = True
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      if not isnan(row['playback_rate']) and 0.75 <= row['playback_rate'] <= 2.0:
        playback_rate = row['playback_rate']
    if row['event_type'] == 'seeked':
      #assert prev_timestamp != None
      if prev_timestamp == None:
        raise DataException('prev_timestamp is None - did not have start event prior to seeked')
      #if prev_timestamp == None: # did not have any start event for user, cannot determine where the seek started! discard it.
      #  prev_timestamp = row['event_timestamp']
      #  prev_curr_time = row['curr_time']
      #  continue
      seek_source = prev_curr_time
      if paused == 0:
        time_since_last_event_milliseconds = row['event_timestamp'] - prev_timestamp
        time_since_last_event_seconds = time_since_last_event_milliseconds / 1000.0
        seconds_video_played_since_last_event = time_since_last_event_seconds * playback_rate
        assert seconds_video_played_since_last_event >= 0, 'time since last event is ' + str(time_since_last_event_seconds) + ' playback rate is ' + str(playback_rate)
        seek_source = prev_curr_time + seconds_video_played_since_last_event
      seekEvent = SeekEvent(row['event_timestamp'], seek_source, row['curr_time'], paused)
      output.append(seekEvent)
      prev_timestamp = row['event_timestamp']
      prev_curr_time = row['curr_time']
      #paused = row['paused']
      #assert not isnan(paused)
  return output

def groupEventsAsPlaySpans(all_events):
  output = []
  playback_rate = 1.0
  play_start = None
  play_start_timestamp = None
  paused = True
  for event in all_events:
    if event.event_type == 'play':
      paused = False
      play_start = event.start
      play_start_timestamp = event.timestamp
      playback_rate = event.playback_rate
    elif event.event_type == 'pause':
      if not paused:
        playSpan = PlaySpan(play_start_timestamp, event.timestamp, play_start, event.start, playback_rate)
        output.append(playSpan)
      play_start = None
      play_start_timestamp = None
      paused = True
    elif event.event_type == 'seeked':
      if not paused:
        playSpan = PlaySpan(play_start_timestamp, event.timestamp, play_start, event.start, playback_rate)
        output.append(playSpan)
      #paused = event.paused
      if not paused:
        play_start = event.end
        play_start_timestamp = event.timestamp
    elif event.event_type == 'ratechange':
      if not paused:
        playSpan = PlaySpan(play_start_timestamp, event.timestamp, play_start, event.start, playback_rate)
        output.append(playSpan)
      playback_rate = event.playback_rate
      #paused = event.paused
    else:
      assert False, 'unexpected event type in groupEventsAsPlaySpans: ' + event.event_type
  return output

def groupSeekEventsAsSeekChains(seek_events):
  output = []
  prev_seek_timestamp = None
  current_seek_chain = []
  for seek_event in seek_events:
    if prev_seek_timestamp == None:
      prev_seek_timestamp = seek_event.timestamp
      current_seek_chain.append(seek_event)
    else:
      if seek_event.timestamp - prev_seek_timestamp > 5000: # has been at least 5 seconds since last seek, create new seek chain
        if len(current_seek_chain) > 0:
          output.append(SeekChain(current_seek_chain))
          current_seek_chain = []
        current_seek_chain.append(seek_event)
        prev_seek_timestamp = seek_event.timestamp
      else: # existing seek chain
        current_seek_chain.append(seek_event)
        prev_seek_timestamp = seek_event.timestamp
  if len(current_seek_chain) > 0:
    output.append(SeekChain(current_seek_chain))
    current_seek_chain = []
  return output

#frame = getFrameForLectureUser(1, 'abcea9860ecfb2fef5140bc9e504f529ed33eb39')
#print frame.sort('event_timestamp')
#print frame
idx = 0
for user in getViewersToLectures().keys():
  frame = getFrameForLectureUser(1, user)
  if type(frame) == type(None):
    continue
  if frame.empty:
    continue
  if frame.index == None:
    continue
  if len(frame.index) <= 2:
    continue
  frame = frame.sort('event_timestamp')
  seek_events = extractSeekEvents(frame)
  print groupSeekEventsAsSeekChains(seek_events)
  idx += 1
  if idx > 100:
    break
# Out:
# [{"direction": "forward", "end": 176.020546, "event_type": "seek_chain", "timestamp": 1381891146002, "start": 115.90214499999999, "seek_events": [{"direction": "forward", "end": 132.805921, "event_type": "seeked", "timestamp": 1381891146002, "paused": false, "start": 115.90214499999999}, {"direction": "forward", "end": 176.020546, "event_type": "seeked", "timestamp": 1381891148735, "paused": false, "start": 136.90542100000002}], "timestamp_end": 1381891148735}]
# []
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1381764030444, "start": 12.168, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381764030444, "paused": false, "start": 12.168}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381764030518, "paused": false, "start": 0.074}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381764030587, "paused": false, "start": 0.069}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381764030662, "paused": false, "start": 0.075}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381764030737, "paused": false, "start": 0.075}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381764033748, "paused": false, "start": 3.011}, {"direction": "forward", "end": 15.810229, "event_type": "seeked", "timestamp": 1381764033813, "paused": false, "start": 0.065}, {"direction": "back", "end": 15.810229, "event_type": "seeked", "timestamp": 1381764033814, "paused": false, "start": 15.811228999999999}, {"direction": "forward", "end": 21.607313, "event_type": "seeked", "timestamp": 1381764033823, "paused": false, "start": 15.819229}, {"direction": "forward", "end": 26.350381, "event_type": "seeked", "timestamp": 1381764033836, "paused": false, "start": 21.620313000000003}, {"direction": "forward", "end": 28.985419, "event_type": "seeked", "timestamp": 1381764033848, "paused": false, "start": 26.362381}, {"direction": "forward", "end": 31.620457, "event_type": "seeked", "timestamp": 1381764033861, "paused": false, "start": 28.998419000000002}, {"direction": "forward", "end": 34.255496, "event_type": "seeked", "timestamp": 1381764033874, "paused": false, "start": 31.633457}, {"direction": "forward", "end": 36.363526, "event_type": "seeked", "timestamp": 1381764033886, "paused": false, "start": 34.267496}, {"direction": "forward", "end": 38.471557, "event_type": "seeked", "timestamp": 1381764033899, "paused": false, "start": 36.376526}, {"direction": "forward", "end": 39.525572, "event_type": "seeked", "timestamp": 1381764033911, "paused": false, "start": 38.483557}, {"direction": "forward", "end": 42.16061, "event_type": "seeked", "timestamp": 1381764033924, "paused": false, "start": 39.538571999999995}, {"direction": "forward", "end": 45.849663, "event_type": "seeked", "timestamp": 1381764033936, "paused": false, "start": 42.17261}, {"direction": "back", "end": 15.810229, "event_type": "seeked", "timestamp": 1381764034396, "paused": false, "start": 46.309663}, {"direction": "back", "end": 15.810229, "event_type": "seeked", "timestamp": 1381764034397, "paused": false, "start": 15.811228999999999}, {"direction": "forward", "end": 45.849663, "event_type": "seeked", "timestamp": 1381764034502, "paused": false, "start": 15.915229}, {"direction": "back", "end": 45.849663, "event_type": "seeked", "timestamp": 1381764034503, "paused": false, "start": 45.850663}, {"direction": "back", "end": 45.849663, "event_type": "seeked", "timestamp": 1381764034504, "paused": false, "start": 45.850663}, {"direction": "back", "end": 45.849663, "event_type": "seeked", "timestamp": 1381764034505, "paused": false, "start": 45.850663}, {"direction": "back", "end": 45.849663, "event_type": "seeked", "timestamp": 1381764034626, "paused": false, "start": 45.970663}, {"direction": "back", "end": 45.849663, "event_type": "seeked", "timestamp": 1381764034627, "paused": false, "start": 45.850663}, {"direction": "back", "end": 44.795648, "event_type": "seeked", "timestamp": 1381764035739, "paused": false, "start": 46.961663}, {"direction": "back", "end": 44.795648, "event_type": "seeked", "timestamp": 1381764035740, "paused": false, "start": 44.796648}, {"direction": "back", "end": 44.795648, "event_type": "seeked", "timestamp": 1381764035741, "paused": false, "start": 44.796648}, {"direction": "back", "end": 44.795648, "event_type": "seeked", "timestamp": 1381764035750 ...
# []
# []
# []
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1382618353233, "start": 0.348, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1382618353233, "paused": false, "start": 0.348}], "timestamp_end": 1382618353233}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1382618779575, "start": 0.086, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1382618779575, "paused": false, "start": 0.086}], "timestamp_end": 1382618779575}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1382619203109, "start": 0.128, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1382619203109, "paused": false, "start": 0.128}], "timestamp_end": 1382619203109}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1382619640397, "start": 0.103, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1382619640397, "paused": false, "start": 0.103}], "timestamp_end": 1382619640397}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1382620062254, "start": 0.101, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1382620062254, "paused": false, "start": 0.101}], "timestamp_end": 1382620062254}]
# []
# [{"direction": "forward", "end": 397.52700000000004, "event_type": "seek_chain", "timestamp": 1381770175084, "start": 397.3302160101652, "seek_events": [{"direction": "forward", "end": 397.52700000000004, "event_type": "seeked", "timestamp": 1381770175084, "paused": true, "start": 397.3302160101652}], "timestamp_end": 1381770175084}, {"direction": "back", "end": 189.139003811, "event_type": "seek_chain", "timestamp": 1381770649046, "start": 196.92700000000002, "seek_events": [{"direction": "back", "end": 189.139003811, "event_type": "seeked", "timestamp": 1381770649046, "paused": true, "start": 196.92700000000002}], "timestamp_end": 1381770649046}, {"direction": "back", "end": 178.811916137, "event_type": "seek_chain", "timestamp": 1381770682895, "start": 212.632003811, "seek_events": [{"direction": "back", "end": 178.811916137, "event_type": "seeked", "timestamp": 1381770682895, "paused": false, "start": 212.632003811}], "timestamp_end": 1381770682895}, {"direction": "back", "end": 191.34470648, "event_type": "seek_chain", "timestamp": 1381770703967, "start": 196.834, "seek_events": [{"direction": "back", "end": 191.896132147, "event_type": "seeked", "timestamp": 1381770703967, "paused": true, "start": 196.834}, {"direction": "back", "end": 191.34470648, "event_type": "seeked", "timestamp": 1381770704275, "paused": true, "start": 191.896132147}], "timestamp_end": 1381770704275}, {"direction": "back", "end": 188.20615247700002, "event_type": "seek_chain", "timestamp": 1381770743649, "start": 219.42270648000002, "seek_events": [{"direction": "back", "end": 188.20615247700002, "event_type": "seeked", "timestamp": 1381770743649, "paused": false, "start": 219.42270648000002}], "timestamp_end": 1381770743649}]
# [{"direction": "forward", "end": 12.648183, "event_type": "seek_chain", "timestamp": 1381859175905, "start": 0.0, "seek_events": [{"direction": "forward", "end": 12.648183, "event_type": "seeked", "timestamp": 1381859175905, "paused": true, "start": 0.0}], "timestamp_end": 1381859175905}]
# []
# [{"direction": "back", "end": 168.115432, "event_type": "seek_chain", "timestamp": 1383487791255, "start": 195.100731, "seek_events": [{"direction": "back", "end": 182.871645, "event_type": "seeked", "timestamp": 1383487791255, "paused": false, "start": 195.100731}, {"direction": "back", "end": 168.115432, "event_type": "seeked", "timestamp": 1383487792984, "paused": false, "start": 184.60064500000001}], "timestamp_end": 1383487792984}]
# []
# [{"direction": "forward", "end": 391.039657, "event_type": "seek_chain", "timestamp": 1387310719618, "start": 3.5324999999999998, "seek_events": [{"direction": "forward", "end": 37.944549, "event_type": "seeked", "timestamp": 1387310719618, "paused": false, "start": 3.5324999999999998}, {"direction": "forward", "end": 69.565006, "event_type": "seeked", "timestamp": 1387310721584, "paused": false, "start": 40.893549}, {"direction": "forward", "end": 131.751906, "event_type": "seeked", "timestamp": 1387310723175, "paused": false, "start": 71.951506}, {"direction": "forward", "end": 188.668729, "event_type": "seeked", "timestamp": 1387310725749, "paused": false, "start": 135.61290599999998}, {"direction": "forward", "end": 231.356347, "event_type": "seeked", "timestamp": 1387310727824, "paused": false, "start": 191.78122900000002}, {"direction": "forward", "end": 260.868774, "event_type": "seeked", "timestamp": 1387310730819, "paused": false, "start": 235.848847}, {"direction": "forward", "end": 313.042529, "event_type": "seeked", "timestamp": 1387310731771, "paused": false, "start": 262.29677399999997}, {"direction": "forward", "end": 348.879047, "event_type": "seeked", "timestamp": 1387310733549, "paused": false, "start": 315.709529}, {"direction": "forward", "end": 391.039657, "event_type": "seeked", "timestamp": 1387310733986, "paused": false, "start": 349.53454700000003}], "timestamp_end": 1387310733986}]
# []
# []
# []
# []
# [{"direction": "back", "end": 32.14475222363406, "event_type": "seek_chain", "timestamp": 1381913159814, "start": 122.983081, "seek_events": [{"direction": "back", "end": 32.14475222363406, "event_type": "seeked", "timestamp": 1381913159814, "paused": false, "start": 122.983081}], "timestamp_end": 1381913159814}, {"direction": "back", "end": 365.18546378653116, "event_type": "seek_chain", "timestamp": 1381913535815, "start": 408.145752223634, "seek_events": [{"direction": "back", "end": 365.18546378653116, "event_type": "seeked", "timestamp": 1381913535815, "paused": false, "start": 408.145752223634}], "timestamp_end": 1381913535815}]
# [{"direction": "forward", "end": 274.043964, "event_type": "seek_chain", "timestamp": 1382691079523, "start": 66.574, "seek_events": [{"direction": "forward", "end": 113.306639, "event_type": "seeked", "timestamp": 1382691079523, "paused": false, "start": 66.574}, {"direction": "forward", "end": 163.372363, "event_type": "seeked", "timestamp": 1382691083397, "paused": false, "start": 117.180639}, {"direction": "forward", "end": 186.033691, "event_type": "seeked", "timestamp": 1382691085103, "paused": false, "start": 165.078363}, {"direction": "forward", "end": 218.708164, "event_type": "seeked", "timestamp": 1382691088143, "paused": false, "start": 189.073691}, {"direction": "forward", "end": 233.464377, "event_type": "seeked", "timestamp": 1382691089306, "paused": false, "start": 219.87116400000002}, {"direction": "forward", "end": 255.07169, "event_type": "seeked", "timestamp": 1382691090361, "paused": false, "start": 234.51937700000002}, {"direction": "forward", "end": 274.043964, "event_type": "seeked", "timestamp": 1382691091470, "paused": false, "start": 256.18068999999997}], "timestamp_end": 1382691091470}]
# []
# []
# []
# []
# [{"direction": "forward", "end": 68.14973449707031, "event_type": "seek_chain", "timestamp": 1381811234442, "start": 11.173, "seek_events": [{"direction": "forward", "end": 31.41276741027832, "event_type": "seeked", "timestamp": 1381811234442, "paused": false, "start": 11.173}, {"direction": "back", "end": 30.880346298217773, "event_type": "seeked", "timestamp": 1381811234547, "paused": false, "start": 31.51776741027832}, {"direction": "back", "end": 30.880346298217773, "event_type": "seeked", "timestamp": 1381811234552, "paused": false, "start": 30.885346298217772}, {"direction": "forward", "end": 43.12600326538086, "event_type": "seeked", "timestamp": 1381811235979, "paused": false, "start": 32.30734629821777}, {"direction": "forward", "end": 59.098594665527344, "event_type": "seeked", "timestamp": 1381811237491, "paused": false, "start": 44.63800326538086}, {"direction": "forward", "end": 68.14973449707031, "event_type": "seeked", "timestamp": 1381811238589, "paused": false, "start": 60.19659466552734}], "timestamp_end": 1381811238589}, {"direction": "back", "end": 21.82921028137207, "event_type": "seek_chain", "timestamp": 1381811250507, "start": 80.06773449707032, "seek_events": [{"direction": "back", "end": 21.82921028137207, "event_type": "seeked", "timestamp": 1381811250507, "paused": false, "start": 80.06773449707032}], "timestamp_end": 1381811250507}, {"direction": "forward", "end": 139.49398803710938, "event_type": "seek_chain", "timestamp": 1381811346487, "start": 2.56, "seek_events": [{"direction": "forward", "end": 31.41276741027832, "event_type": "seeked", "timestamp": 1381811346487, "paused": false, "start": 2.56}, {"direction": "forward", "end": 46.85293960571289, "event_type": "seeked", "timestamp": 1381811347730, "paused": false, "start": 32.65576741027832}, {"direction": "forward", "end": 70.81182861328125, "event_type": "seeked", "timestamp": 1381811348587, "paused": false, "start": 47.70993960571289}, {"direction": "forward", "end": 80.3953857421875, "event_type": "seeked", "timestamp": 1381811349494, "paused": false, "start": 71.71882861328125}, {"direction": "forward", "end": 99.56249237060547, "event_type": "seeked", "timestamp": 1381811349882, "paused": false, "start": 80.7833857421875}, {"direction": "forward", "end": 118.72960662841797, "event_type": "seeked", "timestamp": 1381811350843, "paused": false, "start": 100.52349237060547}, {"direction": "forward", "end": 132.57252502441406, "event_type": "seeked", "timestamp": 1381811351449, "paused": false, "start": 119.33560662841796}, {"direction": "forward", "end": 139.49398803710938, "event_type": "seeked", "timestamp": 1381811352313, "paused": false, "start": 133.43652502441407}], "timestamp_end": 1381811352313}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1381844051766, "start": 67.8, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381844051766, "paused": false, "start": 67.8}], "timestamp_end": 1381844051766}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1381844140996, "start": 54.8313875579834, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381844140996, "paused": false, "start": 54.8313875579834}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381844141786, "paused": false, "start": 0.79}], "timestamp_end": 1381844141786}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1381844248649, "start": 106.863, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381844248649, "paused": false, "start": 106.863}], "timestamp_end": 1381844248649}, {"direction": "forward", "end": 33.01002502441406, "event_type": "seek_chain", "timestamp": 1381845028465, "start": 25.797, "seek_events": [{"direction": "forward", "end": 33.01002502441406, "event_type": "seeked", "timestamp": 1381845028465, "paused": false, "start": 25.797}], "timestamp ...
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1381820912049, "start": 11.897, "seek_events": [{"direction": "forward", "end": 264.414, "event_type": "seeked", "timestamp": 1381820912049, "paused": false, "start": 11.897}, {"direction": "back", "end": 64.542, "event_type": "seeked", "timestamp": 1381820915082, "paused": false, "start": 267.447}, {"direction": "back", "end": 20.513, "event_type": "seeked", "timestamp": 1381820917406, "paused": false, "start": 66.866}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381820918348, "paused": false, "start": 21.455000000000002}], "timestamp_end": 1381820918348}]
# []
# [{"direction": "forward", "end": 139.130013, "event_type": "seek_chain", "timestamp": 1383908472195, "start": 12.198, "seek_events": [{"direction": "forward", "end": 26.877389, "event_type": "seeked", "timestamp": 1383908472195, "paused": false, "start": 12.198}, {"direction": "forward", "end": 51.646747, "event_type": "seeked", "timestamp": 1383908473592, "paused": false, "start": 28.274389}, {"direction": "forward", "end": 73.781067, "event_type": "seeked", "timestamp": 1383908474307, "paused": false, "start": 52.361747}, {"direction": "forward", "end": 103.293494, "event_type": "seeked", "timestamp": 1383908475169, "paused": false, "start": 74.64306699999999}, {"direction": "forward", "end": 122.265769, "event_type": "seeked", "timestamp": 1383908475930, "paused": false, "start": 104.05449399999999}, {"direction": "forward", "end": 139.130013, "event_type": "seeked", "timestamp": 1383908476875, "paused": false, "start": 123.210769}], "timestamp_end": 1383908476875}]
# [{"direction": "forward", "end": 72.40908813476562, "event_type": "seek_chain", "timestamp": 1388923809314, "start": 3.718, "seek_events": [{"direction": "forward", "end": 72.40908813476562, "event_type": "seeked", "timestamp": 1388923809314, "paused": false, "start": 3.718}], "timestamp_end": 1388923809314}]
# []
# []
# []
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1383445715649, "start": 26.420021, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1383445715649, "paused": true, "start": 26.420021}], "timestamp_end": 1383445715649}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1383448811297, "start": 4.8870059999999995, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1383448811297, "paused": true, "start": 4.8870059999999995}], "timestamp_end": 1383448811297}, {"direction": "back", "end": 13.642105263157895, "event_type": "seek_chain", "timestamp": 1383448848898, "start": 35.408, "seek_events": [{"direction": "back", "end": 13.642105263157895, "event_type": "seeked", "timestamp": 1383448848898, "paused": false, "start": 35.408}], "timestamp_end": 1383448848898}, {"direction": "back", "end": 24.25263157894737, "event_type": "seek_chain", "timestamp": 1383448874612, "start": 39.35610526315789, "seek_events": [{"direction": "back", "end": 24.25263157894737, "event_type": "seeked", "timestamp": 1383448874612, "paused": false, "start": 39.35610526315789}], "timestamp_end": 1383448874612}, {"direction": "back", "end": 181.05855641205326, "event_type": "seek_chain", "timestamp": 1383449553799, "start": 185.02955641205327, "seek_events": [{"direction": "back", "end": 181.05855641205326, "event_type": "seeked", "timestamp": 1383449553799, "paused": false, "start": 185.02955641205327}], "timestamp_end": 1383449553799}, {"direction": "back", "end": 235.40518570427474, "event_type": "seek_chain", "timestamp": 1383449685868, "start": 243.720007, "seek_events": [{"direction": "back", "end": 235.40518570427474, "event_type": "seeked", "timestamp": 1383449685868, "paused": true, "start": 243.720007}], "timestamp_end": 1383449685868}]
# [{"direction": "forward", "end": 152.832211, "event_type": "seek_chain", "timestamp": 1384226336325, "start": 104.162, "seek_events": [{"direction": "forward", "end": 135.967967, "event_type": "seeked", "timestamp": 1384226336325, "paused": false, "start": 104.162}, {"direction": "forward", "end": 152.832211, "event_type": "seeked", "timestamp": 1384226337728, "paused": false, "start": 137.37096699999998}], "timestamp_end": 1384226337728}]
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1386250504284, "start": 20.606236, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1386250504284, "paused": false, "start": 20.606236}], "timestamp_end": 1386250504284}]
# []
# [{"direction": "forward", "end": 77.200866, "event_type": "seek_chain", "timestamp": 1383439700442, "start": 3.473, "seek_events": [{"direction": "forward", "end": 77.200866, "event_type": "seeked", "timestamp": 1383439700442, "paused": false, "start": 3.473}], "timestamp_end": 1383439700442}]
# [{"direction": "back", "end": 291.962224, "event_type": "seek_chain", "timestamp": 1381775975374, "start": 312.453, "seek_events": [{"direction": "back", "end": 291.962224, "event_type": "seeked", "timestamp": 1381775975374, "paused": false, "start": 312.453}], "timestamp_end": 1381775975374}]
# []
# []
# []
# []
# [{"direction": "forward", "end": 408.957916, "event_type": "seek_chain", "timestamp": 1381805567689, "start": 393.93, "seek_events": [{"direction": "forward", "end": 395.255718, "event_type": "seeked", "timestamp": 1381805567689, "paused": false, "start": 393.93}, {"direction": "forward", "end": 402.106817, "event_type": "seeked", "timestamp": 1381805568190, "paused": false, "start": 395.756718}, {"direction": "forward", "end": 405.79587, "event_type": "seeked", "timestamp": 1381805568664, "paused": false, "start": 402.58081699999997}, {"direction": "forward", "end": 407.903901, "event_type": "seeked", "timestamp": 1381805569082, "paused": false, "start": 406.21387}, {"direction": "back", "end": 407.903901, "event_type": "seeked", "timestamp": 1381805569523, "paused": false, "start": 408.344901}, {"direction": "forward", "end": 408.430909, "event_type": "seeked", "timestamp": 1381805569961, "paused": false, "start": 408.341901}, {"direction": "back", "end": 408.957916, "event_type": "seeked", "timestamp": 1381805571179, "paused": false, "start": 409.648909}], "timestamp_end": 1381805571179}]
# [{"direction": "forward", "end": 82.73321473951715, "event_type": "seek_chain", "timestamp": 1382801870456, "start": 4.184943, "seek_events": [{"direction": "forward", "end": 82.73321473951715, "event_type": "seeked", "timestamp": 1382801870456, "paused": false, "start": 4.184943}], "timestamp_end": 1382801870456}]
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1386335511401, "start": 33.441566, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1386335511401, "paused": true, "start": 33.441566}], "timestamp_end": 1386335511401}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1386855093548, "start": 414.755, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1386855093548, "paused": true, "start": 414.755}], "timestamp_end": 1386855093548}, {"direction": "back", "end": 91.554187, "event_type": "seek_chain", "timestamp": 1386855320255, "start": 130.916, "seek_events": [{"direction": "back", "end": 91.554187, "event_type": "seeked", "timestamp": 1386855320255, "paused": false, "start": 130.916}], "timestamp_end": 1386855320255}, {"direction": "back", "end": 336.570631, "event_type": "seek_chain", "timestamp": 1386855632109, "start": 403.408187, "seek_events": [{"direction": "back", "end": 336.570631, "event_type": "seeked", "timestamp": 1386855632109, "paused": false, "start": 403.408187}], "timestamp_end": 1386855632109}]
# []
# []
# []
# []
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1385976172126, "start": 12.106, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1385976172126, "paused": false, "start": 12.106}], "timestamp_end": 1385976172126}, {"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1385976198568, "start": 26.442, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1385976198568, "paused": false, "start": 26.442}], "timestamp_end": 1385976198568}]
# []
# []
# []
# []
# [{"direction": "forward", "end": 251.909644, "event_type": "seek_chain", "timestamp": 1381809880986, "start": 65.377, "seek_events": [{"direction": "forward", "end": 228.721309, "event_type": "seeked", "timestamp": 1381809880986, "paused": false, "start": 65.377}, {"direction": "forward", "end": 251.909644, "event_type": "seeked", "timestamp": 1381809882271, "paused": false, "start": 230.006309}], "timestamp_end": 1381809882271}, {"direction": "forward", "end": 314.096544, "event_type": "seek_chain", "timestamp": 1381809934688, "start": 304.326644, "seek_events": [{"direction": "forward", "end": 314.096544, "event_type": "seeked", "timestamp": 1381809934688, "paused": false, "start": 304.326644}], "timestamp_end": 1381809934688}, {"direction": "forward", "end": 378.391474, "event_type": "seek_chain", "timestamp": 1381809944385, "start": 323.793544, "seek_events": [{"direction": "forward", "end": 330.960788, "event_type": "seeked", "timestamp": 1381809944385, "paused": false, "start": 323.793544}, {"direction": "forward", "end": 350.46007, "event_type": "seeked", "timestamp": 1381809945458, "paused": false, "start": 332.03378799999996}, {"direction": "forward", "end": 358.892192, "event_type": "seeked", "timestamp": 1381809947851, "paused": false, "start": 352.85306999999995}, {"direction": "forward", "end": 378.391474, "event_type": "seeked", "timestamp": 1381809948887, "paused": false, "start": 359.928192}], "timestamp_end": 1381809948887}]
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1383263202771, "start": 33.2, "seek_events": [{"direction": "back", "end": 10.540151999999999, "event_type": "seeked", "timestamp": 1383263202771, "paused": false, "start": 33.2}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1383263204107, "paused": false, "start": 11.876152}], "timestamp_end": 1383263204107}, {"direction": "back", "end": 51.755346, "event_type": "seek_chain", "timestamp": 1383263265838, "start": 61.731, "seek_events": [{"direction": "back", "end": 58.165412, "event_type": "seeked", "timestamp": 1383263265838, "paused": false, "start": 61.731}, {"direction": "back", "end": 56.503543, "event_type": "seeked", "timestamp": 1383263267209, "paused": false, "start": 59.536412000000006}, {"direction": "back", "end": 56.028724, "event_type": "seeked", "timestamp": 1383263269930, "paused": false, "start": 59.224543}, {"direction": "back", "end": 51.755346, "event_type": "seeked", "timestamp": 1383263271751, "paused": false, "start": 57.849723999999995}], "timestamp_end": 1383263271751}, {"direction": "back", "end": 46.76974, "event_type": "seek_chain", "timestamp": 1383263302978, "start": 82.982346, "seek_events": [{"direction": "back", "end": 61.01433, "event_type": "seeked", "timestamp": 1383263302978, "paused": false, "start": 82.982346}, {"direction": "back", "end": 56.266133, "event_type": "seeked", "timestamp": 1383263305324, "paused": false, "start": 63.360330000000005}, {"direction": "back", "end": 51.517936, "event_type": "seeked", "timestamp": 1383263307100, "paused": false, "start": 58.04213300000001}, {"direction": "back", "end": 49.856068, "event_type": "seeked", "timestamp": 1383263311304, "paused": false, "start": 55.721936}, {"direction": "back", "end": 46.76974, "event_type": "seeked", "timestamp": 1383263313377, "paused": false, "start": 51.929068}], "timestamp_end": 1383263313377}, {"direction": "back", "end": 96.388397, "event_type": "seek_chain", "timestamp": 1383263531034, "start": 101.58926699999999, "seek_events": [{"direction": "back", "end": 96.388397, "event_type": "seeked", "timestamp": 1383263531034, "paused": false, "start": 101.58926699999999}, {"direction": "back", "end": 96.388397, "event_type": "seeked", "timestamp": 1383263531035, "paused": false, "start": 96.389397}], "timestamp_end": 1383263531035}, {"direction": "back", "end": 95.201348, "event_type": "seek_chain", "timestamp": 1383263541771, "start": 107.124397, "seek_events": [{"direction": "back", "end": 96.625807, "event_type": "seeked", "timestamp": 1383263541771, "paused": false, "start": 107.124397}, {"direction": "back", "end": 95.201348, "event_type": "seeked", "timestamp": 1383263544018, "paused": false, "start": 98.872807}], "timestamp_end": 1383263544018}, {"direction": "back", "end": 129.388366, "event_type": "seek_chain", "timestamp": 1383263595557, "start": 146.74034799999998, "seek_events": [{"direction": "back", "end": 136.273251, "event_type": "seeked", "timestamp": 1383263595557, "paused": false, "start": 146.74034799999998}, {"direction": "back", "end": 133.186923, "event_type": "seeked", "timestamp": 1383263597654, "paused": false, "start": 138.370251}, {"direction": "back", "end": 130.575415, "event_type": "seeked", "timestamp": 1383263602274, "paused": false, "start": 137.806923}, {"direction": "back", "end": 129.388366, "event_type": "seeked", "timestamp": 1383263606270, "paused": false, "start": 134.571415}], "timestamp_end": 1383263606270}, {"direction": "back", "end": 239.546534, "event_type": "seek_chain", "timestamp": 1383263728376, "start": 251.49436599999999, "seek_events": [{"direction": "back", "end": 244.057321, "event_type": "seeked", "timestamp": 1383263728376, "paused": false, "start": 251.49436599999999}, {"direction": "back", "end": 239.546534, "event_type": "seeked", "timestamp": 1383263731445, "paused": false, "start": 247.126321}], "timestamp_end": 1383263731445}, {"direction": "back", "end ...
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1384351333783, "start": 7.88712, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1384351333783, "paused": true, "start": 7.88712}], "timestamp_end": 1384351333783}]
# [{"direction": "forward", "end": 278.59053435114504, "event_type": "seek_chain", "timestamp": 1387417027344, "start": 88.715, "seek_events": [{"direction": "forward", "end": 278.59053435114504, "event_type": "seeked", "timestamp": 1387417027344, "paused": false, "start": 88.715}], "timestamp_end": 1387417027344}]
# [{"direction": "back", "end": 41.633602, "event_type": "seek_chain", "timestamp": 1382726096583, "start": 78.443729, "seek_events": [{"direction": "back", "end": 64.821938, "event_type": "seeked", "timestamp": 1382726096583, "paused": false, "start": 78.443729}, {"direction": "back", "end": 54.808793, "event_type": "seeked", "timestamp": 1382726097552, "paused": false, "start": 65.790938}, {"direction": "back", "end": 49.011709, "event_type": "seeked", "timestamp": 1382726098659, "paused": false, "start": 55.915793}, {"direction": "back", "end": 41.633602, "event_type": "seeked", "timestamp": 1382726099494, "paused": false, "start": 49.846709000000004}], "timestamp_end": 1382726099494}, {"direction": "forward", "end": 102.239479, "event_type": "seek_chain", "timestamp": 1382946843973, "start": 2.492, "seek_events": [{"direction": "forward", "end": 58.497846, "event_type": "seeked", "timestamp": 1382946843973, "paused": false, "start": 2.492}, {"direction": "forward", "end": 102.239479, "event_type": "seeked", "timestamp": 1382946848703, "paused": false, "start": 63.227846}], "timestamp_end": 1382946848703}]
# []
# []
# []
# [{"direction": "forward", "end": 401.4515377, "event_type": "seek_chain", "timestamp": 1381875113810, "start": 1.586, "seek_events": [{"direction": "forward", "end": 18.0088019, "event_type": "seeked", "timestamp": 1381875113810, "paused": false, "start": 1.586}, {"direction": "forward", "end": 51.9095881, "event_type": "seeked", "timestamp": 1381875114292, "paused": false, "start": 18.4908019}, {"direction": "forward", "end": 100.4280975, "event_type": "seeked", "timestamp": 1381875114881, "paused": false, "start": 52.4985881}, {"direction": "forward", "end": 156.772173, "event_type": "seeked", "timestamp": 1381875115481, "paused": false, "start": 101.0280975}, {"direction": "forward", "end": 222.5069277, "event_type": "seeked", "timestamp": 1381875116771, "paused": false, "start": 158.062173}, {"direction": "forward", "end": 259.5479403, "event_type": "seeked", "timestamp": 1381875117350, "paused": false, "start": 223.0859277}, {"direction": "forward", "end": 281.4595252, "event_type": "seeked", "timestamp": 1381875118231, "paused": false, "start": 260.42894029999997}, {"direction": "forward", "end": 309.1098585, "event_type": "seeked", "timestamp": 1381875118993, "paused": false, "start": 282.2215252}, {"direction": "forward", "end": 335.716783, "event_type": "seeked", "timestamp": 1381875119615, "paused": false, "start": 309.7318585}, {"direction": "forward", "end": 353.9764371, "event_type": "seeked", "timestamp": 1381875120330, "paused": false, "start": 336.431783}, {"direction": "forward", "end": 373.2795, "event_type": "seeked", "timestamp": 1381875121070, "paused": false, "start": 354.7164371}, {"direction": "forward", "end": 383.7135881, "event_type": "seeked", "timestamp": 1381875121774, "paused": false, "start": 373.9835}, {"direction": "forward", "end": 393.6259717, "event_type": "seeked", "timestamp": 1381875122302, "paused": false, "start": 384.2415881}, {"direction": "forward", "end": 401.4515377, "event_type": "seeked", "timestamp": 1381875123264, "paused": false, "start": 394.58797169999997}], "timestamp_end": 1381875123264}]
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1389069613446, "start": 7787.294, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1389069613446, "paused": false, "start": 7787.294}], "timestamp_end": 1389069613446}]
# [{"direction": "forward", "end": 163.37236340533673, "event_type": "seek_chain", "timestamp": 1381937729420, "start": 3.279, "seek_events": [{"direction": "forward", "end": 163.37236340533673, "event_type": "seeked", "timestamp": 1381937729420, "paused": false, "start": 3.279}], "timestamp_end": 1381937729420}, {"direction": "forward", "end": 324.243639, "event_type": "seek_chain", "timestamp": 1382365980862, "start": 283.97771400000005, "seek_events": [{"direction": "forward", "end": 293.363293, "event_type": "seeked", "timestamp": 1382365980862, "paused": false, "start": 283.97771400000005}, {"direction": "forward", "end": 309.868306, "event_type": "seeked", "timestamp": 1382365982444, "paused": false, "start": 294.945293}, {"direction": "forward", "end": 324.243639, "event_type": "seeked", "timestamp": 1382365984492, "paused": false, "start": 311.916306}], "timestamp_end": 1382365984492}]
# []
# []
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1381807020191, "start": 11.960013, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381807020191, "paused": false, "start": 11.960013}], "timestamp_end": 1381807020191}]
# [{"direction": "back", "end": 103.820502, "event_type": "seek_chain", "timestamp": 1382404168668, "start": 120.461, "seek_events": [{"direction": "back", "end": 103.820502, "event_type": "seeked", "timestamp": 1382404168668, "paused": false, "start": 120.461}], "timestamp_end": 1382404168668}, {"direction": "back", "end": 337.284879, "event_type": "seek_chain", "timestamp": 1382404411455, "start": 346.607502, "seek_events": [{"direction": "back", "end": 334.649841, "event_type": "seeked", "timestamp": 1382404411455, "paused": false, "start": 346.607502}, {"direction": "back", "end": 337.284879, "event_type": "seeked", "timestamp": 1382404415961, "paused": false, "start": 339.155841}], "timestamp_end": 1382404415961}]
# []
# []
# []
# []
# []
# []
# [{"direction": "back", "end": 66.929968, "event_type": "seek_chain", "timestamp": 1389162122587, "start": 90.068, "seek_events": [{"direction": "back", "end": 77.470121, "event_type": "seeked", "timestamp": 1389162122587, "paused": false, "start": 90.068}, {"direction": "back", "end": 66.929968, "event_type": "seeked", "timestamp": 1389162125441, "paused": false, "start": 80.324121}], "timestamp_end": 1389162125441}]
# []
# []
# [{"direction": "forward", "end": 321.9384765625, "event_type": "seek_chain", "timestamp": 1382224887457, "start": 0.088, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1382224887457, "paused": false, "start": 0.088}, {"direction": "forward", "end": 321.9384765625, "event_type": "seeked", "timestamp": 1382224891959, "paused": false, "start": 4.502}], "timestamp_end": 1382224891959}]
# [{"direction": "back", "end": 100.131449, "event_type": "seek_chain", "timestamp": 1386874910305, "start": 107.609, "seek_events": [{"direction": "back", "end": 101.712471, "event_type": "seeked", "timestamp": 1386874910305, "paused": false, "start": 107.609}, {"direction": "back", "end": 100.131449, "event_type": "seeked", "timestamp": 1386874912411, "paused": false, "start": 103.81847099999999}], "timestamp_end": 1386874912411}]
# []
# []
# [{"direction": "forward", "end": 297.75930749682334, "event_type": "seek_chain", "timestamp": 1383192958995, "start": 260.399702, "seek_events": [{"direction": "forward", "end": 297.75930749682334, "event_type": "seeked", "timestamp": 1383192958995, "paused": false, "start": 260.399702}], "timestamp_end": 1383192958995}]
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1385396865977, "start": 37.286, "seek_events": [{"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1385396865977, "paused": false, "start": 37.286}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1385396867323, "paused": false, "start": 1.346}], "timestamp_end": 1385396867323}, {"direction": "forward", "end": 110.66226175349429, "event_type": "seek_chain", "timestamp": 1385396904084, "start": 36.761, "seek_events": [{"direction": "forward", "end": 110.66226175349429, "event_type": "seeked", "timestamp": 1385396904084, "paused": false, "start": 36.761}], "timestamp_end": 1385396904084}, {"direction": "forward", "end": 282.452249047014, "event_type": "seek_chain", "timestamp": 1385396918290, "start": 124.8682617534943, "seek_events": [{"direction": "forward", "end": 282.452249047014, "event_type": "seeked", "timestamp": 1385396918290, "paused": false, "start": 124.8682617534943}], "timestamp_end": 1385396918290}, {"direction": "forward", "end": 338.83730622617543, "event_type": "seek_chain", "timestamp": 1385396924594, "start": 288.75624904701397, "seek_events": [{"direction": "forward", "end": 338.83730622617543, "event_type": "seeked", "timestamp": 1385396924594, "paused": false, "start": 288.75624904701397}], "timestamp_end": 1385396924594}, {"direction": "back", "end": 183.91013977128335, "event_type": "seek_chain", "timestamp": 1385396937085, "start": 351.3283062261754, "seek_events": [{"direction": "back", "end": 183.91013977128335, "event_type": "seeked", "timestamp": 1385396937085, "paused": false, "start": 351.3283062261754}], "timestamp_end": 1385396937085}]
# []
# []
# [{"direction": "back", "end": 0.0, "event_type": "seek_chain", "timestamp": 1381844951282, "start": 1.564, "seek_events": [{"direction": "forward", "end": 80.105159, "event_type": "seeked", "timestamp": 1381844951282, "paused": false, "start": 1.564}, {"direction": "back", "end": 0.0, "event_type": "seeked", "timestamp": 1381844952300, "paused": false, "start": 81.123159}], "timestamp_end": 1381844952300}, {"direction": "forward", "end": 153.886226, "event_type": "seek_chain", "timestamp": 1381845756560, "start": 5.164, "seek_events": [{"direction": "forward", "end": 82.213189, "event_type": "seeked", "timestamp": 1381845756560, "paused": false, "start": 5.164}, {"direction": "forward", "end": 153.886226, "event_type": "seeked", "timestamp": 1381845757812, "paused": false, "start": 83.465189}], "timestamp_end": 1381845757812}]
# []
# []
# []
# [{"direction": "back", "end": 54.808793, "event_type": "seek_chain", "timestamp": 1382228555345, "start": 86.065, "seek_events": [{"direction": "back", "end": 54.808793, "event_type": "seeked", "timestamp": 1382228555345, "paused": false, "start": 86.065}], "timestamp_end": 1382228555345}, {"direction": "back", "end": 96.969403, "event_type": "seek_chain", "timestamp": 1382228616881, "start": 116.34479300000001, "seek_events": [{"direction": "back", "end": 96.969403, "event_type": "seeked", "timestamp": 1382228616881, "paused": false, "start": 116.34479300000001}], "timestamp_end": 1382228616881}]
# [{"direction": "forward", "end": 326.438537, "event_type": "seek_chain", "timestamp": 1384067694637, "start": 317.796, "seek_events": [{"direction": "forward", "end": 326.438537, "event_type": "seeked", "timestamp": 1384067694637, "paused": false, "start": 317.796}], "timestamp_end": 1384067694637}, {"direction": "forward", "end": 374.395326, "event_type": "seek_chain", "timestamp": 1384067701783, "start": 333.584537, "seek_events": [{"direction": "forward", "end": 340.208309, "event_type": "seeked", "timestamp": 1384067701783, "paused": false, "start": 333.584537}, {"direction": "forward", "end": 347.568014, "event_type": "seeked", "timestamp": 1384067703100, "paused": false, "start": 341.525309}, {"direction": "forward", "end": 367.035621, "event_type": "seeked", "timestamp": 1384067706309, "paused": false, "start": 350.777014}, {"direction": "forward", "end": 374.395326, "event_type": "seeked", "timestamp": 1384067707093, "paused": false, "start": 367.819621}, {"direction": "back", "end": 374.395326, "event_type": "seeked", "timestamp": 1384067707144, "paused": false, "start": 374.446326}, {"direction": "back", "end": 374.395326, "event_type": "seeked", "timestamp": 1384067707177, "paused": false, "start": 374.428326}, {"direction": "back", "end": 374.395326, "event_type": "seeked", "timestamp": 1384067707205, "paused": false, "start": 374.42332600000003}], "timestamp_end": 1384067707205}, {"direction": "forward", "end": 410.006803, "event_type": "seek_chain", "timestamp": 1384067721565, "start": 388.755326, "seek_events": [{"direction": "forward", "end": 396.949262, "event_type": "seeked", "timestamp": 1384067721565, "paused": false, "start": 388.755326}, {"direction": "forward", "end": 407.395295, "event_type": "seeked", "timestamp": 1384067725041, "paused": false, "start": 400.425262}, {"direction": "forward", "end": 410.006803, "event_type": "seeked", "timestamp": 1384067725687, "paused": false, "start": 408.041295}], "timestamp_end": 1384067725687}, {"direction": "forward", "end": 18.445267, "event_type": "seek_chain", "timestamp": 1384125620763, "start": 1.2775, "seek_events": [{"direction": "forward", "end": 240.315476, "event_type": "seeked", "timestamp": 1384125620763, "paused": false, "start": 1.2775}, {"direction": "back", "end": 227.140286, "event_type": "seeked", "timestamp": 1384125622279, "paused": false, "start": 242.210476}, {"direction": "back", "end": 192.357783, "event_type": "seeked", "timestamp": 1384125622866, "paused": false, "start": 227.874036}, {"direction": "forward", "end": 290.908208, "event_type": "seeked", "timestamp": 1384125624033, "paused": false, "start": 193.81653300000002}, {"direction": "forward", "end": 319.893628, "event_type": "seeked", "timestamp": 1384125624722, "paused": false, "start": 291.769458}, {"direction": "forward", "end": 363.63526, "event_type": "seeked", "timestamp": 1384125625420, "paused": false, "start": 320.766128}, {"direction": "forward", "end": 390.512649, "event_type": "seeked", "timestamp": 1384125626520, "paused": false, "start": 365.01026}, {"direction": "back", "end": 390.512649, "event_type": "seeked", "timestamp": 1384125626521, "paused": false, "start": 390.51389900000004}, {"direction": "forward", "end": 400.525794, "event_type": "seeked", "timestamp": 1384125627245, "paused": false, "start": 391.417649}, {"direction": "back", "end": 31.620457, "event_type": "seeked", "timestamp": 1384125628172, "paused": false, "start": 401.684544}, {"direction": "back", "end": 18.445267, "event_type": "seeked", "timestamp": 1384125628985, "paused": false, "start": 32.636707}], "timestamp_end": 1384125628985}]
# []
# []

# %%
def parseOptions(options, lst):
  if options == None:
    return tuple([None for x in lst])
  for key in options:
    assert key in lst, 'provided option ' + str(key) + ' is not in acceptable options ' + str(lst)
  output = []
  for x in lst:
    if x in options:
      output.append(options[x])
    else:
      output.append(None)
  return tuple(output)

def incrementPartsSkippedForwardOver(seek_chain, output):
  if seek_chain.direction != 'forward':
    return
  for i in range(int(round(seek_chain.start)), int(round(seek_chain.end))):
    if not 0 <= i < len(output):
      continue
    output[i] += 1

def getLectureLength(lecture_id):
  if lecture_id in video_annotations.video_lengths_ml_004:
    return video_annotations.video_lengths_ml_004[lecture_id]
  return getLectureEndTimes()[lecture_id]

def getPartsSkippedForwardOver(lecture_id, **kwargs):
  skipped_users,successful_users,user_whitelist = parseOptions(kwargs, ['skipped_users', 'successful_users', 'user_whitelist'])
  lecture_length = getLectureLength(lecture_id)
  output = [0]*int(round(lecture_length+1))
  for user in getViewersToLectures().keys():
    frame = getFrameForLectureUser(lecture_id, user)
    if type(frame) == type(None):
      continue
    if frame.empty:
      continue
    frame = frame.sort('event_timestamp')
    try:
      seek_events = extractSeekEvents(frame)
    except DataException as e:
      if skipped_users != None:
        skipped_users.add(user)
      continue
    seek_chains = groupSeekEventsAsSeekChains(seek_events)
    for seek_chain in seek_chains:
      incrementPartsSkippedForwardOver(seek_chain, output)
    if successful_users != None:
      successful_users.add(user)
  return output

def incrementPartsSkippedBackOver(seek_chain, output):
  if seek_chain.direction != 'back':
    return
  for i in range(int(round(seek_chain.end)), int(round(seek_chain.start))):
    if not 0 <= i < len(output):
      continue
    output[i] += 1

def getPartsSkippedBackOver(lecture_id, **kwargs):
  skipped_users,successful_users,user_whitelist = parseOptions(kwargs, ['skipped_users', 'successful_users', 'user_whitelist'])
  lecture_length = getLectureLength(lecture_id)
  output = [0]*int(round(lecture_length+1))
  for user in getViewersToLectures().keys():
    frame = getFrameForLectureUser(lecture_id, user)
    if type(frame) == type(None):
      continue
    if frame.empty:
      continue
    frame = frame.sort('event_timestamp')
    try:
      seek_events = extractSeekEvents(frame)
    except DataException as e:
      if skipped_users != None:
        skipped_users.add(user)
      continue
    seek_chains = groupSeekEventsAsSeekChains(seek_events)
    for seek_chain in seek_chains:
      incrementPartsSkippedBackOver(seek_chain, output)
    if successful_users != None:
      successful_users.add(user)
  return output
    
def incrementPartsPlayed(play_span, output):
  assert play_span.end >= play_span.start, 'play span end is ' + str(play_span.end) + ' while start is ' + str(play_span.start)
  for i in range(int(round(play_span.start)), int(round(play_span.end))):
    if not 0 <= i < len(output):
      continue
    output[i] += 1

def extractAllEventsForUserInLecture(lecture_id, user_id, filter_func=None):
  frame = getFrameForLectureUser(lecture_id, user)
  if type(frame) == type(None):
    return None
  if frame.empty:
    return None
  frame = frame.sort('event_timestamp')
  all_events = extractAllEvents(frame)
  if filter_func == None:
    return all_events
  return filter_func(all_events, lecture_id, user_id)

def getPartsPlayed(lecture_id, **kwargs):
  skipped_users,successful_users,user_whitelist,filter_func = parseOptions(kwargs, ['skipped_users', 'successful_users', 'user_whitelist', 'filter_func'])
  lecture_length = getLectureLength(lecture_id)
  output = [0]*int(round(lecture_length+1))
  for user in getViewersToLectures().keys():
    try:
      all_events = extractAllEventsForUserInLecture(lecture_id, user, filter_func)
      if all_events == None:
        continue
    except DataException as e:
      if skipped_users != None:
        skipped_users.add(user)
      continue
    play_spans = groupEventsAsPlaySpans(all_events)
    skip_user = False
    for play_span in play_spans:
      if not play_span.end >= play_span.start:
        skip_user = True
    if skip_user:
      if skipped_users != None:
        skipped_users.add(user)
      continue
    for play_span in play_spans:
      incrementPartsPlayed(play_span, output)
    if successful_users != None:
      successful_users.add(user)
  return output

'''
def getPartsPlayed(lecture_id, **kwargs):
  skipped_users,successful_users,user_whitelist = parseOptions(kwargs, ['skipped_users', 'successful_users', 'user_whitelist'])
  lecture_length = getLectureLength(lecture_id)
  output = [0]*int(round(lecture_length+1))
  for user in getViewersToLectures().keys():
    frame = getFrameForLectureUser(lecture_id, user)
    if type(frame) == type(None):
      continue
    if frame.empty:
      continue
    frame = frame.sort('event_timestamp')
    try:
      all_events = extractAllEvents(frame)
    except DataException as e:
      if skipped_users != None:
        skipped_users.add(user)
      continue
    play_spans = groupEventsAsPlaySpans(all_events)
    skip_user = False
    for play_span in play_spans:
      if not play_span.end >= play_span.start:
        skip_user = True
    if skip_user:
      if skipped_users != None:
        skipped_users.add(user)
      continue
    for play_span in play_spans:
      incrementPartsPlayed(play_span, output)
    if successful_users != None:
      successful_users.add(user)
  return output
'''
# Out:
# "\ndef getPartsPlayed(lecture_id, **kwargs):\n  skipped_users,successful_users,user_whitelist = parseOptions(kwargs, ['skipped_users', 'successful_users', 'user_whitelist'])\n  lecture_length = getLectureLength(lecture_id)\n  output = [0]*int(round(lecture_length+1))\n  for user in getViewersToLectures().keys():\n    frame = getFrameForLectureUser(lecture_id, user)\n    if type(frame) == type(None):\n      continue\n    if frame.empty:\n      continue\n    frame = frame.sort('event_timestamp')\n    try:\n      all_events = extractAllEvents(frame)\n    except DataException as e:\n      if skipped_users != None:\n        skipped_users.add(user)\n      continue\n    play_spans = groupEventsAsPlaySpans(all_events)\n    skip_user = False\n    for play_span in play_spans:\n      if not play_span.end >= play_span.start:\n        skip_user = True\n    if skip_user:\n      if skipped_users != None:\n        skipped_users.add(user)\n      continue\n    for play_span in play_spans:\n      incrementPartsPlayed(play_span, output)\n    if successful_users != None:\n      successful_users.add(user)\n  return output\n"

# %%
# %matplotlib inline
import matplotlib.pyplot
import matplotlib.pylab as pylab
import numpy

def binsum(inp):
  output = []
  for i in range(len(inp)):
    curbin = inp[i-2:i+3]
    val = sum(curbin)
    output.append(val)
  return output

def binavg(inp):
  output = []
  for i in range(len(inp)):
    curbin = inp[i-2:i+3]
    if len(curbin) == 0:
      output.append(0)
      continue
    val = sum(curbin) / float(len(curbin))
    output.append(val)
  return output

def barPlotWithStderr(means, stderrs=None, x_tick_labels=None, xlabel='', ylabel='', title='', addLabels=True):
    if stderrs:
        assert len(means) == len(stderrs)
    if x_tick_labels:
        assert len(means) == len(x_tick_labels)
        x_tick_labels = [str(x) for x in x_tick_labels]
    else:
        x_tick_labels = [str(x) for x in range(len(means))]
    N = len(means)
    ind = numpy.arange(N) # the x locations for the groups
    width = 0.35 # the width of the bars
    fig, ax = matplotlib.pyplot.subplots()
    if stderrs:
        rects1 = ax.bar(ind, means, width, color='r', yerr=stderrs)
    else:
        rects1 = ax.bar(ind, means, width, color='r')
    
    if ylabel and not title:
        title = ylabel
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticks(ind+width)
    ax.set_xticklabels( x_tick_labels )
    
    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            #ax.text('foobar', 1.05*height, '%d'%int(height), ha='center', va='bottom')
            ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height), ha='center', va='bottom')
    if addLabels:
      autolabel(rects1)

def plotBarDictionary(datadict, xlabel='', ylabel='', title='', x_tick_label_map=None):
    keys = datadict.keys()
    keys.sort()
    means = [datadict[k] for k in keys]
    if not x_tick_label_map:
      x_tick_labels = keys
    else:
      x_tick_labels = [x_tick_label_map[key] for key in keys]
    barPlotWithStderr(means, x_tick_labels=x_tick_labels, xlabel=xlabel, ylabel=ylabel, title=title)

# %%
def getPickleFileForTable(tbname=tablename, dbname=databasename):
  return '/lfs/local/0/geza/' + dbname + '_' + tbname

'''
def dumpTable(tbname, dbname):
  if os.path.exists(getPickleFileForTable(tbname, dbname)):
    print 'table has already been dumped at ' + getPickleFileForTable(tbname, dbname)
    return
  global tablename
  global databasename
  tablename = tbname
  databasename = dbname
  data = listFieldsPandas(['*'])
  pickle.dump(data, open(getPickleFileForTable(tbname, dbname), 'w'))
'''

@memoized
def loadTable(tbname, dbname=course_dbs[]):
  return pickle.load(open(getPickleFileForTable(tbname, dbname)))
# Out:
#   File "<ipython-input-10-d08fa0fa1764>", line 18
#     def loadTable(tbname, dbname=course_dbs[]):
#                                             ^
# SyntaxError: invalid syntax

# %%
quiz_submission_metadata = loadTable('quiz_submission_metadata', 'coursera_crypto-009_anonymized_general')
quiz_metadata = loadTable('quiz_metadata', 'coursera_crypto-009_anonymized_general')
hash_mapping = loadTable('hash_mapping', 'coursera_crypto-009_hash_mapping')

# %%
#session_user_id_to_eventing_user_id = {}
#for session_user_id,eventing_user_id in hash_mapping[['session_user_id', 'eventing_user_id']].itertuples(index=False):
#  session_user_id_to_eventing_user_id[session_user_id] = eventing_user_id

# %%
quiz_submission_counts = Counter([x[0] for x in quiz_submission_metadata[['item_id']].itertuples(index=False)])
quiz_submission_counts = {k: v for k,v in quiz_submission_counts.iteritems() if v > 100 and k >= 0}
print quiz_submission_counts

# %%
quiz_ids_and_types = [(quiz_id,quiz_type) for quiz_id,quiz_type in quiz_metadata[['id', 'quiz_type']].itertuples(index=False)]
#print quiz_ids_and_types
video_quiz_ids = [quiz_id for quiz_id,quiz_type in quiz_ids_and_types if quiz_type == 'video' and quiz_id in quiz_submission_counts]
print video_quiz_ids
homework_ids = [quiz_id for quiz_id,quiz_type in quiz_ids_and_types if quiz_type == 'homework' and quiz_id in quiz_submission_counts]
print homework_ids
exam_ids = [quiz_id for quiz_id,quiz_type in quiz_ids_and_types if quiz_type == 'exam' and quiz_id in quiz_submission_counts]
print exam_ids # [102] is the final exam

# %%
#def getGradeCounts(quiz_id, quiz_submission_metadata):
#  max_score = quiz_submission_metadata[['raw_score']].max().get_value(0)
#  raw_scores = [raw_score for raw_score, in quiz_submission_metadata[['raw_score']].itertuples(index=False) if 0 <= raw_score <= max_score]
#  return Counter(raw_scores)

def noFilter(session_user_id):
  return True

def makeGradeDistribution(raw_scores):
  max_score = max(raw_scores)
  scores = [0] * (int(round(max_score)) + 1)
  for raw_score in raw_scores:
    rounded_score = int(round(raw_score))
    scores[rounded_score] += 1
  return scores

def getRawGrades(quiz_id, quiz_submission_metadata, filterFunc=noFilter):
  output = []
  quiz_submissions = quiz_submission_metadata[quiz_submission_metadata['item_id'] == quiz_id]
  max_score = quiz_submissions[['raw_score']].max().get_value(0)
  for raw_score,session_user_id in quiz_submissions[['raw_score','session_user_id']].itertuples(index=False):
    if not 0 <= raw_score <= max_score:
      continue
    if not filterFunc(session_user_id):
      continue
    output.append(raw_score)
  return output

def normalizedBySum(values):
  norm_factor = sum(values)
  return [float(x)/norm_factor for x in values]

#print getGradeCounts(exam_ids[0], quiz_submission_metadata)
final_exam_grades = getRawGrades(exam_ids[0], quiz_submission_metadata)
print numpy.average(final_exam_grades)
final_exam_distribution = makeGradeDistribution(final_exam_grades)
pylab.plot(final_exam_distribution)
pylab.show()
pylab.plot(normalizedBySum(final_exam_distribution))
pylab.show()

# %%
#print quiz_submission_metadata[quiz_submission_metadata.item_id == 102]

# %%
print getViewersWhoWatchedMostLecturesSet()

# %%
def sessionUserIdViewedAllLectures(session_user_id):
  return session_user_id in getViewersWhoWatchedMostLecturesSet()


#print getGradeCounts(exam_ids[0], quiz_submission_metadata)
final_exam_grades = getRawGrades(exam_ids[0], quiz_submission_metadata, filterFunc=sessionUserIdViewedAllLectures)
print numpy.average(final_exam_grades)
final_exam_distribution = makeGradeDistribution(final_exam_grades)
pylab.plot(final_exam_distribution)
pylab.show()
pylab.plot(normalizedBySum(final_exam_distribution))
pylab.show()

# %%
user_to_num_seek_events = {}
user_to_num_lectures_watched = {}

for user,lectures_watched in getViewersToLectures().iteritems():
  user_to_num_lectures_watched[user] = len(lectures_watched)

for user,event_type in listFields(['anon_username', 'event_type'], 'where event_type="seeked"'):
  if user not in user_to_num_seek_events:
    user_to_num_seek_events[user] = 1
  else:
    user_to_num_seek_events[user] += 1

# %%
user_to_seeks_per_lecture = {}

for user,num_lectures_watched in user_to_num_lectures_watched.iteritems():
  if num_lectures_watched <= 0:
    continue
  if user not in user_to_num_seek_events:
    user_to_seeks_per_lecture[user] = 0
  else:
    user_to_seeks_per_lecture[user] = float(user_to_num_seek_events[user]) / user_to_num_lectures_watched[user]

# %%
seeks_per_lecture_distribution = makeGradeDistribution(user_to_seeks_per_lecture.values())
pylab.plot(seeks_per_lecture_distribution[:10])

# %%
user_to_lecture_to_num_forward_seek_chains = {}
user_to_lecture_to_num_backward_seek_chains = {}
user_to_lecture_to_num_seek_chains = {}

#frame = getFrameForLectureUser(1, 'abcea9860ecfb2fef5140bc9e504f529ed33eb39')
#print frame.sort('event_timestamp')
#print frame
idx = 0
#user_list = getViewersToLectures().keys()
user_list = getViewersWhoWatchedMostLectures()
viewers_to_lectures = getViewersToLectures()
for idx,user in enumerate(user_list):
  if idx % 100 == 0:
    print idx, len(user_list)
  user_to_lecture_to_num_forward_seek_chains[user] = {}
  user_to_lecture_to_num_backward_seek_chains[user] = {}
  user_to_lecture_to_num_seek_chains[user] = {}
  for lecture_id in viewers_to_lectures[user]:
    frame = getFrameForLectureUser(lecture_id, user)
    if type(frame) == type(None):
      continue
    if frame.empty:
      continue
    if frame.index == None:
      continue
    if len(frame.index) <= 2:
      continue
    frame = frame.sort('event_timestamp')
    try:
      seek_events = extractSeekEvents(frame)
    except DataException as e:
      continue
    seek_chains = groupSeekEventsAsSeekChains(seek_events)
    user_to_lecture_to_num_forward_seek_chains[user][lecture_id] = 0
    user_to_lecture_to_num_backward_seek_chains[user][lecture_id] = 0
    user_to_lecture_to_num_seek_chains[user][lecture_id] = 0
    for seek_chain in seek_chains:
      user_to_lecture_to_num_seek_chains[user][lecture_id] += 1
      if seek_chain.direction == 'forward':
        user_to_lecture_to_num_forward_seek_chains[user][lecture_id] += 1
      if seek_chain.direction == 'backward':
        user_to_lecture_to_num_backward_seek_chains[user][lecture_id] += 1
