# %%
import MySQLdb
import sqlite3
import json
import gzip

from json import loads

from pandas import DataFrame
from pandas.io.sql import read_frame

datastage_login = json.load(open('datastage_login.json'))

#database = MySQLdb.connect(host='datastage.stanford.edu', user=datastage_login['user'], passwd=datastage_login['passwd'])
# Out:
# /usr/lib/python2.7/site-packages/matplotlib-1.1.1-py2.7-linux-x86_64.egg/pytz/__init__.py:35: UserWarning: Module dateutil was already imported from /usr/lib/python2.7/site-packages/matplotlib-1.1.1-py2.7-linux-x86_64.egg/dateutil/__init__.pyc, but /usr/lib/python2.7/site-packages/python_dateutil-1.4.1-py2.7.egg is being added to sys.path
#   from pkg_resources import resource_stream
# /usr/lib/python2.7/site-packages/matplotlib-1.1.1-py2.7-linux-x86_64.egg/pytz/__init__.py:35: UserWarning: Module pytz was already imported from /usr/lib/python2.7/site-packages/matplotlib-1.1.1-py2.7-linux-x86_64.egg/pytz/__init__.pyc, but /usr/lib/python2.7/site-packages/pytz-2013.9-py2.7.egg is being added to sys.path
#   from pkg_resources import resource_stream

# %%
geodb_connection = sqlite3.connect('ipdb.sqlite')
geodb_table = 'country_blocks'

def getTableNameSqlite():
  return geodb_table

def getDatabaseSqlite():
  return geodb_connection

def listFieldsSqlite(fieldnames, extraquery=''):
  fieldnameString = ','.join(fieldnames)
  data = read_frame("select " + fieldnameString + " from " + getTableNameSqlite() + " " + extraquery, getDatabaseSqlite())
  return data.itertuples(index=False)

def numeric_ip_to_address(num):
  base = 16777216 # 256**3
  first = num // base
  num -= first * base
  base = 65536 # 256**2
  second = num // base
  num -= second * base
  base = 256
  third = num // base
  num -= third * base
  fourth = num
  return '.'.join([str(x) for x in first,second,third,fourth])

def address_to_numeric_ip(address):
  num = 0
  base = 1
  for val in reversed(address.split('.')):
    num += base * int(val)
    base *= 256
  return num

def normalize_ip(ip_address):
  return '.'.join([str(int(x)) for x in ip_address.split('.')])

#16777471 -> 1.0.0.255
print numeric_ip_to_address(16777471)
print address_to_numeric_ip('1.0.0.255')

ip_block_to_country_code = {}
country_code_to_name = {}

def joinNums(num1, num2=None, num3=None, num4=None):
  if num4:
    return '.'.join([str(x) for x in [num1,num2,num3,num4]])
  if num3:
    return '.'.join([str(x) for x in [num1,num2,num3]])
  if num2:
    return '.'.join([str(x) for x in [num1,num2]])
  return str(num1)

for country_code,ip_start_str,ip_end_str in listFieldsSqlite(['country_code', 'ip_start_str', 'ip_end_str']):
  ip_start = [int(x) for x in ip_start_str.split('.')]
  ip_end = [int(x) for x in ip_end_str.split('.')]
  if ip_start[0] != ip_end[0]:
    for ip0 in range(ip_start[0], ip_end[0]+1):
      ip_block_to_country_code[joinNums(ip0)] = country_code
  else:
    ip0 = ip_start[0]
    if ip_start[1] != ip_end[1]:
      for ip1 in range(ip_start[1], ip_end[1]+1):
        ip_block_to_country_code[joinNums(ip0,ip1)] = country_code
    else:
      ip1 = ip_start[1]
      if ip_start[2] != ip_end[2]:
        for ip2 in range(ip_start[2], ip_end[2]+1):
          ip_block_to_country_code[joinNums(ip0,ip1,ip2)] = country_code
      else:
        ip2 = ip_start[2]
        if ip_start[3] != ip_end[3]:
          for ip3 in range(ip_start[3], ip_end[3]+1):
            ip_block_to_country_code[joinNums(ip0,ip1,ip2,ip3)] = country_code
        else:
          ip3 = ip_start[3]
          ip_block_to_country_code[joinNums(ip0,ip1,ip2,ip3)] = country_code

def country_code_for_ip(ip_address):
  parts = [int(x) for x in ip_address.split('.')]
  b2 = joinNums(parts[0],parts[1],parts[2])
  if b2 in ip_block_to_country_code:
    return ip_block_to_country_code[b2]
  b3 = joinNums(parts[0],parts[1],parts[2],parts[3])
  if b3 in ip_block_to_country_code:
    return ip_block_to_country_code[b3]
  b1 = joinNums(parts[0],parts[1])
  if b1 in ip_block_to_country_code:
    return ip_block_to_country_code[b1]
  b0 = joinNums(parts[0])
  if b0 in ip_block_to_country_code:
    return ip_block_to_country_code[b0]
  raise Exception('no code found for: ' + ip_address)
# Out:
# 1.0.0.255
# 16777471

# %%
#print ip_block_to_country_code['128']
#print ip_block_to_country_code['128.12']
#print ip_block_to_country_code['128.12.245']
#print ip_block_to_country_code['128.12.245.5']


print country_code_for_ip('128.12.245.5')
# Out:
# US

# %%
databases = {}

databasename = 'ml-004_clickstream_video.sqlite'
tablename = 'videos'

def getTableName():
  return tablename

def getDatabaseName():
  return databasename

def getColumns():
  return list(read_frame("select * from " + getTableName() + " limit 1", getDatabase()).columns.values)

def getDatabase():
  if databasename not in databases and 'sqlite' in databasename:
    databases[databasename] = sqlite3.connect(databasename)
  elif databasename not in databases:
    MySQLdb.connect(host='datastage.stanford.edu', user=datastage_login['user'], passwd=datastage_login['passwd'], db=databasename)
  return databases[databasename]

def listDistinct(fieldname, extraquery=''):
  data = read_frame("select distinct " + fieldname + " from " + getTableName() + " " + extraquery, getDatabase())
  return [x[0] for x in data[[fieldname]].itertuples(index=False)]

def listFields(fieldnames, extraquery=''):
  fieldnameString = ','.join(fieldnames)
  data = read_frame("select " + fieldnameString + " from " + getTableName() + " " + extraquery, getDatabase())
  return data.itertuples(index=False)

# %%
numLectures = 0
for lecture_id, in listFields(['max(lecture_id)']):
  numLectures = lecture_id + 1
print numLectures

user_to_lectures_watched = {}

for anon_username,lecture_id,event_type in listFields(['anon_username', 'lecture_id', 'event_type']):
  if anon_username not in user_to_lectures_watched:
    user_to_lectures_watched[anon_username] = set()
  if lecture_id not in user_to_lectures_watched[anon_username]:
    user_to_lectures_watched[anon_username].add(lecture_id)

num_lectures_watched_to_num_users = [0]*(numLectures)

for user,watched_lectures in user_to_lectures_watched.iteritems():
  num_lectures_watched_to_num_users[len(watched_lectures)] += 1

#pylab.plot(num_lectures_watched_to_num_users)
#pylab.xlabel('lecture num')
#pylab.ylabel('num users who have watched it')
#pylab.title('lecture num to num users who have watched it')

most_lectures_watched = max([len(lectures_watched) for user,lectures_watched in user_to_lectures_watched.iteritems()])

users_who_watched_all_lectures = [user for user,lectures_watched in user_to_lectures_watched.iteritems() if len(lectures_watched) >= most_lectures_watched/2 and max(lectures_watched) >= most_lectures_watched*3/4]
print len(users_who_watched_all_lectures)
users_who_watched_all_lectures_set = frozenset(users_who_watched_all_lectures)
# Out:
# 115
# 7622

# %%
print country_code_for_ip('167.80.244.193')
print country_code_for_ip('208.100.40.43')
#print country_code_for_ip('10.21.163.244')
print country_code_for_ip('38.65.195.5')
# Out:
# US
# US
# US

# %%
#print getColumns()

user_to_country = {}
country_to_users = {}

for anon_username,user_ip in listFields(['anon_username', 'user_ip']):
  if anon_username in user_to_country:
    continue
  country_code = None
  for ip_addr in user_ip.split(','):
    try:
      country_code = country_code_for_ip(ip_addr)
      break
    except Exception as e:
      continue
  if country_code == None:
    print user_ip
    print anon_username
    continue
  user_to_country[anon_username] = country_code
  if country_code not in country_to_users:
    country_to_users[country_code] = []
  country_to_users[country_code].append(anon_username)

# %%
# %matplotlib inline
import matplotlib.pyplot
import matplotlib.pylab as pylab
import numpy

def binsum(inp):
  output = []
  for i in range(len(inp)):
    curbin = inp[i-2:i+3]
    val = sum(curbin)
    output.append(val)
  return output

def barPlotWithStderr(means, stderrs=None, x_tick_labels=None, xlabel='', ylabel='', title='', addLabels=True):
    if stderrs:
        assert len(means) == len(stderrs)
    if x_tick_labels:
        assert len(means) == len(x_tick_labels)
        x_tick_labels = [str(x) for x in x_tick_labels]
    else:
        x_tick_labels = [str(x) for x in range(len(means))]
    N = len(means)
    ind = numpy.arange(N) # the x locations for the groups
    width = 0.35 # the width of the bars
    fig, ax = matplotlib.pyplot.subplots()
    if stderrs:
        rects1 = ax.bar(ind, means, width, color='r', yerr=stderrs)
    else:
        rects1 = ax.bar(ind, means, width, color='r')
    
    if ylabel and not title:
        title = ylabel
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticks(ind+width)
    ax.set_xticklabels( x_tick_labels )
    
    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            #ax.text('foobar', 1.05*height, '%d'%int(height), ha='center', va='bottom')
            ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height), ha='center', va='bottom')
    if addLabels:
      autolabel(rects1)

def plotBarDictionary(datadict, xlabel='', ylabel='', title='', x_tick_label_map=None):
    keys = datadict.keys()
    keys.sort()
    means = [datadict[k] for k in keys]
    if not x_tick_label_map:
      x_tick_labels = keys
    else:
      x_tick_labels = [x_tick_label_map[key] for key in keys]
    barPlotWithStderr(means, x_tick_labels=x_tick_labels, xlabel=xlabel, ylabel=ylabel, title=title)

# %%
country_to_num_users = {country:len(users) for country,users in country_to_users.iteritems()}
total_users = float(sum(country_to_num_users.values()))
numusers_and_country = sorted([(numusers/total_users,country) for country,numusers in country_to_num_users.iteritems()], reverse=True)
numusers = [x[0] for x in numusers_and_country[:15]]
numusers.append(1.0 - sum(numusers))
countries = [x[1] for x in numusers_and_country[:15]]
countries.append('oth')
barPlotWithStderr(means=numusers, x_tick_labels=countries, addLabels=False)

# %%
for numusers,country in numusers_and_country:
  print country, numusers
# Out:
# US 0.340654918596
# IN 0.11148371087
# CN 0.0705554903506
# GB 0.0428564242719
# RU 0.0296272698312
# CA 0.0295266678962
# DE 0.0281350077966
# ES 0.0210090374072
# FR 0.0202042219279
# BR 0.0195000083835
# AU 0.0145202126054
# NL 0.0118374943411
# IT 0.0115524555256
# IL 0.0109656109052
# PL 0.0106302711222
# JP 0.0102613973609
# SG 0.0101272614477
# KR 0.00957395080565
# UA 0.00935597994668
# GR 0.00885297027213
# TW 0.0080984557603
# MX 0.00783018393387
# SE 0.00724333931356
# TR 0.00717627135695
# CH 0.00640498985597
# RO 0.00590198018142
# HK 0.00563370835499
# CO 0.00554987340923
# VN 0.00509716470213
# IE 0.00491272782147
# FI 0.00462768900589
# BE 0.00462768900589
# PK 0.00454385406013
# AR 0.00422528126624
# PT 0.00420851427709
# EG 0.00415821330964
# DK 0.00390670847236
# CZ 0.00357136868932
# IR 0.00343723277611
# MY 0.00303482503647
# RS 0.00293422310156
# ZA 0.0028503881558
# HR 0.00271625224258
# PE 0.00259888331852
# AT 0.00256534934022
# NO 0.00253181536192
# BY 0.00249828138361
# SA 0.00238091245955
# BG 0.00221324256803
# HU 0.00217970858973
# CL 0.00207910665482
# NZ 0.00201203869821
# TH 0.001877902785
# SI 0.001877902785
# PH 0.001877902785
# ID 0.00184436880669
# BD 0.00179406783924
# MA 0.00177730085009
# EU 0.00165993192602
# SK 0.00147549504535
# NG 0.00140842708875
# AE 0.00129105816469
# VE 0.00127429117553
# EE 0.00124075719723
# LK 0.00120722321893
# LT 0.00117368924062
# KZ 0.00102278633826
# EC 0.00095571838165
# LV 0.000922184403347
# KE 0.000905417414195
# TN 0.000888650425043
# ET 0.000821582468436
# DZ 0.000804815479284
# MK 0.000754514511829
# NP 0.000704213544374
# GH 0.000620378598615
# DO 0.00057007763116
# CR 0.00057007763116
# UY 0.000553310642008
# GT 0.000519776663704
# AP 0.000519776663704
# AM 0.000519776663704
# A1 0.000469475696249
# PS 0.000419174728794
# MD 0.000419174728794
# IS 0.000402407739642
# CY 0.000402407739642
# BO 0.000402407739642
# LU 0.00038564075049
# AL 0.00038564075049
# MN 0.000368873761339
# LB 0.000368873761339
# PR 0.000352106772187
# SY 0.000318572793883
# JM 0.000318572793883
# BA 0.000301805804732
# TT 0.00028503881558
# KG 0.00028503881558
# GE 0.000268271826428
# SD 0.000251504837276
# PA 0.000251504837276
# JO 0.000251504837276
# QA 0.000234737848125
# KW 0.000234737848125
# MO 0.000217970858973
# AZ 0.000217970858973
# PY 0.000167669891518
# IQ 0.000167669891518
# BS 0.000167669891518
# MT 0.000150902902366
# UG 0.000134135913214
# NI 0.000134135913214
# HN 0.000134135913214
# BH 0.000134135913214
# YE 0.000117368924062
# SV 0.000117368924062
# MU 0.000117368924062
# KH 0.000117368924062
# CM 0.000117368924062
# SN 0.000100601934911
# MM 0.000100601934911
# RW 8.38349457588e-05
# OM 8.38349457588e-05
# LY 8.38349457588e-05
# BZ 8.38349457588e-05
# ZM 6.7067956607e-05
# UZ 6.7067956607e-05
# TZ 6.7067956607e-05
# MV 6.7067956607e-05
# MG 6.7067956607e-05
# ME 6.7067956607e-05
# MC 6.7067956607e-05
# BN 6.7067956607e-05
# TG 5.03009674553e-05
# CI 5.03009674553e-05
# BB 5.03009674553e-05
# A2 5.03009674553e-05
# ZW 3.35339783035e-05
# VI 3.35339783035e-05
# PF 3.35339783035e-05
# NA 3.35339783035e-05
# GI 3.35339783035e-05
# FJ 3.35339783035e-05
# WS 1.67669891518e-05
# VC 1.67669891518e-05
# SZ 1.67669891518e-05
# SR 1.67669891518e-05
# SC 1.67669891518e-05
# RE 1.67669891518e-05
# MW 1.67669891518e-05
# MQ 1.67669891518e-05
# ML 1.67669891518e-05
# MH 1.67669891518e-05
# LR 1.67669891518e-05
# LI 1.67669891518e-05
# KY 1.67669891518e-05
# KN 1.67669891518e-05
# JE 1.67669891518e-05
# GU 1.67669891518e-05
# GQ 1.67669891518e-05
# GP 1.67669891518e-05
# GG 1.67669891518e-05
# GF 1.67669891518e-05
# FO 1.67669891518e-05
# DM 1.67669891518e-05
# DJ 1.67669891518e-05
# CW 1.67669891518e-05
# CV 1.67669891518e-05
# CU 1.67669891518e-05
# BT 1.67669891518e-05
# BM 1.67669891518e-05
# AW 1.67669891518e-05
# AG 1.67669891518e-05
# AF 1.67669891518e-05

# %%
country_to_num_users = {country:len([x for x in users if x in users_who_watched_all_lectures_set]) for country,users in country_to_users.iteritems()}
total_users = float(sum(country_to_num_users.values()))
numusers_and_country = sorted([(numusers/total_users,country) for country,numusers in country_to_num_users.iteritems()], reverse=True)
numusers = [x[0] for x in numusers_and_country[:15]]
numusers.append(1.0 - sum(numusers))
countries = [x[1] for x in numusers_and_country[:15]]
countries.append('oth')
barPlotWithStderr(means=numusers, x_tick_labels=countries, addLabels=False)

# %%
start_finish_country = []
for country,users in country_to_users.iteritems():
  finishing_users = [x for x in users if x in users_who_watched_all_lectures_set]
  start_finish_country.append((len(users), len(finishing_users), country))

start_finish_country = sorted(start_finish_country, reverse=True)
finish_ratios = [finish/float(start) for start,finish,country in start_finish_country[:15]]
finish_ratios.append(sum([finish for start,finish,country in start_finish_country[15:]]) / float(sum([start for start,finish,country in start_finish_country[15:]])))

countries = [country for start,finish,country in start_finish_country[:15]]
countries.append('oth')
barPlotWithStderr(means=finish_ratios, x_tick_labels=countries, addLabels=False)

# %%
def noFilterUsers(anon_username):
  return True

def usersWhoHaveWatchedMostLectures(anon_username):
  return anon_username in users_who_watched_all_lectures_set

def usersInUS(anon_username):
  return anon_username in user_to_country and user_to_country[anon_username] == 'US'

def usersInIN(anon_username):
  return anon_username in user_to_country and user_to_country[anon_username] == 'IN'

def usersInCN(anon_username):
  return anon_username in user_to_country and user_to_country[anon_username] == 'CN'

def usersOutsideUS(anon_username):
  return anon_username in user_to_country and user_to_country[anon_username] != 'US'

def usersInEnglishSpeakingCountries(anon_username):
  return anon_username in user_to_country and user_to_country[anon_username] in ['US', 'IN', 'GB', 'CA']

def usersOutsideEnglishSpeakingCountries(anon_username):
  return anon_username in user_to_country and user_to_country[anon_username] not in ['US', 'IN', 'GB', 'CA']


userFilter = noFilterUsers


def listFieldsFilterUsers(fieldnames, extraquery=''):
  assert fieldnames[0] == 'anon_username'
  for tupval in listFields(fieldnames, extraquery):
    if not userFilter(tupval[0]):
      continue
    yield tupval

# %%
def plotEventTimes(target_event_type, dbname, lecturenum):
  global databasename

  databasename = dbname

  user_to_events = {}
  for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=' + str(lecturenum)):
    if anon_username not in user_to_events:
      user_to_events[anon_username] = []
    user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))

  videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])

  numStarts = [0]*(videoLength+1)

  for user,events in user_to_events.iteritems():
    for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
      curr_time = int(round(curr_time))
      if event_type == target_event_type:
        if curr_time == 0:
          continue
        numStarts[curr_time] += 1

  matplotlib.pyplot.plot(numStarts)
  matplotlib.pyplot.title(target_event_type + ' events (' + dbname + ' lecture ' + str(lecturenum) + ')')
  matplotlib.pyplot.xlabel('video time, seconds')
  matplotlib.pyplot.ylabel('num ' + target_event_type + ' events at this point')
  matplotlib.pyplot.show()

def plotEventTimesNoDuplicatesPerUser(target_event_type, dbname, lecturenum):
  global databasename

  databasename = dbname

  user_to_events = {}
  for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=' + str(lecturenum)):
    if anon_username not in user_to_events:
      user_to_events[anon_username] = []
    user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))

  videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])

  numStarts = [0]*(videoLength+1)

  for user,events in user_to_events.iteritems():
    numStartsUser = [0]*(videoLength+1)
    for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
      if event_type == target_event_type:
        if curr_time == 0:
          continue
        numStartsUser[curr_time] += 1
    for i in range(len(numStarts)):
      if numStartsUser[i] > 0:
        numStarts[i] += 1

  matplotlib.pyplot.plot(numStarts)
  matplotlib.pyplot.title(target_event_type + ' events, no duplicates per user (' + dbname + ' lecture ' + str(lecturenum) + ')')
  matplotlib.pyplot.xlabel('video time, seconds')
  matplotlib.pyplot.ylabel('num ' + target_event_type + ' events at this point (each user counted at most 1 time)')
  matplotlib.pyplot.show()
  
#matplotlib.pyplot.plot(binsum(numStarts))
#matplotlib.pyplot.title('start events within 3 seconds')
#matplotlib.pyplot.xlabel('video time, seconds')
#matplotlib.pyplot.ylabel('num start events from this point (or within 3 seconds)')
#matplotlib.pyplot.show()

# %%
#def extractFixedSeeks(eventDictionary):
#  isPlaying = False
#  playStartTime = 0
#  playStartTimeStamp = 0
#  prevEventType = ''

def extractPlayedSpans(events, endTime=None):
  isPlaying = False
  playedSpans = []
  playStartTime = 0
  playStartTimeStamp = 0
  prevEventType = ''
  for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
    curr_time = int(round(curr_time))
    if event_type == 'play':
      isPlaying = True
      playStartTime = curr_time
      playStartTimeStamp = event_timestamp
    if event_type == 'pause':
      isPlaying = False
      playedSpans.append((playStartTime, curr_time))
    if event_type == 'seeked':
      if isPlaying:
        playDurationMillisecs = event_timestamp - playStartTimeStamp
        playDurationSeconds = int(playDurationMillisecs/1000.0)
        playEndTime = playStartTime + playDurationSeconds
        if (endTime and playEndTime > endTime) or playDurationSeconds > 600:
          isPlaying = False
          continue
        playedSpans.append((playStartTime, playEndTime))
      playStartTime = curr_time
      playStartTimeStamp = event_timestamp
    prevEventType = event_type
  if endTime and isPlaying:
    playedSpans.append((playStartTime, endTime))
  return playedSpans

# %%
#plotEventTimes('play', 'pgm-003_clickstream_video.sqlite', 2)
plotEventTimes('play', 'ml-004_clickstream_video.sqlite', 2)

# %%
#plotEventTimes('ratechange', 'pgm-003_clickstream_video.sqlite', 2)
plotEventTimes('ratechange', 'ml-004_clickstream_video.sqlite', 2)

# %%
def plotSegmentViews(dbname, lecturenum):

  global databasename
  databasename = dbname #'coursera_eventing_pgm-003'

  user_to_events = {}
  for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=' + str(lecturenum)):
    if anon_username not in user_to_events:
      user_to_events[anon_username] = []
    user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))
  
  videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    for start,end in extractPlayedSpans(events, endTime=videoLength):
      #print end, len(numPlayTimes)
      for sec in range(start, end):
        if sec >= len(numPlayTimes) or sec < 0:
          break
        numPlayTimes[sec] += 1
  
  #matplotlib.pyplot.plot(numPlayTimes)
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes) or sec < 0:
          break
        numPlayTimes[sec] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='total num times segment was watched, over all users')

  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes) or sec < 0:
          break
        playTimes[sec] += 1
        if playTimes[sec] > 1:
          numPlayTimes[sec] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='total number of times video was re-watched, over all users')
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes) or sec < 0:
          continue
        playTimes[sec] += 1
    for i in range(len(numPlayTimes)):
      if playTimes[i] >= 1:
        numPlayTimes[i] += 1
  
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='number unique users who watched the segment at least once')
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes) or sec < 0:
          continue
        playTimes[sec] += 1
    for i in range(len(numPlayTimes)):
      if playTimes[i] >= 2:
        numPlayTimes[i] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='number unique users who watched the segment at least twice')
  

  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes) or sec < 0:
          continue
        playTimes[sec] += 1
    for i in range(len(numPlayTimes)):
      if playTimes[i] == 1:
        numPlayTimes[i] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='number unique users who watched the segment exactly once')  
  
  
  
  matplotlib.pyplot.title('video segments viewed (' + dbname + ' lecture ' + str(lecturenum) + ')')
  matplotlib.pyplot.legend(bbox_to_anchor=(2.3, 0.8))
  matplotlib.pyplot.xlabel('video time, seconds')
  matplotlib.pyplot.ylabel('number of times viewed')
  matplotlib.pyplot.show()

# %%
#plotSegmentViews('pgm-003_clickstream_video.sqlite', 2)
plotSegmentViews('ml-004_clickstream_video.sqlite', 50)

# %%
lecture_starts = [0 for i in range(numLectures)]

for event_type,curr_time,lecture_id in listFields(['event_type', 'curr_time', 'lecture_id'], 'where event_type="play" and curr_time=0'):
  lecture_starts[lecture_id] += 1

pylab.plot(lecture_starts)

# %%
lecture_end_times = [0 for i in range(numLectures)]
lecture_pause_to_counts = [{} for i in range(numLectures)]

for event_type,curr_time,lecture_id in listFields(['event_type', 'curr_time', 'lecture_id'], 'where event_type="pause"'):
  if curr_time > 3600: # there are no lectures more than an hour long, if have such a result is bugggy data
    continue
  if curr_time not in lecture_pause_to_counts[lecture_id]:
    lecture_pause_to_counts[lecture_id][curr_time] = 0
  lecture_pause_to_counts[lecture_id][curr_time] += 1
  if lecture_pause_to_counts[lecture_id][curr_time] >= 10:
    lecture_end_times[lecture_id] = max(curr_time, lecture_end_times[lecture_id])

# %%
'''
lecture_lengths = [0 for i in range(numLectures)]
lecture_pause_times = [{} for i in range(numLectures)]
for anon_username,event_type,lecture_id,curr_time in listFields(['anon_username', 'event_type', 'lecture_id', 'curr_time'], 'where event_type="pause"'):
  if curr_time not in lecture_pause_times[lecture_id]:
    lecture_pause_times[lecture_id][curr_time] = 1
  else:
    lecture_pause_times[lecture_id][curr_time] += 1
    if (lecture_pause_times[lecture_id][curr_time] >= 10):
      lecture_lengths[lecture_id] = max(lecture_lengths[lecture_id], curr_time)
'''

print lecture_end_times
pylab.plot(lecture_end_times)
# Out:
# [0, 433.99521995400005, 749.13366666600007, 749.26708984375, 853.70099700000003, 490.01171875, 492.28699999999998, 669.223388671875, 528.133332, 620.7864990234375, 710.93333199999995, 690.21400000000006, 349.93333200000001, 525.09699999999998, 413.87299999999999, 819.177001953125, 669.4320068359375, 542.32600000000002, 672.9840087890625, 502.19999899999999, 304.62359619140625, 531.999999, 538.53333199999997, 459.39999899999998, 977.86666500000001, 358.999999, 839.03331000000003, 967.34400000000005, 795.06666499999994, 578.26666499999999, 828.1400146484375, 775.92147299999999, 213.33333200000001, 488.50201416015625, 444.59300000000002, 889.78900146484375, 614.81852600000002, 846.55657499999995, 375.281005859375, 582.64147300000002, 610.82501220703125, 640.22100830078125, 513.81201171875, 575.95551, 467.46666599999998, 721.18902587890625, 706.00372314453125, 435.58401489257812, 620.04302978515625, 231.29400634765625, 403.21499999999997, 719.30799999999999, 764.19249400000001, 467.58100000000002, 697.48101806640625, 411.4580078125, 803.666015625, 390.26666499999999, 685.7550048828125, 350.529, 455.11200000000002, 723.25599999999997, 462.3330078125, 680.15899999999999, 713.45979499999999, 410.01800537109375, 569.7490234375, 791.98699999999997, 695.76300048828125, 845.64801025390625, 669.50099999999998, 887.1190185546875, 636.25, 1181.780029296875, 944.75099999999998, 943.19500732421875, 1262.818, 752.53221995400008, 752.5360107421875, 424.62400000000002, 469.22900390625, 502.24799999999999, 609.73299999999995, 327.5880126953125, 545.60000000000002, 913.9840087890625, 630.28302001953125, 234.1510009765625, 768.66666499999997, 458.24600219726562, 627.54302978515625, 722.76800537109375, 787.71400000000006, 456.08700561523438, 0, 737.18799999999999, 825.84100341796875, 843.46666500000003, 474.57000732421875, 871.58502197265625, 614.6090087890625, 506.892, 507.91400146484375, 510.81600952148438, 344.97943299999997, 799.11500000000001, 377.952, 691.468017578125, 770.78700000000003, 848.62, 422.23200000000003, 879.99000000000001, 980.02200000000005, 830.69444399999998, 282.066665]

# %%
def arraySum(l):
  output = None
  for x in l:
    if output == None:
      output = x
    else:
      output = numpy.add(output, x)
  return output

def getNumStarts():
  num_lecture_starts = [0 for i in range(numLectures)]
  for anon_username,event_type,curr_time,lecture_id in listFieldsFilterUsers(['anon_username', 'event_type', 'curr_time', 'lecture_id'], 'where event_type="play" and curr_time=0'):
    num_lecture_starts[lecture_id] += 1
  return num_lecture_starts

def plotSeeksOverTime():
  lecture_to_user_to_seeks = [{} for i in range(numLectures)]
  
  for anon_username,event_type,lecture_id,playback_rate,event_timestamp in listFieldsFilterUsers(['anon_username', 'event_type', 'lecture_id', 'playback_rate', 'event_timestamp'], 'where event_type="seeked"'):
    if anon_username not in lecture_to_user_to_seeks[lecture_id]:
      lecture_to_user_to_seeks[lecture_id][anon_username] = []
    lecture_to_user_to_seeks[lecture_id][anon_username].append({'event_type': event_type, 'curr_time': curr_time})

  lecture_to_num_viewers = getNumStarts()
  lecture_to_num_seeks = [0 for i in range(numLectures)]
  #lecture_to_num_viewers = [0 for i in range(numLectures)]
  for lecture_id,user_to_seeks in enumerate(lecture_to_user_to_seeks):
    for user,seeks in user_to_seeks.iteritems():
      #lecture_to_num_viewers[lecture_id] += 1
      for event in seeks:
        if event['event_type'] == 'seeked':
          lecture_to_num_seeks[lecture_id] += 1
  pylab.plot(lecture_to_num_seeks)
  pylab.show()
  
  lecture_to_num_seeks_per_user = [0 for i in range(numLectures)]
  for i in range(numLectures):
    if lecture_end_times[i] < 10:
      continue
    if lecture_to_num_viewers[i] < 1:
      continue
    lecture_to_num_seeks_per_user[i] = lecture_to_num_seeks[i] / float(lecture_to_num_viewers[i])
  pylab.plot(lecture_to_num_seeks_per_user)
  pylab.show()
  
  lecture_to_num_seeks_per_user_per_second = [0 for i in range(numLectures)]
  for i in range(numLectures):
    if lecture_end_times[i] < 10:
      continue
    lecture_to_num_seeks_per_user_per_second[i] = lecture_to_num_seeks_per_user[i] / float(lecture_end_times[i])
  pylab.plot(lecture_to_num_seeks_per_user_per_second)
  pylab.show()


def plotPlaybackRatesOverTime():
  lecture_to_user_to_playback_rates = [{} for i in range(numLectures)]
  
  for anon_username,event_type,lecture_id,playback_rate in listFieldsFilterUsers(['anon_username', 'event_type', 'lecture_id', 'playback_rate'], 'where event_type="pause"'):
    if anon_username not in lecture_to_user_to_playback_rates[lecture_id]:
      lecture_to_user_to_playback_rates[lecture_id][anon_username] = []
    lecture_to_user_to_playback_rates[lecture_id][anon_username].append(playback_rate)
  
  lecture_to_num_075 = [0]*numLectures
  lecture_to_num_100 = [0]*numLectures
  lecture_to_num_125 = [0]*numLectures
  lecture_to_num_150 = [0]*numLectures
  lecture_to_num_175 = [0]*numLectures
  lecture_to_num_200 = [0]*numLectures
  
  for lecture in range(len(lecture_to_user_to_playback_rates)):
    for user,playback_rates in lecture_to_user_to_playback_rates[lecture].iteritems():
      for playback_rate in playback_rates:
        if 0.74 <= playback_rate <= 0.76:
          lecture_to_num_075[lecture] += 1
        if 0.99 <= playback_rate <= 1.01:
          lecture_to_num_100[lecture] += 1
        if 1.24 <= playback_rate <= 1.26:
          lecture_to_num_125[lecture] += 1
        if 1.49 <= playback_rate <= 1.51:
          lecture_to_num_150[lecture] += 1
        if 1.74 <= playback_rate <= 1.76:
          lecture_to_num_175[lecture] += 1
        if 1.99 <= playback_rate <= 2.01:
          lecture_to_num_200[lecture] += 1
  
  pylab.plot(lecture_to_num_075, label='0.75')
  pylab.plot(lecture_to_num_100, label='1.00')
  pylab.plot(lecture_to_num_125, label='1.25')
  pylab.plot(lecture_to_num_150, label='1.50')
  pylab.plot(lecture_to_num_175, label='1.75')
  pylab.plot(lecture_to_num_200, label='2.00')
  pylab.legend(bbox_to_anchor=(2.3, 0.8))
  pylab.show()
  
  lecture_to_total = arraySum([lecture_to_num_075,lecture_to_num_100,lecture_to_num_125,lecture_to_num_150,lecture_to_num_175,lecture_to_num_200])
  lecture_to_frac_075 = numpy.true_divide(lecture_to_num_075, lecture_to_total)
  lecture_to_frac_100 = numpy.true_divide(lecture_to_num_100, lecture_to_total)
  lecture_to_frac_125 = numpy.true_divide(lecture_to_num_125, lecture_to_total)
  lecture_to_frac_150 = numpy.true_divide(lecture_to_num_150, lecture_to_total)
  lecture_to_frac_175 = numpy.true_divide(lecture_to_num_175, lecture_to_total)
  lecture_to_frac_200 = numpy.true_divide(lecture_to_num_200, lecture_to_total)
  
  pylab.plot(lecture_to_frac_075, label='0.75')
  pylab.plot(lecture_to_frac_100, label='1.00')
  pylab.plot(lecture_to_frac_125, label='1.25')
  pylab.plot(lecture_to_frac_150, label='1.50')
  pylab.plot(lecture_to_frac_175, label='1.75')
  pylab.plot(lecture_to_frac_200, label='2.00')
  pylab.legend(bbox_to_anchor=(2.3, 0.8))
  pylab.show()

# %%
#userFilter = usersWhoHaveWatchedMostLectures
userFilter = noFilterUsers

plotPlaybackRatesOverTime()

# %%
userFilter = usersWhoHaveWatchedMostLectures
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()

# %%
userFilter = usersInUS
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()

# %%
userFilter = usersInIN
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()

# %%
userFilter = usersInCN
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()

# %%
userFilter = lambda x: usersInUS(x) and usersWhoHaveWatchedMostLectures(x)
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()
userFilter = noFilterUsers

# %%
userFilter = lambda x: usersInIN(x) and usersWhoHaveWatchedMostLectures(x)
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()
userFilter = noFilterUsers

# %%
userFilter = lambda x: usersInCN(x) and usersWhoHaveWatchedMostLectures(x)
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()
userFilter = noFilterUsers

# %%
userFilter = lambda x: usersInEnglishSpeakingCountries(x) and usersWhoHaveWatchedMostLectures(x) and not usersInUS(x)
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()
userFilter = noFilterUsers

# %%
userFilter = lambda x: usersOutsideEnglishSpeakingCountries(x) and usersWhoHaveWatchedMostLectures(x)
#userFilter = noFilterUsers

plotPlaybackRatesOverTime()
userFilter = noFilterUsers

# %%
#userFilter = usersWhoHaveWatchedMostLectures
userFilter = noFilterUsers

plotSeeksOverTime()

# %%
userFilter = usersWhoHaveWatchedMostLectures
#userFilter = noFilterUsers

plotSeeksOverTime()
userFilter = noFilterUsers

# %%
userFilter = usersInUS
#userFilter = noFilterUsers

plotSeeksOverTime()
userFilter = noFilterUsers

# %%
userFilter = usersInIN
#userFilter = noFilterUsers

plotSeeksOverTime()
userFilter = noFilterUsers

# %%
userFilter = usersInCN
#userFilter = noFilterUsers

plotSeeksOverTime()
userFilter = noFilterUsers

# %%
userFilter = lambda x: usersInUS(x) and usersWhoHaveWatchedMostLectures(x)
#userFilter = noFilterUsers

plotSeeksOverTime()
userFilter = noFilterUsers

# %%
userFilter = lambda x: usersInIN(x) and usersWhoHaveWatchedMostLectures(x)
#userFilter = noFilterUsers

plotSeeksOverTime()
userFilter = noFilterUsers

# %%
userFilter = lambda x: usersInIN(x) and usersWhoHaveWatchedMostLectures(x)
#userFilter = noFilterUsers

plotSeeksOverTime()
userFilter = noFilterUsers

# %%
'''
print 'all lectures'

total_events = sum(lecture_to_num_075) + sum(lecture_to_num_100) + sum(lecture_to_num_125) + sum(lecture_to_num_150) + sum(lecture_to_num_175) + sum(lecture_to_num_200)
print total_events

print sum(lecture_to_num_075), sum(lecture_to_num_075)/float(total_events)
print sum(lecture_to_num_100), sum(lecture_to_num_100)/float(total_events)
print sum(lecture_to_num_125), sum(lecture_to_num_125)/float(total_events)
print sum(lecture_to_num_150), sum(lecture_to_num_150)/float(total_events)
print sum(lecture_to_num_175), sum(lecture_to_num_175)/float(total_events)
print sum(lecture_to_num_200), sum(lecture_to_num_200)/float(total_events)

print 'lectures before 70'

total_events = sum(lecture_to_num_075[:70]) + sum(lecture_to_num_100[:70]) + sum(lecture_to_num_125[:70]) + sum(lecture_to_num_150[70:]) + sum(lecture_to_num_175[:70]) + sum(lecture_to_num_200[:70])
print total_events

print sum(lecture_to_num_075[:70]), sum(lecture_to_num_075[:70])/float(total_events)
print sum(lecture_to_num_100[:70]), sum(lecture_to_num_100[:70])/float(total_events)
print sum(lecture_to_num_125[:70]), sum(lecture_to_num_125[:70])/float(total_events)
print sum(lecture_to_num_150[:70]), sum(lecture_to_num_150[:70])/float(total_events)
print sum(lecture_to_num_175[:70]), sum(lecture_to_num_175[:70])/float(total_events)
print sum(lecture_to_num_200[:70]), sum(lecture_to_num_200[:70])/float(total_events)

print 'lectures after 70'

total_events = sum(lecture_to_num_075[70:]) + sum(lecture_to_num_100[70:]) + sum(lecture_to_num_125[70:]) + sum(lecture_to_num_150[70:]) + sum(lecture_to_num_175[70:]) + sum(lecture_to_num_200[70:])
print total_events

print sum(lecture_to_num_075[70:]), sum(lecture_to_num_075[70:])/float(total_events)
print sum(lecture_to_num_100[70:]), sum(lecture_to_num_100[70:])/float(total_events)
print sum(lecture_to_num_125[70:]), sum(lecture_to_num_125[70:])/float(total_events)
print sum(lecture_to_num_150[70:]), sum(lecture_to_num_150[70:])/float(total_events)
print sum(lecture_to_num_175[70:]), sum(lecture_to_num_175[70:])/float(total_events)
print sum(lecture_to_num_200[70:]), sum(lecture_to_num_200[70:])/float(total_events)
'''
# Out:
# "\nprint 'all lectures'\n\ntotal_events = sum(lecture_to_num_075) + sum(lecture_to_num_100) + sum(lecture_to_num_125) + sum(lecture_to_num_150) + sum(lecture_to_num_175) + sum(lecture_to_num_200)\nprint total_events\n\nprint sum(lecture_to_num_075), sum(lecture_to_num_075)/float(total_events)\nprint sum(lecture_to_num_100), sum(lecture_to_num_100)/float(total_events)\nprint sum(lecture_to_num_125), sum(lecture_to_num_125)/float(total_events)\nprint sum(lecture_to_num_150), sum(lecture_to_num_150)/float(total_events)\nprint sum(lecture_to_num_175), sum(lecture_to_num_175)/float(total_events)\nprint sum(lecture_to_num_200), sum(lecture_to_num_200)/float(total_events)\n\nprint 'lectures before 70'\n\ntotal_events = sum(lecture_to_num_075[:70]) + sum(lecture_to_num_100[:70]) + sum(lecture_to_num_125[:70]) + sum(lecture_to_num_150[70:]) + sum(lecture_to_num_175[:70]) + sum(lecture_to_num_200[:70])\nprint total_events\n\nprint sum(lecture_to_num_075[:70]), sum(lecture_to_num_075[:70])/float(total_events)\nprint sum(lecture_to_num_100[:70]), sum(lecture_to_num_100[:70])/float(total_events)\nprint sum(lecture_to_num_125[:70]), sum(lecture_to_num_125[:70])/float(total_events)\nprint sum(lecture_to_num_150[:70]), sum(lecture_to_num_150[:70])/float(total_events)\nprint sum(lecture_to_num_175[:70]), sum(lecture_to_num_175[:70])/float(total_events)\nprint sum(lecture_to_num_200[:70]), sum(lecture_to_num_200[:70])/float(total_events)\n\nprint 'lectures after 70'\n\ntotal_events = sum(lecture_to_num_075[70:]) + sum(lecture_to_num_100[70:]) + sum(lecture_to_num_125[70:]) + sum(lecture_to_num_150[70:]) + sum(lecture_to_num_175[70:]) + sum(lecture_to_num_200[70:])\nprint total_events\n\nprint sum(lecture_to_num_075[70:]), sum(lecture_to_num_075[70:])/float(total_events)\nprint sum(lecture_to_num_100[70:]), sum(lecture_to_num_100[70:])/float(total_events)\nprint sum(lecture_to_num_125[70:]), sum(lecture_to_num_125[70:])/float(total_events)\nprint sum(lecture_to_num_150[70:]), sum(lecture_to_num_150[70:])/float(total_events)\nprint sum(lecture_to_num_175[70:]), sum(lecture_to_num_175[70:])/float(total_events)\nprint sum(lecture_to_num_200[70:]), sum(lecture_to_num_200[70:])/float(total_events)\n"

# %%
#for lecture in range(len(lecture_to_user_to_playback_rates)):
#  total_watches =

# %%
def arraySum(l):
  output = None
  for x in l:
    if output == None:
      output = x
    else:
      output = numpy.add(output, x)
  return output

lecture_to_total = arraySum([lecture_to_num_075,lecture_to_num_100,lecture_to_num_125,lecture_to_num_150,lecture_to_num_175,lecture_to_num_200])
lecture_to_frac_075 = numpy.true_divide(lecture_to_num_075, lecture_to_total)
lecture_to_frac_100 = numpy.true_divide(lecture_to_num_100, lecture_to_total)
lecture_to_frac_125 = numpy.true_divide(lecture_to_num_125, lecture_to_total)
lecture_to_frac_150 = numpy.true_divide(lecture_to_num_150, lecture_to_total)
lecture_to_frac_175 = numpy.true_divide(lecture_to_num_175, lecture_to_total)
lecture_to_frac_200 = numpy.true_divide(lecture_to_num_200, lecture_to_total)

pylab.plot(lecture_to_frac_075)
pylab.plot(lecture_to_frac_100)
pylab.plot(lecture_to_frac_125)
pylab.plot(lecture_to_frac_150)
pylab.plot(lecture_to_frac_175)
pylab.plot(lecture_to_frac_200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-3a692047b17d> in <module>()
#       8   return output
#       9
# ---> 10 lecture_to_total = arraySum([lecture_to_num_075,lecture_to_num_100,lecture_to_num_125,lecture_to_num_150,lecture_to_num_175,lecture_to_num_200])
#      11 lecture_to_frac_075 = numpy.true_divide(lecture_to_num_075, lecture_to_total)
#      12 lecture_to_frac_100 = numpy.true_divide(lecture_to_num_100, lecture_to_total)
#
# NameError: name 'lecture_to_num_075' is not defined

# %%
lecture_to_user_to_start_timestamps = [{} for i in range(numLectures)]
lecture_to_user_to_finish_timestamps = [{} for i in range(numLectures)]
lecture_to_user_to_seek_timestamps = [{} for i in range(numLectures)]
lecture_to_user_to_ratechange_timestamps = [{} for i in range(numLectures)]

lecture_to_user_to_seek_times = [{} for i in range(numLectures)]

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="play" and curr_time=0'):
  if anon_username not in lecture_to_user_to_start_timestamps[lecture_id]:
    lecture_to_user_to_start_timestamps[lecture_id][anon_username] = []
  lecture_to_user_to_start_timestamps[lecture_id][anon_username].append(event_timestamp)

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="pause"'):
  if curr_time != lecture_end_times[lecture_id]:
    continue
  if anon_username not in lecture_to_user_to_finish_timestamps[lecture_id]:
    lecture_to_user_to_finish_timestamps[lecture_id][anon_username] = []
  lecture_to_user_to_finish_timestamps[lecture_id][anon_username].append(event_timestamp)

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="ratechange"'):
  if anon_username not in lecture_to_user_to_ratechange_timestamps[lecture_id]:
    lecture_to_user_to_ratechange_timestamps[lecture_id][anon_username] = []
  lecture_to_user_to_ratechange_timestamps[lecture_id][anon_username].append(event_timestamp)
  
for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="seeked" and curr_time<>0'):
  if curr_time == lecture_end_times[lecture_id]:
    continue
  if anon_username not in lecture_to_user_to_seek_timestamps[lecture_id]:
    lecture_to_user_to_seek_timestamps[lecture_id][anon_username] = []
    lecture_to_user_to_seek_times[lecture_id][anon_username] = []
  lecture_to_user_to_seek_timestamps[lecture_id][anon_username].append(event_timestamp)
  lecture_to_user_to_seek_times[lecture_id][anon_username].append(curr_time)

# %%
lecture_to_num_start = []
lecture_to_num_finish = []
lecture_to_num_seek = []
lecture_to_num_ratechange = []

for v in lecture_to_user_to_start_timestamps:
  lecture_to_num_start.append(sum([len(x) for x in v.values()]))

for v in lecture_to_user_to_finish_timestamps:
  lecture_to_num_finish.append(sum([len(x) for x in v.values()]))

for v in lecture_to_user_to_seek_timestamps:
  lecture_to_num_seek.append(sum([len(x) for x in v.values()]))

for v in lecture_to_user_to_ratechange_timestamps:
  lecture_to_num_ratechange.append(sum([len(x) for x in v.values()]))

# %%
pylab.plot(lecture_to_num_start)
pylab.xlabel('lecture num')
pylab.ylabel('number of view start events')
pylab.title('view start events over time')

# %%
#rates_videos_watched_at = [0]*
