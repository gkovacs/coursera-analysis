# %%
#import pymysql as db
try:
  import MySQLdb
except:
  import pymysql as MySQLdb
import sqlite3
from pandas import DataFrame
from pandas.io.sql import read_sql
import json
#from pandas.io.pytables import HDFStore, read_hdf
#import multiprocessing
#pool = multiprocessing.Pool(100)
#print pool.map(f, range(10))

#tablename = 'course_grades'
#tablename = 'videos'
#databasename = 'coursera_eventing_12-002-ml'
#databasename = 'coursera_eventing_pgm-003'
#databasename = 'coursera_pgm-003_anonymized_general'

datastage_login = json.load(open('datastage_login.json'))

# %%
import collections
import functools

class memoized(object):
   '''Decorator. Caches a function's return value each time it is called.
   If called later with the same arguments, the cached value is returned
   (not reevaluated).
   '''
   def __init__(self, func):
      self.func = func
      self.cache = {}
   def __call__(self, *args):
      if not isinstance(args, collections.Hashable):
         # uncacheable. a list, for instance.
         # better to not cache than blow up.
         return self.func(*args)
      if args in self.cache:
         return self.cache[args]
      else:
         value = self.func(*args)
         self.cache[args] = value
         return value
   def __repr__(self):
      '''Return the function's docstring.'''
      return self.func.__doc__
   def __get__(self, obj, objtype):
      '''Support instance methods.'''
      return functools.partial(self.__call__, obj)

# %%
databases = {}

#databasename = 'ml-004_clickstream_video.sqlite'
databasename = 'ml-004_clickstream_video.sqlite'
tablename = 'videos'

def listVideosReal(dbname):
  output_set = set()
  output = []
  for lecture_id in listDistinct('lecture_id'):
    if lecture_id not in output_set:
      output_set.add(lecture_id)
      output.append(lecture_id)
  return sorted(output)

@memoized
def listVideosJsonMemoized(dbname):
  jsonfile = dbname + '_videolist.pickle'
  if not os.path.exists(jsonfile):
    pickle.dump(listVideosReal(dbname), open(jsonfile, 'w'))
  return pickle.load(open(jsonfile))

def listVideos():
  return listVideosJsonMemoized(getDatabaseName())

def getTableName():
  return tablename

def getDatabaseName():
  return databasename

def getDatabasePath():
  return '/lfs/local/0/geza/' + databasename

def getDatabaseNameForLectureNum(lectureid):
  return getDatabaseName().replace('.sqlite', '_lecture-' + str(lectureid) + '.sqlite')

def getDatabasePathForLectureNum(lectureid):
  return getDatabasePath().replace('.sqlite', '_lecture-' + str(lectureid) + '.sqlite')

def getDatabaseNameForLectureNumAndUser(lectureid, userid):
  return getDatabaseName().replace('.sqlite', '_lecture-' + str(lectureid) + '_user-' + str(userid) + '.sqlite')

def getDatabasePathForLectureNumAndUser(lectureid, userid):
  return getDatabasePath().replace('.sqlite', '_lecture-' + str(lectureid) + '_user-' + str(userid) + '.sqlite')

def getColumns():
  return list(read_sql("select * from " + getTableName() + " limit 1", getDatabase()).columns.values)

def getDatabase(dbname=databasename):
  if dbname not in databases and 'sqlite' in dbname:
    databases[dbname] = sqlite3.connect('/lfs/local/0/geza/' + dbname)
  elif databasename not in databases:
    MySQLdb.connect(host='datastage.stanford.edu', user=datastage_login['user'], passwd=datastage_login['passwd'], db=dbname)
  return databases[dbname]

def getDatabaseForLectureNum(lectureid):
  if 'sqlite' not in databasename:
    raise Exception('can only use getDatabaseForLectureNum feature on sqlite databases')
  real_database_name = getDatabasePathForLectureNum(lectureid)
  if real_database_name not in databases:
    databases[real_database_name] = sqlite3.connect(real_database_name)
  return databases[real_database_name]

def getDatabaseForLectureNumAndUser(lectureid, userid):
  if 'sqlite' not in databasename:
    raise Exception('can only use getDatabaseForLectureNumAndUser feature on sqlite databases')
  real_database_name = getDatabasePathForLectureNumAndUser(lectureid, userid)
  if real_database_name not in databases:
    databases[real_database_name] = sqlite3.connect(real_database_name)
  return databases[real_database_name]

def listDistinctForDatabase(fieldname, database_instance, extraquery=''):
  data = read_sql("select distinct " + fieldname + " from " + getTableName() + " " + extraquery, database_instance)
  return [x[0] for x in data[[fieldname]].itertuples(index=False)]

def listDistinct(fieldname, extraquery=''):
  return listDistinctForDatabase(fieldname, getDatabase(), extraquery)

def listDistinctForLecture(fieldname, lectureid, extraquery=''):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return listDistinctForDatabase(fieldname, getDatabaseForLectureNum(lectureid), extraquery)

def listFieldsForDatabase(fieldnames, database_instance, extraquery=''):
  fieldnameString = ','.join(fieldnames)
  data = read_sql("select " + fieldnameString + " from " + getTableName() + " " + extraquery, database_instance)
  return data.itertuples(index=False)

def listFields(fieldnames, extraquery=''):
  return listFieldsForDatabase(fieldnames, getDatabase(), extraquery)

@memoized
def getDataFrame(dbname, tbname):
  return read_sql("select * from " + getTableName(), getDatabase(dbname))

def getDataFrame():
  return getDataFrameReal(getDatabase(), getTableName())

def cacheLecture(lectureid):
  if os.path.exists(getDatabasePathForLectureNum(lectureid)):
    return
  print 'caching lecture:', lectureid
  data = read_sql('select * from ' + getTableName() + ' where lecture_id=' + str(lectureid), getDatabase())
  write_frame(data, getTableName(), getDatabaseForLectureNum(lectureid))

def listFieldsForLecture(fieldnames, lectureid, extraquery=''):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return listFieldsForDatabase(fieldnames, getDatabaseForLectureNum(lectureid), extraquery)

@memoized
def getFrameForLectureReal(dbname, lectureid):
  if not os.path.exists(getDatabasePathForLectureNum(lectureid)):
    cacheLecture(lectureid)
  return read_sql('select * from ' + getTableName(), getDatabaseForLectureNum(lectureid))

def getFrameForLecture(lectureid):
  return getFrameForLectureReal(getDatabaseName(), lectureid)

@memoized
def getUserToEventsForLectureReal(dbname, lectureid):
  lecture_frame = getFrameForLectureReal(dbname, lectureid)
  return frameToDictByKey(lecture_frame, 'anon_username')

def getFrameForLectureUser(lectureid, userid):
  user_to_events = getUserToEventsForLectureReal(getDatabaseName(), lectureid)
  if userid in user_to_events:
    return user_to_events[userid]
  else:
    return None

def frameToDictByKey(frame, key):
  output = {}
  for k,grouped_frame in frame.groupby(key):
    output[k] = grouped_frame
  return output

#def cacheLectureUser(lectureid, userid):
#  #if os.path.exists(getDatabasePathForLectureNumAndUser(lectureid, userid)):
#  #  return
#  print 'caching lecture and user id:', lectureid, userid
#  #data = read_sql('select * from ' + getTableName() + ' where lecture_id=' + str(lectureid) + ' and anon_username="' + str(userid) + '"', getDatabaseForLectureNum(lectureid))
#  #frame = getFrameForLecture(lectureid)
#  #data = frame[frame.anon_username == userid]
#  data = getFrameForLectureAndUser(lectureid, userid)
#  #write_frame(data, getTableName(), getDatabaseForLectureNumAndUser(lectureid, userid))

# %%
# %matplotlib inline
import matplotlib.pyplot
import matplotlib.pylab as pylab
import numpy

def binsum(inp):
  output = []
  for i in range(len(inp)):
    curbin = inp[i-2:i+3]
    val = sum(curbin)
    output.append(val)
  return output

def barPlotWithStderr(means, stderrs=None, x_tick_labels=None, xlabel='', ylabel='', title='', addLabels=True):
    if stderrs:
        assert len(means) == len(stderrs)
    if x_tick_labels:
        assert len(means) == len(x_tick_labels)
        x_tick_labels = [str(x) for x in x_tick_labels]
    else:
        x_tick_labels = [str(x) for x in range(len(means))]
    N = len(means)
    ind = numpy.arange(N) # the x locations for the groups
    width = 0.35 # the width of the bars
    fig, ax = matplotlib.pyplot.subplots()
    if stderrs:
        rects1 = ax.bar(ind, means, width, color='r', yerr=stderrs)
    else:
        rects1 = ax.bar(ind, means, width, color='r')
    
    if ylabel and not title:
        title = ylabel
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticks(ind+width)
    ax.set_xticklabels( x_tick_labels )
    
    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            #ax.text('foobar', 1.05*height, '%d'%int(height), ha='center', va='bottom')
            ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height), ha='center', va='bottom')
    if addLabels:
      autolabel(rects1)

def plotBarDictionary(datadict, xlabel='', ylabel='', title='', x_tick_label_map=None):
    keys = datadict.keys()
    keys.sort()
    means = [datadict[k] for k in keys]
    if not x_tick_label_map:
      x_tick_labels = keys
    else:
      x_tick_labels = [x_tick_label_map[key] for key in keys]
    barPlotWithStderr(means, x_tick_labels=x_tick_labels, xlabel=xlabel, ylabel=ylabel, title=title)

# %%
#frame = getDataFrame()

# %%
#print frame

# %%
lecture_end_times = {}
lecture_pause_to_counts = {}

for event_type,curr_time,lecture_id in listFields(['event_type', 'curr_time', 'lecture_id'], 'where event_type="pause"'):
  if curr_time > 3600: # there are no lectures more than an hour long, if have such a result is bugggy data
    continue
  if lecture_id not in lecture_end_times:
    lecture_end_times[lecture_id] = curr_time
    lecture_pause_to_counts[lecture_id] = {curr_time: 1}
  else:
    if curr_time not in lecture_pause_to_counts[lecture_id]:
      lecture_pause_to_counts[lecture_id][curr_time] = 0
    lecture_pause_to_counts[lecture_id][curr_time] += 1
    if (lecture_pause_to_counts[lecture_id][curr_time] >= 10):
      lecture_end_times[lecture_id] = max(curr_time, lecture_end_times[lecture_id])

# %%
def fix_lecture_end_times(ref_times):
  for k,v in ref_times.iteritems():
    if k in lecture_end_times:
      lecture_end_times[k] = v

import video_annotations

fix_lecture_end_times(video_annotations.video_lengths_ml_004)

# %%
import plotly.plotly as py
from plotly.graph_objs import *

def iplot(data, layout=None):
  if not layout:
    py.iplot(Figure(data=data))
  else:
    py.iplot(Figure(data=data, layout=layout))

def scatter(x, y):
  return Data([Scatter(x=x, y=y)])

def scatterdict(d):
  return scatter(d.keys(), d.values())

def scatterlist(l):
  return scatter(range(len(l)), l)

def mklayout(title, x, y):
  if title and x and y:
    return Layout(title=title, xaxis=XAxis(title=x), yaxis=YAxis(title=y))
  if title and x:
    return Layout(title=title, xaxis=XAxis(title=x))
  if title and y:
    return Layout(title=title, yaxis=YAxis(title=y))
  if x and y:
    return Layout(xaxis=XAxis(title=x), yaxis=YAxis(title=y))
  if title:
    return Layout(title=title)
  if x:
    return Layout(xaxis=XAxis(title=x))
  if y:
    return Layout(yaxis=YAxis(title=y))
  return Layout()

fig_data = []
fig_labels = []
fig_xlabel = None
fig_ylabel = None
fig_title = None

#def newfig():
#  global fig_data
#  global fig_labels
#  fig_data = []
#  fig_labels = []

def addxlabel(label):
  global fig_xlabel
  fig_xlabel = label

def addylabel(label):
  global fig_ylabel
  fig_ylabel = label

def addtitle(label):
  global fig_title
  fig_title = label

def addtrace(datl, label=None):
  fig_data.append(datl)
  if label:
    fig_labels.append(label)
  else:
    fig_labels.append('trace ' + str(len(fig_labels)))

def plotfig():
  global fig_data
  global fig_labels
  global fig_xlabel
  global fig_ylabel
  global fig_title
  figd = Data([Scatter(x=range(len(datl)), y=datl, name=labl) for datl,labl in zip(fig_data, fig_labels)])
  figl = mklayout(fig_title, fig_xlabel, fig_ylabel)
  fig_data = []
  fig_labels = []
  fig_xlabel = None
  fig_ylabel = None
  fig_title = None
  py.iplot(Figure(data=figd, layout=figl))
  
curfigure = None

def newfig_mpl():
  global curfigure
  curfigure = pylab.figure()

def plotfig_mpl():
  py.iplot_mpl(curfigure)

# %%
data = scatterdict(lecture_end_times)
layout = mklayout('lecture end times', 'lecture index', 'lecture duration in seconds')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/172" height="525" width="100%"></iframe>

# %%
print lecture_end_times
# Out:
# {1: 414, 2: 434, 3: 749, 4: 853, 5: 490, 6: 492, 7: 669, 8: 528, 9: 620, 10: 710, 11: 690, 12: 349, 13: 525, 14: 413, 15: 819, 16: 669, 17: 542, 18: 672, 19: 502, 20: 304, 21: 531, 22: 538, 23: 459, 24: 977, 25: 358, 26: 839, 27: 967, 28: 794, 29: 578, 30: 828, 31: 775, 32: 213, 33: 488, 34: 444, 35: 889, 36: 614, 37: 846, 38: 375, 39: 582, 40: 610, 41: 640, 42: 513, 43: 575, 44: 467, 45: 721, 46: 706, 47: 435, 48: 620, 49: 231.29400634765625, 50: 403.21499999999997, 51: 719.30799999999999, 52: 764.19249400000001, 53: 467.58100000000002, 54: 697.48101806640625, 55: 411.4580078125, 56: 803.666015625, 57: 390.26666499999999, 58: 685, 59: 350.529, 60: 455.11200000000002, 61: 723.25599999999997, 62: 462.3330078125, 63: 680.15899999999999, 64: 713.45979499999999, 65: 410.01800537109375, 66: 569.7490234375, 67: 791.98699999999997, 68: 695.76300048828125, 69: 845.64801025390625, 70: 669.50099999999998, 71: 887.1190185546875, 72: 636.25, 73: 1181.780029296875, 74: 944.75099999999998, 75: 943.19500732421875, 76: 1262.818, 77: 752.53221995400008, 78: 752.5360107421875, 79: 424.62400000000002, 80: 469.22900390625, 81: 502.24799999999999, 82: 609.73299999999995, 83: 327.5880126953125, 84: 545.60000000000002, 85: 913.9840087890625, 86: 630.28302001953125, 87: 234.1510009765625, 88: 768.66666499999997, 89: 458.24600219726562, 90: 627.54302978515625, 91: 722.76800537109375, 92: 787.71400000000006, 93: 456.08700561523438, 95: 737.18799999999999, 96: 825.84100341796875, 97: 843.46666500000003, 98: 474.57000732421875, 99: 871.58502197265625, 100: 614.6090087890625, 101: 506.892, 102: 507.91400146484375, 103: 510.81600952148438, 104: 344.97943299999997, 105: 799.11500000000001, 106: 377.952, 107: 691.468017578125, 108: 770.78700000000003, 109: 848.62, 110: 422.23200000000003, 111: 879.99000000000001, 112: 980.02200000000005, 113: 830.69444399999998, 114: 282.066665}

# %%
numLectures = 0
for lecture_id, in listFields(['max(lecture_id)']):
  numLectures = lecture_id + 1
print numLectures
# Out:
# 115

# %%
for anon_username,event_type,curr_time,lecture_id in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id'], 'where event_type="play" limit 10'):
  print curr_time, curr_time == 0
# Out:
# 655.888978 False
# 180.805698 False
# 686.290747 False
# 0.0 True
# 715.555577 False
# 85.873197 False
# 725.557958 False
# 395.207094 False
# 741.088434 False
# 797.553876 False

# %%
lecture_to_user_to_start_timestamps = [{} for i in range(numLectures)]
lecture_to_user_to_finish_timestamps = [{} for i in range(numLectures)]
lecture_to_user_to_seek_timestamps = [{} for i in range(numLectures)]

lecture_to_user_to_seek_times = [{} for i in range(numLectures)]

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="play"'):
  if abs(curr_time - 0) > 3:
    continue
  if anon_username not in lecture_to_user_to_start_timestamps[lecture_id]:
    lecture_to_user_to_start_timestamps[lecture_id][anon_username] = []
  lecture_to_user_to_start_timestamps[lecture_id][anon_username].append(event_timestamp)

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="pause"'):
  #if curr_time != lecture_end_times[lecture_id]:
  if abs(curr_time - lecture_end_times[lecture_id]) > 3:
    continue
  if anon_username not in lecture_to_user_to_finish_timestamps[lecture_id]:
    lecture_to_user_to_finish_timestamps[lecture_id][anon_username] = []
  lecture_to_user_to_finish_timestamps[lecture_id][anon_username].append(event_timestamp)

for anon_username,event_type,curr_time,lecture_id,event_timestamp in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where event_type="seeked" and curr_time<>0'):
  if curr_time == lecture_end_times[lecture_id]:
    continue
  if anon_username not in lecture_to_user_to_seek_timestamps[lecture_id]:
    lecture_to_user_to_seek_timestamps[lecture_id][anon_username] = []
    lecture_to_user_to_seek_times[lecture_id][anon_username] = []
  lecture_to_user_to_seek_timestamps[lecture_id][anon_username].append(event_timestamp)
  lecture_to_user_to_seek_times[lecture_id][anon_username].append(curr_time)

# %%
lecture_to_num_users_finished_without_starting = [0 for i in range(numLectures)]

#for user_to_finish_timestamps,user_to_start_timestamps in zip(lecture_to_user_to_finish_timestamps, lecture_to_user_to_start_timestamps):
for lecture_num in range(numLectures):
  user_to_finish_timestamps = lecture_to_user_to_finish_timestamps[lecture_num]
  user_to_start_timestamps = lecture_to_user_to_start_timestamps[lecture_num]
  for userid,finish_timestamps in user_to_finish_timestamps.iteritems():
    if userid not in user_to_start_timestamps:
      if lecture_num == 114:
        print userid
      lecture_to_num_users_finished_without_starting[lecture_num] += 1


data = scatterlist(lecture_to_num_users_finished_without_starting)
iplot(data)
#layout = mklayout('view start events over time', 'lecture num', 'number of view start events')
#iplot(data, layout)
# Out:
# 75ec7afbc2cf25ffb30d3dd6c74f00a9559542d6
# f1026580e6cdce834ca50d525e6833ed5171f0b6
# 2514f3524caf03e6555b44b283ef29ff37e1a1a8
# aa7d060f3b866327bf4229c0dcbfb228fc96f885
# 56cf4a12009b1da6b5413e856ccfe06dc7ec24be
# 27960b9ab0a21dddf26092585caa963018b06993
# 804efb7c4b4ff40c8f81dc6e68fcba762cb81619
# 3b043b2789124e909bc0f1f9ec6bd731129a9b03
# 66fe9e50b18e2066cfaac3528296dce86aa8a702
# dfab69a484850a6efb8821b5ef825a0bb0f86009
# 2a1cdc1a1b6718ddc8d3366b7650fabd242208ea
# 37afc80b0369b36e1421dc69662e7838b08e85a6
# 2201e7949b2b185969f9c1be8973d30aa1cbc120
# 3484574b36437e20b19066c7d444bd863c70e800
# 79ed5d0c76f79226f71c8d822e9dab4ac0d3de55
# 0939f6b739275afda1e070558c3bec2396e49f1e
# 4dcea5085ad326e286c01b3ac71400b613e2f22a
# 366d162e4923a7e85692b3b3d351698b7daff484
# 0e3c6fcd7a9201dddf6278f785337a6679969c08
# 0f0a36db381ac91a03f0f4f97fb569cfbc351231
# 094e7c7b05f8e3ee5141ae5fb8b71d0a602b144f
# 69bd1a92738dbcff99ff2dd0f126c7a53cbe9c1e
# 2e663c539f1ce02976fdd5932d7a339189c7d528
# 2bb86a9f914f7d76f3541772dd30180aa40cfa84
# c6b9511ad035a012d9d2b7cf601a7429d985316e
# 6a294cff8f6bca33c95d3af1cbf921f769fd5530
# 961a78e551fdfffd6c92d8d8f8309f13bef3f328
# d91598622636560363dc8d9e41c27692da8c1889
# bfb1d61eac97aa22c3e833b8489e5a7ea2da8e36
# 0a9c78d706e3140dbc42d6138f67d8dd74ef44bd
# ffc226096eb8222e7034aa44590485c049f18fdc
# ca975fadd624ed20ea8b22f6e4e32d38130f247c
# 4d0e664b9eaf821aa8f79254396f57beb7686036
# 2ef26084a30d9d34f6702294b7b3eb0782832945
# cb18f5e8d4953296c8cbd17d10517654b1c6341e
# 4416ac43a548bfd779ca9aeadad670ab4724ff4d
# 4d6d74261cbbca84ba80276c85cbdfe3fa371979
# ef61231520afda0565e20373a82644bc874cef7c
# 835dd7f2f2aaad8f30b971441453a09b04c0fd10
# 9fe628367babcf94539d5e5188930d523d88e735
# f3a9f616d9d9ab135de95571d3ba8c4b3b8aefe2
# 3afcd13df663fed87e00110415b3a44f05b7fbeb
# 87aaf692a1635290b586d11d7d0fddbfe711894e
# 845c680fbb31cb878987cd93820f87857f11f7ab
# 6cb2c7c4c935786dceb94b9d036f821a6b94bd10
# ec33cc93ced77bada979b827b2e90773694e7449
# 9eb6fecf3f1566571e5fb30994921ca066dfdaf2
# f310046c04c2b968217cd68cd0eb8803a7429c52
# 2a6d63fc004e53970cd8c49f7854342b9794467a
# 7f95b8093aad025c9512d5aa92428f20dc1258ff
# 74192ba6f6c332b2f704910284052552e20c65ca
# 4311ae4b622d910f4cf80efe60bcfc65dced3962
# 37020f6604db5c63b3ce5806b02f7f29bc2d0f9b
# 97bda74aec8ff32f8a484e30cc87d1a926c46ff2
# 3e90258b03c26c499cfe721b9ac64277c3bdd13e
# fba5a080b874c83e83e541255d1a3711823d030c
# dd11b8eac73cb21b451ad89ed8e3e7c2888aa21f
# 7dd6edc1b8facfd3547d3d5476b37daddbd5ad84
# a8c529615e5bcbd38d2b2b08a01e8f115785cc56
# 6d9233a72986032bffedbbe278c8bf1841efa8dc
# 0f0a8a2469d0fdb13e6e6dbfe6e7f02fedb58601
# f694e823e00be538f4bf2b3eacf010e1d1e2e0b9
# 4596f7b51dabea217c32f58bb91168a30a5db5e6
# 8ff73ee2e4d9c8ba87a64a4e2d7b9602cea62f4d
# c4e9fde06a0ace29cb45b9318589b455108e69c8
# 2096e8eead6d9cc181c75787e9729a724c2f4f98
# b5919af4837cf688993f9ee626bbfe037fd7fa72
# eec235ec51adc31f5a435f295ebd708619b6996f
# 7b8e8dafbde38e8dec696f4e020558c4f52a1af7
# 1eb65d51278f876cc9a6ef9e0debd39b12f0c12c
# dc2472725233639d10eccaaa68cdddb0ced706bd
# 0b960107ee2f56ea3e1fde681e4059da06508041
# bd55bd3ab3897128bc4dc1d4e92321a5903e8889
# 0c638bf72fe32604fd2480e3840dff21e1ac99da
# f90ddd3c852e41d5ba245e28e87a5644bdff2053
# d5862b587d54a9de3e0b18a98ac5af73546e101c
# 0d34cbc1d5e7d657d6704efa294b1fbb327b1fe7
# 58dd05cac2c3cffca64eebc57443532779879e32
# 7d557670e70cc8bd2acfd29e99086dc86f09acc2
# a5cfb756f30101a94b97cf0439839c00951177da
# a89188543fed8162b3c020c348752f1210a6e35c
# b985eae6e167d369c0183367c59d836bf75a2abb
# 21b1c2b0a5e49bb48dd8429dc1ac5ac5bc4f698e
# adda1d5bf66976d116f47499090a093d158fef5b
# 0a495aa2dc2a1949ceb6abf1c9ed12655230d651
# 98748dd694199bbf9857d2221d75f967069c2dce
# c3146dba0bc3aab3893dad599c02d49db31a56d8
# 2c2725f48d06fdd83d846aa2e8d5e6a95c6abea8
# c227e5d14fbf8019b06399fe0368d25b26586a80
# c7f8171dd2211bb8db6b0d120efae5624df4daf9
# 0c4b7c4bf30a335f32696e81304ecf533227ef39
# 2bcfb8fe56572c2ff8703f047408ab8fc38a2f59
# e49c944d534b58a9eb7dccb18236e546c5d388dc
# 4b56762527ab4283722e9c62991e87761fed4905
# a15708bdff1441ba8ffdebc26f085f178833a3ff
# fcdcee379c02f09b4075579c663be8317c2de5b6
# b1e86fb981a260c22dc45ab4c47f5066de80c49f
# 2d523e59beea0d3b52a8537f8c70f80fa42a506e
# 422d53c2d964bfa15f42d44609e1d3a11a42b08e
# c97a12b7b523f455d0ed09f0747d11dd68a81d47
# 95427d83d3a9d5a42a7b5c52a055610a5dd35518
# 87890660316f5961a3d18eeb8ab79c88286aec9e
# 336a49ee66622230315a6e8583c9349a1db41c3a
# a4b5723f016b998ebb643ed7d43c6353a480271a
# b9caa19a4d177708addf84d33c6a6ab9f7a4c058
# c653c604606f3a05467004b6913ca696405b32fd
# a3bd39bfce6bd68414200988953de90819900d42
# 809c5113dcf6c469c703ac50f5c3e9b6685d615c
# a3117fe889c5b1d1347171d0834d2020de89db85
# 825291fa0ca2443d6fd3b4ce53e16eed087fe5a3
# 30477aa08e01f6f86ace74337450a1f6cf2b443f
# 39b91295fbba54e6c065dde5d1e939fc486c23ea
# 7d1063abdf1b22902724f185820670c1e9111773
# 5e8fd9a3db045741a44c830a27f95ccd7048d1a7
# dfe5eaf04685357ae16879bc226e472b0d950ed4
# ce068b8972de85502cf3dc5c9cb012d6628c68b6
# 1100e2162c603a30a01189b9de77ffb9690783ee
# 7ffb3d47a508bdf617fdea58b94c415e3c91060c
# 94f02e13aaedd77f11cdeb65b019a45f98eb4388
# 9a1fe258b01c861a5c0970c0a9de5bfab52e7178
# 2f6c2d3d8070b5f83d5a2c21265d3aa774569d19
# 865c69aeb7cc1fa61c6d81283af54fedc1e7c520
# 7421a81a6cd221cd32aea34d04c765e7ed603f27
# 4daeaf0ee70efcddddc0ebe8741e2715f0c52cd8
# ee58d9c4430a4576b11adcba0475796ebeb5c067
# dfce323bdfca25f1eeb5430f7838b5548681a8c6
# 6776c9b2bae670ea73ede21abf3e742d21d35f8b
# fac4bb150127b68ef80bb4d4f08eac1c41b80aa6
# c7af71d18b1ff955ec1453e5814969066589a96b
# a691eeecb93c6aa218fb6280b11e4ae0f589165a
# 16c525eee775ad84132a796b6e7f8205cef118be
# 46322205d32850d060535188ee0cfe567ed6b7d4
# e2ae598a29cce00f55b479e0f4401a8e99c911ec
# f77b793625cb066874f952bee1a84c676040d768
# 3e1d5905d32892703fcf203eec90381689b76ba1
# c42e60efcc909581d0f17762db1e55067b0091b8
# 90ae837e4d718d9e76a2e1c08873537f54dd4ce3
# 210214b218a1541db56019735f0ea0423cfd1353
# 479619c9463df11ea36197a50ffac333154d0f61
# 157fe60e962466f4b5c804389c50ba9007e355b8
# 74137c4ae232df527c85600469b555cefa173ef6
# f68143d429cc429a7c1378528ac3b3b90decf527
# b56bdb16d770362757f5362f59868211ff8630e2
# 643e95a388680dcf271363f37b674235acdfa745
# d2b7c09ad66418c5f8d317a599fe4948483ae954
# 7f11e867986be0850e3af58dbff0a899a001cea0
# 0360a9012c7fcbd3f818097a883274da6b5e523f
# 63b062688ece791f9bc8b09845be1a5df3edc648
# e69189f176f7736318d05742578c60e03a904f30
# 94cc24475830610955d5439a155822fe7ce99655
# add6900b2935dece06b353b7cd5d6dc08e814b4f
# a8daa435cf5829eb924fc08618a0d77161c497f1
# 6eded2ea2eea15f9446c0e1395ad9776102dce21
# 0400c922e2da3b955c03ecf513ccc7c154209c74
# a7f198bcc9c5d0555b4ebde2cba4bb516eff753b
# 777e50cc12c2b64330dec479030eb9feea871e7a
# c33ab8a1f9103490025f838ebacaa2bf5306f9e2
# 29a670a25ac0a27fe4e8f8ece85e283b26424735
# e6503e84efa64491dd947541475da98744a33643
# 9784f38ce2013580a83802f5c26f3ac05e922e26
# cdc3117b1bba7b9c50992c06b44a941f53dd9c6a
# b05f562503b829324a05908661bde9a573bd02a0
# c708ab58e23334ae66da90d28f3a30a7675b4401
# 23b4bd80c76fa257c30e0cf569c286b4100e3985
# 7419451b74de1fba84d6116ecb5dcd29156d23a5
# 9c4d9cf0a9bbf4d6e536136ef0cb2d13284fdb6a
# ce6d8a519c2d6a0166d8bb3e5c120221981d8e23
# 3777c500b85ad1b81039a4f07ca968d072445615
# 1cfa9346eed3a8fcdce0017c163585b40d058e40
# a5e5daf00685a98adc7bbbad95c766b7dc0a2db5
# 372b3c3ef71503b6a7cdcbadc46a820c88c70b52
# 25b504cfa23386d4c523d0b63f5af2155abaeec2
# f3ac5bf96d2087614362cf841c1d89653de4ca7b
# 5f0d2b083835bea9f46cf619b919d429599e5e20
# fe16c48e499479e8458827c7fa3d956b2f120ec3
# 64a2baadb7d162d4ae6c419fe62aef4230f8e621
# 6c05390abbdcdb888a657ba66538b4ce8fb5dc9a
# 2cda049b1a18792f5120f13b1f292e6e82da2bad
# 7d19090c5237cd0ea382babc05c255c0f54c54e5
# 90857f84dff09e8210ae1c1aa0faf3d186add4c1
# 3093b9da3675c86a5cd27b17e89b28e7eed95cce
# 20575cd14a5460334a040937478c6f3ad18de806
# 95582728dddd523c8b9410f2c33484511119499e
# 4adbbf2e1ee80ce3181c34f46bfda11caea62ea2
# ef28ed33531696ebaaee26182e4a67313cf212f2
# 4f57e77a21f2cc434f48a941448fbb2b7bece4a1
# d9c9f6f549ef70b3d6d7ada7e71272d7857bcbf5
# 0222f7d615528f8acaed48ccdf058853a8d2154b
# 0ac81e11a5f78ea06fda324662c171f6bec8a6b0
# 207174df5ea75001102a03b135e4cabc83ad4c01
# 0691f81fe6f65d96653763d41ebc00a0fd0b7db3
# f907715596d7dc45d30e03cc201d47e81134cb7f
# ccf2a239a74d51ce1719f3c1581c6c860be0abae
# 411a73abf1e3e8f32a7806726a4448a835978c75
# 692a0f19a30a4b21a8371b92f48838625643933c
# fe5f66db10470d92fbc18fbfd7d7ac96a5b0e049
# 7103fb519fa06da2cd865f3746f501a49e5be35b
# 252523f20546051c8fd2bd0dab1984caccd9014b
# c09d914ff8a00b526c1b8617405de1b74216629f
# cf0a1436c15b65e3c84ac59263aad37933c8d7d6
# eb7d72214b599b1b7618f35c2b54fbec019d0088
# 9da5e42b996fcac27cb5f56eaaa85ac96667d648
# 2b2aa627c7be8856308df6588792303bef5954f0
# 237a1e3d3c8ffdddcc885375e8cd87883ec3bc1e
# d4eda55908ab7ecca61b626b72964817eb906068
# e54a7022aee9a136e6ebaf17604218afcffc03ad
# eed57d6cdfc0949485f1ffe6d65444d45a8a5f11
# 23bdd760d08c8917539ae06546501ca7cb57e3d8
# d5461af13fb15c230ceae67cd043257bbcee9c55
# dee7b482e493b8491103e8aa98185c659987e9cb
# 79a91f96d410a3f736b3db9c84d4dcb38b186af1
# b641859b56a2eb49bd7896501ea238d6fd381372
# 422bb2fe0f309582c70beab5245b7112108d4f62
# a9d73d51a982667da5e4d57851d8974e12ab0457
# e1c547502a0927e5cc7dff63422de75bf63213a0
# d4e9e25543f602a83be24c544ee97f9a6110eefa
# 4d451295c396019970e27de19ed56aad69b49ffc
# 2902e6d06d095685e759a68d871c039ae5884a79
# b5de4b36db3a877a4cb5ebc1fdf12d7cc50d44e9
# 93ab9983d021acd76200bfd5ebb4db2796e576a8
# c3cec5cb1c57ab84319f797bd7cd3ec529f1cb5d
# 9df936d4eed6615f4e59fadf90d8da5fd3bbc5c5
# 40209af76077a60d6ebede1f66be85e7a2d32b78
# 37129f09b02613744ebf0650c3638be469e6f5f9
# 0cda9f34d253c4a8ade2e94fb9e38b4fb1a0176b
# 917e58863d153edd44c37dda706f54cc1667411c
# 74217b1e90798f68e3e3e8279880359755255798
# f5c59612ecf99c717ac563d76c62cc9e8ff13ddf
# 15c6ec9388e596548cd6af862e208498f6891f1b
# ba5a5cf8dc863c1a6cf76da35db848ca591efc05
# f682bfce71938114c2cafbef92991d2f1d89c0c6
# d13820f0fadc00c385cb604676ee2c033f233f77
# 08d83eea923a0e9f931dabb31224f7eb4393296c
# 54b888c827246e0be1bb1fecee8ba38acd8da37b
# fd2afae2d5b1776eccc1b6757f8c4b4e001afca9
# 29a7410d5c89bb2fd77bc62f8a55e30fca6f7fcd
# 10ca97a1a5c0cba0e135ad8bc07d076d36f395d8
# a811cd576392f3c4396477d07a139c817a849ac6
# 00e26568013fe5a0afb975c9c93fee3a9bdbfeaa
# cf8e5485cf69b3f96fbc3ad20abf78e8873fd038
# 26ca830cc1ef312c139ceeba455b476d4edde037
# a52c1ef4c27f5afd0f468ae00ba974d4a9acf54c
# c0a96866cbca04788ef07f73ef11e637f13c7e85
# 0593ca57d9ec674f26b759267c11c42511fc97e4
# 511caa30e4e95bb71bd2d7e6c469fb9db2ca5b0e
# 657de4cbca345441bf37352d3586cba9af0426f7
# 112f92f30c6f0e98314b08a92ee892e01cebe075
# 543eb6dea7f120cf6165417b37caabb7ad275978
# 4ffab8c3c5327a82b7bee418b99af6fc85568536
# a24b20bb92afbbe6f1cc7796291f802c52dec97f
# 26ff4ebf544a9affc897751abb95619b84de0130
# eea43384f2a5ce1fc813a595eca25f018fc7f72f
# 2d2b2c3b18d98eb5e395bf6a1b4d098ccb182389
# c124ad8cced7ab0206c1b044f93a2d6e63a812b5
# f4d8e70b9bad9b26e8d3a6e21d7269004bc15ca5
# c24c0ba8c12f690d8223b6798b48f7832b3b5d28
# 5edeb8dec141f8ae919a933aaecb70b114047b7a
# a850d6745a025bb519eaaa44113e7effa7006f1a
# a75e8783fd07355ded4fb5bd751d738479162548
# ef55bd0660f6508bba7641057de405ed8ec0ae08
# 16b64ec54c99ce96dd2a1e08991b3236d23d9c37
# 19cc4a91fd0fd18e0231df6507cbe9ea88fe8791
# 63712b4f7170e83f66cfd3edafcb12b8adbd59ab
# c5c9b07d200c4f49ed884d356aedebcbb36480f0
# 07f14ca3e846ba85c83e65b10e8aef16fc41c408
# d872ad255ef90603d2362c590d65b64bc4f35111
# e79726a57cdcdb1fc73382e160c53dbd6c6a250b
# caedbc45178a80a50fe41a76e0286f15e90a3b06
# 7dd158ff5cd2c4d2a8e3d87bb2695244e5783715
# 358c786e8f85a9247aef603fe64c48efeeb66750
# 499f2804e1a1c641dd7bb0a17c742b7d27e186ed
# c7e0654395eb794288ad6fc2b159df57adc26e83
# ed518ef98f9e8f033a0cc7f15cb72ca709493fad
# 429b88f3b67505da5aea705853f03f1c82cdf556
# 680f7d5654d2cafcf03bff6d49b2f6d88c2051e8
# c8e63542a482b0acdcba9e4ab4dc39619a0aa768
# b4d0b4fa0adfcf41ecd1296679ee2d4c64158bfa
# 7cdd65fc98b02e0a93b6d69617ac4029ddf35c82
# 0b5fe4ddb5e380ba6476fb8e578e66fcedc6b53d
# fc67c855cbc02147923b374006290b9acf9b351f
# 603339d5e632bb3196b62f50eddbe1d4f6329be2
# d7e13a0aaa1eee5f6cd166fc827310f4a9a29a1e
# bbdc4bfc14d75965ea66f4add793b1b8f0fd7f2a
# 58e478ee44504d8f8a43cb3cd275ed05530ced0b
# f180e6ed323bbeb6086ccf9dd3cf1096d7605b30
# 75ac6b9a61ef09d6cd561661819c66182d5b1a8f
# 4ca727d34c9523ffe10836a6dd20628043c83e31
# cb42b44d32521ab903d69b0e3407d7ee97bb4339
# ea91595e45e729b4c008a3aee4f55e0bb12ea0eb
# 5dd745dceae2b223ee81ca58e2503880d72f7142
# 363d9b19255be7df374d0ff95b17f2496e417984
# 4d1d8fe2c415c0d487f721b67689b7873795e117
# 0b0668d7c0c756e90042db3d74ba1d804f373c01
# 5dcc01b1b1d07dd3abb88cdbb7fb28698517052f
# be5f4e68f71a04862ac05be3f49fcedb51124dba
# e78cdef20eac7caf927dd1a7bbf781bad46dbebd
# 9c8bcf78d4acb564da2de5f4e716882fdea57b82
# e99da4cfac90abb31bc0ab4c604e2ce03f7f7b94
# aec42d2c2efaa76565b7616375038b5df4ace608
# 0dfe0844ece8609d42a8d021e1735d41be348bc3
# c45add112b212393dc53908b3c4a3ba8e9ec14cf
# d238abb43d041cb307d43a037f16b2178d53136a
# 7df7d0c2852e119e104cafe64be38a597c17029e
# ac05339e5fbbe5c9db011ef9b27c5380f65ccc1c
# 283c18df31c76cf959a68794d4ebb2ef94821ccb
# 6ae1a0f0192f6ba7109d5b42e075567e20d59b49
# 8f6309face1fe53b782d179cd1b7137fde9bf8e0
# c834ecb2eb07dddf4921cf497debc16bf9442364
# c625a3c0b7a2dfc695cf3ae1758a11717f60e901
# 6d4327753fe883f7f76edc587563ae8e3735c55e
# 8a719e0bd0c01bde194c07140076395b9a753d9d
# b467aca6f4e24c33f39ea09dc4eb2698f6ede182
# 04f64c6c665d920389b9d79fc5eb06eaf2857595
# 28b08d8cba5123870042898052fb7da9ed645d65
# a8c9c91b6fc478109d1cab0508e1a4b282c5a3a8
# d158049cee998d063b8f0f5392185456f7bb4584
# 795d5b93dbd20912e36fe5422a662ceaea63ebfa
# d87b348687680d986bf87f40d42c0372319f3e06
# 349f408520c406a38e71c1f71f54d1b56a23bbc0
# fc498969147e41755ff39044285a0ef7c1090bb8
# b027a96c0eccd5eb680d49d8ace2618556c37d54
# 14e4b23dd6187ac92b40b090daaad54389acb84c
# 2f0d5baa340495d380135d4a6b168de4abc93534
# dc5e8ede129de031562bd9c0823022cb115410d3
# c060a89f76feea8047e557aeef2900c4b7e44528
# 3d9ce9017cf96d06ada9b3f7834effef74336230
# abbd51a8f2ab6c065a577707923f203b2b4b3f3b
# b983096b352eda049cfdd9e223a9f9003640f610
# 5edf76db87b8435647e571f99af205d901861432
# 9e4130616a4a4355a4246a31cd5845fae881ea19
# 16a2eee89af24bb81e833d96d00870e63f407f27
# 9238ac2f155cb77f98d5aa787381414fab876df7
# 5bd15c4b73cae95df20e45a9710f60623cff74cd
# d1413663780adc3d829512caeaf6da466927e38a
# 2cc9c9dcda139f6dab7078cac28fa47cc6130feb
# 7277bfaa4c0e3600c41d508a076d9bff14779d01
# 8d37bb0963d5242e2b1b89cf4a43dc11b7f75b1a
# 0043f3f88ac1708ef28ee45f5eb0f08323fdbb6c
# 180899413379ac980d434a81633b930e2c14b997
# cb963982de8fe71a2ecd900ebd7e2bd020680dac
# a5287c275aa3b9dbf6d093ba9985101147a70c27
# 2fda643612097338b0f90e08fd8026dc82321451
# 81d470ebd8cb5a333ee51c4d4c8aa2521b64483b
# 6b7ac65444259a42a43d980b8e0ca9095bcd25ad
# b7d5a3aad38cf7736fd851754ff92835dd364470
# f792fee86b630f52b1d7b478ceb9f114cf72898f
# 5817e22fade602857eca2f118f99c1f9065b64b5
# bd945314c7e0cfcb06e4f85006eae3fdeacd4c21
# ce00fd2541ca5a841871aacf67c5a79dd9e978bd
# bf7a9c55296c3353710562188ea327368a1c74ff
# 1203e594c474f56500e4210fbfbe697e57a58d0a
# 839042b05629847e9c372438a838487b43fcc789
# 95c3c27f7a1bc4eaf88884bbf1a367096da019de
# 2c5bec30deb557f1b4cad3b02acaf0f1b8510269
# c6901b61830e751af179e1a653572e96172a1b9d
# 6aac5fedb0dc03c240b52f222d131a29995f61ed
# c2279b9c54dde2530d29a5b01beaaee9c86dc34c
# b7ebe87c16ab4ddca67bdd146ae8dff5d3f84461
# 55cdcba672322ddbc038a2033a120ff3a57cb662
# f724fc6b92dbd9b94ffb96d2f5c380e300a3af2b
# e2362f28022c151dbf31de654e80e7c5ef254a8e
# 92be178ecce4e1e7f0998bb7e128e421866e94ea
# a74baf38cf0738d769f097b18940c40ddcbdcc3a
# a766554e411c051a5844113c6c2de2c7a735feb0
# 76b9950c4727136d5737d21a61599073805dc43f
# fe4a5fce5e407f6e98e0bdb056025960b1f781ee
# 0386a85935083498c491c74e4b5bb49553c906f7
# 8d0361ffb56dd15b7733cef3b322e856cd0c9ae9
# 4f6f824f0645f74a81b5782be1686a332d83b07f
# fbe19fd0563fe9f02b17ca4642f5f5a4c2d26233
# 96bac05d15ebc8b5c7ee52ffa0f2edb3a885129e
# 1a53d31fe85d6a63ca8e9c5466b8bec70b86a503
# d69071bd329c19234ef8d394697b387fc82ddb0c
# 86c4ec6c35de37d626cbe44bff59322c659f11d9
# 4cb413f7affef702d2d7cc016ea91ea7bdd2c892
# 8f2fc5176d37c0ef31b97d83cdb679ce0a022097
# fa36502be927ff615f5f225191e96180f5558533
# ef1b58ec5db957d0de69ac0f9818482f091fefd2
# 422799ffbf678d7c6436e307ddf365c60e17a715
# 4edc0912376bfd449e7900076002712e0350cf4d
# 0bc2f21a8eb2eac04d5a42dc1d47a3074ec25eb9
# d016ac928e8f7788e74d258821f55403a51e9874
# 5e90bf05050a1efb031013e36daf80d2a4ceec21
# c11e407c26df740f55ba8be7839a6ea43c77aa74
# 905d90fb7b8b9721e026ea02790ee0efbd357db6
# aab262df2defced4727839877383564f1c0d7737
# c9fcb38abc9dda7897ca56e60f8b43274b715c74
# 78d01d7361bb6574e66c5e5fc7528e575e9cad12
# 77f2a55e5d34a4e1badec193aba0e0474df7f66b
# 114fd2944344b59a501d6558104ea59d52a13220
# 509bb9d50f7c3cb7ddc9ef00ad1a7d5d85505e49
# bdbd793162a6c0d483fb52f5a5c5c81af704e197
# f3f1364948c9a54703c598d15b9cb2447a5d9dbe
# 8732f62ed824f5a0133ffc44f8d8379bb7012dcb
# a9e4bf6a8d5ee66083c05e6ed47077a94ac738a6
# 61b46271e71155056c7eef28872c95b5404d9925
# eb0c6c0bf656a404dd33e8e40251b1e90fa0ed34
# 291e5d31e188eb0104a9fed70a429344d1316d2e
# 9fc1fd871f21824f09ab27cd292927c6657cae0c
# 23ad1af7b7333af6692f461eed580498264c4784
# f562249b07299e9084419ee5e257ad3bc657ca41
# 4d5f9732116ec96fcdfde984ef3bd6f00f27ff9d
# 8dc3bba6924566edfd303348caa08d4c1d6f5b01
# 8490f512f3fe4ea0af8d181540599d01cd1b025f
# 8abbb5272d4e9e86e18199abfb7dc6c35881e06c
# 771c677218a526b387a87df8c44e516994f90832
# 05a63d3b7116db1c8e9951b5776a375244327e68
# 15c3156e7f61f261928124a1fd65d6a72ad5e18d
# 869d46fda1d93a853931a22f7311950cc980ac99
# 319a6d5402198574da79bdb2b4234f1600723b49
# 0c84b726c5aef46de88b7e2dd5c0de2b1cc96036
# adde542f55b83091ae106a8a4b1f630cc95ce577
# 87f1fc680832fbd9913e0d21e5b49af6629ffa92
# 45ad85c438cd74c5c6e3e2baab5f635228f344be
# 2cc1a9d4bb1d1834f61964c8e63dc6e34a59b6d4
# f2bfdb246aff3768306a95c71136be18fd023405
# 441f4aec23c831ca1dd7db7f22d51120708a9870
# 73eefd99433243c17e2404025dc34d9202c150ee
# 52ac66b87b1462a821d9d6104942ce6c6d7dfc15
# 83154d8ec9a1cf4cc56d629156fd3b367ff20f51
# 58f155cddcbdade529d71598f2e43ceb13fba142
# c7760230a4b48877bfc2eaf61aedc4258e4b7c98
# 0e560811639e0c0d81be1d692691770a7132a3a2
# fd466b2d1af79f4ecd474ef471a270f7564f481f
# a066a18e3672655fbd082c9b7f2cac3d64d78829
# 364f90395012721b7a1366c1b7c91b79cce0091b
# 710bd96a8935a793e02cc6a6d87f9190fc895fa4
# f3aaa922e72aea565ccdeaa19aaf0a3b77b9d658
# 105110e3cc08b8998834530be2f075357aa02da0
# 688fc46df8ed76efa4e782a77c68bb1bff81ff97
# 0c32362c727c18003d72e69701d0c986522d85a3
# 411c0b70513249e435d4bc22b21a59aabe135810
# 1e950697b34235ee815831cba3bd85ecbe3f2756
# 136aabe8ba69f5ed4daad19d086b13775281176a
# 077b0bae0fcdde6713e16c2cfe95bb942b9a5718
# 898506f15877618f0836cfc133e0179de80af338
# ac935c2445cafdc3f6e09f7bbca0aa9ca721176c
# de21201870e03f3d913b7639da0c837f70f204b9
# cb325c33097063479d638bc2000e3e3f321890b4
# 3f40486865098160f379641c80228f2d7b6800f1
# 4f042bc5a02ab81e07e8c37f3ea33538c0b06be7
# d212f1610c23ebe8d768865f25a5ce4571400347
# 833ff852f1350dacf6f88c170632836dbc40b356
# 9ea7c23ea0e29783ec1e4df67ddb8afc6352ef01
# 93a3aa9c4f09242bb95586491628e2efbef4e435
# 5ad58a4286b0adf345e7123d4434a48818611995
# 0283bcfd3688a30940d03b2091a4d90946d4874d
# a6d3bda3d4e6c215048c438bc1dea7c9b4de6f54
# 4451451ee2b5fc15bad6bd5fb559e4212d23b6b1
# fe0ade240eadbc0d7b9827e49cd1b59ac5afcaf3
# 2cf89fb29775a5cb403308d367919c18c25dd56b
# 32a21c4228dde9127caa668b322b130ae1b392c7
# 2cdb4ee857f29c0fac1760e6cad943b54dbf1c8d
# 74d4b222a4a66732edababd4c4b534a73aeb48d3
# 6a5bfef597f1d9d28f96c08222510fa04e784034
# 5ba3e3424bab9851636b83199cf00d9cb3b73937
# d0723d7d138cf961eec97946a53b59094297c667
# 9dbafbef1a2a40d095e06dc9bd1ad50747b589e9
# db89a4873f41c72494132600e1b90c76b5dabd28
# f840e4442e680216675448c33083fc1084d8084c
# 2ac618795309ba7e6d69b0100c8ef6e6c83fc249
# 8f5a45c421decc36bf86e05e885baf5523afc8fe
# 186b8ca4d841aa888d4a0d28f0fb487d5eaa5ab9
# 67da60c34b64b257316df8a03d9a6e329b587b4c
# 3699e794328dd16447118b375d83d998b54e472e
# 95bcf2e204af8805dfb009013119a946fbd8511d
# f9b10652e5ee8ad7aece4e53114db2d21ea9374e
# 2f4e9b702e6eb6dbf6fa70990017b8af8da3f1d2
# b10149ec33975d75ef1120f3abf2db51dd69d5ae
# 9b2b59e0482f14d219c9afc9d26350629fa0b6c0
# 26a52b93938fcbddb4e2a215c31bbf7e999b34aa
# 3deda47860ce95dcfdddac407f107dd9b1fab383
# d609ee3d39c9a66ab0cb8c58a78547391a111ae8
# 604be9c83f4a957fef2c555672ed75c6874251ef
# 39edc3881743f3dcc55b031ae4a9f3e1146ae514
# 4ab6b0be0bd88b9de7d083b9ef126020d43099d9
# 7f5e65e743602fcb438d3d38134e47833e0bfa71
# 00864ccccbb7f1cb852be8e481ac97edc98f8a8f
# 61af1e788aa10ff8dfbd6e8a836208064b0d7ad4
# abd16916e30cfcdeb26e231b41b3d80e3b4cf5ac
# feb9084cce2c56403e8d10f4f8d76c46d5848608
# 91d759f30b8933202fc7b7bd7813c32842fe7852
# 29d6af7e0d096384060d08282d21522aa08b6db7
# 1fcb0a349518b3cc941d6c3c5a27a72488c31220
# 122a03fbda91c280a0a35c4fabcbb6efbb25454c
# baea5035b77013f5ff22cf01365a57a0a3e1ec5a
# 133ab6e0e159dc90af297a6a9c9e93b8c0220b3f
# f8c7cf754d2fddb72a53dea7479e08d230637a24
# a9abc4634adaacc0ebc3a21cb0060da65df015e4
# d4a10ab14e31bb82e490baee8520fb69a541368b
# e0dc4d7186b130ed57182426e7117514ade8bea7
# 72b9e045cf8260550bf6ddda67302922a7d51f67
# 59fcdfb6f3ba9ddd2370f68310650bd49fb8a525
# f44f010adbba9e1ec4f820cd39bd3f88731e34e4
# fa34180a720b917436f1de27527f0ad47b5bc457
# 011f5e6d2bd18f7ad770857f22ebb50b0c0eae2e
# 61f004680591ca5682be11b20cff0e437a8e0d8b
# 69eb254c24aabe10d86c8565a174bdf55a35d7e3
# db36054b71c613a2a2425039b2e77391e2833509
# a84b170a81d570cbadc2f1e08d5410681915a5b5
# 86ea28a2e1d67f62a306caa6150d8def57c2cb1b
# 7a717a2d02094fbce74d113e91286912f1a5dfb5
# 98d5741b911ff2b0ccf1ee0490a57be8968c6860
# 4737d0ecfe55a0233fc0a46c6788c7aec5b62a13
# 3bd9ebfeec63f487f1bb86f3953a70ec55176666
# 688c82a80a3220a781185184e837415010c62859
# 7bcdc8d15eb8ce4d65329d88a52a27305a0d0320
# 44196914836bd3b9da8731ca96b2edcbb23a7d63
# 8a2ec479c82a4311d8a181b447dce39848db0de0
# 42ac06d3c888eb5ce0f591302c830588a2d5a1fb
# b44e564c1641f5b1499034bcdcb0695825efa4c3
# b90414d31dd143cae21d6151a64236a3c234aba7
# 8b374a216ee7fae28a9addc44ad26818120b9bae
# 531791a27e6c6ad4bf59b4a756a76a6cd7c8f1eb
# 952a4bcca29832c958ed3e7af9a4c4f9af1d150b
# b95c047441fba35d3565511f13730ea263538a58
# eab03d10cd0394b16bf226b45248b6976bb61558
# 5311cc0d49f8de03402d1edd69d1c8f0022291d1
# 754f1e4033fd382ce3dfd3c0e18ff3d3fa095c11
# fe1e6a4a72ba2b0f161260e4eeaf721712cd39ef
# f0f139946532dacf2ee7ae75fee553cfa2279ccf
# 5c8eaeaa7043945b971e7cd43732c4d3c605ba31
# 6f8e87242cdfc9d3e2381d4ee9ed9f2c1efeaa89
# 47fcf4559a0f0613360fd6a770e2bbf548ace95f
# cc3f511b86861825c141831345bcd704695fe51e
# 28fca91f6542f6d749166c769df40efef1e15b72
# a7b76b49f947dbb7318ee79049e7940e9bb7e386
# 4e2082b9e8ab4ecf364533baeb3b7022d028e454
# 83499a0c538b4d51ad43aa1f161f57df4d090a0c
# 3cf0f93f06fefdd0c1aa41a96184bb0287147edd
# 200501477e53d290609e562dc93caacf8a51b396
# 8a67ad4ffe0c81fe2bff1e44af971c335380ac4b
# f9ab05129696ba39d64c3f07e139d6ea5a7134f8
# 17cbc2b54c2ada5a78bd6735595de0c7c2444e05
# 801774ddb9f46e50541031d01365c254b89411ae
# da015d9bc72db28d830dd7430329a4c771136a3b
# 09264d1d2e0b3677ba86f5573a9667281ba98ee4
# 63668c405e820a64a08d7ae21a31833fc8e69671
# 91059edff74814824a9220a02158f18478bfbd7a
# 3631249f1296a192b5ed8e978b924ac8defa360b
# 93ed5a24f33e8f842d317eaf308a8ac5a8c04692
# 320cf14f610304272d67c2e68cc904e1d69fda8f
# d3ce0092deb639d95f1b410cddf4ac1ba468fd49
# 78cd8a86dca2992450559347c4902db4058026d9
# ca78cd0d04e28d30afd4c7c957d19c6913aa3702
# 391473dd57414a65c7e41529626e8d32ab48df33
# e412b42a0b12646da53e492ad2efb9fc43f8d7b2
# 56a943646bb21295cd14910ea2cbf90c3907532e
# d882aea35b57a128c6199aef789e5a8f632c3c91
# 90539858c48f2e727314f9d157e2dacf5fe2ac17
# c2a975b918f0ba3217601ea99d1aaba5c4b32409
# ccbb89c9f459c821cb033cf60f7b845e32202747
# cb456013682bfdbda5d7c15f0d9b557836f757d8
# d77518555a5bcfa9786762dc77334164e193fa9e
# ea247da56d74f989f9e0665712e4bf52ce8eb4ba
# 06e54353328ef7220b20b8de0547d224b5f479fd
# db1cf4a1500806ab91957ee38495a7da262befcb
# 0b0c562382a183c710eede0e4f7ce3d69a883338
# 104ab236e224b952d3e1e768f7d69167a8c3a0df
# f66e3357a6c7746eef9e9174b43422dd33825c63
# 5ac16578332eb2537907176742fe9bd254aa0f0f
# 4aca5beda6088be874985d500a5f08bf069981c5
# 8de043e87fec0d620073287e8b857d89faa44948
# 69c852302a3aaac3c906f2d09fb44c8cc06ac86f
# 898d8ecf9f23d4cf1d9d957f60b7fb109037632a
# c9227e478288a7fad758a2008312e340cfa267f4
# bf7652cbb1e970b5faaac55c5ac26a6d00a80fa3
# c30fc7460d3cfe9dff34407aa46a397d0647076a
# 2c841e773e1d3e5d825ca85c37deb82b22f85733
# 142cf33f918d7beb23104e60ac3138de21ba624a
# 1ebcdd106ba67499cd9e52b6b936d613afa7fd65
# 080e02505dfc9ce0551087030acb93316c08e91c
# 587d1c21fc741c65a0f3cca74625c1dc347968f0
# 6b628a8819237b0b28119ec9dfc7865fcae4cfe6
# 2534e9b23a20e94b45f4138368b02909c615051b
# 7a72cad14f396d5452c960d9168bbdadaad19436
# 49fb5b405c1eaefea5f54b10c4a3b56a18cc6562
# d4c204df3962e8282eee0924d2d856261e37a6b1
# b21f8cd9040e82413e063531339e4a68f172555e
# 7929a72284fd264733e3ef00d6f3260bae890514
# fed00b8ef1f504f4f1ef8638e84d2e0ced5e77b2
# fd1f12b89838bde74b12d1aedc62bfd2f4f4867b
# 89f2fe5ea6f10379aaee0a100f622f9671616267
# c322e0f1713aa66312ded18f96af4a8219608131
# 8322b106e7a9069f82d997dac759c8150eff8aaa
# b63457298f42747f8286e8b455cd62a355d77820
# b6ef9df8c0edde4964d3a5177ffab4d177737d60
# 06838f53a2cd2cdb902abb09a569fb0d937bfbcb
# 52a4c9d3699473cd43444042156f04f288fd8f90
# 18fd9ae053fbabdd7cc0c1bc1b2e6a545789f6e2
# e95c55207db132dbd8fd63bb2e53f2a1d58795e7
# a8d5e62fe575871f7f0fbd321eb3635b4cad3c5f
# 6b4b9d5d8fff984bfb1911d9c39c129b84759fc1
# 38ce75c426bbd916ec2d5f6c8cc8b022009f7682
# 57d3a2ec1c15af60d9c3a4312c3c17551018255b
# 5329e64ab04101835459ae3a7afc2abc8966f72c
# 8246ee33d53d43fea70a1888480cd8200d547579
# 601dbb2c225b277e182f9e620544908a6dc1356d
# 412bbdeefdc241fa65a2c60629f67448cc1cbbd9
# 3b696da0005437b171b51c83c2ae88ca79fffdb5
# 652846fafdf3d0d9c812ed2797c2e7d2896baa06
# d9316bada94d5a417ae7dcf6b4ca74aa4c4f3582
# a1d9282c38856e9b9d4957bfbe664fa807f82cc6
# d002e5c244ed947202a574778491198cc671a171
# a2be08aea2324796b2709222f39bd3ade39a0eb9
# 124dad774102f4002946c0aa7261427a24d27002
# def632a4dde52d7ffbd4990e1cc851f211d04830
# 0fb303177d8cf95d74852fa4d3e30244daada561
# 1f0fe8ccbe9ed100b24f59750d07481d7a585b91
# f30de8d93016301cde19efc18684ed977f91d60a
# 77beb1a55ff7bb069ab8996135187835f0e27248
# cd66ed218f3eed117daba41bc1761e191f242c1f
# 3aeba0951e420972d2b155afbd6c5363880b68b8
# 659eed42ee25d68cc8854b275949da1c59d46e80
# c9f22632093806e3325ce655ffeabdb056193f0b
# dce91b9d1b37c88a1e28b5bdb5cf05f44dcb36c5
# a8d9825ddd6f37dc4db9e13558c0bc6256c8d29b
# b12a3ec56da9fd72c5fa11a32dda1849dfa08c71
# c4ccd2cbde65a2884611502ec75c360aa6ff311a
# 946efddae282ed6a7de1b4293f7e379fd5f7f312
# 301fa201cf1c78b38ae4b316a1f385891258cd12
# 718c077521b429d7bbaf19070bb7fc81f890d202
# 1d3146fd4ac1b4294b7d03811851677acca743bb
# 3ccc9912b758f3bb0d40518e80223ea826642264
# 1615b347cdd32f510796fd0512a6d7a4cc005024
# 7b8e23e149b027c60bb0a75f95da88c3864d2141
# b88e090acfa89e6ed9d15c62194249434350f551
# 276036d06d17db7cd412210cd3f73359f4fab5f8
# c76d50ef710b33443bb05baab879f20557954e9f
# 870bd86fbf8b44daf6a371dc8538973f1f4ac841
# 2eb18b94f9d74ad4ecc498e4c6fe333e5bfcf7ef
# 211a5699fa1d8a08667fa62fa10b78a896019b92
# 2a6e3f70d71bbb727525bfe2808e85721fcc0add
# fc262c04949e57765fdc18e84813095dae3e4496
# 5e45011f330c1945c03cc7f9c06b855894a7b89f
# 6b9b8dab5f2bb1dc12c316beda73cdfe651db386
# 629e48711eff877962b3ba7393fbde65576dbbb0
# b0b4f50560a3df6029506dae8d2496cf0e6f30d4
# 376340f7cf1038fbe1b090b94ff202ea4ae37dc1
# 174f89eb05fecaef828da7d1aaa2f7c42ba5382b
# f03e53d9d94fa58046cd74922c80df2b148fc7de
# 3d70bcb7e6d4d22e445e9883ae6f145baf2b4e59
# 70bcdd01ef8afa6bd05e5eaf6f059af3b7be7d2f
# 6ff3330924894d08d6bc69bfd6bcc4346d7fd931
# 9edb5ef3ae3750c3f4395fc03123ce141bf1f337
# 4fbc46387f45c12b95525316ee9d6b8521f631c2
# d5455855f4fd59de3b4dd9834d6f11aae90a02b0
# fb603da81fb69b098e499204534c4ea95b0ed720
# 79a4730d00ff7db4fb96581df70aee6b90e03e47
# 8a10faa976e83a8ed96cb726222d361cfc5ac235
# aff6aed92d57d6aa7a7786a47a1c1f70c0852e85
# f02944d24d79d08781990a763bcd3e5566484bc2
# 719eab55b513d0b9f686d1eb00350b97b802fbe0
# bd6410edd2c46fd678f6a02b669209f619eb045e
# 4799e3ac282c866029533a5c2834b5b5bb46d71a
# c0088b637f339c7cc22c020d2ffe865f2cd3ba15
# dda036a1d51704238758c4dcd4a8fd252c0226d5
# c2a25f0ee9449a41393c7dfccbaf82af9c78e362
# 935751857e1c749118bdd77d07456647c7c891db
# 96da0721ff952d440f4739a04c273a5e71942a75
# 845c9d84ae5b83e5780843fa2e2a933ffd0e32e5
# 7799f5eb5c2a380bbc0e29701a1741924b2592ec
# 06a04eeda53d54202b5fee075141f254cedb039b
# 410ff3e84719c2e877c23b0597b7c9c52c038566
# 3027c57e6a28929b3e726e03e138d5682b3c8bb2
# 9683533097c02b9dfec2e857e7ca5a1049385b3c
# 673912ffb976fa63ae4190f82a663a6d016f1d79
# 0e769f414a4355a3cd979b9c281390cdd29203f4
# c93e83b8761e688067319eb7c01fbd1d0b3cc8d5
# d2e0dab7298b4c87123ddd53d059b00f47542fff
# 23a1934b7e50c6a7b9e42669675efcbb267e4679
# 24775e577b5010843b51fcf8a21bded107c9b320
# 153d895d82a91e2dde575c5f5b7a8ea44889a986
# 969e8686d6fc0fdd39fa27e0956387d71e90ca0e
# 52a34da1387993762b09de9929f737a5a94a4ff8
# fb456d492b94a39b4697fe8051a59075f1b4c479
# 88d7b6d2e4de934de1895043a779d5ca65106153
# 4ccf42974cdc5eae7d107963e78fbb012f132eec
# de031e5225e5f0fc95cd888af0aebb1aea6244c2
# 3402f614527ede54d3d9f2c491d084f30731cd65
# 60b13f2f41f384cf883269a7e00663b78f221492
# 2129eb70c72101bfb0bbb23e39d8a7a40c8cdee0
# d7ed8d141e879c4bd269f11e630bc09b807a4f3a
# d2fb14b70263af75a9ee14b64cd5b8cd30b816d8
# 01f178d7d19cedd8ca61dca08af130cb3c4d0fb8
# 308f0b1677baa8c5dbc2c8c7397ea397b21db7b0
# 7ccaee6c23059695e8ec0290d52d10d312e13ca0
# c005966ff4c48230ea81ebadf89e07c61cd830e2
# 784877ae878807595dfd9a69cbb69834cdbc6ac9
# 0a870e6542a1798b1a58afccf4c7c08234ca1c70
# 0a9c87ddd0b0a6d0e4543efe505e41f102b69875
# 6c1604c37b4268cb1fb68829ceb206c05e73878f
# b22a05b65bc5fa5b98f7a1c14b9931fdaf46370d
# 2fa609128bfadd102aafb05647b923f9ba83da26
# c5fb0c512fd188807cc0b61e4a4a7b553f9d34aa
# d3e04190ae9dd0e7865ba559f0f52e08e5a8171d
# 873c6282c6c3e4b90b5476190883e2aad4b9ddc3
# 3466bcd169640791283f2154334ae5c8e77bc2ac
# 0aca28e065202b480dc3dbce34d83757c231dff2
# 8c69c5feee4232191e9e7bfb21ff9d25a775ab46
# 850446c111ab05e03cd999101f888083ddc72e96
# 3e6a0215f5de266ee00994ecb7bdca70b551bdd0
# 3b1596e744f44cf88285ac908f8900ce54d2ae54
# 7b14cf433772c071e6b5a921e50808a26965387b
# 4b1930e93a65d49c264b4bfc60d69d3f7ebf99f1
# 94ea578729d529e92b896ce4d00d78e0c68907d4
# 199d0a2962044bbf278df852b349d510b41bbb36
# f54500e9f822b9cdeedde0f020c24ceb9b15e331
# 161b2f7a7d7fb6af41b0d7fedd01b07cf715c7b2
# 300d0ae60e68ef003bc74934a7dc12c48642dae0
# 0749f5b1d4e29651e758f8d8753ba3fd110e9ee7
# ad813f9a2a4194c279caba65e0bfdf22720f177e
# eff69ca4db522fdb8143c3921a7a788d4c19b9dc
# 94bac444bdcf34f06fa1aa6f43a8c26ae7959dda
# b3faae1db05af6a7d006691c92a9b41d7054cc38
# 441a7dc1d49915fc63b103f3af7cf3e6415bd8a2
# 3e59f27e43714699884f18217e23aa190d18f7b1
# 56b4f00982cf1fc84371ef72cb1b33450a73d799
# 8bb838275e1e71b07d6d99936cf87f82b4203b2f
# 419bd593da12470014082c7d5e11f1f717ca3708
# 65d7b757bb113a0d9060696219a0c5ec072132be
# f7f9e4a87b4af38db763807aa0714a7e498f0eac
# e5cb17854bee70888e5edd3fe1064a7cfda590a9
# 23982bc262673df588d253bfcdd67530d94f0c6e
# 6f692e9810333bfe3f5d08e5ea49ffdbef64ddba
# 80be611def671fec00124fd12e626992d9cfeaf0
# 9117fe4bdfd25cc5a90cfaf36fddb033357d8a74
# 83b8bb56e295a6297d9f226ad02e43b02ca42014
# 4ccf5279cebb51f6c7ffb50410677efec15d1b83
# 03abe14335aeb57b788642ef419b430ebb73364c
# 6e848ceb0bcf5ae329292e1706d1dccb2819e55a
# cca7189e636e1086d888263346ea2033f2526ee6
# b4b230e84773c474223b0c60b3d3a204db6371ff
# df11accb7c537e6e6c8c8c90e9b94a82b92bd367
# d7a7d2ce7972e39638df4af5b03824943bb2ef4d
# 75246a3716eb1aa354d087faafefef553ee38677
# 4154a6ba14df599f9eed670846853c6841cdfdc9
# 5cc27146b1fda412276832354359bf4c421dc89b
# 36b28bab51c212390d1edf212ec87f8bd93b3025
# 62a4f35c5fdb9c73ec74db4195e0e0b91c7322a2
# fadefd7be0ae1eba261f8548224e047838866033
# 4b0c8afbf11ab53d4872747eb378c27c4e255947
# e467c14edbb5692db4f1e130a2069b6a78f78b59
# fb9be74b01fbb8f75e4d3904db7e6367021055b3
# dd664293e7ae469e085ed0982324b93bf09e24b0
# 62752f2639850f0c0a2c2cb55697192e635c74a0
# 7e1ebf3ef2777ff6fd3f3975624040d10fecf133
# de01a0b9f5c0f3587f410a3ed53b09565348581a
# f8b545afb449daf007e06e25765c6a5311c3d11d
# 56153ebc53ccabbbc5fd5f50434bc011d484e8ea
# 1bd26d0ec8b14d1e3db019427be5f264b244b793
# 30aaf4d21749c5e6c81d3c54e17c2b6d8009c204
# 83719678b5539edd393bf7b4755f7d17a8ba8a91
# c4e6c1bc04441d7aaecdd4001db79f61873bb2fd
# 11706bb89655334afbe740b508585b90f6acd72e
# 293a69476a6a7207134808f17d162fa0539a6322
# f65c861e137553782297ea55314595cfbd87b875
# 713c0de77af3bd9e60ba9d76e4455531b86d0883
# 2b527a13758823e83e836d84947092aadce9d681
# 27c2c9495695ae81381ccb4fa7294859f832e028
# a8e6619d79a235671031eb1067cf4d9e333a9203
# fe2df7251de942859082fd088739c32595ffbbcb
# 4e72be42c12fa29d74033e5f3dce7c83eae6225a
# 522953f3939e1181876eaef49d75a50e0f8f9558
# 04377e1132199280ca76eaf19e288ab37ab1c46b
# 3269c4c489adda7442304a34040a3f144f32b538
# cebd7dcef3a5363b291fc43e84eb3a2ed897a920
# a79bb6e4bbd41fecaa8edcfa22d18a5606778198
# 711a880a8fa184f80827f25ef216dae3a51345ee
# 55fc0c0959df1184e96fa0d9359982d9b5e38cf4
# 18fffefca51d8b8c6e1e85aa3b6a606989e427ae
# 1274fc1f0ef381eba6747a059f3df42432596d7a
# 25ac409c021769a3467a5037019c7399a46d4a7d
# f6d483ca1791b70bed80896f8e5096a576d1f02c
# 643d3f4b12d021dfbab8e09f4a9528ec4fcf4cce
# a062375f8ec1534e9f52ef0c05eae09be4870919
# e471c91166f90a868ec3bf295ca9137241973062
# b5ddb8626bfca8ae959bbeaf7e12ce0eed634c42
# 8a8b6b5c25e53e87de751088bbec46940518cd9c
# ec0e165e533d2780237ed0a9c67971cbf0cdf635
# 59f53828dbc4cac6fb398e61c95379de9063e6ed
# 6db95ae5a40fa18b1f8a65f5d18da417607f78e5
# 8323a659822343ffa741e23186b4e63283c99ff5
# 55d4e054e09b0b9e01970d975cc9a4622b69b999
# cf5c4ce66b20023eb5142af3516dc1b73a9c8576
# 0355de14207c642ffd51b102e8dd2c2e0a0cac08
# 81001652de5e7899bdd2862483e51306343f9644
# 285afa03b2b3cf342879dc0eda7cf67da5a35aaa
# fdbb609385480f21ee660307b47978b59f9b40aa
# c762055dde38b095be0ae3a727fc947e05e98069
# 3d730b1c606dfe062403a67017019456a1b1b2af
# d5d6d41148f3a03b9e1ccc006d3dc1776d59ce7e
# 5d01c48c41d6bc843a6c66f2436f0a0f62f6c8b0
# 8193add4d305df8944827e496651d191aadced31
# be661e57ac8dad075553fb9f9d74d2a1569b25fe
# 28611e4cd40a351b1bc9533285acb961af435233
# 4ea35ca0eb24c5f54dbc90ce1a4cbd6033296cd8
# a80e9351efae642d8161ad59fc014a4dcfa25714
# d30f53ec089c73e08ce628a8a2df5d63aa8e3e72
# 2c93a5ca00035b0d66035c115380c3535d6bab56
# 5f68d71a64e5c128cc21f389301185b67ed1cfdd
# 912c8feb441e543b5b1ea4df1924cde7c630352a
# ad7101d32f4d7158ec1147c91e11dbbd253ca941
# f9ddd9ae6edaa127f9a448682e829de27c637221
# bc6b6150f35722c7973b949ecec75dfd1c3f0022
# 6b2f2ebae3d62507e6191846234e7446878fe916
# 7aee039f728897c4445d250c477374daf65169c5
# c3631f5e46d91bb9b6c719c1f31bd0dc5c92e84d
# 51c9a6894b3c76e0ed762ec0281f4b9bf5a71f1a
# ffd9de8888568cee6b54c2f7830ec7faec502185
# 504cc5d71619a8a839806821df3baff8ced00682
# fe250faa8029b7d2cdba2d226730802842ea707d
# 15cff935d0fc13a28b14a268ab5a8471dd45536b
# 165b9cb75b71843ba1ab09fdae0df389b1852210
# 2e5e918c0e1ac8e4057a0a9fa0fb20428b7d6d06
# fb95aaaf64efbe1108c4f89712685cb373c860b7
# 1f1e40ca85bc9d6af05b8ccaf619a6fc1a762b96
# 606559250fbd6450e9272c8fd00d53913010f556
# 033808da248d4b1477ed2fe4995f899241d8bfdf
# cc21d5e9f72b57cc09cc89461c72a11902da745d
# 0475477109d099c7e3de3e49022e86b571d518bf
# 59c8e120e00ae4f5e332ff24befa83ef515be7a0
# dc732505d32718fcab4cb119e3e0f408bd39fdd7
# ae1ffafa73f1d28ee8a580ef6d3c29317131f211
# e9d7b34406ae073d11063c6e19cb3b801e3bd3dc
# ebd0eef3a5c0709a402fc7b43859485c749cc608
# 720de7b29db7ce7e16e459bde9ae00748d25811c
# ef0cf3306de150f7245f5d0f88fb4026d4ee8a33
# a3d7ce50c30097733e1528c7ecbc7791c5d734e9
# 2fcb091601509b7ccc470e643bd2e3f9df7a702e
# 15c7b5abfcf50145975c3595384fff625c165821
# 87459aa2f3710ea8e8bd8fb60100495e36e84f7f
# 562a9e62aa718a8a81258cd2f0ddae198ff01880
# fdd0cebc2592390b54b61ab2512365380ab79899
# aec29f517fbec85de92d0a533011c69029e9f38b
# 39633d62136088721f77154916e396779fa7801c
# 304cd4af6236f29231124167821303088741383a
# e858fcc01297f85ac1d841615675d9d364433d64
# c2ead1652ed9a661776ba0150093c95227428b20
# f86a58101d3e7367a088c465467759ceab7213b2
# 6e02a5287d7fa999100a0a9d64eb22672d36639f
# ee2b2d91f993c2dbaf576182807edae23487dd15
# 57505a465b305400fc7baa4846f10c1ef7c1572f
# 6f510d8a5f9d02cc13ba76e20365e735b45bd2d8
# 5fe71d3ea5dcf9283e0a9708c5b295c7f7836f40
# e11cdcc459244f366a4b1e29bf688fa5bd789d1f
# 4914034d8e5eab89285617e2ca083bacfea29250
# 8bb4470e99aa81fcccb17c9bba1bceef256ded3a
# 8f561c8116041532fb7d16d7f60694b7c3e0fecd
# b110488f0ca25f6cb593d0a21f34695b48e4a797
# ad6ebd6e9279f71bbd554d11d83436af22dc886a
# 81d1db7b5209f7d3231cc3a9c3836dff8f152cbf
# 395658ff6280ed5b84d01554fca84bdf6caca146
# 9fcaa8dc356306f5c3a14ec64f87e8ff021d3467
# 1d8f60f0ed89f82e04531b5909e0d6c8de0a2c04
# 63f9caf7f47848c35b1629467b9647bbd4dee496
# de5650d3d2309875746b8d3de75eb833cc7a418d
# ce7d88906ab8f5ad3a04692fa3c2faf6b4bdbe97
# 596843c0edb6a6e5d865d8939769ab7ef6c570ab
# 625d62ea798e59e952a3029e99061a48c2533f19
# b010f796b0c69d0ed3e94e5436920db6fc6a45b5
# 34c8dc787fc63ad85752b53f702198106ee07b2b
# 8545d5e2940dce9e0577e3b447f5f7e63cb776cd
# 838b79a528c14e2b3c3db7bdf1f4e5dcfdc83c22
# 383756b0090afb399330d17433fdfaae7ca41a52
# ba4446aa53c3b3deecb84556235babf5bd5e7c15
# a7f226677fffdae9e466d20adba5541700e3d905
# c1335fb508a8752161b571da746b907f3c746204
# 3250640a6cf576c1e2c1b4ade14015dfa6a22ecd
# 35e8c54d8e88eef965bea905ddc0afb11eab5069
# 2e21ea1fc638d584172f6978ddd9324863ad050e
# 591e1171e838baf50776b421b58a9e462cc5c24b
# ade2a65cedb328782409052ceaeafedb92055127
# 705c91bd3c8821cc3888d373524d8b92e31916cf
# 8239632dd5b56fe07bd3a47b3b6f3496be68362c
# e04d90502511c32fbd46325484a8a6b8d321bc1d
# 63b9f7cdac1a96a1d3c7954caae00dadccb5c004
# 8f12166eed4e2f21d65022af69c44dd0ebdd6011
# 391d2d2c8c0b4da710c6943118d80536b5d9ac19
# 4b5ecf85df187ce380c0a1c264c360cdff11de00
# 9bd11e641f4084660da61d07f9858a36490a8388
# 1e085e97707c04151ec3f67daa3f5b50c49da63b
# 0b7a5967813a62603bd73dc95b39c3d6b0693f93
# 3c9bd8ec9eaecde25ca45e15b64636334cb5381b
# 5c5ba2bebce2371eefd83c8910b167bfcb16434b
# ea52852e2aa7e03f5dbd0517458e548f542a4392
# 3ed931c1d50e524033089bfff4875f13a67d0bac
# 6c6a1462c067d9944fbad8a4da44dc26fec7457b
# 715909329cd3b755bf87f383d5e29c137b3aff97
# f5ec9308e386bf783511838b14a113dc50132464
# 3143b61e0e6d28ca70bf85cd8f0d1908c71786db
# b664170e1c678b0373fc7a9f3b77e4fac476fa56
# 56df2af2d76f0f3c554865f3844fc764be65b1ea
# ede514a1600520e87fdd99f554b1d2a1a1c11525
# 61b6e0692447c553b0612464d803712ad0cbbfe6
# 6709ba2548fcf5ddabffb3025b665b10862797ad
# 3945c587fa32ac868f46af263d7407ad9f193874
# 9d79017489ee958de08569e6585697ccb1aebca6
# 3a47ff89a463355d6bf6ac7979f06d74ba9e2afa
# 9c9fb38fe2bd16f42bdd5138946b9b6ef97165f3
# 9c26c890800b18f4d346b0ab9da5cd8fdd2ffe24
# c0e697607cf1a54a3363eafe652203e275d32403
# 3dec9296c79fccc1d1446561decb73eb5dce3e16
# 4b9f40d567905db18bea30e28d92a413188fa9a9
# a145a3611455c13707650f1d728bd456d87d5cee
# fcca7a67f865504dbfa238559077948ce0233b00
# 8fb6696d4bbe0e3318ab50a1e49ca636d45395ac
# 6e4c84c142275493512ae71a7c793da88f8b7caa
# ce6bd05aabebf1935d5d8b91156edcc2aa2f75cf
# afe6574a09e3d199c2b646590347998b38146416
# 06b852c1e69c82f02d8103da5fbbdb50a2856695
# e4f420cc27e8aea5f158c6ae99c556d8eb02d82b
# 222446bf29cf2bf34ecbac7d4eb9929e7c01f522
# 8e03c04cbec1cc59053d886b2b7ca80a3ca23bd4
# f338c2875a7d460b8eb549e0a8ba031ed50b9ed4
# 5b4ef8b89fdbafb294d3a73c8895b02069e69810
# d15fb26f5b6ffd257ce38059f8154af21c926941
# 17cde9d402d9b199bcb5d0c7405da0b0a1c687b5
# 704ba424f030608c3c599b77aa84293010ae1d7f
# bac026ca9e3c5e7617c9083b368803894c0c4cb5
# 3c324c1977894b62daff7080d6f6f3ec0845a361
# a85a278c2c75fc4ddc2e1f6c32748fc825cc633b
# 7e1d9ccb5c82507793d1ce03e787c38cc984682c
# e497f9ede212d25697bbc68245c0b6fcfe87db09
# 8ce70df4b1c06a6e2515ccea9a0f8b2c9eadccec
# daf7796ffc72df2501ef9a4132b7ed1ba684847c
# b04babd239de55f69319b038c9944b3e7680d314
# bc7355e89e8a6067c199be1d69cda4262edeb726
# 5073213c7f59e33b095bc2c5d58f85b5b78197c6
# d1ac13836457c7f389b0aaa71da34c395d9bfd15
# 6db14fb9b2bf36abbc5aee7345879777a7fa9861
# 1c6b8c9cf3c1a10a68ddc33a82b5aa222e629fe3
# e4b387d11e188fdcd19eb815738d0798f4fae598
# 256e1b924d9a2772fde30a259fd2309d299e1cb1
# 9c0d79a5bb53928bc75a0ea01a37a5f853761eeb
# 452aaa26f4171a2e0bd0ab6e0dde557c86f255b2
# 3ed670cdf6057c73893199e1cfcf1b6eb413b005
# 820117709cddfd4faabc8eb728ac562c1072087a
# 55ae9e174ad6410bb4bdae86b8abd81340868072
# 76c57e55cf123539621d9bcf0d1d85ecd3b407e2
# 2fff95c52d17908631452397404ed4280884a222
# b2ce937dc55f4b2e1029c63e4555df30558c0f51
# a15b61ae42e450f2a0c48692b16483d663769f5b
# 33f9003a58022a356a3bf0034f7f76e6825e9c08
# fc01afb98769a484a2120b3ec91ab072a30afa03
# 18d99d4dbbf91fe82430b0e7360bdcf891579bb8
# 5702bdee1a6f92a25be4fde6dd0afd4601e2fc55
# 492ac67d387ee5c1f3d132f4fbbbf21a0c017010
# 06ea0f12eaf82558052acddbd5014ed3dffaa640
# 8a8c5444ef55b46d46f6222d335fa5cc2c71ff4e
# 3f25825c6781678102dea175ea2d462fad3aeb3a
# 32ccaab346857bd165155003385ac5f22cac7ca8
# ec5f575266d34add37816f8ea7d34b84541c8833
# 18664f2001f8e0387871cb806526c11d90c6c616
# 58a20ca92ad8f962418276e662d2809825d7ffea
# 2ff34f698ca2131ac1a8ea4714efadd3a0d54c28
# 57c8c473e241c644dc964999059b3dd0ec62207c
# c41c818dfc4cc50fe04db4f6a4b965fd66679472
# 5b2ba79cb601ec5f0c323703e093d2efa3b07026
# 5ad15b1c59336858db9237a5e324d52f675da5e7
# 3d857632ab9aca93c0759de0229790635a5e6ae4
# 74e711b4c9950411b6b906a6a21f70d7884f6bbf
# 74a7387ed1a2eae301659fb7813c33c43c915cb8
# 09036fc763a03f1b9bc79a47a050ffef4aec6f3e
# 03bc439bd3049ced9ea1394b8e69de07d81ca3b8
# 09176ca2e113a42aa3e78c8a1c725a2f0b4a485c
# edb96d76527edba6d5c31802b8fb02ba0cf0c8c8
# 5bca67f675e6c0fa0bc6911d8177e8b396f1c034
# ac4ff819cd881d6a8811742b3d9784b6267734ff
# 2b19eb82c2a6be8c627454b819c83a73795c8409
# 9d1bf622f0df42de417321e4b3ea5ecb1a86a28d
# bebb60f67b647d280ade45e5d8f62d80577b9ca0
# 4d7e8c6fe342d886f62fbeaa62bbf9cd5a1015dc
# 9f5b82d0b8134cc4d12e6d3ed015b14771215954
# bbd5c8a9a134b3f1d0cdbc0793291ab4e28d6736
# 5868ffb07fb4421e1488ff0a3e3c9b9a50b3ab60
# 575b5308889732610bd2fe52124bfd5e49d8213b
# 025c07a630e3e88c960818a6b3b8f4957b3bf228
# 169178231f29812965e69367b842ff868f97b4b0
# cd95d2d03b5985031cab6bb3a68701e42d82ae6d
# a41a2d86e75664737373c71860c1e989a42722b9
# 448efea10831197568d6a9a6c0fe45cdd4ca2cff
# 85bbe2693ce4fe1a9310dceb8e3ad27e8c7aa4a1
# ef9cf7954a086dc1ad3c3b6d5ccaac6bd5fc8e07
# 115dba937dd5855ea5673d763e9939766cf139bf
# 7e38ce5252a43c3fb7e995e0d37fc19491159a1e
# f980812ddaaabfae01b1295b3dd6635eafcc3a52
# 0475cd5ff1b8891cbe3323f05e9128eaae4847eb
# 94c32254458e9b580f15f72b8da91e6b880f3696
# 55128c0954494450039a4672dff82c4311edcf97
# f978e156f295532dd274f79f375f01ccfd3dc448
# 70154ba6460be044e8b5a5a20a6584933b166be3
# baa9876c3033b0ce4fc16ec6ab600b3820b3e0dc
# 124c9c759f50f6768d83f977738e1e45609d065d
# 3dbd367f9ed04e25804b441bc86188b1d1bed4f1
# b41ed62cddbb362b6b3da98a64c0505db64a02ab
# d2404f22c697877f9eaf1e1250b372579c6f2843
# beb72b87a2a7b5a6f5f2cd23c5866a53ff70ec01
# 1bfc91e7c012f1043e4a28cbc5b3299edeb9414c
# c22d1767cc6a984781b8be711ec6fb444b5c873f
# 47ecc79be25b5d236dc262fe4f82964f07567512
# 61020f3f901d73ceb6598def6f8f069da81694e7
# fcf294c82c176e2c9d1a04d32c3824b3d665fa01
# 5f1977928b38a5126aa864b3510d676ed852abfa
# 4aae037f9fa19e40f50fa744a8af282ad32b28fe
# 5309ad4065552e3026cca94fc4bd70e571d6c9de
# 7c7ba7be9feec44d0d2597f2bf7016da58cd7543
# 3e8c028ec79cd99a14db6831a389dd41fbb5dc60
# 2d5769c5746a0fe6455c43699c3168a9318ff1ac
# e13410ada7510a85ca6fe1c7c6d1e95fa62c24fb
# 754007b26ccef8b767c6472826a662dbac9e0836
# 87925106e22ad07b2b566d64b7a7ffd623aabe22
# c059a26d45d7fd6c642f97c91f6315a23a33f3bf
# 3405a1608a2985e3febcba6457f5e82fa15fe2d6
# 3fc87a4e9366b49492d11d2080c3a598922f56ce
# 16ed655539f67e975a25df908453208cad8c4739
# 470bcac4b6f83cdcada720efae90dfa7e812f5db
# 2243c8b508ac5111b0022d3aebb2556aa60f3020
# a12fac89b02eacef884ee6213be267a07031eddb
# 174728314b6390a26b4509c53fbbac90e833bcd9
# 5d509ff9d7356191f274381c06f0768ccbb4bf64
# 059a812a6bd27c3108416bc6f9c0544760ac9bf0
# db9903c64a035319ed7a39403d2676e01071fb9b
# 83886577202c06b52f6aec849a0048eec0e80f5a
# 5b21549ca6c634c6841396924af157e76c6932bd
# 7fb759e8f64cc41129c74414e547d1775b884338
# abe52763afeb102ca48112960f5a59d94d9a5d2d
# eed2d1a4dcefadece4a47c3097afaf806bba9a57
# 5dd76b3c725edde2db1df5d7fa644267af3ba733
# cf67b892094c54ae7e5539345c56ea65767afaee
# d04fbefcda94e18438adf13fb103bc74115e0396
# 1706a737518366da92282d85747f8711dae0039e
# 4600ce0963244100326af34439292a5e2c93ec02
# 7594093ad1b96aab301843de43c354863c7fda79
# 24171e4195dd5c99e5999409746b0bfbd0cea3ab
# 4481818c2c26bf8caad58bc4341e324f10f0c11c
# 8628632ec686d32508708982c6afa2bb398fa724
# b13b5bda4ee654a2903568b684baf3776fbc63ff
# 30b4c004ac9f396bb062b0390f2b953621ea6de6
# e6c6db302bb1de6664880f198c4a8f279bf1be4e
# d31cd33dad61b0ffa85944f643629412c444d448
# 91569bd8649fdf91a6912e951ab94042b976288a
# bf6d71fc76e1b8e5085dc726558c4e15327274a2
# 45eabbc3f525be4d67fefe5505c580f4730c0ef5
# 26e312b6889f6ac215c119119e0f2bc39b745b74
# 80d1068c2c5898b9047d10a6efef99ad5bf54b9a
# 522255f51b42a803e1e0c6f2fa06bd9e44ea9246
# 05b4e7bdc20e043e0d0a5434b8ba45e1aa1175c4
# 7bd24973e65ec350e11026d2ee9d681a18daa537
# e72aa3df19bba9cff061536db8a4c6a1c25d857a
# f184763ba987871c65609e1db65be42b5241b284
# aaf5c1b3ac00b7ba23930dcf6b1421c92e607fec
# beefd1d94b4f775c42d3f3340927afe65c384e35
# 558f41351eb2e7c66ab6681daa1ba2c78d0ee73b
# ac13ce10b2375e2f9b00d7682efbe071eb172819
# 6fa9fff61065d8c0abbd7816aa3ecf8dd0a61bfa
# e6b98ef42d693623860b88c663b6cf67865dfa81
# fb31d4a4a58032ded9c2bcc6147990e996933b10
# 14bd418ea38482a3766210628ec866d4399e899d
# ec517f4f49c51eff89b83dca433d7f9829ed5aae
# 52e26916f8342372008c12bba16c416dc486a505
# 2533c87764e37e983b8f98d40f8696c95a6bd405
# a363e6afee2f82cfe5823c3efbc9a0f3194c71bc
# f0df71f55aa44d0fb8e310c9c024f931e4c25329
# 1f6c2a625a9b1066f08238690b62a4a5b5ad4428
# 8cd9ac48c2e6dad306df2aa4f6ecce34f2fa0801
# 178442bfb9ce151c39830f423be66a9963f217c5
# 8fabe6a0c95f51da467fce2173ce4391ba347d47
# c8796f3d05394b67d34d09f38570796f2d6d05e7
# 456932aa43296d903a09c471ea816c104ba08b8d
# 5c06d5ed1972c36cb0e541716be27a813783048d
# d510625212a60376d4ad742c86daa79a266b8783
# 121e91db7b5c6a40466d8cc9880993dd1fae766c
# c1f9f665020cc6aa213b2c83c27a285c651eeea4
# a6cb600b8bf05fd14cc6d61d518e370734952b6a
# 41be2aa6212e15053e13281c8caedb780e40a0e5
# e9010364cf1925f43611857019a6c9b07538e471
# 563b3ba7309ecb56889b435aab280d47464b8ca2
# e90fc857d07f7fdb69162c63ab0905c498405daf
# c98e6ceb1d42fda11f746149acb5919f7dc8e266
# f1a670166920e243654ad6aca6f9e6dba77c792b
# 252d8d86a22b51db2bf246b9b7376cde35c742f6
# 641fed6db29612d1477744d517dfaba3a8b5b193
# 95b075f62596a537e983a6fc588442c163672714
# 69559b74cbc4f4a10b6566e5eb691ae635ef25b5
# bfee655f683480448daad9f52c67c332062e709b
# 6da00ac59d9b2344034a57b08fa49cb0031d69b0
# 8438d5e97452c71365bf18d5362fbb5d9ab2d24a
# 4a5cc088544e61fca513f8c2b34e4b0d7493e0ed
# 4f65d39afb96cbbca94afb6b6b95a59f30453d09
# 4e2cd276bf2ce0bb0a05d8c56b7ca8d682c708bf
# 41896d4756f1cae5e6f127cd3e7990e4fdded7a1
# f758de42d7186d04224d908f82aa4255b265fb4b
# c6128598a880b0758cab5408a5d5fe15eafa0cc1
# 3207563a5a2284e8a78a668e09ababeec7429935
# 825c50aee4eccf3f220fae3f89254e133067a5cf
# d42dc85277a3ae5d335a4284c3dd11aad6817473
# 4f99ccced470f47c36408b5a5a3f08608c502d9b
# d2b7f734225e9c754ea7bd35dcb69d306aab40b9
# b5cf0a058cc97d5575ecd781976afac0449b8b31
# 4873eb0a71e44e701c243951a6540201e6db2beb
# d1426362b4478f0f35ffa9f71ebf3867ae234519
# 8c913dffab75a3e771e00b698652e1fb6971e6e5
# 2e12bcf2578af5618a8e259946a6e1ecc07a2318
# a09455e466ad851a2a8a0a8c8d632aaf5017791a
# a64fef214cd25f8fefeb364d1d275c1cc532a44b
# d5c17bfebfa006ecef43e994b23ca5f066428770
# de28d73ad71f053acb20bda617c051c1687335eb
# b5136803599e80a4048e4dbf91b44573aa7a4ced
# 12ae440a96f67fabc82a923e155b008476203ac0
# 43852d24d89cea6c8732f03a0372ae62403539d0
# 699093f20998f61c095afad1779ad40c12f2980a
# 6e74988cac5f8cb4a6a5f41761e54fb29a7fa652
# 574dfdc1aa61613e5c3b754fe5e06b4ba16e0009
# c55fdc1ae36d672cae2a141eed3bdcc8a792ee47
# 328c2909135a929af73028d0422e7573fa5dd431
# 9386841f5516ee78991a5218f33df9d15c4d516e
# fc6931ce42d95da9c4bc9d262a0a7a109b7bbeb0
# eafffc3977bbc7e7b66f193984395eec96d70668
# 9973543a95829737a4758211ac70cd1e643755a7
# e429844ec2d395d68205648616516b5bf0162a8a
# 4c983e0c006b8d9960ef649fffd5ddae8d171448
# 3fda0017d61173610d2e4190cdff0e044b42dfd4
# 32252a9fffc82c0505098e69c095aa7e4cc3d299
# d478342f49a62ad2a92d0d528c1f86a36db89dac
# cbf1376cbb46ecc656fc24c5a0af0dbed49271b4
# f21672fcb130e6fe0a9face0115b536e100a6ed6
# 8df4e28f219d2c18532f78daee2e59afc809a3ac
# d342fcecffd32b63402ef15bc656a8665d86a63e
# 95e2ce42b95d6e25da7e0c5d417e6c7e8c095b35
# d6460743d89efe23ffcbffbab2535aa018abe7b5
# 4c6a32d7070519a8c63ae8941c206d285816daa7
# 6720a696388d77550dc1b427eba20ec60b2d897c
# c1a8213834e3289290fe1b24c5b929e3482b0c7e
# 14462a0b2ebad42bb98a72fdefd6e8ecc57062d1
# 39d908fe54fc4ac6120e09bcc94ebbaf78d889ad
# 7a05b0e152b0cb87914044cdd4c3f22065e8de8b
# 55a905908ca666cbcec209cc99dbe78ac6e59f74
# baeed8b89e351c7819fe8d9010aecad444da8d08
# c82304c1a3833e70299fc507ae7b2b946fcb16a2
# 53687095c0035cbc64d3a90b6adf0d11c9eced52
# e601a0cff8db21dea1522c5a785b6f2657a628fe
# 3a2d39ee744b5328d48faf90197a493157593c17
# 9fd2f5b5449c9ee916ecffb4357d8a4f3cec1877
# c4b7d542db53a1c784ccf0891f4154eee604e017
# 0cd89c48585404c89331a66cbd05ab6b9cf3535b
# fc0451b85c6302cecd2d9d8ae0aff3a796a67ca6
# 7014df365fb37ca2280c333800b7f90f0b813465
# 1a660bd6504838df14a8684469cba68658035bfe
# 8a420ed4e03dce9f6d7999b0a855444829fa98a3
# 5dba6ee02385a14fc5723c1995048404f9786700
# 48b32b5e5dd351ce21651ca2b53a5cc4c6e33eb7
# 59c1bb8e12f04d989f1a8ffd987befd5b86cd9fb
# f63cd4bd8974ee390f9ca58679f830333385f340
# a637cc0317b9d20138e2fdf1968c98e018f6fa13
# e7f56efcb474eec5d5b24654f246e04d9beeacf9
# f199df60d5768e70f566ad985f5072aac0cfaeb7
# 8965266675561441c75567bee388fe327f4f2456
# d764bc5a19f6594ea2f068f55cab007b8711b31e
# 818f5f2e240fed0fe96980f77e5ea074cf4f1c3f
# a9789fe167fd3d99d7178ec6ad7c64980571a435
# 67fbaf70374f31b31a8efe58f627db824eb2d490
# 4b0d48bd809242475daf09357a3dd0df959fd7ca
# d9966b8643f01bd95a997f6889935e47856111d6
# 5ed2ad641da7d0731b7c7c2aaf8ac13b5e3a17f3
# 3e170a10e944b9766ee69abcd2971c5a2452d5aa
# 2e607e83882a85559049464d63d50381aa02f682
# 767ef310cf9465b2d216422bc3d801a0363ccfd2
# 4f28621c69fbcb95ded2a4c6b8e0a8de5a7d806c
# 23bf41d832b88986181e67f58ff47bdf1760af17
# ...
# fff08af14a771581eb25c04fa97e39856c194fd6
# 293970c253202ca995ce178b46525d32f9dd7110
# 3b6f22a92c47e270d23e0345edacfc47ca79372f
# 1991f79a7163041cb1732890fe25d7e27aff0590
# 6d37100eb524613dfa2a5d65ac6749528d3688c1
# eea1d3eb54154f1c9e602f284ceaaaa4577d2a57
# aeb7ed47d24d1b930e9b97eda03474efa83e4164
# 1b9c3e6121eb38b7f88e2836424b8e248c578ef5
# 6a190456380122ce92376d7547b8ff924f6a24d1
# e993eb47b26866274ccedabdd3416a0d433f7d0f
# d5b050c1509bcbbafb493e52bd67ede1ed525e73
# c66673c333af18fcf9cfdf55721312f26d92fa62
# 5a60e3c7126e7821962719cbbc0067f0f1f0dd4b
# bd8dc811721e7790ed66c9157f34610dc488271e
# 014c95dd8549f918e2fc98caa85d87193f64c79b
# b893ad64bf36baa74ad66f9d18d438c64e8b12da
# a31a0e2b357670c9603591cb403697c3a8d90848
# a85c98ab233445d1fe415d2b470a5a42369a6de3
# 7985a6f8e591e61fbf5408f2c6dced8dbf9e8a49
# 7ba36da5f5dabc77e3daa13b1a1e296109fdfe25
# fd760c33b254d705d62504786d33b8f94b56b4c7
# ffd79eb25ecda997e219b734d5e6ee0067ffef55
# c8f15f2f977c067e0603cb1500fe3164fc7eb0eb
# bbcc7c9ba2c0a209a7a7fd32b57bd57543615c7e
# 71ec2d2b993a7d56cae3cc4a700584e2579fa3f0
# 8343e9769c56d8fd1eafb70e68259c61180fbdea
# 898fd0f7779d117f65064e9eecdfc5a7f0ddba06
# 182c070b29b259f655b60340961d4e42d6d9e864
# 360ea47c9c5b959a3e4ce97fc3083671f6b788d7
# 96701e0d2b6bdde892ad21668a2c41973e293c07
# 3d6ae23aabf03606e752485f4c08b29a2db4d72b
# 3cc14271f9fa3119e0f6382238f3e7197541505f
# 5e32a45d7df0e34c984c5992a18a08ea3da4011f
# e6d72f69da3760727de8aa9b229bc01523a18efb
# 8d66af6776def6c89b56f3fb0b47ad69115eeb58
# fe5b44f8069930d1eeab1c4d7d28c9a93594f290
# 8a9457ca6d47f7f054e6447354a66ded2a29808b
# da54ae083bc6ff8315f691ee71bef8c955feedbe
# 53e2da6c7829305a8dc843e09a531e6504e50034
# d694f4eb26b1d94d8544a30e9604bf9eb27e890e
# 195fec3d20ab8c72743131aa9a23aa4cbf785bcc
# ffad7f39d33d9b53c6dcaa499c2e4f99f24382a6
# ef46c2cb6d76bf1f02f9e19dc47245115f9cd0a0
# 0c5355511f341c0a34484fd80e6f55b0acf32c69
# cb3cf894c8af37fd85d7718b9bb803069fc03419
# 94d4382a8956b7ebfc253ef2f20e784df16735b2
# 2fdc0b5196afaea9767c76cfa7444f47c0046659
# c64b120f3caad021731be6b8bf359abd150d719b
# 5e275e718a386354586c441b9ff1f20ea4cba841
# 1cd44010ed26617908d2132c66186b30de35bdf4
# bf73dd8a99b464ba2380c0eeca0aaa55c5696965
# 449fcc203e6c81c11d949356bd4e7cbe80e9fe15
# 173f06166397dd7427174a62758917dda1aeebbc
# 4aee1b7563800d4c54494846b5ac169b87e81a9d
# 8de3c99923219acfbaf66a74dfe96629b7933ba2
# d4c81bf82584bf0ef244929e7ecf6cbf5e63fc6c
# 04fe2dcaed4804befe845ba048887788d2a7f428
# 031be806f1762554f569caca7b33483a4e53e3dc
# 403973e882e12d7b24899c3656d6648a767d72dc
# 6c1fce1324dd1de7293fd0896908eee85822cce1
# e78b9ccfed5003448fede76fbe29f2f658d352da
# 066f3b9d211bde75c6430e24f7e717dfff01e11e
# a3729bd55e92ec8020e6a0713cfb5687637f3180
# c5894fa73356cb0c65b6515622b58f91cac98368
# 24e42951dd8101e0f8cb9c891bb35a4b3922967c
# a61d1bbced7563bac8362102e05ec4c78ec59894
# bd02fcb27fc96571a1b04f98a825dcd631d81599
# ba0f009ae4c720df07ccf79911794011227b6a24
# dcb4e9a1f968bb31be0d821f7e1b32be626c9255
# 67d7108dab8ddc00e43f3b59164650e7d49f3299
# 39449524cb99af34d7a6d30beddf65472dd4d546
# ffc8999b647a04990f6b8f7d54a3a4f60bcb764d
# b29ed0c09d525001ed12ca78d36ff3a427e1a529
# 7a617394db4934048d90b2099459fe43e2c10cf0
# 5b780c19185a57fe20e601f0070fdda6975700a5
# 493553adeac7b7be359dca552794e770004d04b6
# a3d19af2c48b1ea0835b3b0f6ca28ad7ab857c66
# c9357ab29d2eae7b75f4b83fb4ae06cf95c396bc
# c667ca2f7b558e8567da76115a6f944f27e7934e
# 3d01a117368220c1ca61589ee4126818bdd7fc21
# 94d7eabebb2b0fcf6d0f5d7689218dfcc5b20cce
# 4797ba149ea301ab66e32296159166eef158ac14
# dc37ba991a0061f467e3cc4031aa708f66f7aea0
# f55c31c2f09aff37a3304085ee48238af27d6b20
# 7ca019b4655014ec8c72a36f4ea52dd6b43d735e
# 1c7d29e34eb925ea59800e69ec132ad167e70d4e
# a862f823be16b74e0ad4c1888bf87b29d54d19c7
# 1d1e65a9c7feb5f10da2d9e255c8a11ac9afe221
# 9417107125d68dc1a78c3822bee8d3bd043ab6e7
# c1ab1cd1c63aee07d888400ecb56e204ebae0a3d
# 7386648ff96f92bd49dfa451f1d8f828e621ea45
# eff2c2176aaa812929becf2d877aa88eb100074b
# bf7bf8230e1ac364dd1dc9ec6d30c9f80b218944
# ad5d162bde1ccdbef3e9752eec04eb15110ab26f
# bbf6ee565e0c76dda983a99711b79e5388f444fc
# 9a8a08875a654f681772dc7614f8af98f0ad9d3d
# 674f483b2eba670081e2a797a285acf483d4bd70
# 4c9d4486eee830892c80a0297839f621754afe7a
# 40cc020f2fd0389e32d983d2c28394b78061aa76
# 9609004162bc1749c45754a8cea1a1604b31caa0
# c43f49b3c5b374b0bd6b3b2a807ae8e3c5876b53
# d009ef122383a8540e5e0924aa5e6c557636a576
# 52725f0e1dfe2645e36a96385a5e801cd1f5f69a
# ce2f2b9f918e2b69de5a87d10ce4aeaae8943b3c
# eaf315de4f73e1318adf792ceadcb2539e02aed1
# e60e15b931367ce8e3e0b4c77b8cbc906bbd344a
# 88a00992d68654e86721e78baf92e8d58347b3f1
# 18850bb5fba644b90a2ac4a1e9c2f11e27fb5d37
# abf086e2fddd66d05376f073f3bf51374cbf10fa
# c643f9268f845215446bc720a9a30b352808ed71
# 12ad054c6cc4cf191a5097a68d46c2e27060ff99
# f5d73c3b381cce6be3157239cb28f19bec6d248a
# 4bbe341961d2b4862663a6d80ced1eaa5f3a4c9e
# 5448b7a3d3a03fc0d517fd7375be216aa286ba8d
# edbb4d12a103a90eb1a25f573411edf0098a2840
# 4e9b6ca37ac6ec5369f291d329c6811c93f225e7
# 5c5aaff2d0c18de2633c3dd4853314353ab1f0ab
# c8c203ff3e8a464f0b5e5339c6e4d8f5046f9dce
# c1df124b3f92c9f00f2d93fb9a78bf6789effb52
# d851097eda53d13e55638a962a16bdb5b5ea3a4a
# fda88a3b1304787df3f768adc7e525ad0185fbb1
# be91bf42a23810d565a24a90f67724e8f6c59617
# 0e29ca7f39de8a7deb1a8553e756b3624b21fc5f
# 39fc83cc335a9de2c4b31f96f6cbdc6ccf0ef376
# 70036a1d60200c4df2d0007e96abb39f34225c1c
# 9fdc3e18c095789881c904572be41c37a4e1df67
# 8bf8f29eb2323cfe7910f3a1bdcd79e83281bd43
# 32961d2eddf389bc537d15b947a292bf827297a0
# 5c69fd8ee59ccde918163d10e02521d581038a8e
# 098369d532c5b5a57452276b97165180c418931c
# 0516f89ec14521f9f6c3213164a5f5fca47b1dd4
# 1a449eaa31ade89cc1c520f74bec283bdfbbaa55
# 2666d7af1ea2eb398c562385f70f57932556bfa0
# be8b577b2d38fe6edacbdb413b774626f6562459
# 267384c7d7df6d6274c832b087f68fb63c37a5f4
# ee8620d019f5d5139ec236c2a4e1bdfd63abae9e
# 5308274ffbea75a2e412ff922d16dc157aae6cf8
# fe8a6d6a02615535b8560c3930e1a82fe88d3b58
# 7ef9367c9b0eee6249106bea96607a45f7256cd2
# fceb6d1ff9caf9680741042a8da84acdf2ffcf2a
# 019bb5785a3dc6c8f993ddd0f874342e6fe061da
# 6997ea9e0455fea47751309391e43dfba52f03e5
# c0dd7f4bf0e3b6bfe5c41770bec1507e9bdd9a8b
# 70c511f291b00c3642cf92aa6ac52ebbb60ccb30
# 86affa0dfa5e70074eb539124d129bf8a02e5853
# b7ea60e302249d9c434179ea2a091739b7d88374
# 67415be480775fe05f034de347ca83606170bf04
# 34c651cd385a81187cab8f3e2c9931db3d42bc6d
# 6fa28e803ab4f9c2366c52ffbc56960c015c68d2
# 39459eb1731574b94f3a30992c7b094908de0d38
# c9943e82408c668e5b020be53447d38a3c9b9f35
# 26ee582b36632d6b76788b342cdf498a08d5bd72
# dffb2bb63119a9d7491467fffdd6abafe5b475e7
# 486906de35ef966b0fd048f4955f1b7b64385a07
# a9911d126c07a3b1e5827374f93a8727699741a2
# 02bf255e6b24d646cdebc46b689464f573620414
# 3b31bffbf6496499bf8d9bea89034d65cdc31c40
# bf06b9a1cd906a8cf040bc95e1232ef2b2c1dff1
# c18c105151e8604c47bb29d80d4460007558a04f
# cd1b05766e1605adbac195764f365e563364d764
# a68a180ef5b2ef15b6d1c4ea9b16b40df3a0144d
# 5b358af76a39993c7c1e432d4aec5e6b46232f22
# 8d20421a9cfb0d07ab6ebe2bec68aacf6a0344af
# ea57ddaaf61e9d3c69f2462c84e9c83cea2f1447
# 2fd07624939400a73b50fdf7cf2e9a07e92fb788
# 9dabeff633bb1a1d99c537313621939856cf0c1e
# 03a7535843ec41390bb64a28c461f77cfe377275
# 75b7959ff384bd6eeda782e162d1fb9f6b37088e
# 2eb079928052b7365d922dd5bee73415163d4ee1
# b0e16d184f266809ed65e1e08d28d1741c1556c8
# da4679498e4213e5e2da47596285e09781f368eb
# f365e0623d7c3a4eedac243e6158e9353de9d124
# 99f9286f64d89f66d7933317b5b4d4eaea73459e
# 2574224adfc7baa1195fa821f3a27d1303c0ea33
# fa80004b04a76021f2deeb589fe8d08516113ca6
# 96c7c5ad9e53c3da765f0ad4b6e6d9b0713e688b
# aade28f908624f2bf87ffd577d1c8b69a4f9d422
# b679e8831dad378d0f39aa8c712c69b44530d398
# eb398c1e4a107bcc49c06aa34c16e4db3bd9ba7b
# 42faef902fc11d308d4e645c4ce29a9ef3fa0641
# 11d6a78dee0327009151cdeb0c12734328c64802
# 8d87450768c17793516b0fec339226006325cea2
# 60748208b4c2bbb2efd04fdee3be211ae68a0b34
# 58c610e7cf15c0ed044f86b8deb549ec5aad8be2
# 670218bd02a1b5d08a87a2b28e5ca4862e32e8fa
# b8031c0f2f09b9bc43efe4348d4b73c553730815
# 24fd824462bc5eb628781c6dbfe65d3b74d225bb
# 031c300c2410c08c4b5eb415e4f0a16ebb167afe
# 99c69cf7eda9cc6dc6d49c92f6cb2ec5aa8827da
# da02c144d5eae938d08597e21541fa2c86f3bbb2
# fce6b3e46bfe7608a38cca681fa114dfab781dea
# 41807ffddbab7d7124fdbf9e7189d3cce4692af4
# 0f16ba460127cfe0d5ebf0ff630cbe2e8fa39522
# 5f72bc8c9a5982c02131866f805bf934da8e28d2
# 201f6133891e2a26c965c1c1a5b859401538c279
# 3f95c46e0c4dec083f2920de98a684536977debf
# 48ad44735232f53ead4534db57894d54b7863b13
# 4954f0204c02869283c6713599eaf61c10ad51b4
# a32a370323496cb3d270827958ce4ff12bf0e21d
# 04e87f529a20b87997d5cc31ccc8ddca3602e828
# 6122a4c6e9c09bff2400c59127081a163879dc87
# 2baa00ff757a1bd957cef13112117ef1e714cd25
# 24894c00ba336433ca220fb1fe3c038ded1f3b6f
# 9405ff5bfee7f1da66d238a327d847a13d371648
# a82e460834c6eded7bd3b8817ef988fdb3458a09
# 41a04cee71ea3358c42bf6c17d1d5ddc2f06bcc9
# 340e0e3d58ac04682b09da2cc7593843762ef3ba
# f85ceb652eb5d32c72841b5935898faf7d27f438
# 6d09922b32417045027c30c3e515ee2001de9a2f
# 7897df07cdd8a9addfc7e792d0a597c2acfa0b03
# 61ae0a37d1fda756f9559151c2bd18bd37427ea3
# a4bd7719f18747cdea5611d7eaa45ab0fb1e9fd2
# caf0eb5e225794141016d4d74b42decf0ecdbd4d
# e88472626fbcffda4bd994e5128e35d91741a79d
# 029a66db09c45b596049c09a444ec2a3c9fd3244
# 2655bbc2175d175a235bfc6ff74a136c36ce701f
# 45e8cf746d3540955ad765b8d810a3837b3c0471
# e5213c3a23b926d1067105a2d39c2604c5aa94b6
# 4863b138e69eda191caa7988b24d7b4d6a451061
# f9b37175c5f2da89516863136e872ce4ec0a9fb6
# 5669863369b79daab148eb46ee990edd96021e1e
# dbb7188528b9182b603f1de3563e7965de8de215
# 2c417124a5df377aa3bdb2d3c30e26a1e2011de7
# ad12713d067602d6e186f58378fe4c8f939e4c48
# c5edde426d5bfd79fddcf416bbacaa0d017321b0
# b635807536b047b438e8b0bd78a2cbd9b45747b9
# 2d7e6ffd7d6741289429d2a223bdf62272e75ad6
# e23cc873737b558cc9173d657d6ea1bc24e12833
# b9add7d69dbcddecd837c3a855a9d60dba4265c1
# 8e4d3e9c4790dfb3e7d25ac74d5e9480b35996cb
# cdd04e45e96b30109346a6bdd9411e1f2dfc9d0d
# b8f8f766fb2f58e3a27c2ece940a2aea8621f035
# beab4520436c098a1942bd054c2d8d4cad7b640a
# dbd1c849815738be162c493d5a3894e374339ebe
# 63f8da424b8ee5b0744d24149c2eefdf68c451ef
# ef3cb19b1ce47d3d7dead059a21f0f38040e056d
# 242f8898157e05909db22538294809db0a3f03ef
# a1e28ef0e16b6d305330e5bf88cb733ac76cfe24
# 1a3b38b6ea936c31e76c3943b4f3d623c6f04fc9
# b8f9c525cdda29d7e7574d5caccec5af84816243
# f88974cd7a8374beba23644d8b9f80b643ee1057
# e03c8072701dff471881741f1d4aa752ab389ad5
# a812f9bb174e904e4b26343ac1863903b9dc82fe
# 273b53c1b1187b960c5edae4715f6d3bd60e5f22
# f4eb0bfa40253c0b3e5660cdbd465c9265564032
# d1ebc77d98aa165abbce1d5f70bc90034126111a
# d952e76d815696c6a0b5d551b15346a40523163a
# 1ca2f17b67eb0891590556da31b26a1c4af25f15
# e790860695779b4872436c2710944869455f2916
# 3998b337ac9e24c8073584c5929bc390736b96de
# 0ebf04baef4d5fa63a7b784c937691aada168c67
# a3e1d146fc77f95557d45599bdc99e22396019f7
# 51d9bdfed6f936c54b4399bdfca413b8cc648dbe
# e01c4648836678dcaf71ec2dd76bee795d14c96c
# 005bd8e461c5f00300d9ec515988168fa6a486e5
# 7d0198364cc9bcf7b3e97c1fe990500ff12e489a
# 6d41dbc554457357404f382d92048519542a798a
# 8e17a9291e703216a794522f85d238130e2a6706
# d55936abb989a6aa77f6e351b574d190f09cccfb
# e363e765467b195395785997dadf7c4bce3224a0
# c8964cf123720aa8d33823e9c0f33b80faac8458
# 5ac8c7cf7c7673ce409425ad7212a8c730cb7843
# 36f1153c87e77a9356a9badb259a7ad46c0b6ca5
# da9984b2ad0aac03a9d878c9eb7fc46a6ae3b037
# e8e933b43d6cadd367c77bb519108d8204a024e0
# 72ab40e0e24a0be8fed9a123c4b5f8859e104e21
# 5fd920e5c6ecba8a06f8af42ad802f75c2d700e3
# 4e341fab284685c55814caf3047456cb0d89ab89
# fd52d75060bd854ba5521244c189ceb493536858
# 84a4dcb9f60ee683012999e21c0bfe80132614be
# ad7a91db1d8947463eff4c5eded70f1fe28a0e5b
# 2d0b68d8271526b7ef174cd35829c1720ce3d1d3
# f0175adc9b4ec09e9e034ee37038178ab5982f31
# 099e2dd4e586b7b3f59ad5169f319fe09804c1e8
# 181a79fbd5c4b34a0f873b4b4858d3eade3f0d35
# b4417b134d0eaa61a4cc64f76aa8bdfc9711a7a8
# badc9d6ca4a4c61983af291a49973fab1fadf392
# c11c98e36f47717601c8c8f7d81144d3d0626cf9
# 4bbe0e3bdd5538f3dc104ebf808ed6e68d5f7718
# 82689516732e9a1023264d0634bf2463e585ad6a
# 30df682cdfee9c30734048c1547f56c3646f8c96
# 83f1c061d22018a1cbc9259df394c5589d5a7887
# b58ea50a8257f8a547dc228710a00814f51074a9
# 6bf8331d937f86643f8b24406e58ce3030841d12
# 56e12dd50e3e8ac126f1a5e62cee72dacf103468
# b545d6460108fea12170aefda241e0e77d129c3c
# 60b7f5b44f9e887930e0769b9a9d630c92c56632
# 676bd38c2e0af297e064d529eb06b3d92c8d2308
# fc8d476bba7ccd714c1582c597c4c19d04386267
# d6ef898becc7932287ca3865ccd58597f24e3c9b
# 3a39e05c6a6701ff5547ba39a67f8553bbe68965
# 651c13127ee47b7d69e91443464177f8dd333890
# fd8fd0683e07324f8205ac79b452454e04e7fc2a
# dc863b6b930c4b7f0f7f4629acf15224de5e7fa5
# 1e666a1e4cc4d7c4a443dd2ddb1651350a66e5d0
# 1860dea06595b352ba9ebe0902c838af4aee8a52
# 71d93a47503f8a346abbb96b50a3d82e879f5c59
# 7678b39c55176b76f2c224dc95b2fceceb8bead7
# aae857ebeed3d56faf5aced95b822fbeb6d79470
# 190866e405701567c474de2dcf5c02402645fce8
# 43642488538693d2f2fc3bb5aefa174b50352aa5
# b925d7f5e87010b16451b66e5be194a5fb22f463
# 688e7e13099397977271b01b715ca4a0fb6c0d82
# 3297e73ff36b2ec50926bf4c740740581e3acbc2
# f597e18c052ca9cc0cbae5d16aba1487505995b3
# d5553d47eac8ba1baf278591fb857773d8dd6ddb
# 95af4d98b7bdca3972bf8e1b8ca5bcb21f57b1db
# 98c010e65732ad1b8ce0a4645ee9485e68341a55
# 4c27d015069179075d85f29c6b0a1ff307dd73a5
# 8f5aacf3dad043c2b66cc09d4ab289778c1903f3
# cc17f242050477c3499953e161cd1ae54df4a14b
# 6c7b8fe6fbd0af5b6e49efcaade201299fca180b
# 672352defdcd2f5bbbde6d53c43076d50b6aacae
# a9f7bfae0404f3edc451c84558e55dd4eb2fd3be
# 72cd9dcb765c1ac5197e8748c32a87a500c777a5
# 20d5b4d5821f44cedc5fea3653e39bfa3f408ead
# 94b2e1e8ce9c6df7d83cb2c30bf6bfb11f54f9e0
# 3dd178af01b9ea6d72148fac968bf8fd7fc1dce3
# e3ce12589cc711e1f45dc6efab95c65621f86c8a
# 4d7a33c736c7a5a6342bd97913642c7fe1982fd5
# 3136fcade67e1acad1360d0fff1294b6fad8ccca
# 9070c5b4ef098dc72a022c041e162749355247ca
# c59cbc607562b6a7c14d449a31f3e6d90cf2694e
# 50e77a4c062445a4574ff8bd5da42c9f5b3c58d8
# 41e3da21139610a127754b214bdbc7f52ef08557
# 854c4c809b36df770653b76e3c15c53ad593ed60
# d140c0440c1c4e3034656ffac46add6fc61c154c
# 087c64d2af3a294413b6f111569cc49ebcc30bc4
# a1f2c298ed766cccf59506e44b2a30b1566758e2
# 80348c19d50861b7f0bc41eee860decc64689b99
# cbc0fe66a8e0eb6db7a8b2d948dc783513e90d43
# e03b1095e4b996965d36bb87aa564feacccedbbd
# ee3d5c5bf013c4a46bef507c71af893ef8a2180b
# e2d6c7898b0a9226519a973ea784fd79a6aee9aa
# 014f2dbfccbf33e74e02f62ad2104d239eb5be45
# 8e0103adf8257d1878292902b30146c5bcd39237
# fd5d0218497b326c0ecb1531bc45129e2be62fbc
# bc574395dc4a0cd8aecc44b7f00134f8b683919e
# e17f9904d1ddd7c9a61669bc76cb81162a34e9a6
# 7f2f49d72db025a9254aa667eedcb3f3dbdb5587
# 0bee57e651b80500d6c0a23bf9337095f2628846
# 1a70fd5abed2ed45cc228ca8d8ca5527250d7127
# 7c3822654440afb8cbf7b905f4b36e8d69bc63bc
# 73abb79f868fa46e6f5c0745165953622a65799c
# c13bd2c0cf21e2b9a4d71c394619d6e6031c534e
# 945743206cbcb17e40162994df855abe2e393b43
# 716b8ce22a2ce86062e1df714c3ac534ff165bb6
# ad3fa276f42019e24270d5f9f568ea1b3567f71d
# 74001d7515045679aa0a5333f466acc9178e85ae
# 56db6782bfcce3c89fe1fdf7de738364041b6c8c
# eb131ce8d361471c36522503caec949c1fe3c448
# 43d277585b14483b0afc62aaa27e29298c8c7a80
# 5748d7b280a5179e9a5161bd83954384abfb22fa
# 2727c6fcbe057e7a01d7305fa08589bd95658236
# 34fd59e9545367d3293652162b8d1b5d1a75cff0
# d861fb8a9457d59e7f478218555fa807eaf25eb1
# 411db3f9e94bcd3693926c7b595c4554bab8ef0a
# 0872bae1428b99f528f27493e287adf01c29f98c
# 4a0ebb7ba942150b13511bbbcf62e76008187b76
# 515596176b5e34feb5b71c5d2be8e4de86861bfc
# 125e946b1ca5ef38561490444d87bb766b7aa4da
# ff7253290120aaa51daf7b8c581a1ae3fc1b8f1c
# 1803c0f6b7d29b68a9d7385ffb846a93075b9e26
# 1439a23939c350fd6ab30c7f0c991e4a65a70eb8
# 8f7eccb8dff881cfc047bd7739e0980220e94641
# d2b1212efd6afd53ab9a250ea8dff09b2cddfdac
# 858a5c1e1f5aadf3244229b3e2dd06494d794032
# eee0526156f7e5d39947378e5b860d0e61f9c9fe
# 92c0c054a1038678f9c7d04ea6b1625c871d31c1
# 626cd734a3a270a208dbb6d121b2c771fd9c1b7c
# 4ee7941b2cecd0fc9e67657b3b44a694e2975cf1
# 806d72fca51e5681c81fb4fc062bb67b8baa01bc
# 7da7a69587aa3c9814154c4fc9c0230cbe45fc0b
# 0fd8f78f185d54eae6bec466850a7238aa0e05de
# 76930a1c2d3bfd8aa129279148e82431bd2476e8
# 4f7ab383947e8837841cdf5999040b2d7059541a
# 08ee1dea6ad4ef477f4a699621555df51bb54be2
# 94b75dd478e2f7e8cd80f0c5dd8ecb19d1649c8c
# 79ae0f33c6b4a8b46fcf1733e51d2ccd2d6600b2
# 856eafe15628333d3c15d9e1bb7738febde5a10d
# 90cd50c46e4078a5efe02c86879ec764ee47368a
# 75baa010ea8b2daa6fa2c7a549b9a1727ea897a0
# 0c83e7e3c6ed28ca48bb66c75b053bc5dbfd79fc
# 3929dd8d2a6086b328472f30cc4b0c658f7ced75
# 2351d0f6100a8f062e697d575f962d0ef3961d65
# 7570f25fbecc40958c0a5a244a85d9921bb072d4
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/218" height="525" width="100%"></iframe>

# %%
for tup in listFields(['anon_username', 'event_type', 'curr_time', 'lecture_id', 'event_timestamp'], 'where anon_username="2466e09c4681bc4a744502d81838596a2d81c12b"'):
  print tup
# Out:
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 50, 1384834494568)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 50, 1384834494572)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 50, 1384834494573)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 50, 1384834495578)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 392.60006800000002, 50, 1384834888708)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 392.60006800000002, 50, 1384834902847)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 403.21499899999998, 50, 1384834913734)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 687.60061099999996, 51, 1384836351794)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 687.60061099999996, 51, 1384836405489)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 719.30799999999999, 51, 1384836437452)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 51, 1384835490577)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 51, 1384835490577)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 51, 1384835490572)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 51, 1384835491205)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 52.296627551020407, 51, 1384835685013)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 23.854602040816328, 51, 1384835687859)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 640.221, 41, 1384747851244)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 42, 1384747878760)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 42, 1384747878768)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 42, 1384747878769)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 42, 1384747880055)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 234.59999999999999, 42, 1384748114683)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 234.59999999999999, 42, 1384748133104)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 513.81200000000001, 42, 1384748412392)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 197.05397318007664, 41, 1384747318242)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 216.67760536398467, 41, 1384747321568)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 218.312908045977, 41, 1384747322855)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 219.13055938697318, 41, 1384747324403)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 222.400014, 41, 1384747327830)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 222.400014, 41, 1384747332339)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 294.73339299999998, 41, 1384747404712)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 294.73339299999998, 41, 1384747479781)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 384.66677199999998, 41, 1384747569699)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 384.66677199999998, 41, 1384747594706)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 386.20001400000001, 41, 1384747596183)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 386.20001400000001, 41, 1384747597121)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384746648505)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 36, 1384718572948)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 36, 1384718572950)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 36, 1384718572951)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 36, 1384718573403)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 582.63599999999997, 39, 1384722849988)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 548.40706513409964, 39, 1384722880531)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 40, 1384722893917)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 40, 1384722893936)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 40, 1384722893937)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 40, 1384722894502)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 32.933877000000003, 40, 1384722927570)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 269.867165, 58, 1384717154096)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 261.73337800000002, 58, 1384717158052)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676117)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676172)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676189)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676211)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676319)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676275)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676239)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676426)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676460)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676487)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676538)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676558)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676582)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676617)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676711)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676748)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676764)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676801)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676839)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676881)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724676911)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677049)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677026)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677080)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677085)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677123)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677164)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677268)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677304)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677329)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677368)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677404)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677426)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677463)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677621)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677653)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677687)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677707)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677744)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677771)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677805)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677915)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677932)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677957)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724677976)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678013)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678050)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678074)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678176)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678210)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678232)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678256)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678286)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678333)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678368)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678438)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 41, 1384724678491)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 215.85995402298852, 41, 1384724680926)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 222.400158, 41, 1384724687665)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 39, 1384722233698)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 39, 1384722233700)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 39, 1384722233701)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 39, 1384722234471)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 479.80000000000001, 40, 1384724348373)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 479.80000000000001, 40, 1384724377280)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384724512780)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384724512782)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 41, 1384724512781)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384724513602)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 52.329685823754794, 41, 1384724516966)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 363.86682500000001, 39, 1384722598315)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 363.86682500000001, 39, 1384722631048)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 40, 1384723777649)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 40, 1384723868345)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 40, 1384723868340)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 40, 1384723868343)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 40, 1384723868446)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 224.56953767560665, 36, 1384718874757)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 35, 1384715688499)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 35, 1384715688502)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 35, 1384715688502)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 35, 1384715689526)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 569.80001300000004, 36, 1384719635148)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 427.53342400000002, 33, 1384714704058)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 488.50200000000001, 33, 1384714765277)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 488.50200000000001, 33, 1384714796003)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 488.50200000000001, 33, 1384714796880)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 422.37018390804599, 33, 1384714800788)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 422.37018390804599, 33, 1384714804726)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 427.60000100000002, 33, 1384714810153)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 34, 1384714858274)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 34, 1384714858286)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 34, 1384714858287)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 34, 1384714858652)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 339.000045, 34, 1384715197795)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 339.000045, 34, 1384715211935)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 444.59300000000002, 34, 1384715317831)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 523.66667900000004, 36, 1384719174048)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 523.66667900000004, 36, 1384719207258)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 569.80001300000004, 36, 1384719253445)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 33, 1384714205713)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 33, 1384714205727)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 33, 1384714205728)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 33, 1384714206293)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 38, 1384720956795)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 38, 1384720956793)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 38, 1384720956795)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 38, 1384720957268)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 361.53337800000003, 38, 1384721318964)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 361.53337800000003, 38, 1384721335682)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 375.28100000000001, 38, 1384721349671)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 640.53360399999997, 58, 1384717537007)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 640.53360399999997, 58, 1384717577941)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 685.755, 58, 1384717623386)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 587.73335599999996, 35, 1384716277416)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 587.73335599999996, 35, 1384716424594)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 889.78899999999999, 35, 1384716726850)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 58, 1384716864084)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 58, 1384716864088)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 58, 1384716864089)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 58, 1384716864601)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 10.0, 58, 1384716874770)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 10.0, 58, 1384716883458)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 211.533356, 49, 1384709628186)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 211.533356, 49, 1384709673134)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 231.29400000000001, 49, 1384709693021)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 427.53342400000002, 33, 1384714633993)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 620.04300000000001, 48, 1384709405138)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 49, 1384709415196)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 49, 1384709415199)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 49, 1384709415200)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 49, 1384709416586)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 242.533333, 48, 1384708679494)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 48, 1384708354196)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 48, 1384708354199)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 48, 1384708355612)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 48, 1384708354200)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 151.60013599999999, 48, 1384708507387)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 151.60013599999999, 48, 1384708588584)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 242.533333, 48, 1384709027325)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 111, 1387990652597)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 111, 1387990652599)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 111, 1387990652600)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 111, 1387990654489)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 925.80042500000002, 112, 1387993277091)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 925.80042500000002, 112, 1387993310773)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 980.02200000000005, 112, 1387993365361)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 113, 1387993420921)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 345.13349199999999, 113, 1387993766798)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 345.13349199999999, 113, 1387993921308)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 753.66666599999996, 113, 1387994329829)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 355.53333300000003, 112, 1387992154134)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 365.000022, 112, 1387992163585)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 388.13333299999999, 112, 1387992186697)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 409.13335599999999, 112, 1387992207709)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 420.00099699999998, 112, 1387992218560)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 557.60002199999997, 112, 1387992356209)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 50.064980842911886, 112, 1387992385254)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 50.064980842911886, 112, 1387992385567)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 112, 1387992407004)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 12.533332999999999, 112, 1387992431019)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 484.37868965517242, 112, 1387992446926)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 554.46966283524898, 112, 1387992501676)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 555.72128735632191, 112, 1387992503205)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 557.60003900000004, 112, 1387992505260)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 557.60003900000004, 112, 1387992505456)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 560.067001, 112, 1387992507956)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 560.067001, 112, 1387992559716)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 925.73334999999997, 112, 1387992925398)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 901.16965517241385, 112, 1387993252287)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 901.16965517241385, 112, 1387993252343)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 753.66666599999996, 113, 1387994369439)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 830.69399999999996, 113, 1387994446643)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 114, 1387994488406)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 282.066665, 114, 1387994770843)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 114, 1387994810459)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 9.7218620689655175, 114, 1387994813151)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 36.366965517241383, 114, 1387994816578)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 92.53772413793105, 114, 1387994818579)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 420.53333300000003, 111, 1387991076329)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 411.33632183908048, 111, 1387991086381)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 644.53339500000004, 111, 1387991319749)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 644.53339500000004, 111, 1387991341326)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 624.87157088122603, 111, 1387991344313)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 600.14643678160917, 111, 1387991348796)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 176.44754789272031, 111, 1387991377572)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 157.34176245210728, 111, 1387991380113)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 126.99727969348658, 111, 1387991381674)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 95.528927203065138, 111, 1387991383567)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 88.785708812260538, 111, 1387991388043)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 639.48187739463606, 111, 1387991420465)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 648.47283524904219, 111, 1387991421440)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 651.80013599999995, 111, 1387991427719)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 879.99000000000001, 111, 1387991656290)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 850.76938697318008, 111, 1387991662265)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 850.76938697318008, 111, 1387991665591)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'error', 0.0, 112, 1387991744553)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 112, 1387991762446)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 7.8002039999999999, 112, 1387991770304)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 7.8002039999999999, 112, 1387991806386)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 46.333378000000003, 112, 1387991844929)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 193.40002200000001, 112, 1387991992001)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 199.0, 112, 1387991997607)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 204.26668900000001, 112, 1387992002857)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 219.66716500000001, 112, 1387992018257)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 224.19999999999999, 112, 1387992022807)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 235.400068, 112, 1387992034008)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 254.000294, 112, 1387992052564)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 257.86668900000001, 112, 1387992056415)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 261.66684800000002, 112, 1387992060266)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 266.26673399999999, 112, 1387992064822)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 284.80024900000001, 112, 1387992083373)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 289.33358199999998, 112, 1387992087929)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 298.46666599999998, 112, 1387992097039)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 313.20011299999999, 112, 1387992111746)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 317.40038500000003, 112, 1387992115950)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 323.33337799999998, 112, 1387992121903)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 328.60000000000002, 112, 1387992127157)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 338.39999999999998, 112, 1387992136970)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 787.60005000000001, 105, 1387847344951)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 107, 1387848178082)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 422.23200000000003, 110, 1387854553462)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 261.53578544061304, 110, 1387854559386)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 390.95555555555558, 110, 1387854561872)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 390.95555555555558, 110, 1387854565694)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 391.40006699999998, 110, 1387854566333)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 391.40006699999998, 110, 1387854566972)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 397.66666600000002, 110, 1387854573241)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 110, 1387854586006)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 391.4948045977012, 110, 1387854588345)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 392.03405363984677, 110, 1387854590114)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 397.60026599999998, 110, 1387854595883)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 4.4181169999999996, 107, 1387848182662)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 130.53222448979591, 107, 1387848373745)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 109, 1387851230103)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 810.13333299999999, 109, 1387852040389)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 810.13333299999999, 109, 1387852125571)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 848.62, 109, 1387852164165)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 527.81346104725412, 109, 1387852169513)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 527.81346104725412, 109, 1387852171709)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 805.26776500638573, 109, 1387852315803)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 803.10015325670497, 109, 1387852318958)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 442.13333299999999, 108, 1387850122984)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 724.60004500000002, 108, 1387850482007)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 770.78700000000003, 108, 1387850528344)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 323.86835632183909, 108, 1387851162066)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 323.86835632183909, 108, 1387851166435)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 351.28874100000002, 108, 1387851194022)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 110, 1387854110218)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 110, 1387854118246)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 397.60000000000002, 110, 1387854516044)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 397.60000000000002, 110, 1387854528623)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 658.60031700000002, 107, 1387848980422)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 658.60031700000002, 107, 1387849030460)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 691.46799999999996, 107, 1387849063533)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 108, 1387849072518)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 285.73340200000001, 104, 1387846472271)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 344.97899999999998, 104, 1387846531748)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 105, 1387846536176)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 105, 1387846536179)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 105, 1387846536179)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 105, 1387846536867)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 787.60005000000001, 105, 1387847407441)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 799.11500000000001, 105, 1387847419208)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 106, 1387847426269)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 104, 1387845821169)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 104, 1387845821614)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 204.53369699999999, 104, 1387846355133)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 86.749393358876119, 105, 1387846643923)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 4.4181169999999996, 107, 1387848185087)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 104, 1387845821166)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 104, 1387845821170)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 74.018482758620692, 104, 1387846031365)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 204.53369699999999, 104, 1387846162085)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 285.73340200000001, 104, 1387846436318)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 442.13333299999999, 108, 1387849514717)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 346.80219899999997, 106, 1387847773247)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 332.57845210727965, 106, 1387847774504)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 332.57845210727965, 106, 1387847774547)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 346.93527699999999, 106, 1387847789046)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 346.93527699999999, 106, 1387847800945)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 377.952, 106, 1387847832136)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 370.71154022988503, 106, 1387847837299)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 370.71154022988503, 106, 1387847839819)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 371.20001999999999, 106, 1387847840524)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 371.20001999999999, 106, 1387847841247)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 377.952, 106, 1387847848198)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 399.53444387755098, 107, 1387848701738)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 575.92934183673469, 107, 1387848739449)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 423.34775510204082, 107, 1387848744975)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 77.543172413793101, 104, 1387846026870)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 724.60004500000002, 108, 1387850405447)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 710.60001499999998, 95, 1387773476234)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 710.60001499999998, 95, 1387773504652)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 737.18799999999999, 95, 1387773531455)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 93, 1387771773965)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 93, 1387771773967)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 93, 1387771773968)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 93, 1387771774430)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 340.75465517241378, 93, 1387772150438)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 422.40000600000002, 93, 1387772232295)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 409.48807279693483, 93, 1387772236739)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 409.48807279693483, 93, 1387772236747)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 422.40006699999998, 93, 1387772249892)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 422.40006699999998, 93, 1387772295762)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 456.08699999999999, 93, 1387772329654)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 95, 1387772366550)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 95, 1387772366552)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 95, 1387772366553)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 95, 1387772366990)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 42.867165, 95, 1387772410069)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 42.867165, 95, 1387772417317)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 64.266689, 95, 1387772438748)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 64.266689, 95, 1387772801101)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 342.70297828863346, 95, 1387773093326)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 332.34656960408682, 95, 1387773097726)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 126.75857471264368, 92, 1387691528720)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 133.400025, 92, 1387691535571)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 133.400025, 92, 1387691839796)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 92, 1387691240192)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 92, 1387691240195)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 92, 1387691240196)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 92, 1387691240716)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 205.13342399999999, 92, 1387691445976)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 205.13342399999999, 92, 1387691463022)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 197.18000510855683, 92, 1387691525031)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 179.07163729246491, 92, 1387691526982)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 787.71400000000006, 92, 1387692510677)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 611.66680499999995, 92, 1387692318074)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 611.66680499999995, 92, 1387692334378)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 273.53333300000003, 91, 1387644861582)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 722.76800000000003, 91, 1387645310996)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 311.07639335887615, 91, 1387645483419)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 311.07639335887615, 91, 1387645487131)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 283.38413282247768, 91, 1387645499916)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 83.666666000000006, 90, 1387643853689)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 595.79999999999995, 90, 1387644365861)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 595.79999999999995, 90, 1387644400058)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 627.54300000000001, 90, 1387644432115)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 91, 1387644436481)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 91, 1387644436485)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 91, 1387644436486)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 91, 1387644436975)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 273.53333300000003, 91, 1387644710796)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 83.666666000000006, 90, 1387642692168)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 89, 1387641932291)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 89, 1387641932293)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 89, 1387641932294)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.13333300000000001, 89, 1387641933728)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 89, 1387641960295)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 442.73335600000001, 89, 1387642403261)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 442.73335600000001, 89, 1387642411888)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 458.24599999999998, 89, 1387642427579)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 255.16635504469986, 89, 1387642431355)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 255.16635504469986, 89, 1387642442533)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 353.06667199999998, 89, 1387642540681)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 353.06667199999998, 89, 1387642541433)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 90, 1387642607893)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 90, 1387642607896)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 90, 1387642607896)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 90, 1387642608360)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 101, 1387420339982)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 101, 1387420339988)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 101, 1387420339988)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 486.33349199999998, 101, 1387420827491)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 486.33349199999998, 101, 1387420869733)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 506.892, 101, 1387420890571)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 260.24340229885058, 101, 1387421160215)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 260.24340229885058, 101, 1387421163894)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 498.60000600000001, 103, 1387423853147)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 498.60000600000001, 103, 1387423888122)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 510.81599999999997, 103, 1387423900477)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 311.800005, 102, 1387422972171)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 103, 1387423249539)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 103, 1387423249546)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 103, 1387423249547)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 103, 1387423250137)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 101, 1387420340928)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 324.0, 101, 1387421249507)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 315.13367299999999, 101, 1387421251864)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 479.70239080459771, 101, 1387421321107)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 479.70239080459771, 101, 1387421322712)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 486.33345500000001, 101, 1387421329524)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 102, 1387421354495)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 102, 1387421354502)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 102, 1387421354503)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 102, 1387421354987)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 16.216922094508302, 102, 1387421388872)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 311.800005, 102, 1387421684645)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 480.7043214285714, 102, 1387423155003)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 507.91399999999999, 102, 1387423182565)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 498.53333300000003, 103, 1387423748893)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 468.53333300000003, 103, 1387423768898)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 468.53333300000003, 103, 1387423768908)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 330.33333299999998, 103, 1387423771750)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 390.12511877394638, 103, 1387423775069)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 418.82997701149424, 103, 1387423784956)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 434.48717241379308, 103, 1387423788858)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 614.60900000000004, 100, 1387271375008)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 373.66673400000002, 99, 1387270108823)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 410.74695402298852, 99, 1387270158772)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 871.58500000000004, 99, 1387270619921)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 100, 1387270622885)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 100, 1387270622922)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 100, 1387270622923)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 100, 1387270623632)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 276.800748, 100, 1387270900439)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 276.800748, 100, 1387270922518)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 427.80000000000001, 100, 1387271073488)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 427.80000000000001, 100, 1387271187853)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 98, 1387269105858)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 98, 1387269105874)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 98, 1387269105875)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 98, 1387269106738)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 464.80022600000001, 98, 1387269571596)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 464.80022600000001, 98, 1387269634627)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 474.56999999999999, 98, 1387269644750)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 99, 1387269651947)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 99, 1387269651954)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 99, 1387269651955)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 99, 1387269652587)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 373.66673400000002, 99, 1387270026369)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 9, 1385353291407)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 9, 1385353291413)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 9, 1385353291413)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 9, 1385353292388)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 544.46666600000003, 9, 1385353837000)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 4, 1385346723851)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 4, 1385346723857)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 4, 1385346723858)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 4, 1385346724655)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 9, 1385355272624)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 9, 1385355272626)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 9, 1385355272626)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 9, 1385355272753)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 534.36751382630905, 9, 1385355276250)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 536.74600424393361, 9, 1385355277095)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 544.46668399999999, 9, 1385355285004)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 4, 1385351155058)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 4, 1385351155060)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 4, 1385351155060)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 4, 1385351155128)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 101.39518007662836, 4, 1385351164823)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 75.228681992337158, 4, 1385351167437)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 180.533941, 4, 1385351272942)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 780.53337799999997, 4, 1385347505338)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 211.82375419923372, 25, 1385316874511)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 211.82375419923372, 25, 1385316877895)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 165.97445675351213, 25, 1385316890990)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 144.88377992848021, 25, 1385316895073)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 128.37803284802044, 25, 1385316899346)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 358.999999, 25, 1385314761469)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 77, 1386643912445)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 77, 1386643912452)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 77, 1386643912452)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 77, 1386643913232)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 4.5341040000000001, 77, 1386643917960)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 19.600158, 77, 1386643933032)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 185.0, 77, 1386644098489)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 185.0, 77, 1386644119614)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 196.999, 77, 1386644131757)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 78, 1386644428061)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 78, 1386644428065)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 78, 1386644428066)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 78, 1386644429186)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 7.2000000000000002, 78, 1386644436487)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 68.466666000000004, 78, 1386644497792)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 73.000112999999999, 78, 1386644502341)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 78.000022000000001, 78, 1386644507306)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 83.666689000000005, 78, 1386644513007)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 151.93356, 78, 1386645488439)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 432.66666600000002, 78, 1386645769165)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 432.66666600000002, 78, 1386645934782)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 83.666689000000005, 78, 1386644820582)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 151.93356, 78, 1386644888818)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 650.66011663218387, 78, 1386646208814)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 752.53599899999995, 78, 1386646311024)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 735.23632086206896, 78, 1386646326525)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 735.23632086206896, 78, 1386646330568)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 752.53599899999995, 78, 1386646348206)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 79, 1386646351481)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 79, 1386646351489)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 79, 1386646351490)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 79, 1386646352236)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 3.7999999999999998, 79, 1386646356377)
# ...
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 53, 1384919483666)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 53, 1384919486640)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 31.666665999999999, 53, 1384919518508)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 46.066780000000001, 53, 1384919532862)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 53.799999999999997, 53, 1384919540592)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 60.066665999999998, 53, 1384919546897)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 64.599999999999994, 53, 1384919551449)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 69.866938000000005, 53, 1384919556705)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 87.400113000000005, 53, 1384919574220)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.266666000000001, 53, 1384919578074)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 130.80000000000001, 53, 1384919617645)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 141.33360500000001, 53, 1384919628146)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 147.60006799999999, 53, 1384919634446)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 163.73335599999999, 53, 1384919650552)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919708770)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919714028)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 216.025396, 53, 1384919717490)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919751339)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919761540)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919791120)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919797450)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919820661)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919864270)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919879041)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 52, 1384918470404)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 52, 1384918470413)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 52, 1384918470414)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 52, 1384918475381)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 236.533401, 56, 1384922332611)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 718.60036200000002, 56, 1384922814653)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 718.60036200000002, 56, 1384922821232)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 718.60036200000002, 56, 1384922831032)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 718.60036200000002, 56, 1384922881440)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 216.025396, 53, 1384919915263)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 216.025396, 53, 1384920022213)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 227.80000000000001, 53, 1384920034086)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 220.95143039591318, 53, 1384920056455)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 220.95143039591318, 53, 1384920056460)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 227.80006900000001, 53, 1384920063563)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 227.80006900000001, 53, 1384920069532)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 467.58100000000002, 53, 1384920309381)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 54, 1384920331460)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 54, 1384920331466)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 54, 1384920331467)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 54, 1384920361590)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 50.374693000000001, 54, 1384920419820)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 91.976802000000006, 54, 1384920465574)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920475256)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920480157)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920483307)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920565363)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920579716)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920585666)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920590216)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920594768)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920613671)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920653577)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920674930)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920707483)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920712033)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920717287)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920721137)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920727437)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 91.976802000000006, 54, 1384920771893)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 91.976802000000006, 54, 1384920778535)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 162.73337799999999, 54, 1384920849394)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 243.533492, 54, 1384920930224)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 259.0, 54, 1384920945630)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 301.000068, 54, 1384920987695)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 301.000068, 54, 1384921051094)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 377.33337799999998, 54, 1384921127406)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 395.20011299999999, 54, 1384921145267)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 408.13371799999999, 54, 1384921158218)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'stalled', 413.73333300000002, 54, 1384921163821)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 679.73337800000002, 54, 1384921429795)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 679.73337800000002, 54, 1384921464362)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 697.48099999999999, 54, 1384921482275)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 55, 1384921493744)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 55, 1384921493748)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 55, 1384921493750)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 55, 1384921501062)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384746648501)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 41, 1384746648504)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384746649571)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 101.38876628352492, 41, 1384746657998)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 222.333369, 41, 1384746779133)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384747020482)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 41, 1384747020484)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384747020485)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 41, 1384747020604)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 212.58934865900383, 41, 1384747022671)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 217.80005, 41, 1384747028047)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 217.80005, 41, 1384747037965)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 218.266672, 41, 1384747038373)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 166.80087356321837, 41, 1384747091017)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 197.05397318007664, 41, 1384747092141)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 74, 1386123118444)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 74, 1386123118449)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 74, 1386123118450)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 74, 1386123119744)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 1166.800113, 73, 1386122067300)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 1181.78, 73, 1386122082462)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 72, 1386122102340)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 72, 1386122102343)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 72, 1386122102344)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 72, 1386122102690)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 149.51468710089398, 72, 1386122109150)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 225.08461047254153, 72, 1386122110036)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 199.08205619412516, 72, 1386122117327)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 171.45434227330779, 72, 1386122120642)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 183.00026, 72, 1386122132398)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 183.00026, 72, 1386122137247)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 209.13343399999999, 72, 1386122163345)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 209.13343399999999, 72, 1386122803261)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 233.21040868454662, 72, 1386122856497)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 215.33365261813537, 72, 1386122861556)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 197.45689655172416, 72, 1386122880390)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 932.13335600000005, 75, 1386125125185)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 943.19500000000005, 75, 1386125136542)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 76, 1386125139229)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 76, 1386125139234)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 76, 1386125139235)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 76, 1386125140370)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 24.600021999999999, 76, 1386125165037)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 672.53525670498095, 76, 1386126217554)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 754.78777011494253, 76, 1386126258834)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 770.80001400000003, 76, 1386126342565)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 846.71704980842912, 76, 1386126440324)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 1262.818, 76, 1386126856834)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 1170.8887203065135, 76, 1386126859380)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 1170.8887203065135, 76, 1386126863411)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 1262.818, 76, 1386126955823)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 485.45110855683271, 76, 1386125930446)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 770.80001900000002, 76, 1386126215987)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 672.53525670498095, 76, 1386126217521)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 632.21539719029374, 76, 1386126219315)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 770.80001400000003, 76, 1386126275035)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 932.13335600000005, 75, 1386125037568)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 1166.800113, 73, 1386122059029)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 24.600021999999999, 76, 1386125436838)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 432.60019299999999, 72, 1386047494021)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 432.60019299999999, 72, 1386047527030)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 636.25, 72, 1386047730805)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 831.60000000000002, 71, 1386045687265)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 831.60000000000002, 71, 1386045972350)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386046871193)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 71, 1386046871197)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386046871199)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386046871399)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 72, 1386046913005)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 72, 1386046913011)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 72, 1386046913012)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 72, 1386046913501)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 202.33237547892722, 72, 1386047200642)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 143.01404853128992, 72, 1386047204209)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386048514146)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 71, 1386048514152)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386048514153)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386048514423)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 118.96231800766283, 71, 1386048521489)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 346.53333800000001, 71, 1386048749248)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 887.11900000000003, 71, 1386046028050)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386044800011)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 0.0, 71, 1386044800015)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386044800015)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'ratechange', 0.0, 71, 1386044801100)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 0.0, 71, 1386044855471)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 809.60006199999998, 109, 1387852325660)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 780.34022988505751, 109, 1387852328229)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 780.34022988505751, 109, 1387852328283)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 809.66687200000001, 109, 1387852357762)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'seeked', 787.92687100894, 109, 1387852360037)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 787.92687100894, 109, 1387852360080)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 809.66668900000002, 109, 1387852381957)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'play', 809.66668900000002, 109, 1387852392456)
# (u'2466e09c4681bc4a744502d81838596a2d81c12b', u'pause', 848.62, 109, 1387852431571)

# %%
lecture_to_num_start = []
lecture_to_num_finish = []
lecture_to_num_seek = []

for v in lecture_to_user_to_start_timestamps:
  lecture_to_num_start.append(sum([len(x) for x in v.values()]))

for v in lecture_to_user_to_finish_timestamps:
  lecture_to_num_finish.append(sum([len(x) for x in v.values()]))

for v in lecture_to_user_to_seek_timestamps:
  lecture_to_num_seek.append(sum([len(x) for x in v.values()]))

# %%
data = scatterlist(lecture_to_num_start)
layout = mklayout('view start events over time', 'lecture num', 'number of view start events')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/190" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_finish)
layout = mklayout('view finish events over time', 'lecture num', 'number of view finish events')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/191" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_seek)
layout = mklayout('seek events over time', 'lecture num', 'number of seek events')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/192" height="525" width="100%"></iframe>

# %%
lecture_to_finish_ratio = []

for numstart,numfinish in zip(lecture_to_num_start, lecture_to_num_finish):
  if numstart == 0:
    lecture_to_finish_ratio.append(0)
  else:
    lecture_to_finish_ratio.append(float(numfinish)/numstart)

data = scatterlist(lecture_to_finish_ratio)
layout = mklayout('lecture finish fraction over time', 'lecture num', 'fraction of students who finish viewing lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/193" height="525" width="100%"></iframe>

# %%
lecture_to_seek_ratio = []

for numstart,numseek in zip(lecture_to_num_start, lecture_to_num_seek):
  if numstart == 0:
    lecture_to_seek_ratio.append(0)
  else:
    lecture_to_seek_ratio.append(float(numseek)/numstart)

data = scatterlist(lecture_to_seek_ratio)
layout = mklayout('ratio of seek events to video starts over time', 'lecture num', 'ratio of seek events to number of video starts')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/194" height="525" width="100%"></iframe>

# %%
lecture_to_num_users_with_at_least_one_start = []
lecture_to_num_users_with_at_least_one_finish = []
lecture_to_num_users_with_at_least_one_seek = []

def nonzero(l):
  if len(l) > 0:
    return 1
  return 0

for v in lecture_to_user_to_start_timestamps:
  lecture_to_num_users_with_at_least_one_start.append(sum([nonzero(x) for x in v.values()]))

for v in lecture_to_user_to_finish_timestamps:
  lecture_to_num_users_with_at_least_one_finish.append(sum([nonzero(x) for x in v.values()]))

for v in lecture_to_user_to_seek_timestamps:
  lecture_to_num_users_with_at_least_one_seek.append(sum([nonzero(x) for x in v.values()]))

# %%
data = scatterlist(lecture_to_num_users_with_at_least_one_start)
layout = mklayout('number of users who started watching lecture over time', 'lecture num', 'number of users who started watching lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/195" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_users_with_at_least_one_finish)
layout = mklayout('number of users who finished watching lecture over time', 'lecture num', 'number of users who finished watching lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/196" height="525" width="100%"></iframe>

# %%
data = scatterlist(lecture_to_num_users_with_at_least_one_seek)
layout = mklayout('number of users who seeked at least once in lecture over time', 'lecture num', 'number of users who seeked at least once in lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/197" height="525" width="100%"></iframe>

# %%
lecture_to_users_who_seeked_ratio = []

for numstart,numseek in zip(lecture_to_num_users_with_at_least_one_start, lecture_to_num_users_with_at_least_one_seek):
  if numstart == 0:
    lecture_to_users_who_seeked_ratio.append(0)
  else:
    lecture_to_users_who_seeked_ratio.append(float(numseek)/numstart)

data = scatterlist(lecture_to_users_who_seeked_ratio)
layout = mklayout('fraction of users who seeked at least once during the lecture, over time', 'lecture num', 'fraction of users who seeked at least once during the lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/198" height="525" width="100%"></iframe>

# %%
lecture_to_users_who_finished_ratio = []

for numstart,numseek in zip(lecture_to_num_users_with_at_least_one_start, lecture_to_num_users_with_at_least_one_finish):
  if numstart == 0:
    lecture_to_users_who_finished_ratio.append(0)
  else:
    lecture_to_users_who_finished_ratio.append(float(numseek)/numstart)

data = scatterlist(lecture_to_users_who_seeked_ratio)
layout = mklayout('fraction of users who finished watching the lecture, over time', 'lecture num', 'fraction of users who finished watching the lecture')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/199" height="525" width="100%"></iframe>

# %%
num_seeks_to_users_single_lecture = [0]*51

for user,seek_times in lecture_to_user_to_seek_timestamps[30].iteritems():
  numseeks = len(seek_times)
  if numseeks >= len(num_seeks_to_users_single_lecture):
    num_seeks_to_users_single_lecture[len(num_seeks_to_users_single_lecture)-1] += 1
  else:
    num_seeks_to_users_single_lecture[numseeks] += 1

data = scatterlist(num_seeks_to_users_single_lecture)
layout = mklayout('histogram of users and seek times (in lecture 30)', 'number of times video seeked (in lecture 30)', 'number of users who seeked video this many times (in lecture 30)')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/200" height="525" width="100%"></iframe>

# %%
timepoint_to_num_seeks = []

for user,seek_times in lecture_to_user_to_seek_times[30].iteritems():
  for seek_time in seek_times:
    while seek_time >= len(timepoint_to_num_seeks) - 1:
      timepoint_to_num_seeks.append(0)
    timepoint_to_num_seeks[int(round(seek_time))] += 1

data = scatterlist(timepoint_to_num_seeks)
layout = mklayout('distribution of seeks over time (in lecture 30)', 'time in video (in lecture 30)', 'number of seeks that go to this destination')
iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/201" height="525" width="100%"></iframe>

# %%
num_seeks_to_users_all_lectures = [0]*101

for lecture in lecture_to_user_to_seek_timestamps:
  for user,seek_times in lecture.iteritems():
    numseeks = len(seek_times)
    if numseeks >= len(num_seeks_to_users_all_lectures):
      num_seeks_to_users_all_lectures[len(num_seeks_to_users_all_lectures)-1] += 1
    else:
      num_seeks_to_users_all_lectures[numseeks] += 1

data = scatterlist(num_seeks_to_users_all_lectures)
layout = mklayout('histogram of users and num seeks (over all lectures)', 'number of times video seeked (over all lectures)', 'number of users who seeked video this many times (over all lectures)')
iplot(data, layout)

# log-log version
#data = scatterlistloglog(num_seeks_to_users_all_lectures)
#layout = mklayout('histogram of users and num seeks (over all lectures)', 'number of times video seeked (over all lectures)', 'number of users who seeked video this many times (over all lectures)')
#iplot(data, layout)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/202" height="525" width="100%"></iframe>

# %%
def at_least_a_minute_apart(times):
  prevtime=-9999
  output = []
  for time in sorted(times):
    if abs(time - prevtime) > 60 * 1000:
      output.append(time)
      prevtime = time
  return output

def at_least_an_hour_apart(times):
  prevtime=-9999
  output = []
  for time in sorted(times):
    if abs(time - prevtime) > 3600 * 1000:
      output.append(time)
      prevtime = time
  return output

def at_least_a_day_apart(times):
  prevtime=-9999
  output = []
  for time in sorted(times):
    if abs(time - prevtime) > 24 * 3600 * 1000:
      output.append(time)
      prevtime = time
  return output

# %%
#newfig()

xaxis_length = 6

num_starts_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(start_times)
  if numstarts >= len(num_starts_to_users_single_lecture):
    num_starts_to_users_single_lecture[len(num_starts_to_users_single_lecture)-1] += 1
  else:
    num_starts_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_to_users_single_lecture, label='all watches')
addtrace(num_starts_to_users_single_lecture, label='all watches')

num_starts_minute_apart_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(at_least_a_minute_apart(start_times))
  if numstarts >= len(num_starts_minute_apart_to_users_single_lecture):
    num_starts_minute_apart_to_users_single_lecture[len(num_starts_minute_apart_to_users_single_lecture)-1] += 1
  else:
    num_starts_minute_apart_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_minute_apart_to_users_single_lecture, label='at least a minute apart')
addtrace(num_starts_minute_apart_to_users_single_lecture, label='at least a minute apart')

num_starts_hour_apart_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(at_least_an_hour_apart(start_times))
  if numstarts >= len(num_starts_hour_apart_to_users_single_lecture):
    num_starts_hour_apart_to_users_single_lecture[len(num_starts_hour_apart_to_users_single_lecture)-1] += 1
  else:
    num_starts_hour_apart_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_hour_apart_to_users_single_lecture, label='at least an hour apart')
addtrace(num_starts_hour_apart_to_users_single_lecture, label='at least an hour apart')

num_starts_day_apart_to_users_single_lecture = [0]*xaxis_length

for user,start_times in lecture_to_user_to_start_timestamps[30].iteritems():
  numstarts = len(at_least_a_day_apart(start_times))
  if numstarts >= len(num_starts_day_apart_to_users_single_lecture):
    num_starts_day_apart_to_users_single_lecture[len(num_starts_day_apart_to_users_single_lecture)-1] += 1
  else:
    num_starts_day_apart_to_users_single_lecture[numstarts] += 1

#pylab.plot(num_starts_day_apart_to_users_single_lecture, label='at least a day apart')
addtrace(num_starts_day_apart_to_users_single_lecture, label='at least a day apart')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))

addxlabel('number of times started watching video (in lecture 30)')
addylabel('number of users who started watching video this many times (in lecture 30)')
addtitle('histogram of users and num starts (in lecture 30)')

#from matplotlylib import fig_to_plotly

#fig_to_plotly(gcf(), notebook=True)

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/203" height="525" width="100%"></iframe>

# %%
#newfig()

xaxis_length = 6

num_finishes_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(finish_times)
  if numfinishes >= len(num_finishes_to_users_single_lecture):
    num_finishes_to_users_single_lecture[len(num_finishes_to_users_single_lecture)-1] += 1
  else:
    num_finishes_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_to_users_single_lecture, label='all watches')

num_finishes_minute_apart_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(at_least_a_minute_apart(finish_times))
  if numfinishes >= len(num_finishes_minute_apart_to_users_single_lecture):
    num_finishes_minute_apart_to_users_single_lecture[len(num_finishes_minute_apart_to_users_single_lecture)-1] += 1
  else:
    num_finishes_minute_apart_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_minute_apart_to_users_single_lecture, label='at least a minute apart')

num_finishes_hour_apart_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(at_least_an_hour_apart(finish_times))
  if numfinishes >= len(num_finishes_hour_apart_to_users_single_lecture):
    num_finishes_hour_apart_to_users_single_lecture[len(num_finishes_hour_apart_to_users_single_lecture)-1] += 1
  else:
    num_finishes_hour_apart_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_hour_apart_to_users_single_lecture, label='at least an hour apart')

num_finishes_day_apart_to_users_single_lecture = [0]*xaxis_length

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(at_least_a_day_apart(finish_times))
  if numfinishes >= len(num_finishes_day_apart_to_users_single_lecture):
    num_finishes_day_apart_to_users_single_lecture[len(num_finishes_day_apart_to_users_single_lecture)-1] += 1
  else:
    num_finishes_day_apart_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_day_apart_to_users_single_lecture, label='at least a day apart')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))

addxlabel('number of times finished watching video (in lecture 30)')
addylabel('number of users who finished watching video this many times (in lecture 30)')
addtitle('histogram of users and num finishes (in lecture 30)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/204" height="525" width="100%"></iframe>

# %%
#newfig()

xaxis_length = 6

watch_session_to_completions = [0]*xaxis_length
watch_session_to_seeks = [0]*xaxis_length
watch_session_to_at_least_one_seek = [0]*xaxis_length
watch_session_to_starts = [0]*xaxis_length

for lecturenum in range(len(lecture_to_user_to_start_timestamps)):
  for user,start_times in lecture_to_user_to_start_timestamps[lecturenum].iteritems():
    for watch_session_idx,start_time in enumerate(at_least_an_hour_apart(start_times)):
      finished_watching = False
      at_least_one_seek = False
      if user in lecture_to_user_to_finish_timestamps[lecturenum]:
        for end_time in lecture_to_user_to_finish_timestamps[lecturenum][user]:
          if start_time <= end_time <= start_time + 3600 * 1000:
            finished_watching = True
      num_seeks = 0
      if user in lecture_to_user_to_seek_timestamps[lecturenum]:
        for seek_time in lecture_to_user_to_seek_timestamps[lecturenum][user]:
          if start_time <= seek_time <= start_time + 3600 * 1000:
            num_seeks += 1
            at_least_one_seek = True
      if watch_session_idx >= xaxis_length:
        watch_session_idx = xaxis_length-1
      watch_session_to_starts[watch_session_idx] += 1
      if finished_watching:
        watch_session_to_completions[watch_session_idx] += 1
      if at_least_one_seek:
        watch_session_to_at_least_one_seek[watch_session_idx] += 1
      watch_session_to_seeks[watch_session_idx] += num_seeks

addtrace(watch_session_to_starts, label='watches started')
addtrace(watch_session_to_completions, label='watches finished')
addtrace(watch_session_to_at_least_one_seek, label='seeked at least once during session')
addtrace(watch_session_to_seeks, label='total number of seeks')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/205" height="525" width="100%"></iframe>

# %%
#newfig()

watch_session_to_completions_ratio = []
watch_session_to_seeks_ratio = []
watch_session_to_at_least_one_seek_ratio = []

for completions,starts in zip(watch_session_to_completions,watch_session_to_starts):
  if starts == 0:
    watch_session_to_completions_ratio.append(0)
  else:
    watch_session_to_completions_ratio.append(float(completions)/starts)

for seeks,starts in zip(watch_session_to_seeks,watch_session_to_starts):
  if starts == 0:
    watch_session_to_seeks_ratio.append(0)
  else:
    watch_session_to_seeks_ratio.append(float(seeks)/starts)

for at_least_one_seek,starts in zip(watch_session_to_at_least_one_seek,watch_session_to_starts):
  if starts == 0:
    watch_session_to_at_least_one_seek_ratio.append(0)
  else:
    watch_session_to_at_least_one_seek_ratio.append(float(at_least_one_seek)/starts)


addtrace(watch_session_to_completions_ratio, label='watches finished')
addtrace(watch_session_to_at_least_one_seek_ratio, label='seeked at least once during session')
#pylab.plot(watch_session_to_seeks_ratio, label='total number of seeks')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos, normalized by number of starts')

#pylab.ylim([0.0,1.0])

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/206" height="525" width="100%"></iframe>

# %%
print watch_session_to_completions
print watch_session_to_at_least_one_seek
# Out:
# [822156, 88207, 16566, 4139, 1239, 799]
# [488861, 137117, 33560, 9803, 3247, 2092]

# %%
#newfig()

addtrace(watch_session_to_completions_ratio, label='watches finished')
addtrace(watch_session_to_at_least_one_seek_ratio, label='seeked at least once during session')
addtrace(watch_session_to_seeks_ratio, label='total number of seeks')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos, normalized by number of starts')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/207" height="525" width="100%"></iframe>

# %%
xaxis_length = 6

watch_session_to_completions = [0]*xaxis_length
watch_session_to_completions_and_at_least_one_seek = [0]*xaxis_length
watch_session_to_starts = [0]*xaxis_length

for lecturenum in range(len(lecture_to_user_to_start_timestamps)):
  for user,start_times in lecture_to_user_to_start_timestamps[lecturenum].iteritems():
    for watch_session_idx,start_time in enumerate(at_least_an_hour_apart(start_times)):
      finished_watching = False
      at_least_one_seek = False
      if user in lecture_to_user_to_finish_timestamps[lecturenum]:
        for end_time in lecture_to_user_to_finish_timestamps[lecturenum][user]:
          if start_time <= end_time <= start_time + 3600 * 1000:
            finished_watching = True
      num_seeks = 0
      if user in lecture_to_user_to_seek_timestamps[lecturenum]:
        for seek_time in lecture_to_user_to_seek_timestamps[lecturenum][user]:
          if start_time <= seek_time <= start_time + 3600 * 1000:
            num_seeks += 1
            at_least_one_seek = True
      if watch_session_idx >= xaxis_length:
        watch_session_idx = xaxis_length-1
      watch_session_to_starts[watch_session_idx] += 1
      if finished_watching:
        watch_session_to_completions[watch_session_idx] += 1
        if at_least_one_seek:
          watch_session_to_completions_and_at_least_one_seek[watch_session_idx] += 1

addtrace(watch_session_to_completions, label='watches finished')
addtrace(watch_session_to_completions_and_at_least_one_seek, label='completed, and seeked at least once during session')

#pylab.legend(bbox_to_anchor=(1.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/208" height="525" width="100%"></iframe>

# %%
watch_session_to_completion_and_at_least_one_seek_ratio = []

for completed_and_seeked_at_least_once,completions in zip(watch_session_to_completions_and_at_least_one_seek,watch_session_to_completions):
  if completions == 0:
    watch_session_to_completion_and_at_least_one_seek_ratio.append(0)
  else:
    watch_session_to_completion_and_at_least_one_seek_ratio.append(float(completed_and_seeked_at_least_once)/completions)

addtrace(watch_session_to_completion_and_at_least_one_seek_ratio, label='fraction of people among those who completed who seeked at least once during the session')

#pylab.legend(bbox_to_anchor=(2.3, 0.8))
addxlabel('watch session idx - watching video for the nth time')
addylabel('number of such events total, across all videos, normalized by number of starts')

#pylab.ylim([0.0,1.0])

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/209" height="525" width="100%"></iframe>

# %%
addtrace(num_starts_day_apart_to_users_single_lecture)
addxlabel('number of times started watching video (in lecture 30, at least a day apart)')
addylabel('number of users who started watching video this many times (in lecture 30, at least a day apart)')
addtitle('histogram of users and num starts (in lecture 30, at least a day apart)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/210" height="525" width="100%"></iframe>

# %%
num_finishes_to_users_single_lecture = [0]*11

for user,finish_times in lecture_to_user_to_finish_timestamps[30].iteritems():
  numfinishes = len(finish_times)
  if numfinishes >= len(num_finishes_to_users_single_lecture):
    num_finishes_to_users_single_lecture[len(num_finishes_to_users_single_lecture)-1] += 1
  else:
    num_finishes_to_users_single_lecture[numfinishes] += 1

addtrace(num_finishes_to_users_single_lecture)
addxlabel('number of times finished watching video (in lecture 30)')
addylabel('number of users who finished watching video this many times (in lecture 30)')
addtitle('histogram of users and num finishes (in lecture 30)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/211" height="525" width="100%"></iframe>

# %%
num_starts_to_users_all_lectures = [0]*11

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    numstarts = len(start_times)
    if numstarts >= len(num_starts_to_users_all_lectures):
      num_starts_to_users_all_lectures[len(num_starts_to_users_all_lectures)-1] += 1
    else:
      num_starts_to_users_all_lectures[numstarts] += 1

addtrace(num_starts_to_users_all_lectures)
addxlabel('number of times started watching video (all lectures)')
addylabel('number of users who started watching video this many times (all lectures)')
addtitle('histogram of users and num starts (all lectures)')

plotfig()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/212" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

addtrace(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in hours')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/213" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

time_between_rewatches[0] = 0
      
addtrace(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in hours, excluding first hour')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/214" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600*24))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

#time_between_rewatches[0] = 0
      
addtrace(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in days')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/215" height="525" width="100%"></iframe>

# %%
time_between_rewatches = [0]*101

def differences_between_times(start_times):
  prev = None
  output = []
  for time in sorted(start_times):
    if prev == None:
      prev = time
    else:
      diff = time - prev
      output.append(diff)
  return output

for lecture in lecture_to_user_to_start_timestamps:
  for user,start_times in lecture.iteritems():
    for time_spacing in differences_between_times(start_times):
      time_spacing_in_hours = int(time_spacing / (1000*3600*24))
      if time_spacing_in_hours >= len(time_between_rewatches):
        time_spacing_in_hours = len(time_between_rewatches)-1
      time_between_rewatches[time_spacing_in_hours] += 1

time_between_rewatches[0] = 0
      
addtrace(time_between_rewatches)
addxlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures)')
#pylab.title('histogram of users and seek times (over all lectures)')
addtitle('time between rewatches, in days, excluding first day')
#pylab.show()
plotfig()

#pylab.loglog(time_between_rewatches)
#pylab.xlabel('number of times video seeked (over all lectures)')
#pylab.ylabel('number of users who seeked video this many times (over all lectures, log-log)')
#pylab.title('histogram of users and seek times (over all lectures, log-log)')
#pylab.show()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~geza/216" height="525" width="100%"></iframe>
