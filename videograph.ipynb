# %%
#import pymysql as db
import MySQLdb
import sqlite3
from pandas import DataFrame
from pandas.io.sql import read_frame
import json
#from pandas.io.pytables import HDFStore, read_hdf
#import multiprocessing
#pool = multiprocessing.Pool(100)
#print pool.map(f, range(10))

#tablename = 'course_grades'
tablename = 'videos'
databasename = 'coursera_eventing_pgm-003'
#databasename = 'coursera_pgm-003_anonymized_general'

datastage_login = json.load(open('datastage_login.json'))

databases = {}

def getTableName():
  return tablename

def getDatabaseName():
  return databasename

def getDatabase():
  if databasename not in databases:
    databases[databasename] = MySQLdb.connect(host='datastage.stanford.edu', user=datastage_login['user'], passwd=datastage_login['passwd'], db=databasename)
  return databases[databasename]

def listDistinct(fieldname, extraquery=''):
  data = read_frame("select distinct " + fieldname + " from " + getTableName() + " " + extraquery, getDatabase())
  return [x[0] for x in data[[fieldname]].itertuples(index=False)]

def listFields(fieldnames, extraquery=''):
  fieldnameString = ','.join(fieldnames)
  data = read_frame("select " + fieldnameString + " from " + getTableName() + " " + extraquery, getDatabase())
  return data.itertuples(index=False)

#data = read_hdf(databasename + '.h5', tablename)
#print data

#store = HDFStore(databasename + '.h5')
#data = store[tablename]

#print len(data)

'''
userlist = []
userlist_set = set()
for i,user in data[['anon_username']].itertuples():
  if user not in userlist_set:
    userlist_set.add(user)
    userlist.append(user)
print len(userlist)
'''

#database = sqlite3.connect(databasename + '.sqlite3')
#userlist = listDistinct('anon_user_id')
#print userlist

#for course in ['coursera_pgm-003_anonymized_general', 'coursera_ml-003_anonymized_general']:
#  databasename = course
#  user_grades = listFields(['anon_user_id', 'normal_grade'])
#  plt.hist([grade for userid,grade in user_grades if grade > 0])
#  plt.title(course)
#  plt.show()



#print len(user_to_events)
#print len([user for user,events in user_to_events.iteritems() if len(events) > 1])
#print len([user for user,events in user_to_events.iteritems() if len(events) > 2])
#print sum([len(events) for user,events in user_to_events.iteritems()])

#for userid,grade in user_grades:
#  print userid, grade

#for user in userlist:
#  lectures_watched = listDistinct('lecture_id', database, "WHERE anon_username='" + user + "'")
#  print user, lectures_watched
#def printLecturesWatched(user):
#  lectures_watched = listDistinct('lecture_id', database, "where anon_username='" + user + "'")
#  return lectures_watched

#lectures_watched = pool.map(printLecturesWatched, userlist)
#for user,lectures in zip(userlist, lectures_watched):
#  print user, lectures

#users = frame_query("SELECT DISTINCT anon_username FROM videos LIMIT 1", database)
#userlist = [username for i,username in users[['anon_username']].itertuples()]
#for username in userlist:
#  #data = frame_query("SELECT anon_username,lecture_id,timestamp,event_type,curr_time FROM videos WHERE anon_username='" + username + "' LIMIT 20", database)
#  lectures_watched = 
#  print data
#data     = frame_query("SELECT anon_username,lecture_id,timestamp,event_type,curr_time FROM videos GROUP BY anon_username LIMIT 20", database)
#print data
#for i,x in data[['event_type']].itertuples():
#  print x
# Out:
# "\nuserlist = []\nuserlist_set = set()\nfor i,user in data[['anon_username']].itertuples():\n  if user not in userlist_set:\n    userlist_set.add(user)\n    userlist.append(user)\nprint len(userlist)\n"

# %%
# %matplotlib inline
import matplotlib.pyplot
import numpy

def binsum(inp):
  output = []
  for i in range(len(inp)):
    curbin = inp[i-2:i+3]
    val = sum(curbin)
    output.append(val)
  return output

def barPlotWithStderr(means, stderrs=None, x_tick_labels=None, xlabel='', ylabel='', title='', addLabels=True):
    if stderrs:
        assert len(means) == len(stderrs)
    if x_tick_labels:
        assert len(means) == len(x_tick_labels)
        x_tick_labels = [str(x) for x in x_tick_labels]
    else:
        x_tick_labels = [str(x) for x in range(len(means))]
    N = len(means)
    ind = numpy.arange(N) # the x locations for the groups
    width = 0.35 # the width of the bars
    fig, ax = matplotlib.pyplot.subplots()
    if stderrs:
        rects1 = ax.bar(ind, means, width, color='r', yerr=stderrs)
    else:
        rects1 = ax.bar(ind, means, width, color='r')
    
    if ylabel and not title:
        title = ylabel
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    ax.set_xticks(ind+width)
    ax.set_xticklabels( x_tick_labels )
    
    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            #ax.text('foobar', 1.05*height, '%d'%int(height), ha='center', va='bottom')
            ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height), ha='center', va='bottom')
    if addLabels:
      autolabel(rects1)

def plotBarDictionary(datadict, xlabel='', ylabel='', title='', x_tick_label_map=None):
    keys = datadict.keys()
    keys.sort()
    means = [datadict[k] for k in keys]
    if not x_tick_label_map:
      x_tick_labels = keys
    else:
      x_tick_labels = [x_tick_label_map[key] for key in keys]
    barPlotWithStderr(means, x_tick_labels=x_tick_labels, xlabel=xlabel, ylabel=ylabel, title=title)

# %%
def plotEventTimes(target_event_type, dbname, lecturenum):
  global databasename

  databasename = dbname

  user_to_events = {}
  for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=' + str(lecturenum)):
    if anon_username not in user_to_events:
      user_to_events[anon_username] = []
    user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))

  videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])

  numStarts = [0]*(videoLength+1)

  for user,events in user_to_events.iteritems():
    for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
      if event_type == target_event_type:
        if curr_time == 0:
          continue
        numStarts[curr_time] += 1

  matplotlib.pyplot.plot(numStarts)
  matplotlib.pyplot.title(target_event_type + ' events (' + dbname + ' lecture ' + str(lecturenum) + ')')
  matplotlib.pyplot.xlabel('video time, seconds')
  matplotlib.pyplot.ylabel('num ' + target_event_type + ' events at this point')
  matplotlib.pyplot.show()

def plotEventTimesNoDuplicatesPerUser(target_event_type, dbname, lecturenum):
  global databasename

  databasename = dbname

  user_to_events = {}
  for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=' + str(lecturenum)):
    if anon_username not in user_to_events:
      user_to_events[anon_username] = []
    user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))

  videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])

  numStarts = [0]*(videoLength+1)

  for user,events in user_to_events.iteritems():
    numStartsUser = [0]*(videoLength+1)
    for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
      if event_type == target_event_type:
        if curr_time == 0:
          continue
        numStartsUser[curr_time] += 1
    for i in range(len(numStarts)):
      if numStartsUser[i] > 0:
        numStarts[i] += 1

  matplotlib.pyplot.plot(numStarts)
  matplotlib.pyplot.title(target_event_type + ' events, no duplicates per user (' + dbname + ' lecture ' + str(lecturenum) + ')')
  matplotlib.pyplot.xlabel('video time, seconds')
  matplotlib.pyplot.ylabel('num ' + target_event_type + ' events at this point (each user counted at most 1 time)')
  matplotlib.pyplot.show()
  
#matplotlib.pyplot.plot(binsum(numStarts))
#matplotlib.pyplot.title('start events within 3 seconds')
#matplotlib.pyplot.xlabel('video time, seconds')
#matplotlib.pyplot.ylabel('num start events from this point (or within 3 seconds)')
#matplotlib.pyplot.show()

# %%
plotEventTimes('play', 'coursera_eventing_pgm-003', 71)
plotEventTimes('pause', 'coursera_eventing_pgm-003', 71)
plotEventTimes('seeked', 'coursera_eventing_pgm-003', 71)

# %%
plotEventTimesNoDuplicatesPerUser('play', 'coursera_eventing_pgm-003', 71)
plotEventTimesNoDuplicatesPerUser('pause', 'coursera_eventing_pgm-003', 71)
plotEventTimesNoDuplicatesPerUser('seeked', 'coursera_eventing_pgm-003', 71)

# %%
databasename = 'coursera_eventing_pgm-003'

user_to_events = {}
for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=71'):
  if anon_username not in user_to_events:
    user_to_events[anon_username] = []
  user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))

videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])

numStarts = [0]*(videoLength+1)

for user,events in user_to_events.iteritems():
  for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
    if event_type == 'seeked':
      if curr_time == 0:
        continue
      numStarts[curr_time] += 1

matplotlib.pyplot.plot(numStarts)
matplotlib.pyplot.title('seek event destinations')
matplotlib.pyplot.xlabel('video time, seconds')
matplotlib.pyplot.ylabel('num seek events going to this point')
matplotlib.pyplot.show()

matplotlib.pyplot.plot(binsum(numStarts))
matplotlib.pyplot.title('seek event destinations, within 3 seconds')
matplotlib.pyplot.xlabel('video time')
matplotlib.pyplot.ylabel('num seek events going to this point (or within 3 seconds)')
matplotlib.pyplot.show()

# %%
databasename = 'coursera_eventing_pgm-003'

user_to_events = {}
for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=71'):
  if anon_username not in user_to_events:
    user_to_events[anon_username] = []
  user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))

videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])

numStarts = [0]*(videoLength+1)

for user,events in user_to_events.iteritems():
  for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
    if event_type == 'pause':
      if curr_time == 0:
        continue
      numStarts[curr_time] += 1

matplotlib.pyplot.plot(numStarts)
matplotlib.pyplot.title('pause events')
matplotlib.pyplot.xlabel('video time, seconds')
matplotlib.pyplot.ylabel('num pause events at this time')
matplotlib.pyplot.show()

matplotlib.pyplot.plot(binsum(numStarts))
matplotlib.pyplot.title('pause events, within 3 seconds')
matplotlib.pyplot.xlabel('video time')
matplotlib.pyplot.ylabel('num pause events at this time (or within 3 seconds)')
matplotlib.pyplot.show()

# %%
def extractPlayedSpans(events, endTime=None):
  isPlaying = False
  playedSpans = []
  playStartTime = 0
  playStartTimeStamp = 0
  prevEventType = ''
  for anon_username,event_timestamp,event_type,curr_time in sorted(events, key=lambda x: x[1]):
    if event_type == 'play':
      isPlaying = True
      playStartTime = curr_time
      playStartTimeStamp = event_timestamp
    if event_type == 'pause':
      isPlaying = False
      playedSpans.append((playStartTime, curr_time))
    if event_type == 'seeked':
      if isPlaying:
        playDurationMillisecs = event_timestamp - playStartTimeStamp
        playDurationSeconds = int(playDurationMillisecs/1000.0)
        playEndTime = playStartTime + playDurationSeconds
        if (endTime and playEndTime > endTime) or playDurationSeconds > 600:
          isPlaying = False
          continue
        playedSpans.append((playStartTime, playEndTime))
      playStartTime = curr_time
      playStartTimeStamp = event_timestamp
    prevEventType = event_type
  if endTime and isPlaying:
    playedSpans.append((playStartTime, endTime))
  return playedSpans

# %%
def plotSegmentViews(dbname, lecturenum):

  global databasename
  databasename = dbname #'coursera_eventing_pgm-003'

  user_to_events = {}
  for anon_username,event_timestamp,event_type,curr_time in listFields(['anon_username', 'event_timestamp', 'event_type', 'curr_time'], 'where lecture_id=' + str(lecturenum)):
    if anon_username not in user_to_events:
      user_to_events[anon_username] = []
    user_to_events[anon_username].append((anon_username,event_timestamp,event_type,curr_time))
  
  videoLength = max([max([int(curr_time) for anon_username,event_timestamp,event_type,curr_time in events]) for user,events in user_to_events.iteritems()])
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    for start,end in extractPlayedSpans(events, endTime=videoLength):
      #print end, len(numPlayTimes)
      for sec in range(start, end):
        if sec >= len(numPlayTimes): continue
        numPlayTimes[sec] += 1
  
  #matplotlib.pyplot.plot(numPlayTimes)
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes): continue
        numPlayTimes[sec] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='total num times segment was watched, over all users')

  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes): continue
        playTimes[sec] += 1
        if playTimes[sec] > 1:
          numPlayTimes[sec] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='total number of times video was re-watched, over all users')
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes): continue
        playTimes[sec] += 1
    for i in range(len(numPlayTimes)):
      if playTimes[i] >= 1:
        numPlayTimes[i] += 1
  
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='number unique users who watched the segment at least once')
  
  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes): continue
        playTimes[sec] += 1
    for i in range(len(numPlayTimes)):
      if playTimes[i] >= 2:
        numPlayTimes[i] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='number unique users who watched the segment at least twice')
  

  numPlayTimes = [0]*(videoLength+1)
  
  for user,events in user_to_events.iteritems():
    playTimes = [0]*(videoLength+1)
    for start,end in extractPlayedSpans(events, endTime=None):
      for sec in range(start,end):
        if sec >= len(numPlayTimes): continue
        playTimes[sec] += 1
    for i in range(len(numPlayTimes)):
      if playTimes[i] == 1:
        numPlayTimes[i] += 1
  
  #barPlotWithStderr(numPlayTimes, addLabels=False)
  matplotlib.pyplot.plot(numPlayTimes, label='number unique users who watched the segment exactly once')  
  
  
  
  matplotlib.pyplot.title('video segments viewed (' + dbname + ' lecture ' + str(lecturenum) + ')')
  matplotlib.pyplot.legend(bbox_to_anchor=(2.3, 0.8))
  matplotlib.pyplot.xlabel('video time, seconds')
  matplotlib.pyplot.ylabel('number of times viewed')
  matplotlib.pyplot.show()

# %%
#print getColumns()

user_to_country = {}
country_to_users = {}

for anon_username,user_ip in listFields(['anon_username', 'user_ip']):
  if anon_username in user_to_country:
    continue
  country_code = None
  for ip_addr in user_ip.split(','):
    try:
      country_code = country_code_for_ip(ip_addr)
      break
    except Exception as e:
      continue
  if country_code == None:
    print user_ip
    print anon_username
    continue
  user_to_country[anon_username] = country_code
  if country_code not in country_to_users:
    country_to_users[country_code] = []
  country_to_users[country_code].append(anon_username)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-69753956eb0a> in <module>()
#       4 country_to_users = {}
#       5
# ----> 6 for anon_username,user_ip in listFields(['anon_username', 'user_ip']):
#       7   if anon_username in user_to_country:
#       8     continue
#
# NameError: name 'listFields' is not defined

# %%
plotSegmentViews('coursera_eventing_pgm-003', 71)

# %%
plotSegmentViews('coursera_eventing_pgm-003', 7)

# %%
plotSegmentViews('coursera_eventing_pgm-003', 21)

# %%
plotSegmentViews('coursera_eventing_pgm-003', 102)

# %%
plotSegmentViews('coursera_eventing_pgm-003', 104)

# %%
plotSegmentViews('coursera_eventing_pgm-003', 12)

# %%
plotSegmentViews('coursera_eventing_compilers-003', 14)

# %%
plotSegmentViews('coursera_eventing_12-003-algo', 14)
